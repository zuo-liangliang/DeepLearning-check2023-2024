# %% [markdown]
# <a href="https://colab.research.google.com/github/zuo-liangliang/fcn.berkeleyvision.org/blob/master/result_MultiAttention_LSTM_1%E5%B1%82Transformer_BCE_epoch250_batchsize32_lr0.003_82.14%25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import zipfile

# 定义源文件夹路径和目标 zip 文件夹路径
# source_folder = '/content/drive/MyDrive/Colab_Notebooks/528BVP-acnt2'
source_folder = '/content/drive/MyDrive/AugustResult'
# target_zip_folder = '/content/drive/MyDrive/Colab_Notebooks/zip_folder'
# target_zip_folder = '/content/drive/MyDrive/Colab_Notebooks/528BVP-acnt2/0827zip_folder'
target_zip_folder = '/content/drive/MyDrive/AugustResult/0907_月月账号zip_folder'

# 确保目标 zip 文件夹存在
os.makedirs(target_zip_folder, exist_ok=True)

# 获取源文件夹中以 "result" 开头的文件夹列表
folder_list = [folder for folder in os.listdir(source_folder) if os.path.isdir(os.path.join(source_folder, folder)) and folder.startswith("result")]

# 创建一个大的 zip 文件
with zipfile.ZipFile(os.path.join(target_zip_folder, '0907月月_all_folders.zip'), 'w', zipfile.ZIP_DEFLATED) as zipf:
    # 遍历文件夹列表，逐个压缩为 zip 文件
    for folder in folder_list:
        folder_path = os.path.join(source_folder, folder)

        # 遍历文件夹中的所有文件和子文件夹，并逐个添加到大的 zip 文件中
        for root, dirs, files in os.walk(folder_path):
            for file in files:
                file_path = os.path.join(root, file)
                zipf.write(file_path, os.path.relpath(file_path, source_folder))

print("所有文件夹已压缩为一个大的 zip 文件！")
# Out:
# 所有文件夹已压缩为一个大的 zip 文件！

# %%
import shutil
import os
# 指定要删除的文件夹路径
folder_path = 'xxx' #替换为你的文件夹路径

# 确保要删除的是一个目录而不是文件
assert os.path.isdir(folder_path), f"{folder_path} 不是一个目录"

# 递归删除文件夹下的所有文件和子文件夹
shutil.rmtree(folder_path)

# %%
# 解压指定文件夹到某一路径下
import zipfile

file_path = '/content/drive/MyDrive/Colab_Notebooks/528BVP-acnt2/528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4.zip'
extract_path = '/content/drive/MyDrive/Colab_Notebooks/528BVP-acnt2/528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4'

with zipfile.ZipFile(file_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# %%
# 定位到指定路径下
import os
# os.chdir('/content/drive/MyDrive/SeptemberResult/result_LSTM')
os.chdir('/content/drive/MyDrive/SeptemberResult/result_MultiAttention_LSTM_1层Transformer')
print(os.getcwd())
# Out:
# /content/drive/MyDrive/SeptemberResult/result_MultiAttention_LSTM_1层Transformer

# %%
# result_MultiAttention_LSTM_1层Transformer

from keras.callbacks import Callback
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay

from __future__ import print_function

import time
import os,sys
import numpy as np
import pandas as pd
import scipy.io as scio
import tensorflow as tf
tf.compat.v1.keras.backend.set_session
import keras
from keras.layers import Input, GRU, LSTM, Dense, Flatten, Dropout, Conv2D, Conv3D, MaxPooling2D, MaxPooling3D, TimeDistributed
from keras.models import Model, load_model
import keras.backend as K
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split

# Parameters
use_existing_model = False
fraction_for_test = 0.1
data_dir = '/content/drive/MyDrive/Colab_Notebooks/528BVP-acnt2/528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4/'
# data_dir = '/content/drive/MyDrive/new528BVP/528[-1,1]长度20-分辨率15_acnt2_sample_rate5000__剔14_改6为4/'

fraction_for_test = 0.1
#ALL_MOTION = [1,2,3,4,5,6]
ALL_MOTION = [2,3,4,5]
N_MOTION = len(ALL_MOTION)
T_MAX = 0
n_epochs = 250  #最优的是100；第2优的是200，第3优的是250，原始是50 #修改点1
f_dropout_ratio = 0.5
n_gru_hidden_units = 128
n_batch_size = 32     #原始是32-->16
f_learning_rate = 0.003  #原始是0.001-->0.002

def normalize_data(data_1):
    # data(ndarray)=>data_norm(ndarray): [20,20,T]=>[20,20,T]
    data_1_max = np.concatenate((data_1.max(axis=0),data_1.max(axis=1)),axis=0).max(axis=0)
    data_1_min = np.concatenate((data_1.min(axis=0),data_1.min(axis=1)),axis=0).min(axis=0)
    if (len(np.where((data_1_max - data_1_min) == 0)[0]) > 0):
        return data_1
    data_1_max_rep = np.tile(data_1_max,(data_1.shape[0],data_1.shape[1],1))
    data_1_min_rep = np.tile(data_1_min,(data_1.shape[0],data_1.shape[1],1))
    data_1_norm = (data_1 - data_1_min_rep) / (data_1_max_rep - data_1_min_rep)
    return  data_1_norm

def zero_padding(data, T_MAX):
    # data(list)=>data_pad(ndarray): [20,20,T1/T2/...]=>[20,20,T_MAX]
    data_pad = []
    for i in range(len(data)):
        t = np.array(data[i]).shape[2]
        data_pad.append(np.pad(data[i], ((0,0),(0,0),(T_MAX - t,0)), 'constant', constant_values = 0).tolist())
    return np.array(data_pad)

def onehot_encoding(label, num_class):
    # label(list)=>_label(ndarray): [N,]=>[N,num_class]
    label = np.array(label).astype('int32')
    # assert (np.arange(0,np.unique(label).size)==np.unique(label)).prod()    # Check label from 0 to N
    label = np.squeeze(label)
    # _label = np.eye(num_class)[label-1]     # from label to onehot
    _label = np.eye(num_class)[label-2]   #修改点2
    return _label

def load_data(path_to_data, motion_sel):
    global T_MAX
    data = []
    label = []
    for data_root, data_dirs, data_files in os.walk(path_to_data):
        for data_file_name in data_files:

            file_path = os.path.join(data_root,data_file_name)
            try:
                data_1 = scio.loadmat(file_path)['velocity_spectrum_ro']
                label_1 = int(data_file_name.split('-')[1])
                #location = int(data_file_name.split('-')[2])
                #orientation = int(data_file_name.split('-')[3])
                #repetition = int(data_file_name.split('-')[4])
                repetition = int(data_file_name.split('-')[2])  #修改点3

                # Select Motion
                if (label_1 not in motion_sel):
                    continue

                # Select Location
                # if (location not in [1,2,3,5]):
                #     continue

                # Select Orientation
                # if (orientation not in [1,2,4,5]):
                #     continue

                # Normalization
                data_normed_1 = normalize_data(data_1)

                # Update T_MAX
                if T_MAX < np.array(data_1).shape[2]:
                    T_MAX = np.array(data_1).shape[2]
            except Exception:
                continue

            # Save List
            data.append(data_normed_1.tolist())
            label.append(label_1)
                # Zero-padding
    data = zero_padding(data, T_MAX)

    # Swap axes
    data = np.swapaxes(np.swapaxes(data, 1, 3), 2, 3)   # [N,20,20',T_MAX]=>[N,T_MAX,20,20']
    data = np.expand_dims(data, axis=-1)    # [N,T_MAX,20,20]=>[N,T_MAX,20,20,1]

    # Convert label to ndarray
    label = np.array(label)

    # data(ndarray): [N,T_MAX,20,20,1], label(ndarray): [N,N_MOTION]
    return data, label

# 构建符合输入形状为 (None, 20, 15, 15, 1) 和输出形状为 (None, 4) 的  模型：
from keras.layers import MultiHeadAttention, LayerNormalization  #加Transformer修改点1
num_transformer_layers = 1  # 设置Transformer层数 #加Transformer修改点2  2层-->1层

#加Transformer修改点3
def transformer_layer(inputs, hidden_units, dropout_rate):
    # Self-attention
    attention_output = MultiHeadAttention(
        num_heads=8, key_dim=hidden_units // 8
    )(inputs, inputs)
    attention_output = Dropout(dropout_rate)(attention_output)
    attention_output = LayerNormalization()(attention_output + inputs)

    # Feed-forward network
    ffn = Dense(hidden_units, activation="relu")(attention_output)
    ffn = Dense(hidden_units)(ffn)
    ffn = Dropout(dropout_rate)(ffn)
    ffn = LayerNormalization()(ffn)

    return ffn

#加Transformer修改点4
def assemble_model(input_shape, n_class):
    model_input = Input(shape=input_shape, dtype='float32', name='name_model_input')    # (@,T_MAX,20,20,1)

    # Feature extraction part
    x = TimeDistributed(Conv2D(16,kernel_size=(5,5),activation='relu',data_format='channels_last',\
        input_shape=input_shape))(model_input)   # (@,T_MAX,20,20,1)=>(@,T_MAX,16,16,16)
    x = TimeDistributed(MaxPooling2D(pool_size=(2,2)))(x)    # (@,T_MAX,16,16,16)=>(@,T_MAX,8,8,16)
    x = TimeDistributed(Flatten())(x)   # (@,T_MAX,8,8,16)=>(@,T_MAX,8*8*16)
    x = TimeDistributed(Dense(64,activation='relu'))(x) # (@,T_MAX,8*8*16)=>(@,T_MAX,64)
    x = TimeDistributed(Dropout(f_dropout_ratio))(x)
    x = TimeDistributed(Dense(64,activation='relu'))(x) # (@,T_MAX,64)=>(@,T_MAX,64)

    # Add transformer layers
    for _ in range(num_transformer_layers):
        #x = transformer_layer(x, hidden_units=n_gru_hidden_units, dropout_rate=f_dropout_ratio)
        x = transformer_layer(x, hidden_units=64, dropout_rate=f_dropout_ratio)  # 修改点1
    x = LSTM(n_gru_hidden_units,return_sequences=False)(x)  # (@,T_MAX,64)=>(@,128)
    x = Dropout(f_dropout_ratio)(x)
    model_output = Dense(n_class, activation='softmax', name='name_model_output')(x)  # (@,128)=>(@,n_class)

    # Create the model
    # Model compiling
    model = Model(inputs=model_input, outputs=model_output)
    model.compile(optimizer=keras.optimizers.RMSprop(lr=f_learning_rate),
                    # loss='categorical_crossentropy', # 将损失函数改为多类别交叉熵损失函数 最优的是CCE
                    # loss='mean_squared_error',  # 将损失函数改为均方误差 第2优的是MSE
                    # loss='mean_absolute_error',  # 将损失函数改为平均绝对误差 第3优的是MAE
                    loss='binary_crossentropy',  # 将损失函数改为对数损失函数 第3优的是MAE
                    metrics=['accuracy']
                )
    return model

# 改
#model_type = '双层LSTM'
#model_type = 'LSTM'
#model_type = 'BiLSTM'
model_type = 'MultiAttention_LSTM_1层Transformer'

# 创建结果文件夹
# result_folder = f'result_528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_GRU_改costfunction为mse_epoch200' # 每次都要改
# result_folder = f'result_528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_{model_type}_categorical_crossentropy_epoch{n_epochs}'
# result_folder = f'result_528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_{model_type}_mean_squared_error_epoch{n_epochs}'
# result_folder = f'result_528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_{model_type}_mean_absolute_error_epoch{n_epochs}'
# result_folder = f'result_528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_{model_type}_binary_crossentropy_epoch{n_epochs}'

# result_folder = f'result_{model_type}_CCE_epoch{n_epochs}_batchsize{n_batch_size}_lr{f_learning_rate}'
# result_folder = f'result_{model_type}_MSE_epoch{n_epochs}_batchsize{n_batch_size}_lr{f_learning_rate}'
# result_folder = f'result_{model_type}_MAE_epoch{n_epochs}_batchsize{n_batch_size}_lr{f_learning_rate}'
result_folder = f'result_{model_type}_BCE_epoch{n_epochs}_batchsize{n_batch_size}_lr{f_learning_rate}'

os.makedirs(result_folder, exist_ok=True)

# %%
# Let's BEGIN >>>>

import time
start_time = time.time()  # 记录程序开始时间

# 获取可见的GPU设备列表
# visible_gpus = tf.config.experimental.list_physical_devices('GPU')
# 检查是否存在可见的GPU设备
# if len(visible_gpus) < 1:
    # print('No GPU available')
    # exit(0)
# 设置使用第一个可见的GPU设备
# os.environ["CUDA_VISIBLE_DEVICES"] = str(visible_gpus[0].index)
# 配置GPU选项
# gpu_config = tf.config.experimental.set_memory_growth(visible_gpus[0], True)
# 创建一个会话并应用GPU配置
# sess = tf.compat.v1.Session(config=gpu_config)
# tf.compat.v1.keras.backend.set_session(sess)
# tf.random.set_seed(1)

# 获取可见的 GPU 设备列表
visible_gpus = tf.config.experimental.list_physical_devices('GPU')
if len(visible_gpus) > 0:
    # 如果有可见的 GPU 设备，设置 TensorFlow 在 GPU 上运行
    tf.config.set_visible_devices(visible_gpus, 'GPU')
    gpu_config = tf.config.experimental.set_memory_growth(visible_gpus[0], True)
    sess = tf.compat.v1.Session(config=gpu_config)
    tf.compat.v1.keras.backend.set_session(sess)
    print('GPU available')
else:
    # 如果没有可见的 GPU 设备，设置 TensorFlow 在 CPU 上运行
    tf.config.set_visible_devices([], 'GPU')
    sess = tf.compat.v1.Session()
    print('No GPU available')

# Load data
data, label = load_data(data_dir, ALL_MOTION)
print('\nLoaded dataset of ' + str(label.shape[0]) + ' samples, each sized ' + str(data[0,:,:].shape) + '\n')

# Split train and test
[data_train, data_test, label_train, label_test] = train_test_split(data, label, test_size=fraction_for_test)
print('\nTrain on ' + str(label_train.shape[0]) + ' samples\n' +\
    'Test on ' + str(label_test.shape[0]) + ' samples\n')

# One-hot encoding for train data
label_train = onehot_encoding(label_train, N_MOTION)

# Load or fabricate model
if use_existing_model:
    model = load_model('model_widar3_trained.h5')
    model.summary()
else:
    #model = assemble_model(input_shape=(T_MAX, 20, 20, 1), n_class=N_MOTION)
    model = assemble_model(input_shape=(T_MAX, 15, 15, 1), n_class=N_MOTION) #修改点4
    model.summary()

class AccuracyLossHistory(Callback):
    def on_train_begin(self, logs={}):
        self.acc = []
        self.loss = []
        self.val_acc = []
        self.val_loss = []

    def on_epoch_end(self, epoch, logs={}):
        self.acc.append(logs.get('accuracy'))
        self.loss.append(logs.get('loss'))
        self.val_acc.append(logs.get('val_accuracy'))
        self.val_loss.append(logs.get('val_loss'))

history = AccuracyLossHistory()

model.fit({'name_model_input': data_train},{'name_model_output': label_train},
          batch_size=n_batch_size,
          epochs=n_epochs,
          verbose=1,
          validation_split=0.1, shuffle=True, callbacks=[history])
print('Saving trained model...')
#model.save('model_widar3_trained.h5')
model.save(f'{result_folder}/model.h5')  # 改动

# Testing...
print('Testing...')
label_test_pred = model.predict(data_test)
# label_test_pred = np.argmax(label_test_pred, axis = -1) + 1
label_test_pred = np.argmax(label_test_pred, axis = -1) + 2 #修改点5

# Confusion Matrix
cm = confusion_matrix(label_test, label_test_pred)
print(cm)
cm = cm.astype('float')/cm.sum(axis=1)[:, np.newaxis]
cm = np.around(cm, decimals=2)
print(cm)
#cm_display = ConfusionMatrixDisplay(cm, display_labels=range(1, N_MOTION+1)).plot()
#cm_display = ConfusionMatrixDisplay(cm, display_labels=range(4, N_MOTION+3)).plot() #2345 lebel-2  4567 4=2+2  7=长度4+3
cm_display = ConfusionMatrixDisplay(cm, display_labels=range(2, N_MOTION+2)).plot() #2345 lebel-2  4567 4=2+2  7=长度4+3
plt.show()
plt.savefig(f'{result_folder}/cm.png') # 新增点1 保存混淆矩阵结果2023.09.11

# Accuracy 新增百分号
test_accuracy = np.sum(label_test == label_test_pred) / (label_test.shape[0])
#print(test_accuracy)
test_accuracy_percentage = test_accuracy * 100
test_accuracy_str = f"{test_accuracy_percentage:.2f}%"
print(test_accuracy_str)

df_accuracy = pd.DataFrame({'Test Accuracy': [test_accuracy]})
df_accuracy.to_excel(f'{result_folder}/{test_accuracy_str}.xlsx', index=False) ## 新增点2 保存测试集平均准确率结果2023.09.11


df = pd.DataFrame({
    'Epoch': range(1, n_epochs+1),
    'Train Accuracy': history.acc,
    'Train Loss': history.loss,
    'Validation Accuracy': history.val_acc,
    'Validation Loss': history.val_loss
})

# df.to_excel('accuracy_l'''  '''oss.xlsx', index=False)
# 保存准确率和损失数据到Excel表格中
df.to_excel(f'{result_folder}/accuracy_loss.xlsx', index=False) #改动

plt.plot(range(1, n_epochs+1), history.acc, label='Train Accuracy')
plt.plot(range(1, n_epochs+1), history.loss, label='Train Loss')
plt.plot(range(1, n_epochs+1), history.val_acc, label='Validation Accuracy')
plt.plot(range(1, n_epochs+1), history.val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.legend()
plt.savefig(f'{result_folder}/plot.png')
plt.show()

# 新增 修改文件名 并打印新的文件名
new_result_folder = result_folder + f'_{test_accuracy_str}'
os.rename(result_folder, new_result_folder)
result_folder = new_result_folder

print("新的结果文件夹名称为：", result_folder)

end_time = time.time()  # 记录程序结束时间
duration = end_time - start_time  # 计算程序运行时间
print("程序执行时间为：{:.2f}秒".format(duration))

with open(f'{result_folder}/runtime.txt', 'w') as f:
    f.write("程序执行时间为：{:.2f}秒".format(duration)) # 新增点3 保存程序执行时间结果2023.09.11
# Out:
# GPU available
#
# Loaded dataset of 1120 samples, each sized (20, 15, 15, 1)
#
#
# Train on 1008 samples
# Test on 112 samples
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.RMSprop.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  name_model_input (InputLay  [(None, 20, 15, 15, 1)]      0         []
#  er)
#
#  time_distributed (TimeDist  (None, 20, 11, 11, 16)       416       ['name_model_input[0][0]']
#  ributed)
#
#  time_distributed_1 (TimeDi  (None, 20, 5, 5, 16)         0         ['time_distributed[0][0]']
#  stributed)
#
#  time_distributed_2 (TimeDi  (None, 20, 400)              0         ['time_distributed_1[0][0]']
#  stributed)
#
#  time_distributed_3 (TimeDi  (None, 20, 64)               25664     ['time_distributed_2[0][0]']
#  stributed)
#
#  time_distributed_4 (TimeDi  (None, 20, 64)               0         ['time_distributed_3[0][0]']
#  stributed)
#
#  time_distributed_5 (TimeDi  (None, 20, 64)               4160      ['time_distributed_4[0][0]']
#  stributed)
#
#  multi_head_attention (Mult  (None, 20, 64)               16640     ['time_distributed_5[0][0]',
#  iHeadAttention)                                                     'time_distributed_5[0][0]']
#
#  dropout_1 (Dropout)         (None, 20, 64)               0         ['multi_head_attention[0][0]']
#
#  tf.__operators__.add (TFOp  (None, 20, 64)               0         ['dropout_1[0][0]',
#  Lambda)                                                             'time_distributed_5[0][0]']
#
#  layer_normalization (Layer  (None, 20, 64)               128       ['tf.__operators__.add[0][0]']
#  Normalization)
#
#  dense_2 (Dense)             (None, 20, 64)               4160      ['layer_normalization[0][0]']
#
#  dense_3 (Dense)             (None, 20, 64)               4160      ['dense_2[0][0]']
#
#  dropout_2 (Dropout)         (None, 20, 64)               0         ['dense_3[0][0]']
#
#  layer_normalization_1 (Lay  (None, 20, 64)               128       ['dropout_2[0][0]']
#  erNormalization)
#
#  lstm (LSTM)                 (None, 128)                  98816     ['layer_normalization_1[0][0]'
#                                                                     ]
#
#  dropout_3 (Dropout)         (None, 128)                  0         ['lstm[0][0]']
#
#  name_model_output (Dense)   (None, 4)                    516       ['dropout_3[0][0]']
#
# ==================================================================================================
# Total params: 154788 (604.64 KB)
# Trainable params: 154788 (604.64 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/250
# 29/29 [==============================] - 13s 43ms/step - loss: 0.5893 - accuracy: 0.2492 - val_loss: 0.5736 - val_accuracy: 0.3069
# Epoch 2/250
# 29/29 [==============================] - 0s 14ms/step - loss: 0.5771 - accuracy: 0.2470 - val_loss: 0.5519 - val_accuracy: 0.3267
# Epoch 3/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.5715 - accuracy: 0.2679 - val_loss: 0.5673 - val_accuracy: 0.2277
# Epoch 4/250
# 29/29 [==============================] - 0s 14ms/step - loss: 0.5644 - accuracy: 0.3230 - val_loss: 0.5865 - val_accuracy: 0.2673
# Epoch 5/250
# 29/29 [==============================] - 0s 14ms/step - loss: 0.5571 - accuracy: 0.3275 - val_loss: 0.5275 - val_accuracy: 0.4059
# Epoch 6/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.5526 - accuracy: 0.3484 - val_loss: 0.5489 - val_accuracy: 0.2574
# Epoch 7/250
# 29/29 [==============================] - 0s 14ms/step - loss: 0.5519 - accuracy: 0.3186 - val_loss: 0.5087 - val_accuracy: 0.4851
# Epoch 8/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.5455 - accuracy: 0.3716 - val_loss: 0.5094 - val_accuracy: 0.4455
# Epoch 9/250
# 29/29 [==============================] - 0s 15ms/step - loss: 0.5167 - accuracy: 0.4278 - val_loss: 0.4628 - val_accuracy: 0.5545
# Epoch 10/250
# 29/29 [==============================] - 0s 15ms/step - loss: 0.5301 - accuracy: 0.4256 - val_loss: 0.5212 - val_accuracy: 0.4059
# Epoch 11/250
# 29/29 [==============================] - 0s 15ms/step - loss: 0.5060 - accuracy: 0.4774 - val_loss: 0.4818 - val_accuracy: 0.5347
# Epoch 12/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.4836 - accuracy: 0.5105 - val_loss: 0.3943 - val_accuracy: 0.7030
# Epoch 13/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.4727 - accuracy: 0.5204 - val_loss: 0.4215 - val_accuracy: 0.6238
# Epoch 14/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.4530 - accuracy: 0.5678 - val_loss: 0.3618 - val_accuracy: 0.6832
# Epoch 15/250
# 29/29 [==============================] - 0s 14ms/step - loss: 0.4376 - accuracy: 0.5755 - val_loss: 0.4763 - val_accuracy: 0.5941
# Epoch 16/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.4209 - accuracy: 0.5910 - val_loss: 0.4161 - val_accuracy: 0.6733
# Epoch 17/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.3990 - accuracy: 0.6318 - val_loss: 0.4161 - val_accuracy: 0.5743
# Epoch 18/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.3795 - accuracy: 0.6527 - val_loss: 0.5283 - val_accuracy: 0.4950
# Epoch 19/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.3809 - accuracy: 0.6538 - val_loss: 0.3250 - val_accuracy: 0.7129
# Epoch 20/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.3744 - accuracy: 0.6670 - val_loss: 0.3793 - val_accuracy: 0.6436
# Epoch 21/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.3634 - accuracy: 0.6670 - val_loss: 0.4076 - val_accuracy: 0.5941
# Epoch 22/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.3495 - accuracy: 0.7100 - val_loss: 0.3263 - val_accuracy: 0.6931
# Epoch 23/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.3433 - accuracy: 0.7001 - val_loss: 0.3069 - val_accuracy: 0.7129
# Epoch 24/250
# 29/29 [==============================] - 0s 16ms/step - loss: 0.3301 - accuracy: 0.7155 - val_loss: 0.2762 - val_accuracy: 0.7723
# Epoch 25/250
# 29/29 [==============================] - 0s 17ms/step - loss: 0.3119 - accuracy: 0.7442 - val_loss: 0.2771 - val_accuracy: 0.7525
# Epoch 26/250
# 29/29 [==============================] - 1s 18ms/step - loss: 0.2988 - accuracy: 0.7464 - val_loss: 0.2467 - val_accuracy: 0.7822
# Epoch 27/250
# 29/29 [==============================] - 1s 18ms/step - loss: 0.3099 - accuracy: 0.7420 - val_loss: 0.3123 - val_accuracy: 0.7030
# Epoch 28/250
# 29/29 [==============================] - 1s 18ms/step - loss: 0.2895 - accuracy: 0.7508 - val_loss: 0.2729 - val_accuracy: 0.7723
# Epoch 29/250
# 29/29 [==============================] - 1s 18ms/step - loss: 0.2697 - accuracy: 0.7773 - val_loss: 0.2083 - val_accuracy: 0.8317
# Epoch 30/250
# 29/29 [==============================] - 1s 17ms/step - loss: 0.2656 - accuracy: 0.7916 - val_loss: 0.2271 - val_accuracy: 0.8218
# Epoch 31/250
# 29/29 [==============================] - 1s 18ms/step - loss: 0.2668 - accuracy: 0.7817 - val_loss: 0.2923 - val_accuracy: 0.7723
# Epoch 32/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.2460 - accuracy: 0.8126 - val_loss: 0.2205 - val_accuracy: 0.8020
# Epoch 33/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.2519 - accuracy: 0.8004 - val_loss: 0.3309 - val_accuracy: 0.7723
# Epoch 34/250
# 29/29 [==============================] - 0s 15ms/step - loss: 0.2492 - accuracy: 0.8037 - val_loss: 0.3402 - val_accuracy: 0.6832
# Epoch 35/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.2389 - accuracy: 0.8015 - val_loss: 0.2251 - val_accuracy: 0.8218
# Epoch 36/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.2340 - accuracy: 0.8126 - val_loss: 0.2223 - val_accuracy: 0.8317
# Epoch 37/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.2226 - accuracy: 0.8214 - val_loss: 0.3393 - val_accuracy: 0.7228
# Epoch 38/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.2296 - accuracy: 0.8247 - val_loss: 0.2605 - val_accuracy: 0.7822
# Epoch 39/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.2182 - accuracy: 0.8335 - val_loss: 0.2169 - val_accuracy: 0.8317
# Epoch 40/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.2074 - accuracy: 0.8401 - val_loss: 0.2000 - val_accuracy: 0.8614
# Epoch 41/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.1915 - accuracy: 0.8578 - val_loss: 0.2205 - val_accuracy: 0.8218
# Epoch 42/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.1927 - accuracy: 0.8368 - val_loss: 0.2825 - val_accuracy: 0.7822
# Epoch 43/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.1979 - accuracy: 0.8501 - val_loss: 0.2491 - val_accuracy: 0.7921
# Epoch 44/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.1835 - accuracy: 0.8699 - val_loss: 0.1719 - val_accuracy: 0.8911
# Epoch 45/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.1830 - accuracy: 0.8501 - val_loss: 0.1726 - val_accuracy: 0.8614
# Epoch 46/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.1963 - accuracy: 0.8545 - val_loss: 0.1903 - val_accuracy: 0.8515
# Epoch 47/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.1779 - accuracy: 0.8644 - val_loss: 0.1798 - val_accuracy: 0.8614
# Epoch 48/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.1646 - accuracy: 0.8754 - val_loss: 0.2244 - val_accuracy: 0.8416
# Epoch 49/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.1863 - accuracy: 0.8589 - val_loss: 0.1789 - val_accuracy: 0.8812
# Epoch 50/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.1556 - accuracy: 0.8853 - val_loss: 0.2223 - val_accuracy: 0.8515
# Epoch 51/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.1475 - accuracy: 0.8864 - val_loss: 0.2873 - val_accuracy: 0.7624
# Epoch 52/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.1634 - accuracy: 0.8798 - val_loss: 0.2535 - val_accuracy: 0.8020
# Epoch 53/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.1617 - accuracy: 0.8842 - val_loss: 0.2802 - val_accuracy: 0.8119
# Epoch 54/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.1612 - accuracy: 0.8809 - val_loss: 0.1884 - val_accuracy: 0.8614
# Epoch 55/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.1375 - accuracy: 0.8953 - val_loss: 0.2003 - val_accuracy: 0.8317
# Epoch 56/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.1341 - accuracy: 0.9107 - val_loss: 0.2745 - val_accuracy: 0.7822
# Epoch 57/250
# 29/29 [==============================] - 0s 14ms/step - loss: 0.1405 - accuracy: 0.8875 - val_loss: 0.2038 - val_accuracy: 0.8614
# Epoch 58/250
# 29/29 [==============================] - 0s 15ms/step - loss: 0.1321 - accuracy: 0.9008 - val_loss: 0.1841 - val_accuracy: 0.8713
# Epoch 59/250
# 29/29 [==============================] - 1s 18ms/step - loss: 0.1239 - accuracy: 0.9195 - val_loss: 0.2593 - val_accuracy: 0.8416
# Epoch 60/250
# 29/29 [==============================] - 1s 18ms/step - loss: 0.1307 - accuracy: 0.9041 - val_loss: 0.2393 - val_accuracy: 0.8416
# Epoch 61/250
# 29/29 [==============================] - 1s 19ms/step - loss: 0.1187 - accuracy: 0.9129 - val_loss: 0.3668 - val_accuracy: 0.7525
# Epoch 62/250
# 29/29 [==============================] - 1s 18ms/step - loss: 0.1298 - accuracy: 0.9173 - val_loss: 0.2404 - val_accuracy: 0.8218
# Epoch 63/250
# 29/29 [==============================] - 0s 17ms/step - loss: 0.1262 - accuracy: 0.9052 - val_loss: 0.2420 - val_accuracy: 0.8416
# Epoch 64/250
# 29/29 [==============================] - 1s 19ms/step - loss: 0.1299 - accuracy: 0.8997 - val_loss: 0.2262 - val_accuracy: 0.8218
# Epoch 65/250
# 29/29 [==============================] - 1s 19ms/step - loss: 0.1193 - accuracy: 0.9107 - val_loss: 0.1869 - val_accuracy: 0.8515
# Epoch 66/250
# 29/29 [==============================] - 0s 14ms/step - loss: 0.1130 - accuracy: 0.9096 - val_loss: 0.2031 - val_accuracy: 0.8515
# Epoch 67/250
# 29/29 [==============================] - 0s 14ms/step - loss: 0.1072 - accuracy: 0.9283 - val_loss: 0.1861 - val_accuracy: 0.8812
# Epoch 68/250
# 29/29 [==============================] - 0s 14ms/step - loss: 0.0964 - accuracy: 0.9261 - val_loss: 0.2000 - val_accuracy: 0.8515
# Epoch 69/250
# 29/29 [==============================] - 0s 14ms/step - loss: 0.1183 - accuracy: 0.9107 - val_loss: 0.2114 - val_accuracy: 0.8614
# Epoch 70/250
# 29/29 [==============================] - 0s 14ms/step - loss: 0.1113 - accuracy: 0.9239 - val_loss: 0.1692 - val_accuracy: 0.8911
# Epoch 71/250
# 29/29 [==============================] - 0s 14ms/step - loss: 0.0967 - accuracy: 0.9316 - val_loss: 0.2469 - val_accuracy: 0.8317
# Epoch 72/250
# 29/29 [==============================] - 0s 14ms/step - loss: 0.0994 - accuracy: 0.9361 - val_loss: 0.1958 - val_accuracy: 0.8614
# Epoch 73/250
# 29/29 [==============================] - 0s 14ms/step - loss: 0.0940 - accuracy: 0.9350 - val_loss: 0.2111 - val_accuracy: 0.8614
# Epoch 74/250
# 29/29 [==============================] - 0s 14ms/step - loss: 0.0938 - accuracy: 0.9294 - val_loss: 0.2578 - val_accuracy: 0.8416
# Epoch 75/250
# 29/29 [==============================] - 0s 14ms/step - loss: 0.1057 - accuracy: 0.9217 - val_loss: 0.2720 - val_accuracy: 0.8416
# Epoch 76/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0820 - accuracy: 0.9405 - val_loss: 0.1874 - val_accuracy: 0.8911
# Epoch 77/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0867 - accuracy: 0.9361 - val_loss: 0.2057 - val_accuracy: 0.8713
# Epoch 78/250
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0792 - accuracy: 0.9427 - val_loss: 0.2085 - val_accuracy: 0.8713
# Epoch 79/250
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0939 - accuracy: 0.9405 - val_loss: 0.2186 - val_accuracy: 0.8713
# Epoch 80/250
# 29/29 [==============================] - 0s 14ms/step - loss: 0.0918 - accuracy: 0.9383 - val_loss: 0.2160 - val_accuracy: 0.8812
# Epoch 81/250
# 29/29 [==============================] - 0s 14ms/step - loss: 0.0809 - accuracy: 0.9405 - val_loss: 0.2187 - val_accuracy: 0.8614
# Epoch 82/250
# 29/29 [==============================] - 0s 14ms/step - loss: 0.0858 - accuracy: 0.9405 - val_loss: 0.2264 - val_accuracy: 0.8713
# Epoch 83/250
# 29/29 [==============================] - 0s 14ms/step - loss: 0.0811 - accuracy: 0.9471 - val_loss: 0.2119 - val_accuracy: 0.8515
# Epoch 84/250
# 29/29 [==============================] - 0s 14ms/step - loss: 0.0774 - accuracy: 0.9515 - val_loss: 0.2383 - val_accuracy: 0.8713
# Epoch 85/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0767 - accuracy: 0.9471 - val_loss: 0.2302 - val_accuracy: 0.8713
# Epoch 86/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0524 - accuracy: 0.9658 - val_loss: 0.2581 - val_accuracy: 0.8614
# Epoch 87/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0824 - accuracy: 0.9460 - val_loss: 0.2275 - val_accuracy: 0.8812
# Epoch 88/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0774 - accuracy: 0.9471 - val_loss: 0.2243 - val_accuracy: 0.8614
# Epoch 89/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0784 - accuracy: 0.9504 - val_loss: 0.2605 - val_accuracy: 0.8515
# Epoch 90/250
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0589 - accuracy: 0.9680 - val_loss: 0.1754 - val_accuracy: 0.8812
# Epoch 91/250
# 29/29 [==============================] - 1s 19ms/step - loss: 0.0762 - accuracy: 0.9416 - val_loss: 0.2402 - val_accuracy: 0.8713
# Epoch 92/250
# 29/29 [==============================] - 1s 19ms/step - loss: 0.0671 - accuracy: 0.9548 - val_loss: 0.2108 - val_accuracy: 0.8911
# Epoch 93/250
# 29/29 [==============================] - 1s 17ms/step - loss: 0.0749 - accuracy: 0.9493 - val_loss: 0.2853 - val_accuracy: 0.8218
# Epoch 94/250
# 29/29 [==============================] - 1s 19ms/step - loss: 0.0633 - accuracy: 0.9570 - val_loss: 0.2260 - val_accuracy: 0.8614
# Epoch 95/250
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0791 - accuracy: 0.9526 - val_loss: 0.2236 - val_accuracy: 0.8812
# Epoch 96/250
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0565 - accuracy: 0.9625 - val_loss: 0.2118 - val_accuracy: 0.8713
# Epoch 97/250
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0672 - accuracy: 0.9548 - val_loss: 0.2452 - val_accuracy: 0.8515
# Epoch 98/250
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0574 - accuracy: 0.9592 - val_loss: 0.2976 - val_accuracy: 0.8614
# Epoch 99/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0616 - accuracy: 0.9570 - val_loss: 0.2524 - val_accuracy: 0.8713
# Epoch 100/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0686 - accuracy: 0.9493 - val_loss: 0.2841 - val_accuracy: 0.8416
# Epoch 101/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.0625 - accuracy: 0.9636 - val_loss: 0.2198 - val_accuracy: 0.8614
# Epoch 102/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.0701 - accuracy: 0.9482 - val_loss: 0.2634 - val_accuracy: 0.8515
# Epoch 103/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0629 - accuracy: 0.9537 - val_loss: 0.2199 - val_accuracy: 0.8713
# Epoch 104/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0585 - accuracy: 0.9592 - val_loss: 0.2700 - val_accuracy: 0.8515
# Epoch 105/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0559 - accuracy: 0.9680 - val_loss: 0.2547 - val_accuracy: 0.8911
# Epoch 106/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.0535 - accuracy: 0.9680 - val_loss: 0.2929 - val_accuracy: 0.8515
# Epoch 107/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0526 - accuracy: 0.9680 - val_loss: 0.2441 - val_accuracy: 0.8515
# Epoch 108/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0555 - accuracy: 0.9614 - val_loss: 0.3319 - val_accuracy: 0.8317
# Epoch 109/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0617 - accuracy: 0.9669 - val_loss: 0.2455 - val_accuracy: 0.8713
# Epoch 110/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.0518 - accuracy: 0.9691 - val_loss: 0.2701 - val_accuracy: 0.8614
# Epoch 111/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0495 - accuracy: 0.9680 - val_loss: 0.2387 - val_accuracy: 0.8713
# Epoch 112/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0518 - accuracy: 0.9691 - val_loss: 0.3002 - val_accuracy: 0.8515
# Epoch 113/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.0602 - accuracy: 0.9658 - val_loss: 0.2729 - val_accuracy: 0.8317
# Epoch 114/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0512 - accuracy: 0.9647 - val_loss: 0.2059 - val_accuracy: 0.8911
# Epoch 115/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0612 - accuracy: 0.9592 - val_loss: 0.2154 - val_accuracy: 0.8713
# Epoch 116/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.0457 - accuracy: 0.9724 - val_loss: 0.2469 - val_accuracy: 0.8515
# Epoch 117/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0426 - accuracy: 0.9735 - val_loss: 0.2292 - val_accuracy: 0.8416
# Epoch 118/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0442 - accuracy: 0.9724 - val_loss: 0.2825 - val_accuracy: 0.8515
# Epoch 119/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.0599 - accuracy: 0.9691 - val_loss: 0.2429 - val_accuracy: 0.8911
# Epoch 120/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0346 - accuracy: 0.9791 - val_loss: 0.2701 - val_accuracy: 0.8515
# Epoch 121/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0467 - accuracy: 0.9680 - val_loss: 0.1981 - val_accuracy: 0.9109
# Epoch 122/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0396 - accuracy: 0.9680 - val_loss: 0.2828 - val_accuracy: 0.8812
# Epoch 123/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0372 - accuracy: 0.9735 - val_loss: 0.2647 - val_accuracy: 0.8713
# Epoch 124/250
# 29/29 [==============================] - 0s 14ms/step - loss: 0.0411 - accuracy: 0.9746 - val_loss: 0.2774 - val_accuracy: 0.8713
# Epoch 125/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0592 - accuracy: 0.9658 - val_loss: 0.2797 - val_accuracy: 0.8911
# Epoch 126/250
# 29/29 [==============================] - 0s 14ms/step - loss: 0.0589 - accuracy: 0.9658 - val_loss: 0.3292 - val_accuracy: 0.8614
# Epoch 127/250
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0457 - accuracy: 0.9702 - val_loss: 0.3102 - val_accuracy: 0.8812
# Epoch 128/250
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0362 - accuracy: 0.9846 - val_loss: 0.3226 - val_accuracy: 0.8515
# Epoch 129/250
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0500 - accuracy: 0.9658 - val_loss: 0.2971 - val_accuracy: 0.8515
# Epoch 130/250
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0295 - accuracy: 0.9879 - val_loss: 0.2952 - val_accuracy: 0.8515
# Epoch 131/250
# 29/29 [==============================] - 0s 14ms/step - loss: 0.0478 - accuracy: 0.9702 - val_loss: 0.2858 - val_accuracy: 0.8812
# Epoch 132/250
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0397 - accuracy: 0.9757 - val_loss: 0.3225 - val_accuracy: 0.8020
# Epoch 133/250
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0365 - accuracy: 0.9768 - val_loss: 0.2513 - val_accuracy: 0.8515
# Epoch 134/250
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0292 - accuracy: 0.9824 - val_loss: 0.2861 - val_accuracy: 0.8515
# Epoch 135/250
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0439 - accuracy: 0.9735 - val_loss: 0.2704 - val_accuracy: 0.8416
# Epoch 136/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0323 - accuracy: 0.9813 - val_loss: 0.3371 - val_accuracy: 0.8515
# Epoch 137/250
# 29/29 [==============================] - 0s 14ms/step - loss: 0.0270 - accuracy: 0.9868 - val_loss: 0.3199 - val_accuracy: 0.8614
# Epoch 138/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0363 - accuracy: 0.9768 - val_loss: 0.2370 - val_accuracy: 0.8713
# Epoch 139/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0509 - accuracy: 0.9713 - val_loss: 0.2615 - val_accuracy: 0.8614
# Epoch 140/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0364 - accuracy: 0.9768 - val_loss: 0.2756 - val_accuracy: 0.8515
# Epoch 141/250
# 29/29 [==============================] - 0s 14ms/step - loss: 0.0352 - accuracy: 0.9757 - val_loss: 0.2825 - val_accuracy: 0.8614
# Epoch 142/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0319 - accuracy: 0.9835 - val_loss: 0.3268 - val_accuracy: 0.8713
# Epoch 143/250
# 29/29 [==============================] - 0s 14ms/step - loss: 0.0364 - accuracy: 0.9791 - val_loss: 0.3054 - val_accuracy: 0.8515
# Epoch 144/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0329 - accuracy: 0.9835 - val_loss: 0.3074 - val_accuracy: 0.8713
# Epoch 145/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0341 - accuracy: 0.9813 - val_loss: 0.2760 - val_accuracy: 0.8812
# Epoch 146/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0416 - accuracy: 0.9768 - val_loss: 0.2895 - val_accuracy: 0.8614
# Epoch 147/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0406 - accuracy: 0.9746 - val_loss: 0.2781 - val_accuracy: 0.8713
# Epoch 148/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0326 - accuracy: 0.9802 - val_loss: 0.3002 - val_accuracy: 0.8515
# Epoch 149/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0504 - accuracy: 0.9757 - val_loss: 0.2834 - val_accuracy: 0.8812
# Epoch 150/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0314 - accuracy: 0.9835 - val_loss: 0.3346 - val_accuracy: 0.8515
# Epoch 151/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0355 - accuracy: 0.9791 - val_loss: 0.2913 - val_accuracy: 0.8515
# Epoch 152/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0336 - accuracy: 0.9835 - val_loss: 0.2306 - val_accuracy: 0.8911
# Epoch 153/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0249 - accuracy: 0.9868 - val_loss: 0.2637 - val_accuracy: 0.8515
# Epoch 154/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0359 - accuracy: 0.9835 - val_loss: 0.2419 - val_accuracy: 0.8911
# Epoch 155/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0295 - accuracy: 0.9824 - val_loss: 0.2891 - val_accuracy: 0.8713
# Epoch 156/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0203 - accuracy: 0.9846 - val_loss: 0.2642 - val_accuracy: 0.8515
# Epoch 157/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.0381 - accuracy: 0.9835 - val_loss: 0.3230 - val_accuracy: 0.8614
# Epoch 158/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0411 - accuracy: 0.9757 - val_loss: 0.2868 - val_accuracy: 0.8416
# Epoch 159/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0361 - accuracy: 0.9813 - val_loss: 0.2545 - val_accuracy: 0.8614
# Epoch 160/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0392 - accuracy: 0.9835 - val_loss: 0.3097 - val_accuracy: 0.8713
# Epoch 161/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0335 - accuracy: 0.9802 - val_loss: 0.2307 - val_accuracy: 0.8614
# Epoch 162/250
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0276 - accuracy: 0.9879 - val_loss: 0.3034 - val_accuracy: 0.8416
# Epoch 163/250
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0228 - accuracy: 0.9879 - val_loss: 0.2788 - val_accuracy: 0.8416
# Epoch 164/250
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0215 - accuracy: 0.9912 - val_loss: 0.4982 - val_accuracy: 0.7624
# Epoch 165/250
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0224 - accuracy: 0.9857 - val_loss: 0.2486 - val_accuracy: 0.8614
# Epoch 166/250
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0209 - accuracy: 0.9912 - val_loss: 0.2615 - val_accuracy: 0.8713
# Epoch 167/250
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0393 - accuracy: 0.9757 - val_loss: 0.3798 - val_accuracy: 0.8020
# Epoch 168/250
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0205 - accuracy: 0.9901 - val_loss: 0.3049 - val_accuracy: 0.8218
# Epoch 169/250
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0408 - accuracy: 0.9779 - val_loss: 0.2548 - val_accuracy: 0.8614
# Epoch 170/250
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0173 - accuracy: 0.9923 - val_loss: 0.3000 - val_accuracy: 0.8317
# Epoch 171/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0286 - accuracy: 0.9857 - val_loss: 0.2987 - val_accuracy: 0.8515
# Epoch 172/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0180 - accuracy: 0.9912 - val_loss: 0.3389 - val_accuracy: 0.8218
# Epoch 173/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0267 - accuracy: 0.9835 - val_loss: 0.2980 - val_accuracy: 0.8416
# Epoch 174/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0309 - accuracy: 0.9835 - val_loss: 0.2930 - val_accuracy: 0.8614
# Epoch 175/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0267 - accuracy: 0.9857 - val_loss: 0.3252 - val_accuracy: 0.8317
# Epoch 176/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0216 - accuracy: 0.9890 - val_loss: 0.2636 - val_accuracy: 0.8911
# Epoch 177/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0147 - accuracy: 0.9923 - val_loss: 0.2702 - val_accuracy: 0.8713
# Epoch 178/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0189 - accuracy: 0.9879 - val_loss: 0.2696 - val_accuracy: 0.8515
# Epoch 179/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0418 - accuracy: 0.9768 - val_loss: 0.2201 - val_accuracy: 0.8812
# Epoch 180/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0233 - accuracy: 0.9879 - val_loss: 0.3453 - val_accuracy: 0.8317
# Epoch 181/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.0303 - accuracy: 0.9835 - val_loss: 0.3361 - val_accuracy: 0.8515
# Epoch 182/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0150 - accuracy: 0.9934 - val_loss: 0.2740 - val_accuracy: 0.8812
# Epoch 183/250
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0350 - accuracy: 0.9746 - val_loss: 0.3347 - val_accuracy: 0.8515
# Epoch 184/250
# 29/29 [==============================] - 1s 26ms/step - loss: 0.0265 - accuracy: 0.9890 - val_loss: 0.3089 - val_accuracy: 0.8911
# Epoch 185/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0317 - accuracy: 0.9791 - val_loss: 0.2937 - val_accuracy: 0.8416
# Epoch 186/250
# 29/29 [==============================] - 1s 26ms/step - loss: 0.0179 - accuracy: 0.9912 - val_loss: 0.3343 - val_accuracy: 0.8713
# Epoch 187/250
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0270 - accuracy: 0.9879 - val_loss: 0.3127 - val_accuracy: 0.8713
# Epoch 188/250
# 29/29 [==============================] - 1s 20ms/step - loss: 0.0321 - accuracy: 0.9802 - val_loss: 0.2368 - val_accuracy: 0.8911
# Epoch 189/250
# 29/29 [==============================] - 1s 24ms/step - loss: 0.0241 - accuracy: 0.9901 - val_loss: 0.3283 - val_accuracy: 0.8416
# Epoch 190/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0252 - accuracy: 0.9879 - val_loss: 0.3171 - val_accuracy: 0.8416
# Epoch 191/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0128 - accuracy: 0.9945 - val_loss: 0.4010 - val_accuracy: 0.8416
# Epoch 192/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0349 - accuracy: 0.9813 - val_loss: 0.2808 - val_accuracy: 0.8515
# Epoch 193/250
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0187 - accuracy: 0.9901 - val_loss: 0.2957 - val_accuracy: 0.8812
# Epoch 194/250
# 29/29 [==============================] - 1s 17ms/step - loss: 0.0197 - accuracy: 0.9912 - val_loss: 0.2902 - val_accuracy: 0.8713
# Epoch 195/250
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0196 - accuracy: 0.9901 - val_loss: 0.2880 - val_accuracy: 0.8911
# Epoch 196/250
# 29/29 [==============================] - 1s 17ms/step - loss: 0.0200 - accuracy: 0.9890 - val_loss: 0.3851 - val_accuracy: 0.8317
# Epoch 197/250
# 29/29 [==============================] - 1s 22ms/step - loss: 0.0121 - accuracy: 0.9956 - val_loss: 0.2112 - val_accuracy: 0.9010
# Epoch 198/250
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0191 - accuracy: 0.9901 - val_loss: 0.3432 - val_accuracy: 0.8416
# Epoch 199/250
# 29/29 [==============================] - 1s 21ms/step - loss: 0.0089 - accuracy: 0.9956 - val_loss: 0.2871 - val_accuracy: 0.8416
# Epoch 200/250
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0236 - accuracy: 0.9879 - val_loss: 0.3305 - val_accuracy: 0.8317
# Epoch 201/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0139 - accuracy: 0.9956 - val_loss: 0.3305 - val_accuracy: 0.8218
# Epoch 202/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0238 - accuracy: 0.9879 - val_loss: 0.3169 - val_accuracy: 0.8614
# Epoch 203/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0203 - accuracy: 0.9901 - val_loss: 0.2760 - val_accuracy: 0.8713
# Epoch 204/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0165 - accuracy: 0.9912 - val_loss: 0.2753 - val_accuracy: 0.9010
# Epoch 205/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0247 - accuracy: 0.9890 - val_loss: 0.4201 - val_accuracy: 0.8317
# Epoch 206/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0215 - accuracy: 0.9923 - val_loss: 0.3564 - val_accuracy: 0.8515
# Epoch 207/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0284 - accuracy: 0.9835 - val_loss: 0.3635 - val_accuracy: 0.8218
# Epoch 208/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0199 - accuracy: 0.9868 - val_loss: 0.3296 - val_accuracy: 0.8317
# Epoch 209/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0282 - accuracy: 0.9868 - val_loss: 0.3644 - val_accuracy: 0.8416
# Epoch 210/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0245 - accuracy: 0.9879 - val_loss: 0.5588 - val_accuracy: 0.8119
# Epoch 211/250
# 29/29 [==============================] - 0s 14ms/step - loss: 0.0233 - accuracy: 0.9868 - val_loss: 0.4211 - val_accuracy: 0.8218
# Epoch 212/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0217 - accuracy: 0.9868 - val_loss: 0.3327 - val_accuracy: 0.8515
# Epoch 213/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0215 - accuracy: 0.9912 - val_loss: 0.2878 - val_accuracy: 0.8416
# Epoch 214/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0156 - accuracy: 0.9879 - val_loss: 0.3487 - val_accuracy: 0.8317
# Epoch 215/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0212 - accuracy: 0.9901 - val_loss: 0.3691 - val_accuracy: 0.7822
# Epoch 216/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0159 - accuracy: 0.9934 - val_loss: 0.3241 - val_accuracy: 0.8317
# Epoch 217/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0106 - accuracy: 0.9945 - val_loss: 0.2841 - val_accuracy: 0.8713
# Epoch 218/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0160 - accuracy: 0.9912 - val_loss: 0.3250 - val_accuracy: 0.8515
# Epoch 219/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0353 - accuracy: 0.9835 - val_loss: 0.3601 - val_accuracy: 0.8317
# Epoch 220/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0295 - accuracy: 0.9846 - val_loss: 0.3486 - val_accuracy: 0.8020
# Epoch 221/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0148 - accuracy: 0.9890 - val_loss: 0.3110 - val_accuracy: 0.8317
# Epoch 222/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0187 - accuracy: 0.9890 - val_loss: 0.3115 - val_accuracy: 0.8416
# Epoch 223/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0199 - accuracy: 0.9912 - val_loss: 0.4095 - val_accuracy: 0.7921
# Epoch 224/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0332 - accuracy: 0.9813 - val_loss: 0.3140 - val_accuracy: 0.8416
# Epoch 225/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0092 - accuracy: 0.9967 - val_loss: 0.3704 - val_accuracy: 0.8218
# Epoch 226/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0230 - accuracy: 0.9901 - val_loss: 0.3490 - val_accuracy: 0.8317
# Epoch 227/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0135 - accuracy: 0.9923 - val_loss: 0.2600 - val_accuracy: 0.8614
# Epoch 228/250
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0082 - accuracy: 0.9967 - val_loss: 0.3791 - val_accuracy: 0.8317
# Epoch 229/250
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0203 - accuracy: 0.9901 - val_loss: 0.2675 - val_accuracy: 0.8812
# Epoch 230/250
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0195 - accuracy: 0.9879 - val_loss: 0.2637 - val_accuracy: 0.8812
# Epoch 231/250
# 29/29 [==============================] - 1s 17ms/step - loss: 0.0332 - accuracy: 0.9879 - val_loss: 0.2752 - val_accuracy: 0.8713
# Epoch 232/250
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0162 - accuracy: 0.9934 - val_loss: 0.3438 - val_accuracy: 0.8119
# Epoch 233/250
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0194 - accuracy: 0.9923 - val_loss: 0.3431 - val_accuracy: 0.8614
# Epoch 234/250
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0139 - accuracy: 0.9879 - val_loss: 0.3406 - val_accuracy: 0.8317
# Epoch 235/250
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0165 - accuracy: 0.9890 - val_loss: 0.2495 - val_accuracy: 0.9010
# Epoch 236/250
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0167 - accuracy: 0.9912 - val_loss: 0.2290 - val_accuracy: 0.8812
# Epoch 237/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0160 - accuracy: 0.9901 - val_loss: 0.2915 - val_accuracy: 0.8911
# Epoch 238/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0212 - accuracy: 0.9912 - val_loss: 0.2596 - val_accuracy: 0.8614
# Epoch 239/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0180 - accuracy: 0.9912 - val_loss: 0.3536 - val_accuracy: 0.8416
# Epoch 240/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0179 - accuracy: 0.9879 - val_loss: 0.3503 - val_accuracy: 0.8515
# Epoch 241/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0162 - accuracy: 0.9901 - val_loss: 0.4766 - val_accuracy: 0.8020
# Epoch 242/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0250 - accuracy: 0.9912 - val_loss: 0.3219 - val_accuracy: 0.8515
# Epoch 243/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0224 - accuracy: 0.9912 - val_loss: 0.3278 - val_accuracy: 0.8416
# Epoch 244/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0268 - accuracy: 0.9890 - val_loss: 0.3846 - val_accuracy: 0.8515
# Epoch 245/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0165 - accuracy: 0.9912 - val_loss: 0.3785 - val_accuracy: 0.8218
# Epoch 246/250
# 29/29 [==============================] - 0s 14ms/step - loss: 0.0108 - accuracy: 0.9956 - val_loss: 0.4021 - val_accuracy: 0.8416
# Epoch 247/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0318 - accuracy: 0.9857 - val_loss: 0.3082 - val_accuracy: 0.8812
# Epoch 248/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0096 - accuracy: 0.9945 - val_loss: 0.2975 - val_accuracy: 0.8614
# Epoch 249/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0297 - accuracy: 0.9879 - val_loss: 0.3600 - val_accuracy: 0.8317
# Epoch 250/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0124 - accuracy: 0.9923 - val_loss: 0.4082 - val_accuracy: 0.8416
# Saving trained model...
# Testing...
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 4/4 [==============================] - 1s 14ms/step
# [[22  1  0  2]
#  [ 3 23  3  2]
#  [ 0  1 22  1]
#  [ 3  3  1 25]]
# [[0.88 0.04 0.   0.08]
#  [0.1  0.74 0.1  0.06]
#  [0.   0.04 0.92 0.04]
#  [0.09 0.09 0.03 0.78]]
# 82.14%
# 新的结果文件夹名称为： result_MultiAttention_LSTM_1层Transformer_BCE_epoch250_batchsize32_lr0.003_82.14%
# 程序执行时间为：135.01秒

# %%
# 定位到指定路径下
import os
os.chdir('/content/drive/MyDrive/Colab_Notebooks/RNN-CAP')
print(os.getcwd())

# 打印版本
import sys
import tensorflow as tf

print("Python 版本:", sys.version)
print("TensorFlow 版本:", tf.__version__)

# !pip install xlwt
# !pip install matplotlib

# %%
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_categorical_crossentropy_epoch30.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_categorical_crossentropy_epoch250.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_categorical_crossentropy_epoch50.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_categorical_crossentropy_epoch100.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_categorical_crossentropy_epoch150.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_categorical_crossentropy_epoch200.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_squared_error_epoch30.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_squared_error_epoch50.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_squared_error_epoch100.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_squared_error_epoch150.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_squared_error_epoch200.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_squared_error_epoch250.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_absolute_error_epoch30.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_absolute_error_epoch50.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_absolute_error_epoch100.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_absolute_error_epoch150.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_absolute_error_epoch200.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_absolute_error_epoch250.py

# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_binary_crossentropy_epoch30.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_binary_crossentropy_epoch50.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_binary_crossentropy_epoch100.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_binary_crossentropy_epoch150.py

#!python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_binary_crossentropy_epoch200.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_binary_crossentropy_epoch250.py
