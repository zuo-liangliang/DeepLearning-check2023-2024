# %% [markdown]
# <a href="https://colab.research.google.com/github/zuo-liangliang/fcn.berkeleyvision.org/blob/master/result_MultiAttention_LSTM_1%E5%B1%82Transformer_BCE_epoch250_batchsize32_lr0.006_79.46%25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import zipfile

# 定义源文件夹路径和目标 zip 文件夹路径
# source_folder = '/content/drive/MyDrive/Colab_Notebooks/528BVP-acnt2'
source_folder = '/content/drive/MyDrive/AugustResult'
# target_zip_folder = '/content/drive/MyDrive/Colab_Notebooks/zip_folder'
# target_zip_folder = '/content/drive/MyDrive/Colab_Notebooks/528BVP-acnt2/0827zip_folder'
target_zip_folder = '/content/drive/MyDrive/AugustResult/0907_月月账号zip_folder'

# 确保目标 zip 文件夹存在
os.makedirs(target_zip_folder, exist_ok=True)

# 获取源文件夹中以 "result" 开头的文件夹列表
folder_list = [folder for folder in os.listdir(source_folder) if os.path.isdir(os.path.join(source_folder, folder)) and folder.startswith("result")]

# 创建一个大的 zip 文件
with zipfile.ZipFile(os.path.join(target_zip_folder, '0907月月_all_folders.zip'), 'w', zipfile.ZIP_DEFLATED) as zipf:
    # 遍历文件夹列表，逐个压缩为 zip 文件
    for folder in folder_list:
        folder_path = os.path.join(source_folder, folder)

        # 遍历文件夹中的所有文件和子文件夹，并逐个添加到大的 zip 文件中
        for root, dirs, files in os.walk(folder_path):
            for file in files:
                file_path = os.path.join(root, file)
                zipf.write(file_path, os.path.relpath(file_path, source_folder))

print("所有文件夹已压缩为一个大的 zip 文件！")
# Out:
# 所有文件夹已压缩为一个大的 zip 文件！

# %%
import shutil
import os
# 指定要删除的文件夹路径
folder_path = 'xxx' #替换为你的文件夹路径

# 确保要删除的是一个目录而不是文件
assert os.path.isdir(folder_path), f"{folder_path} 不是一个目录"

# 递归删除文件夹下的所有文件和子文件夹
shutil.rmtree(folder_path)

# %%
# 解压指定文件夹到某一路径下
import zipfile

file_path = '/content/drive/MyDrive/Colab_Notebooks/528BVP-acnt2/528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4.zip'
extract_path = '/content/drive/MyDrive/Colab_Notebooks/528BVP-acnt2/528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4'

with zipfile.ZipFile(file_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# %%
# 定位到指定路径下
import os
# os.chdir('/content/drive/MyDrive/SeptemberResult/result_LSTM')
os.chdir('/content/drive/MyDrive/SeptemberResult/result_MultiAttention_LSTM_1层Transformer')
print(os.getcwd())
# Out:
# /content/drive/MyDrive/SeptemberResult/result_MultiAttention_LSTM_1层Transformer

# %%
# result_MultiAttention_LSTM_1层Transformer

from keras.callbacks import Callback
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay

from __future__ import print_function

import time
import os,sys
import numpy as np
import pandas as pd
import scipy.io as scio
import tensorflow as tf
tf.compat.v1.keras.backend.set_session
import keras
from keras.layers import Input, GRU, LSTM, Dense, Flatten, Dropout, Conv2D, Conv3D, MaxPooling2D, MaxPooling3D, TimeDistributed
from keras.models import Model, load_model
import keras.backend as K
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split

# Parameters
use_existing_model = False
fraction_for_test = 0.1
data_dir = '/content/drive/MyDrive/Colab_Notebooks/528BVP-acnt2/528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4/'
# data_dir = '/content/drive/MyDrive/new528BVP/528[-1,1]长度20-分辨率15_acnt2_sample_rate5000__剔14_改6为4/'

fraction_for_test = 0.1
#ALL_MOTION = [1,2,3,4,5,6]
ALL_MOTION = [2,3,4,5]
N_MOTION = len(ALL_MOTION)
T_MAX = 0
n_epochs = 250  #最优的是100；第2优的是200，第3优的是250，原始是50 #修改点1
f_dropout_ratio = 0.5
n_gru_hidden_units = 128
n_batch_size = 32     #原始是32-->16
f_learning_rate = 0.006  #原始是0.001-->0.002

def normalize_data(data_1):
    # data(ndarray)=>data_norm(ndarray): [20,20,T]=>[20,20,T]
    data_1_max = np.concatenate((data_1.max(axis=0),data_1.max(axis=1)),axis=0).max(axis=0)
    data_1_min = np.concatenate((data_1.min(axis=0),data_1.min(axis=1)),axis=0).min(axis=0)
    if (len(np.where((data_1_max - data_1_min) == 0)[0]) > 0):
        return data_1
    data_1_max_rep = np.tile(data_1_max,(data_1.shape[0],data_1.shape[1],1))
    data_1_min_rep = np.tile(data_1_min,(data_1.shape[0],data_1.shape[1],1))
    data_1_norm = (data_1 - data_1_min_rep) / (data_1_max_rep - data_1_min_rep)
    return  data_1_norm

def zero_padding(data, T_MAX):
    # data(list)=>data_pad(ndarray): [20,20,T1/T2/...]=>[20,20,T_MAX]
    data_pad = []
    for i in range(len(data)):
        t = np.array(data[i]).shape[2]
        data_pad.append(np.pad(data[i], ((0,0),(0,0),(T_MAX - t,0)), 'constant', constant_values = 0).tolist())
    return np.array(data_pad)

def onehot_encoding(label, num_class):
    # label(list)=>_label(ndarray): [N,]=>[N,num_class]
    label = np.array(label).astype('int32')
    # assert (np.arange(0,np.unique(label).size)==np.unique(label)).prod()    # Check label from 0 to N
    label = np.squeeze(label)
    # _label = np.eye(num_class)[label-1]     # from label to onehot
    _label = np.eye(num_class)[label-2]   #修改点2
    return _label

def load_data(path_to_data, motion_sel):
    global T_MAX
    data = []
    label = []
    for data_root, data_dirs, data_files in os.walk(path_to_data):
        for data_file_name in data_files:

            file_path = os.path.join(data_root,data_file_name)
            try:
                data_1 = scio.loadmat(file_path)['velocity_spectrum_ro']
                label_1 = int(data_file_name.split('-')[1])
                #location = int(data_file_name.split('-')[2])
                #orientation = int(data_file_name.split('-')[3])
                #repetition = int(data_file_name.split('-')[4])
                repetition = int(data_file_name.split('-')[2])  #修改点3

                # Select Motion
                if (label_1 not in motion_sel):
                    continue

                # Select Location
                # if (location not in [1,2,3,5]):
                #     continue

                # Select Orientation
                # if (orientation not in [1,2,4,5]):
                #     continue

                # Normalization
                data_normed_1 = normalize_data(data_1)

                # Update T_MAX
                if T_MAX < np.array(data_1).shape[2]:
                    T_MAX = np.array(data_1).shape[2]
            except Exception:
                continue

            # Save List
            data.append(data_normed_1.tolist())
            label.append(label_1)
                # Zero-padding
    data = zero_padding(data, T_MAX)

    # Swap axes
    data = np.swapaxes(np.swapaxes(data, 1, 3), 2, 3)   # [N,20,20',T_MAX]=>[N,T_MAX,20,20']
    data = np.expand_dims(data, axis=-1)    # [N,T_MAX,20,20]=>[N,T_MAX,20,20,1]

    # Convert label to ndarray
    label = np.array(label)

    # data(ndarray): [N,T_MAX,20,20,1], label(ndarray): [N,N_MOTION]
    return data, label

# 构建符合输入形状为 (None, 20, 15, 15, 1) 和输出形状为 (None, 4) 的  模型：
from keras.layers import MultiHeadAttention, LayerNormalization  #加Transformer修改点1
num_transformer_layers = 1  # 设置Transformer层数 #加Transformer修改点2  2层-->1层

#加Transformer修改点3
def transformer_layer(inputs, hidden_units, dropout_rate):
    # Self-attention
    attention_output = MultiHeadAttention(
        num_heads=8, key_dim=hidden_units // 8
    )(inputs, inputs)
    attention_output = Dropout(dropout_rate)(attention_output)
    attention_output = LayerNormalization()(attention_output + inputs)

    # Feed-forward network
    ffn = Dense(hidden_units, activation="relu")(attention_output)
    ffn = Dense(hidden_units)(ffn)
    ffn = Dropout(dropout_rate)(ffn)
    ffn = LayerNormalization()(ffn)

    return ffn

#加Transformer修改点4
def assemble_model(input_shape, n_class):
    model_input = Input(shape=input_shape, dtype='float32', name='name_model_input')    # (@,T_MAX,20,20,1)

    # Feature extraction part
    x = TimeDistributed(Conv2D(16,kernel_size=(5,5),activation='relu',data_format='channels_last',\
        input_shape=input_shape))(model_input)   # (@,T_MAX,20,20,1)=>(@,T_MAX,16,16,16)
    x = TimeDistributed(MaxPooling2D(pool_size=(2,2)))(x)    # (@,T_MAX,16,16,16)=>(@,T_MAX,8,8,16)
    x = TimeDistributed(Flatten())(x)   # (@,T_MAX,8,8,16)=>(@,T_MAX,8*8*16)
    x = TimeDistributed(Dense(64,activation='relu'))(x) # (@,T_MAX,8*8*16)=>(@,T_MAX,64)
    x = TimeDistributed(Dropout(f_dropout_ratio))(x)
    x = TimeDistributed(Dense(64,activation='relu'))(x) # (@,T_MAX,64)=>(@,T_MAX,64)

    # Add transformer layers
    for _ in range(num_transformer_layers):
        #x = transformer_layer(x, hidden_units=n_gru_hidden_units, dropout_rate=f_dropout_ratio)
        x = transformer_layer(x, hidden_units=64, dropout_rate=f_dropout_ratio)  # 修改点1
    x = LSTM(n_gru_hidden_units,return_sequences=False)(x)  # (@,T_MAX,64)=>(@,128)
    x = Dropout(f_dropout_ratio)(x)
    model_output = Dense(n_class, activation='softmax', name='name_model_output')(x)  # (@,128)=>(@,n_class)

    # Create the model
    # Model compiling
    model = Model(inputs=model_input, outputs=model_output)
    model.compile(optimizer=keras.optimizers.RMSprop(lr=f_learning_rate),
                    # loss='categorical_crossentropy', # 将损失函数改为多类别交叉熵损失函数 最优的是CCE
                    # loss='mean_squared_error',  # 将损失函数改为均方误差 第2优的是MSE
                    # loss='mean_absolute_error',  # 将损失函数改为平均绝对误差 第3优的是MAE
                    loss='binary_crossentropy',  # 将损失函数改为对数损失函数 第3优的是MAE
                    metrics=['accuracy']
                )
    return model

# 改
#model_type = '双层LSTM'
#model_type = 'LSTM'
#model_type = 'BiLSTM'
model_type = 'MultiAttention_LSTM_1层Transformer'

# 创建结果文件夹
# result_folder = f'result_528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_GRU_改costfunction为mse_epoch200' # 每次都要改
# result_folder = f'result_528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_{model_type}_categorical_crossentropy_epoch{n_epochs}'
# result_folder = f'result_528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_{model_type}_mean_squared_error_epoch{n_epochs}'
# result_folder = f'result_528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_{model_type}_mean_absolute_error_epoch{n_epochs}'
# result_folder = f'result_528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_{model_type}_binary_crossentropy_epoch{n_epochs}'

# result_folder = f'result_{model_type}_CCE_epoch{n_epochs}_batchsize{n_batch_size}_lr{f_learning_rate}'
# result_folder = f'result_{model_type}_MSE_epoch{n_epochs}_batchsize{n_batch_size}_lr{f_learning_rate}'
# result_folder = f'result_{model_type}_MAE_epoch{n_epochs}_batchsize{n_batch_size}_lr{f_learning_rate}'
result_folder = f'result_{model_type}_BCE_epoch{n_epochs}_batchsize{n_batch_size}_lr{f_learning_rate}'

os.makedirs(result_folder, exist_ok=True)

# %%
# Let's BEGIN >>>>

import time
start_time = time.time()  # 记录程序开始时间

# 获取可见的GPU设备列表
# visible_gpus = tf.config.experimental.list_physical_devices('GPU')
# 检查是否存在可见的GPU设备
# if len(visible_gpus) < 1:
    # print('No GPU available')
    # exit(0)
# 设置使用第一个可见的GPU设备
# os.environ["CUDA_VISIBLE_DEVICES"] = str(visible_gpus[0].index)
# 配置GPU选项
# gpu_config = tf.config.experimental.set_memory_growth(visible_gpus[0], True)
# 创建一个会话并应用GPU配置
# sess = tf.compat.v1.Session(config=gpu_config)
# tf.compat.v1.keras.backend.set_session(sess)
# tf.random.set_seed(1)

# 获取可见的 GPU 设备列表
visible_gpus = tf.config.experimental.list_physical_devices('GPU')
if len(visible_gpus) > 0:
    # 如果有可见的 GPU 设备，设置 TensorFlow 在 GPU 上运行
    tf.config.set_visible_devices(visible_gpus, 'GPU')
    gpu_config = tf.config.experimental.set_memory_growth(visible_gpus[0], True)
    sess = tf.compat.v1.Session(config=gpu_config)
    tf.compat.v1.keras.backend.set_session(sess)
    print('GPU available')
else:
    # 如果没有可见的 GPU 设备，设置 TensorFlow 在 CPU 上运行
    tf.config.set_visible_devices([], 'GPU')
    sess = tf.compat.v1.Session()
    print('No GPU available')

# Load data
data, label = load_data(data_dir, ALL_MOTION)
print('\nLoaded dataset of ' + str(label.shape[0]) + ' samples, each sized ' + str(data[0,:,:].shape) + '\n')

# Split train and test
[data_train, data_test, label_train, label_test] = train_test_split(data, label, test_size=fraction_for_test)
print('\nTrain on ' + str(label_train.shape[0]) + ' samples\n' +\
    'Test on ' + str(label_test.shape[0]) + ' samples\n')

# One-hot encoding for train data
label_train = onehot_encoding(label_train, N_MOTION)

# Load or fabricate model
if use_existing_model:
    model = load_model('model_widar3_trained.h5')
    model.summary()
else:
    #model = assemble_model(input_shape=(T_MAX, 20, 20, 1), n_class=N_MOTION)
    model = assemble_model(input_shape=(T_MAX, 15, 15, 1), n_class=N_MOTION) #修改点4
    model.summary()

class AccuracyLossHistory(Callback):
    def on_train_begin(self, logs={}):
        self.acc = []
        self.loss = []
        self.val_acc = []
        self.val_loss = []

    def on_epoch_end(self, epoch, logs={}):
        self.acc.append(logs.get('accuracy'))
        self.loss.append(logs.get('loss'))
        self.val_acc.append(logs.get('val_accuracy'))
        self.val_loss.append(logs.get('val_loss'))

history = AccuracyLossHistory()

model.fit({'name_model_input': data_train},{'name_model_output': label_train},
          batch_size=n_batch_size,
          epochs=n_epochs,
          verbose=1,
          validation_split=0.1, shuffle=True, callbacks=[history])
print('Saving trained model...')
#model.save('model_widar3_trained.h5')
model.save(f'{result_folder}/model.h5')  # 改动

# Testing...
print('Testing...')
label_test_pred = model.predict(data_test)
# label_test_pred = np.argmax(label_test_pred, axis = -1) + 1
label_test_pred = np.argmax(label_test_pred, axis = -1) + 2 #修改点5

# Confusion Matrix
cm = confusion_matrix(label_test, label_test_pred)
print(cm)
cm = cm.astype('float')/cm.sum(axis=1)[:, np.newaxis]
cm = np.around(cm, decimals=2)
print(cm)
#cm_display = ConfusionMatrixDisplay(cm, display_labels=range(1, N_MOTION+1)).plot()
#cm_display = ConfusionMatrixDisplay(cm, display_labels=range(4, N_MOTION+3)).plot() #2345 lebel-2  4567 4=2+2  7=长度4+3
cm_display = ConfusionMatrixDisplay(cm, display_labels=range(2, N_MOTION+2)).plot() #2345 lebel-2  4567 4=2+2  7=长度4+3
plt.show()
plt.savefig(f'{result_folder}/cm.png') # 新增点1 保存混淆矩阵结果2023.09.11

# Accuracy 新增百分号
test_accuracy = np.sum(label_test == label_test_pred) / (label_test.shape[0])
#print(test_accuracy)
test_accuracy_percentage = test_accuracy * 100
test_accuracy_str = f"{test_accuracy_percentage:.2f}%"
print(test_accuracy_str)

df_accuracy = pd.DataFrame({'Test Accuracy': [test_accuracy]})
df_accuracy.to_excel(f'{result_folder}/{test_accuracy_str}.xlsx', index=False) ## 新增点2 保存测试集平均准确率结果2023.09.11


df = pd.DataFrame({
    'Epoch': range(1, n_epochs+1),
    'Train Accuracy': history.acc,
    'Train Loss': history.loss,
    'Validation Accuracy': history.val_acc,
    'Validation Loss': history.val_loss
})

# df.to_excel('accuracy_l'''  '''oss.xlsx', index=False)
# 保存准确率和损失数据到Excel表格中
df.to_excel(f'{result_folder}/accuracy_loss.xlsx', index=False) #改动

plt.plot(range(1, n_epochs+1), history.acc, label='Train Accuracy')
plt.plot(range(1, n_epochs+1), history.loss, label='Train Loss')
plt.plot(range(1, n_epochs+1), history.val_acc, label='Validation Accuracy')
plt.plot(range(1, n_epochs+1), history.val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.legend()
plt.savefig(f'{result_folder}/plot.png')
plt.show()

# 新增 修改文件名 并打印新的文件名
new_result_folder = result_folder + f'_{test_accuracy_str}'
os.rename(result_folder, new_result_folder)
result_folder = new_result_folder

print("新的结果文件夹名称为：", result_folder)

end_time = time.time()  # 记录程序结束时间
duration = end_time - start_time  # 计算程序运行时间
print("程序执行时间为：{:.2f}秒".format(duration))

with open(f'{result_folder}/runtime.txt', 'w') as f:
    f.write("程序执行时间为：{:.2f}秒".format(duration)) # 新增点3 保存程序执行时间结果2023.09.11
# Out:
# GPU available
#
# Loaded dataset of 1120 samples, each sized (20, 15, 15, 1)
#
#
# Train on 1008 samples
# Test on 112 samples
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.RMSprop.
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  name_model_input (InputLay  [(None, 20, 15, 15, 1)]      0         []
#  er)
#
#  time_distributed_18 (TimeD  (None, 20, 11, 11, 16)       416       ['name_model_input[0][0]']
#  istributed)
#
#  time_distributed_19 (TimeD  (None, 20, 5, 5, 16)         0         ['time_distributed_18[0][0]']
#  istributed)
#
#  time_distributed_20 (TimeD  (None, 20, 400)              0         ['time_distributed_19[0][0]']
#  istributed)
#
#  time_distributed_21 (TimeD  (None, 20, 64)               25664     ['time_distributed_20[0][0]']
#  istributed)
#
#  time_distributed_22 (TimeD  (None, 20, 64)               0         ['time_distributed_21[0][0]']
#  istributed)
#
#  time_distributed_23 (TimeD  (None, 20, 64)               4160      ['time_distributed_22[0][0]']
#  istributed)
#
#  multi_head_attention_3 (Mu  (None, 20, 64)               16640     ['time_distributed_23[0][0]',
#  ltiHeadAttention)                                                   'time_distributed_23[0][0]']
#
#  dropout_13 (Dropout)        (None, 20, 64)               0         ['multi_head_attention_3[0][0]
#                                                                     ']
#
#  tf.__operators__.add_3 (TF  (None, 20, 64)               0         ['dropout_13[0][0]',
#  OpLambda)                                                           'time_distributed_23[0][0]']
#
#  layer_normalization_6 (Lay  (None, 20, 64)               128       ['tf.__operators__.add_3[0][0]
#  erNormalization)                                                   ']
#
#  dense_14 (Dense)            (None, 20, 64)               4160      ['layer_normalization_6[0][0]'
#                                                                     ]
#
#  dense_15 (Dense)            (None, 20, 64)               4160      ['dense_14[0][0]']
#
#  dropout_14 (Dropout)        (None, 20, 64)               0         ['dense_15[0][0]']
#
#  layer_normalization_7 (Lay  (None, 20, 64)               128       ['dropout_14[0][0]']
#  erNormalization)
#
#  lstm_3 (LSTM)               (None, 128)                  98816     ['layer_normalization_7[0][0]'
#                                                                     ]
#
#  dropout_15 (Dropout)        (None, 128)                  0         ['lstm_3[0][0]']
#
#  name_model_output (Dense)   (None, 4)                    516       ['dropout_15[0][0]']
#
# ==================================================================================================
# Total params: 154788 (604.64 KB)
# Trainable params: 154788 (604.64 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/250
# 29/29 [==============================] - 7s 53ms/step - loss: 0.5900 - accuracy: 0.2514 - val_loss: 0.5891 - val_accuracy: 0.2673
# Epoch 2/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.5755 - accuracy: 0.2448 - val_loss: 0.5592 - val_accuracy: 0.2673
# Epoch 3/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.5653 - accuracy: 0.2911 - val_loss: 0.5869 - val_accuracy: 0.2970
# Epoch 4/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.5596 - accuracy: 0.3098 - val_loss: 0.5602 - val_accuracy: 0.3465
# Epoch 5/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.5552 - accuracy: 0.3297 - val_loss: 0.5614 - val_accuracy: 0.3762
# Epoch 6/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.5577 - accuracy: 0.3164 - val_loss: 0.5876 - val_accuracy: 0.2178
# Epoch 7/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.5520 - accuracy: 0.3319 - val_loss: 0.5668 - val_accuracy: 0.3069
# Epoch 8/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.5492 - accuracy: 0.3550 - val_loss: 0.5628 - val_accuracy: 0.3069
# Epoch 9/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.5453 - accuracy: 0.3738 - val_loss: 0.5271 - val_accuracy: 0.4257
# Epoch 10/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.5341 - accuracy: 0.4035 - val_loss: 0.5339 - val_accuracy: 0.4455
# Epoch 11/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.5176 - accuracy: 0.4620 - val_loss: 0.6112 - val_accuracy: 0.2772
# Epoch 12/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.5050 - accuracy: 0.4686 - val_loss: 0.5271 - val_accuracy: 0.4059
# Epoch 13/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.4793 - accuracy: 0.4994 - val_loss: 0.5219 - val_accuracy: 0.4455
# Epoch 14/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.4594 - accuracy: 0.5281 - val_loss: 0.4670 - val_accuracy: 0.4950
# Epoch 15/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.4472 - accuracy: 0.5656 - val_loss: 0.4223 - val_accuracy: 0.6337
# Epoch 16/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.4256 - accuracy: 0.5998 - val_loss: 0.4299 - val_accuracy: 0.5941
# Epoch 17/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.4184 - accuracy: 0.6086 - val_loss: 0.3695 - val_accuracy: 0.6634
# Epoch 18/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.3934 - accuracy: 0.6494 - val_loss: 0.3952 - val_accuracy: 0.6535
# Epoch 19/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.3769 - accuracy: 0.6759 - val_loss: 0.4778 - val_accuracy: 0.5545
# Epoch 20/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.3797 - accuracy: 0.6725 - val_loss: 0.6058 - val_accuracy: 0.4653
# Epoch 21/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.3556 - accuracy: 0.6891 - val_loss: 0.3997 - val_accuracy: 0.6040
# Epoch 22/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.3374 - accuracy: 0.7211 - val_loss: 0.3156 - val_accuracy: 0.7030
# Epoch 23/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.3581 - accuracy: 0.6703 - val_loss: 0.3013 - val_accuracy: 0.7921
# Epoch 24/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.3224 - accuracy: 0.7387 - val_loss: 0.3655 - val_accuracy: 0.7030
# Epoch 25/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.3093 - accuracy: 0.7354 - val_loss: 0.3181 - val_accuracy: 0.7426
# Epoch 26/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.3038 - accuracy: 0.7420 - val_loss: 0.2976 - val_accuracy: 0.7426
# Epoch 27/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.2977 - accuracy: 0.7442 - val_loss: 0.5856 - val_accuracy: 0.5347
# Epoch 28/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.2992 - accuracy: 0.7607 - val_loss: 0.2531 - val_accuracy: 0.8119
# Epoch 29/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.2768 - accuracy: 0.7795 - val_loss: 0.3845 - val_accuracy: 0.7030
# Epoch 30/250
# 29/29 [==============================] - 0s 14ms/step - loss: 0.2737 - accuracy: 0.7762 - val_loss: 0.2583 - val_accuracy: 0.7822
# Epoch 31/250
# 29/29 [==============================] - 0s 15ms/step - loss: 0.2604 - accuracy: 0.8004 - val_loss: 0.2371 - val_accuracy: 0.8119
# Epoch 32/250
# 29/29 [==============================] - 0s 16ms/step - loss: 0.2651 - accuracy: 0.7828 - val_loss: 0.2633 - val_accuracy: 0.8020
# Epoch 33/250
# 29/29 [==============================] - 0s 16ms/step - loss: 0.2559 - accuracy: 0.7850 - val_loss: 0.2491 - val_accuracy: 0.8317
# Epoch 34/250
# 29/29 [==============================] - 0s 15ms/step - loss: 0.2485 - accuracy: 0.8015 - val_loss: 0.2824 - val_accuracy: 0.7624
# Epoch 35/250
# 29/29 [==============================] - 0s 17ms/step - loss: 0.2345 - accuracy: 0.8181 - val_loss: 0.2378 - val_accuracy: 0.8020
# Epoch 36/250
# 29/29 [==============================] - 0s 16ms/step - loss: 0.2332 - accuracy: 0.8269 - val_loss: 0.3719 - val_accuracy: 0.7426
# Epoch 37/250
# 29/29 [==============================] - 1s 18ms/step - loss: 0.2251 - accuracy: 0.8192 - val_loss: 0.3775 - val_accuracy: 0.7129
# Epoch 38/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.2217 - accuracy: 0.8258 - val_loss: 0.2405 - val_accuracy: 0.8515
# Epoch 39/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.2084 - accuracy: 0.8401 - val_loss: 0.3003 - val_accuracy: 0.7822
# Epoch 40/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.2178 - accuracy: 0.8390 - val_loss: 0.1930 - val_accuracy: 0.8416
# Epoch 41/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.2054 - accuracy: 0.8479 - val_loss: 0.2145 - val_accuracy: 0.8515
# Epoch 42/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.1898 - accuracy: 0.8699 - val_loss: 0.2169 - val_accuracy: 0.8515
# Epoch 43/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.1968 - accuracy: 0.8490 - val_loss: 0.2719 - val_accuracy: 0.8119
# Epoch 44/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.1865 - accuracy: 0.8655 - val_loss: 0.2467 - val_accuracy: 0.8317
# Epoch 45/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.1773 - accuracy: 0.8677 - val_loss: 0.2034 - val_accuracy: 0.8515
# Epoch 46/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.1845 - accuracy: 0.8567 - val_loss: 0.2273 - val_accuracy: 0.8317
# Epoch 47/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.1784 - accuracy: 0.8688 - val_loss: 0.1793 - val_accuracy: 0.8416
# Epoch 48/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.1775 - accuracy: 0.8644 - val_loss: 0.2290 - val_accuracy: 0.8119
# Epoch 49/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.1662 - accuracy: 0.8798 - val_loss: 0.1993 - val_accuracy: 0.8911
# Epoch 50/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.1603 - accuracy: 0.8809 - val_loss: 0.2373 - val_accuracy: 0.8515
# Epoch 51/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.1599 - accuracy: 0.8699 - val_loss: 0.1892 - val_accuracy: 0.8515
# Epoch 52/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.1635 - accuracy: 0.8798 - val_loss: 0.1781 - val_accuracy: 0.8812
# Epoch 53/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.1416 - accuracy: 0.9063 - val_loss: 0.1838 - val_accuracy: 0.8812
# Epoch 54/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.1591 - accuracy: 0.8942 - val_loss: 0.2245 - val_accuracy: 0.8119
# Epoch 55/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.1380 - accuracy: 0.9008 - val_loss: 0.3016 - val_accuracy: 0.7327
# Epoch 56/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.1652 - accuracy: 0.8853 - val_loss: 0.2096 - val_accuracy: 0.8515
# Epoch 57/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.1494 - accuracy: 0.8875 - val_loss: 0.2671 - val_accuracy: 0.7723
# Epoch 58/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.1425 - accuracy: 0.8975 - val_loss: 0.2070 - val_accuracy: 0.8812
# Epoch 59/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.1317 - accuracy: 0.9096 - val_loss: 0.1876 - val_accuracy: 0.8614
# Epoch 60/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.1360 - accuracy: 0.8953 - val_loss: 0.1901 - val_accuracy: 0.8713
# Epoch 61/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.1417 - accuracy: 0.8953 - val_loss: 0.2083 - val_accuracy: 0.8317
# Epoch 62/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.1224 - accuracy: 0.9140 - val_loss: 0.3180 - val_accuracy: 0.7822
# Epoch 63/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.1317 - accuracy: 0.9140 - val_loss: 0.1737 - val_accuracy: 0.8614
# Epoch 64/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.1250 - accuracy: 0.9129 - val_loss: 0.2019 - val_accuracy: 0.8614
# Epoch 65/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.1158 - accuracy: 0.9151 - val_loss: 0.1887 - val_accuracy: 0.8515
# Epoch 66/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.1321 - accuracy: 0.9041 - val_loss: 0.1775 - val_accuracy: 0.8713
# Epoch 67/250
# 29/29 [==============================] - 0s 15ms/step - loss: 0.1243 - accuracy: 0.9129 - val_loss: 0.1783 - val_accuracy: 0.8812
# Epoch 68/250
# 29/29 [==============================] - 0s 17ms/step - loss: 0.1298 - accuracy: 0.8986 - val_loss: 0.2299 - val_accuracy: 0.8317
# Epoch 69/250
# 29/29 [==============================] - 0s 16ms/step - loss: 0.1160 - accuracy: 0.9206 - val_loss: 0.2314 - val_accuracy: 0.8515
# Epoch 70/250
# 29/29 [==============================] - 0s 16ms/step - loss: 0.1102 - accuracy: 0.9206 - val_loss: 0.2340 - val_accuracy: 0.8317
# Epoch 71/250
# 29/29 [==============================] - 0s 15ms/step - loss: 0.1002 - accuracy: 0.9361 - val_loss: 0.2005 - val_accuracy: 0.8812
# Epoch 72/250
# 29/29 [==============================] - 1s 19ms/step - loss: 0.1098 - accuracy: 0.9173 - val_loss: 0.2944 - val_accuracy: 0.8416
# Epoch 73/250
# 29/29 [==============================] - 0s 16ms/step - loss: 0.1015 - accuracy: 0.9272 - val_loss: 0.3766 - val_accuracy: 0.7822
# Epoch 74/250
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0937 - accuracy: 0.9405 - val_loss: 0.2041 - val_accuracy: 0.8911
# Epoch 75/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0940 - accuracy: 0.9427 - val_loss: 0.2726 - val_accuracy: 0.8218
# Epoch 76/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0917 - accuracy: 0.9338 - val_loss: 0.2796 - val_accuracy: 0.8119
# Epoch 77/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0992 - accuracy: 0.9294 - val_loss: 0.3382 - val_accuracy: 0.7723
# Epoch 78/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0914 - accuracy: 0.9394 - val_loss: 0.1938 - val_accuracy: 0.8812
# Epoch 79/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0831 - accuracy: 0.9350 - val_loss: 0.2561 - val_accuracy: 0.7723
# Epoch 80/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0964 - accuracy: 0.9272 - val_loss: 0.2385 - val_accuracy: 0.8515
# Epoch 81/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0909 - accuracy: 0.9372 - val_loss: 0.1819 - val_accuracy: 0.8614
# Epoch 82/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0848 - accuracy: 0.9394 - val_loss: 0.2333 - val_accuracy: 0.8317
# Epoch 83/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0857 - accuracy: 0.9416 - val_loss: 0.2073 - val_accuracy: 0.8515
# Epoch 84/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0771 - accuracy: 0.9482 - val_loss: 0.1713 - val_accuracy: 0.8812
# Epoch 85/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.0954 - accuracy: 0.9394 - val_loss: 0.2175 - val_accuracy: 0.8614
# Epoch 86/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0778 - accuracy: 0.9438 - val_loss: 0.2168 - val_accuracy: 0.8614
# Epoch 87/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0723 - accuracy: 0.9493 - val_loss: 0.2991 - val_accuracy: 0.8119
# Epoch 88/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0804 - accuracy: 0.9504 - val_loss: 0.1981 - val_accuracy: 0.8812
# Epoch 89/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0844 - accuracy: 0.9427 - val_loss: 0.2317 - val_accuracy: 0.8614
# Epoch 90/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0755 - accuracy: 0.9460 - val_loss: 0.2099 - val_accuracy: 0.8515
# Epoch 91/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0681 - accuracy: 0.9592 - val_loss: 0.1915 - val_accuracy: 0.8614
# Epoch 92/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0754 - accuracy: 0.9482 - val_loss: 0.2254 - val_accuracy: 0.8416
# Epoch 93/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0856 - accuracy: 0.9449 - val_loss: 0.1979 - val_accuracy: 0.8812
# Epoch 94/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.0695 - accuracy: 0.9559 - val_loss: 0.2811 - val_accuracy: 0.8218
# Epoch 95/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0631 - accuracy: 0.9592 - val_loss: 0.1983 - val_accuracy: 0.9010
# Epoch 96/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0667 - accuracy: 0.9559 - val_loss: 0.2297 - val_accuracy: 0.8713
# Epoch 97/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0595 - accuracy: 0.9570 - val_loss: 0.2191 - val_accuracy: 0.8416
# Epoch 98/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0563 - accuracy: 0.9636 - val_loss: 0.2000 - val_accuracy: 0.8713
# Epoch 99/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0704 - accuracy: 0.9581 - val_loss: 0.2186 - val_accuracy: 0.8416
# Epoch 100/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.0652 - accuracy: 0.9581 - val_loss: 0.2791 - val_accuracy: 0.8218
# Epoch 101/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0632 - accuracy: 0.9603 - val_loss: 0.2745 - val_accuracy: 0.8416
# Epoch 102/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0677 - accuracy: 0.9548 - val_loss: 0.2334 - val_accuracy: 0.8515
# Epoch 103/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0644 - accuracy: 0.9603 - val_loss: 0.3920 - val_accuracy: 0.7525
# Epoch 104/250
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0579 - accuracy: 0.9614 - val_loss: 0.2583 - val_accuracy: 0.8218
# Epoch 105/250
# 29/29 [==============================] - 1s 17ms/step - loss: 0.0676 - accuracy: 0.9570 - val_loss: 0.3039 - val_accuracy: 0.8119
# Epoch 106/250
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0676 - accuracy: 0.9559 - val_loss: 0.2762 - val_accuracy: 0.8020
# Epoch 107/250
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0558 - accuracy: 0.9614 - val_loss: 0.1957 - val_accuracy: 0.8317
# Epoch 108/250
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0534 - accuracy: 0.9724 - val_loss: 0.2020 - val_accuracy: 0.8812
# Epoch 109/250
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0573 - accuracy: 0.9669 - val_loss: 0.6129 - val_accuracy: 0.7129
# Epoch 110/250
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0698 - accuracy: 0.9537 - val_loss: 0.2254 - val_accuracy: 0.8614
# Epoch 111/250
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0575 - accuracy: 0.9647 - val_loss: 0.2524 - val_accuracy: 0.8515
# Epoch 112/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0531 - accuracy: 0.9691 - val_loss: 0.2411 - val_accuracy: 0.8713
# Epoch 113/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0631 - accuracy: 0.9581 - val_loss: 0.3005 - val_accuracy: 0.8218
# Epoch 114/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0580 - accuracy: 0.9570 - val_loss: 0.2252 - val_accuracy: 0.8812
# Epoch 115/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0379 - accuracy: 0.9779 - val_loss: 0.2146 - val_accuracy: 0.8515
# Epoch 116/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0479 - accuracy: 0.9735 - val_loss: 0.2482 - val_accuracy: 0.8317
# Epoch 117/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0466 - accuracy: 0.9691 - val_loss: 0.2118 - val_accuracy: 0.8515
# Epoch 118/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0451 - accuracy: 0.9768 - val_loss: 0.2153 - val_accuracy: 0.8515
# Epoch 119/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0508 - accuracy: 0.9625 - val_loss: 0.2201 - val_accuracy: 0.8713
# Epoch 120/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0416 - accuracy: 0.9757 - val_loss: 0.2034 - val_accuracy: 0.8812
# Epoch 121/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0569 - accuracy: 0.9603 - val_loss: 0.2438 - val_accuracy: 0.8515
# Epoch 122/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0458 - accuracy: 0.9691 - val_loss: 0.2367 - val_accuracy: 0.8416
# Epoch 123/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0561 - accuracy: 0.9647 - val_loss: 0.2327 - val_accuracy: 0.8515
# Epoch 124/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0467 - accuracy: 0.9746 - val_loss: 0.2325 - val_accuracy: 0.8317
# Epoch 125/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0342 - accuracy: 0.9779 - val_loss: 0.1940 - val_accuracy: 0.8614
# Epoch 126/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0302 - accuracy: 0.9791 - val_loss: 0.2262 - val_accuracy: 0.8614
# Epoch 127/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0449 - accuracy: 0.9735 - val_loss: 0.2302 - val_accuracy: 0.8515
# Epoch 128/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0439 - accuracy: 0.9768 - val_loss: 0.2988 - val_accuracy: 0.8317
# Epoch 129/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0315 - accuracy: 0.9835 - val_loss: 0.2385 - val_accuracy: 0.8416
# Epoch 130/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0445 - accuracy: 0.9746 - val_loss: 0.2417 - val_accuracy: 0.8515
# Epoch 131/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0533 - accuracy: 0.9669 - val_loss: 0.2916 - val_accuracy: 0.8515
# Epoch 132/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.0460 - accuracy: 0.9746 - val_loss: 0.3661 - val_accuracy: 0.7426
# Epoch 133/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0380 - accuracy: 0.9735 - val_loss: 0.2755 - val_accuracy: 0.7822
# Epoch 134/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0374 - accuracy: 0.9746 - val_loss: 0.2924 - val_accuracy: 0.8317
# Epoch 135/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0299 - accuracy: 0.9779 - val_loss: 0.3171 - val_accuracy: 0.8218
# Epoch 136/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0408 - accuracy: 0.9746 - val_loss: 0.5333 - val_accuracy: 0.7129
# Epoch 137/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0392 - accuracy: 0.9779 - val_loss: 0.2339 - val_accuracy: 0.8713
# Epoch 138/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.0431 - accuracy: 0.9713 - val_loss: 0.2998 - val_accuracy: 0.8317
# Epoch 139/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0220 - accuracy: 0.9901 - val_loss: 0.2708 - val_accuracy: 0.8515
# Epoch 140/250
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0558 - accuracy: 0.9647 - val_loss: 0.2580 - val_accuracy: 0.8515
# Epoch 141/250
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0312 - accuracy: 0.9835 - val_loss: 0.3057 - val_accuracy: 0.8416
# Epoch 142/250
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0347 - accuracy: 0.9802 - val_loss: 0.2414 - val_accuracy: 0.8614
# Epoch 143/250
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0497 - accuracy: 0.9768 - val_loss: 0.3487 - val_accuracy: 0.8119
# Epoch 144/250
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0301 - accuracy: 0.9813 - val_loss: 0.2790 - val_accuracy: 0.8317
# Epoch 145/250
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0395 - accuracy: 0.9735 - val_loss: 0.3179 - val_accuracy: 0.8119
# Epoch 146/250
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0339 - accuracy: 0.9802 - val_loss: 0.3263 - val_accuracy: 0.8317
# Epoch 147/250
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0337 - accuracy: 0.9813 - val_loss: 0.3510 - val_accuracy: 0.8119
# Epoch 148/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0355 - accuracy: 0.9791 - val_loss: 0.2403 - val_accuracy: 0.8416
# Epoch 149/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0306 - accuracy: 0.9846 - val_loss: 0.2776 - val_accuracy: 0.8713
# Epoch 150/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0287 - accuracy: 0.9791 - val_loss: 0.3626 - val_accuracy: 0.7921
# Epoch 151/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0416 - accuracy: 0.9802 - val_loss: 0.3567 - val_accuracy: 0.8416
# Epoch 152/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0404 - accuracy: 0.9779 - val_loss: 0.3289 - val_accuracy: 0.8317
# Epoch 153/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0329 - accuracy: 0.9846 - val_loss: 0.4310 - val_accuracy: 0.8119
# Epoch 154/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0348 - accuracy: 0.9779 - val_loss: 0.3079 - val_accuracy: 0.8317
# Epoch 155/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0280 - accuracy: 0.9879 - val_loss: 0.4937 - val_accuracy: 0.8119
# Epoch 156/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0370 - accuracy: 0.9791 - val_loss: 0.2813 - val_accuracy: 0.8515
# Epoch 157/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0278 - accuracy: 0.9813 - val_loss: 0.2393 - val_accuracy: 0.8614
# Epoch 158/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0344 - accuracy: 0.9802 - val_loss: 0.2403 - val_accuracy: 0.8812
# Epoch 159/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0364 - accuracy: 0.9813 - val_loss: 0.2516 - val_accuracy: 0.8515
# Epoch 160/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0206 - accuracy: 0.9890 - val_loss: 0.2456 - val_accuracy: 0.8614
# Epoch 161/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0363 - accuracy: 0.9835 - val_loss: 0.2435 - val_accuracy: 0.8812
# Epoch 162/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0214 - accuracy: 0.9890 - val_loss: 0.3066 - val_accuracy: 0.8515
# Epoch 163/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0207 - accuracy: 0.9923 - val_loss: 0.2625 - val_accuracy: 0.8515
# Epoch 164/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0351 - accuracy: 0.9791 - val_loss: 0.2308 - val_accuracy: 0.8515
# Epoch 165/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0435 - accuracy: 0.9713 - val_loss: 0.2858 - val_accuracy: 0.8416
# Epoch 166/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0278 - accuracy: 0.9802 - val_loss: 0.2457 - val_accuracy: 0.8614
# Epoch 167/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0303 - accuracy: 0.9802 - val_loss: 0.2889 - val_accuracy: 0.8515
# Epoch 168/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0242 - accuracy: 0.9846 - val_loss: 0.2595 - val_accuracy: 0.8614
# Epoch 169/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0144 - accuracy: 0.9945 - val_loss: 0.2461 - val_accuracy: 0.8416
# Epoch 170/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0326 - accuracy: 0.9846 - val_loss: 0.2811 - val_accuracy: 0.8515
# Epoch 171/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0423 - accuracy: 0.9768 - val_loss: 0.3039 - val_accuracy: 0.8515
# Epoch 172/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.0336 - accuracy: 0.9813 - val_loss: 0.2848 - val_accuracy: 0.8218
# Epoch 173/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0447 - accuracy: 0.9757 - val_loss: 0.3083 - val_accuracy: 0.8317
# Epoch 174/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0227 - accuracy: 0.9868 - val_loss: 0.2737 - val_accuracy: 0.8515
# Epoch 175/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0276 - accuracy: 0.9835 - val_loss: 0.2379 - val_accuracy: 0.8515
# Epoch 176/250
# 29/29 [==============================] - 1s 17ms/step - loss: 0.0207 - accuracy: 0.9890 - val_loss: 0.2864 - val_accuracy: 0.8317
# Epoch 177/250
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0405 - accuracy: 0.9791 - val_loss: 0.2323 - val_accuracy: 0.8713
# Epoch 178/250
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0317 - accuracy: 0.9813 - val_loss: 0.3537 - val_accuracy: 0.8218
# Epoch 179/250
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0195 - accuracy: 0.9868 - val_loss: 0.2121 - val_accuracy: 0.8911
# Epoch 180/250
# 29/29 [==============================] - 1s 17ms/step - loss: 0.0308 - accuracy: 0.9824 - val_loss: 0.3784 - val_accuracy: 0.8119
# Epoch 181/250
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0196 - accuracy: 0.9912 - val_loss: 0.2901 - val_accuracy: 0.8416
# Epoch 182/250
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0189 - accuracy: 0.9901 - val_loss: 0.2492 - val_accuracy: 0.8713
# Epoch 183/250
# 29/29 [==============================] - 0s 14ms/step - loss: 0.0321 - accuracy: 0.9813 - val_loss: 0.4422 - val_accuracy: 0.8020
# Epoch 184/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0217 - accuracy: 0.9901 - val_loss: 0.2927 - val_accuracy: 0.8317
# Epoch 185/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0247 - accuracy: 0.9868 - val_loss: 0.2357 - val_accuracy: 0.8515
# Epoch 186/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0161 - accuracy: 0.9912 - val_loss: 0.2313 - val_accuracy: 0.9010
# Epoch 187/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0316 - accuracy: 0.9802 - val_loss: 0.2731 - val_accuracy: 0.8614
# Epoch 188/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0174 - accuracy: 0.9890 - val_loss: 0.2463 - val_accuracy: 0.8515
# Epoch 189/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0336 - accuracy: 0.9802 - val_loss: 0.2306 - val_accuracy: 0.8614
# Epoch 190/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0228 - accuracy: 0.9890 - val_loss: 0.3322 - val_accuracy: 0.8416
# Epoch 191/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0159 - accuracy: 0.9923 - val_loss: 0.2551 - val_accuracy: 0.8515
# Epoch 192/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0195 - accuracy: 0.9857 - val_loss: 0.2658 - val_accuracy: 0.8614
# Epoch 193/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0282 - accuracy: 0.9813 - val_loss: 0.2883 - val_accuracy: 0.8812
# Epoch 194/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0210 - accuracy: 0.9923 - val_loss: 0.2451 - val_accuracy: 0.8713
# Epoch 195/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0213 - accuracy: 0.9835 - val_loss: 0.3635 - val_accuracy: 0.8119
# Epoch 196/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0242 - accuracy: 0.9857 - val_loss: 0.2918 - val_accuracy: 0.8515
# Epoch 197/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0205 - accuracy: 0.9879 - val_loss: 0.3014 - val_accuracy: 0.8614
# Epoch 198/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.0262 - accuracy: 0.9835 - val_loss: 0.3518 - val_accuracy: 0.8119
# Epoch 199/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0120 - accuracy: 0.9934 - val_loss: 0.4003 - val_accuracy: 0.8119
# Epoch 200/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0226 - accuracy: 0.9879 - val_loss: 0.2848 - val_accuracy: 0.8416
# Epoch 201/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0209 - accuracy: 0.9846 - val_loss: 0.3701 - val_accuracy: 0.8317
# Epoch 202/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0363 - accuracy: 0.9835 - val_loss: 0.3039 - val_accuracy: 0.8713
# Epoch 203/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0135 - accuracy: 0.9901 - val_loss: 0.4916 - val_accuracy: 0.8020
# Epoch 204/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.0329 - accuracy: 0.9868 - val_loss: 0.2818 - val_accuracy: 0.8317
# Epoch 205/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0236 - accuracy: 0.9846 - val_loss: 0.3831 - val_accuracy: 0.8218
# Epoch 206/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0227 - accuracy: 0.9890 - val_loss: 0.2872 - val_accuracy: 0.8614
# Epoch 207/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0177 - accuracy: 0.9901 - val_loss: 0.3411 - val_accuracy: 0.8614
# Epoch 208/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0261 - accuracy: 0.9846 - val_loss: 0.2625 - val_accuracy: 0.8812
# Epoch 209/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0169 - accuracy: 0.9945 - val_loss: 0.2779 - val_accuracy: 0.8812
# Epoch 210/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0323 - accuracy: 0.9835 - val_loss: 0.3684 - val_accuracy: 0.8119
# Epoch 211/250
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0205 - accuracy: 0.9912 - val_loss: 0.2859 - val_accuracy: 0.8515
# Epoch 212/250
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0291 - accuracy: 0.9835 - val_loss: 0.3038 - val_accuracy: 0.8515
# Epoch 213/250
# 29/29 [==============================] - 1s 17ms/step - loss: 0.0059 - accuracy: 0.9989 - val_loss: 0.3358 - val_accuracy: 0.8317
# Epoch 214/250
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0245 - accuracy: 0.9879 - val_loss: 0.2886 - val_accuracy: 0.8515
# Epoch 215/250
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0274 - accuracy: 0.9846 - val_loss: 0.3000 - val_accuracy: 0.8713
# Epoch 216/250
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0232 - accuracy: 0.9879 - val_loss: 0.2942 - val_accuracy: 0.8614
# Epoch 217/250
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0254 - accuracy: 0.9857 - val_loss: 0.3067 - val_accuracy: 0.8614
# Epoch 218/250
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0109 - accuracy: 0.9967 - val_loss: 0.2712 - val_accuracy: 0.8614
# Epoch 219/250
# 29/29 [==============================] - 0s 14ms/step - loss: 0.0210 - accuracy: 0.9857 - val_loss: 0.2935 - val_accuracy: 0.8713
# Epoch 220/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0250 - accuracy: 0.9857 - val_loss: 0.3270 - val_accuracy: 0.8614
# Epoch 221/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0180 - accuracy: 0.9923 - val_loss: 0.3068 - val_accuracy: 0.8515
# Epoch 222/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0144 - accuracy: 0.9879 - val_loss: 0.3438 - val_accuracy: 0.8317
# Epoch 223/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0144 - accuracy: 0.9901 - val_loss: 0.2843 - val_accuracy: 0.8812
# Epoch 224/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0321 - accuracy: 0.9813 - val_loss: 0.2560 - val_accuracy: 0.8713
# Epoch 225/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0271 - accuracy: 0.9857 - val_loss: 0.3251 - val_accuracy: 0.8317
# Epoch 226/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0079 - accuracy: 0.9978 - val_loss: 0.3156 - val_accuracy: 0.8713
# Epoch 227/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0109 - accuracy: 0.9945 - val_loss: 0.2565 - val_accuracy: 0.8812
# Epoch 228/250
# 29/29 [==============================] - 0s 14ms/step - loss: 0.0229 - accuracy: 0.9901 - val_loss: 0.2465 - val_accuracy: 0.8713
# Epoch 229/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0200 - accuracy: 0.9857 - val_loss: 0.2696 - val_accuracy: 0.8614
# Epoch 230/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0256 - accuracy: 0.9879 - val_loss: 0.2840 - val_accuracy: 0.8614
# Epoch 231/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0102 - accuracy: 0.9945 - val_loss: 0.3118 - val_accuracy: 0.8020
# Epoch 232/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0213 - accuracy: 0.9857 - val_loss: 0.2883 - val_accuracy: 0.8515
# Epoch 233/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0188 - accuracy: 0.9890 - val_loss: 0.4976 - val_accuracy: 0.8119
# Epoch 234/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0161 - accuracy: 0.9923 - val_loss: 0.3353 - val_accuracy: 0.8515
# Epoch 235/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0224 - accuracy: 0.9890 - val_loss: 0.3153 - val_accuracy: 0.8416
# Epoch 236/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0155 - accuracy: 0.9901 - val_loss: 0.3768 - val_accuracy: 0.8515
# Epoch 237/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0185 - accuracy: 0.9901 - val_loss: 0.3449 - val_accuracy: 0.8614
# Epoch 238/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0322 - accuracy: 0.9846 - val_loss: 0.3130 - val_accuracy: 0.8713
# Epoch 239/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0147 - accuracy: 0.9923 - val_loss: 0.3695 - val_accuracy: 0.8614
# Epoch 240/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0190 - accuracy: 0.9912 - val_loss: 0.3192 - val_accuracy: 0.8713
# Epoch 241/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0210 - accuracy: 0.9879 - val_loss: 0.3199 - val_accuracy: 0.8317
# Epoch 242/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0151 - accuracy: 0.9934 - val_loss: 0.3325 - val_accuracy: 0.8812
# Epoch 243/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0169 - accuracy: 0.9912 - val_loss: 0.3182 - val_accuracy: 0.8812
# Epoch 244/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0216 - accuracy: 0.9835 - val_loss: 0.2929 - val_accuracy: 0.8416
# Epoch 245/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0198 - accuracy: 0.9890 - val_loss: 0.2955 - val_accuracy: 0.8416
# Epoch 246/250
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0099 - accuracy: 0.9934 - val_loss: 0.3398 - val_accuracy: 0.8416
# Epoch 247/250
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0272 - accuracy: 0.9890 - val_loss: 0.2878 - val_accuracy: 0.8812
# Epoch 248/250
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0139 - accuracy: 0.9923 - val_loss: 0.3107 - val_accuracy: 0.8614
# Epoch 249/250
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0229 - accuracy: 0.9857 - val_loss: 0.2585 - val_accuracy: 0.8911
# Epoch 250/250
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0100 - accuracy: 0.9945 - val_loss: 0.3011 - val_accuracy: 0.8713
# Saving trained model...
# Testing...
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 4/4 [==============================] - 1s 5ms/step
# [[23  1  0  2]
#  [ 1 24  2  1]
#  [ 0  6 27  2]
#  [ 3  4  1 15]]
# [[0.88 0.04 0.   0.08]
#  [0.04 0.86 0.07 0.04]
#  [0.   0.17 0.77 0.06]
#  [0.13 0.17 0.04 0.65]]
# 79.46%
# 新的结果文件夹名称为： result_MultiAttention_LSTM_1层Transformer_BCE_epoch250_batchsize32_lr0.006_79.46%
# 程序执行时间为：153.05秒

# %%
# 定位到指定路径下
import os
os.chdir('/content/drive/MyDrive/Colab_Notebooks/RNN-CAP')
print(os.getcwd())

# 打印版本
import sys
import tensorflow as tf

print("Python 版本:", sys.version)
print("TensorFlow 版本:", tf.__version__)

# !pip install xlwt
# !pip install matplotlib

# %%
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_categorical_crossentropy_epoch30.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_categorical_crossentropy_epoch250.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_categorical_crossentropy_epoch50.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_categorical_crossentropy_epoch100.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_categorical_crossentropy_epoch150.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_categorical_crossentropy_epoch200.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_squared_error_epoch30.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_squared_error_epoch50.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_squared_error_epoch100.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_squared_error_epoch150.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_squared_error_epoch200.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_squared_error_epoch250.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_absolute_error_epoch30.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_absolute_error_epoch50.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_absolute_error_epoch100.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_absolute_error_epoch150.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_absolute_error_epoch200.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_absolute_error_epoch250.py

# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_binary_crossentropy_epoch30.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_binary_crossentropy_epoch50.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_binary_crossentropy_epoch100.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_binary_crossentropy_epoch150.py

#!python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_binary_crossentropy_epoch200.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_binary_crossentropy_epoch250.py
