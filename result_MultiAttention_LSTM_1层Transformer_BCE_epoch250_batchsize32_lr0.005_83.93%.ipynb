# %% [markdown]
# <a href="https://colab.research.google.com/github/zuo-liangliang/fcn.berkeleyvision.org/blob/master/result_MultiAttention_LSTM_1%E5%B1%82Transformer_BCE_epoch250_batchsize32_lr0.005_83.93%25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import zipfile

# 定义源文件夹路径和目标 zip 文件夹路径
# source_folder = '/content/drive/MyDrive/Colab_Notebooks/528BVP-acnt2'
source_folder = '/content/drive/MyDrive/AugustResult'
# target_zip_folder = '/content/drive/MyDrive/Colab_Notebooks/zip_folder'
# target_zip_folder = '/content/drive/MyDrive/Colab_Notebooks/528BVP-acnt2/0827zip_folder'
target_zip_folder = '/content/drive/MyDrive/AugustResult/0907_月月账号zip_folder'

# 确保目标 zip 文件夹存在
os.makedirs(target_zip_folder, exist_ok=True)

# 获取源文件夹中以 "result" 开头的文件夹列表
folder_list = [folder for folder in os.listdir(source_folder) if os.path.isdir(os.path.join(source_folder, folder)) and folder.startswith("result")]

# 创建一个大的 zip 文件
with zipfile.ZipFile(os.path.join(target_zip_folder, '0907月月_all_folders.zip'), 'w', zipfile.ZIP_DEFLATED) as zipf:
    # 遍历文件夹列表，逐个压缩为 zip 文件
    for folder in folder_list:
        folder_path = os.path.join(source_folder, folder)

        # 遍历文件夹中的所有文件和子文件夹，并逐个添加到大的 zip 文件中
        for root, dirs, files in os.walk(folder_path):
            for file in files:
                file_path = os.path.join(root, file)
                zipf.write(file_path, os.path.relpath(file_path, source_folder))

print("所有文件夹已压缩为一个大的 zip 文件！")
# Out:
# 所有文件夹已压缩为一个大的 zip 文件！

# %%
import shutil
import os
# 指定要删除的文件夹路径
folder_path = 'xxx' #替换为你的文件夹路径

# 确保要删除的是一个目录而不是文件
assert os.path.isdir(folder_path), f"{folder_path} 不是一个目录"

# 递归删除文件夹下的所有文件和子文件夹
shutil.rmtree(folder_path)

# %%
# 解压指定文件夹到某一路径下
import zipfile

file_path = '/content/drive/MyDrive/Colab_Notebooks/528BVP-acnt2/528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4.zip'
extract_path = '/content/drive/MyDrive/Colab_Notebooks/528BVP-acnt2/528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4'

with zipfile.ZipFile(file_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# %%
# 定位到指定路径下
import os
# os.chdir('/content/drive/MyDrive/SeptemberResult/result_LSTM')
os.chdir('/content/drive/MyDrive/SeptemberResult/result_MultiAttention_LSTM_1层Transformer')
print(os.getcwd())
# Out:
# /content/drive/MyDrive/SeptemberResult/result_MultiAttention_LSTM_1层Transformer

# %%
# result_MultiAttention_LSTM_1层Transformer

from keras.callbacks import Callback
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay

from __future__ import print_function

import time
import os,sys
import numpy as np
import pandas as pd
import scipy.io as scio
import tensorflow as tf
tf.compat.v1.keras.backend.set_session
import keras
from keras.layers import Input, GRU, LSTM, Dense, Flatten, Dropout, Conv2D, Conv3D, MaxPooling2D, MaxPooling3D, TimeDistributed
from keras.models import Model, load_model
import keras.backend as K
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split

# Parameters
use_existing_model = False
fraction_for_test = 0.1
data_dir = '/content/drive/MyDrive/Colab_Notebooks/528BVP-acnt2/528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4/'
# data_dir = '/content/drive/MyDrive/new528BVP/528[-1,1]长度20-分辨率15_acnt2_sample_rate5000__剔14_改6为4/'

fraction_for_test = 0.1
#ALL_MOTION = [1,2,3,4,5,6]
ALL_MOTION = [2,3,4,5]
N_MOTION = len(ALL_MOTION)
T_MAX = 0
n_epochs = 250  #最优的是100；第2优的是200，第3优的是250，原始是50 #修改点1
f_dropout_ratio = 0.5
n_gru_hidden_units = 128
n_batch_size = 32     #原始是32-->16
f_learning_rate = 0.005  #原始是0.001-->0.002

def normalize_data(data_1):
    # data(ndarray)=>data_norm(ndarray): [20,20,T]=>[20,20,T]
    data_1_max = np.concatenate((data_1.max(axis=0),data_1.max(axis=1)),axis=0).max(axis=0)
    data_1_min = np.concatenate((data_1.min(axis=0),data_1.min(axis=1)),axis=0).min(axis=0)
    if (len(np.where((data_1_max - data_1_min) == 0)[0]) > 0):
        return data_1
    data_1_max_rep = np.tile(data_1_max,(data_1.shape[0],data_1.shape[1],1))
    data_1_min_rep = np.tile(data_1_min,(data_1.shape[0],data_1.shape[1],1))
    data_1_norm = (data_1 - data_1_min_rep) / (data_1_max_rep - data_1_min_rep)
    return  data_1_norm

def zero_padding(data, T_MAX):
    # data(list)=>data_pad(ndarray): [20,20,T1/T2/...]=>[20,20,T_MAX]
    data_pad = []
    for i in range(len(data)):
        t = np.array(data[i]).shape[2]
        data_pad.append(np.pad(data[i], ((0,0),(0,0),(T_MAX - t,0)), 'constant', constant_values = 0).tolist())
    return np.array(data_pad)

def onehot_encoding(label, num_class):
    # label(list)=>_label(ndarray): [N,]=>[N,num_class]
    label = np.array(label).astype('int32')
    # assert (np.arange(0,np.unique(label).size)==np.unique(label)).prod()    # Check label from 0 to N
    label = np.squeeze(label)
    # _label = np.eye(num_class)[label-1]     # from label to onehot
    _label = np.eye(num_class)[label-2]   #修改点2
    return _label

def load_data(path_to_data, motion_sel):
    global T_MAX
    data = []
    label = []
    for data_root, data_dirs, data_files in os.walk(path_to_data):
        for data_file_name in data_files:

            file_path = os.path.join(data_root,data_file_name)
            try:
                data_1 = scio.loadmat(file_path)['velocity_spectrum_ro']
                label_1 = int(data_file_name.split('-')[1])
                #location = int(data_file_name.split('-')[2])
                #orientation = int(data_file_name.split('-')[3])
                #repetition = int(data_file_name.split('-')[4])
                repetition = int(data_file_name.split('-')[2])  #修改点3

                # Select Motion
                if (label_1 not in motion_sel):
                    continue

                # Select Location
                # if (location not in [1,2,3,5]):
                #     continue

                # Select Orientation
                # if (orientation not in [1,2,4,5]):
                #     continue

                # Normalization
                data_normed_1 = normalize_data(data_1)

                # Update T_MAX
                if T_MAX < np.array(data_1).shape[2]:
                    T_MAX = np.array(data_1).shape[2]
            except Exception:
                continue

            # Save List
            data.append(data_normed_1.tolist())
            label.append(label_1)
                # Zero-padding
    data = zero_padding(data, T_MAX)

    # Swap axes
    data = np.swapaxes(np.swapaxes(data, 1, 3), 2, 3)   # [N,20,20',T_MAX]=>[N,T_MAX,20,20']
    data = np.expand_dims(data, axis=-1)    # [N,T_MAX,20,20]=>[N,T_MAX,20,20,1]

    # Convert label to ndarray
    label = np.array(label)

    # data(ndarray): [N,T_MAX,20,20,1], label(ndarray): [N,N_MOTION]
    return data, label

# 构建符合输入形状为 (None, 20, 15, 15, 1) 和输出形状为 (None, 4) 的  模型：
from keras.layers import MultiHeadAttention, LayerNormalization  #加Transformer修改点1
num_transformer_layers = 1  # 设置Transformer层数 #加Transformer修改点2  2层-->1层

#加Transformer修改点3
def transformer_layer(inputs, hidden_units, dropout_rate):
    # Self-attention
    attention_output = MultiHeadAttention(
        num_heads=8, key_dim=hidden_units // 8
    )(inputs, inputs)
    attention_output = Dropout(dropout_rate)(attention_output)
    attention_output = LayerNormalization()(attention_output + inputs)

    # Feed-forward network
    ffn = Dense(hidden_units, activation="relu")(attention_output)
    ffn = Dense(hidden_units)(ffn)
    ffn = Dropout(dropout_rate)(ffn)
    ffn = LayerNormalization()(ffn)

    return ffn

#加Transformer修改点4
def assemble_model(input_shape, n_class):
    model_input = Input(shape=input_shape, dtype='float32', name='name_model_input')    # (@,T_MAX,20,20,1)

    # Feature extraction part
    x = TimeDistributed(Conv2D(16,kernel_size=(5,5),activation='relu',data_format='channels_last',\
        input_shape=input_shape))(model_input)   # (@,T_MAX,20,20,1)=>(@,T_MAX,16,16,16)
    x = TimeDistributed(MaxPooling2D(pool_size=(2,2)))(x)    # (@,T_MAX,16,16,16)=>(@,T_MAX,8,8,16)
    x = TimeDistributed(Flatten())(x)   # (@,T_MAX,8,8,16)=>(@,T_MAX,8*8*16)
    x = TimeDistributed(Dense(64,activation='relu'))(x) # (@,T_MAX,8*8*16)=>(@,T_MAX,64)
    x = TimeDistributed(Dropout(f_dropout_ratio))(x)
    x = TimeDistributed(Dense(64,activation='relu'))(x) # (@,T_MAX,64)=>(@,T_MAX,64)

    # Add transformer layers
    for _ in range(num_transformer_layers):
        #x = transformer_layer(x, hidden_units=n_gru_hidden_units, dropout_rate=f_dropout_ratio)
        x = transformer_layer(x, hidden_units=64, dropout_rate=f_dropout_ratio)  # 修改点1
    x = LSTM(n_gru_hidden_units,return_sequences=False)(x)  # (@,T_MAX,64)=>(@,128)
    x = Dropout(f_dropout_ratio)(x)
    model_output = Dense(n_class, activation='softmax', name='name_model_output')(x)  # (@,128)=>(@,n_class)

    # Create the model
    # Model compiling
    model = Model(inputs=model_input, outputs=model_output)
    model.compile(optimizer=keras.optimizers.RMSprop(lr=f_learning_rate),
                    # loss='categorical_crossentropy', # 将损失函数改为多类别交叉熵损失函数 最优的是CCE
                    # loss='mean_squared_error',  # 将损失函数改为均方误差 第2优的是MSE
                    # loss='mean_absolute_error',  # 将损失函数改为平均绝对误差 第3优的是MAE
                    loss='binary_crossentropy',  # 将损失函数改为对数损失函数 第3优的是MAE
                    metrics=['accuracy']
                )
    return model

# 改
#model_type = '双层LSTM'
#model_type = 'LSTM'
#model_type = 'BiLSTM'
model_type = 'MultiAttention_LSTM_1层Transformer'

# 创建结果文件夹
# result_folder = f'result_528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_GRU_改costfunction为mse_epoch200' # 每次都要改
# result_folder = f'result_528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_{model_type}_categorical_crossentropy_epoch{n_epochs}'
# result_folder = f'result_528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_{model_type}_mean_squared_error_epoch{n_epochs}'
# result_folder = f'result_528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_{model_type}_mean_absolute_error_epoch{n_epochs}'
# result_folder = f'result_528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_{model_type}_binary_crossentropy_epoch{n_epochs}'

# result_folder = f'result_{model_type}_CCE_epoch{n_epochs}_batchsize{n_batch_size}_lr{f_learning_rate}'
# result_folder = f'result_{model_type}_MSE_epoch{n_epochs}_batchsize{n_batch_size}_lr{f_learning_rate}'
# result_folder = f'result_{model_type}_MAE_epoch{n_epochs}_batchsize{n_batch_size}_lr{f_learning_rate}'
result_folder = f'result_{model_type}_BCE_epoch{n_epochs}_batchsize{n_batch_size}_lr{f_learning_rate}'

os.makedirs(result_folder, exist_ok=True)

# %%
# Let's BEGIN >>>>

import time
start_time = time.time()  # 记录程序开始时间

# 获取可见的GPU设备列表
# visible_gpus = tf.config.experimental.list_physical_devices('GPU')
# 检查是否存在可见的GPU设备
# if len(visible_gpus) < 1:
    # print('No GPU available')
    # exit(0)
# 设置使用第一个可见的GPU设备
# os.environ["CUDA_VISIBLE_DEVICES"] = str(visible_gpus[0].index)
# 配置GPU选项
# gpu_config = tf.config.experimental.set_memory_growth(visible_gpus[0], True)
# 创建一个会话并应用GPU配置
# sess = tf.compat.v1.Session(config=gpu_config)
# tf.compat.v1.keras.backend.set_session(sess)
# tf.random.set_seed(1)

# 获取可见的 GPU 设备列表
visible_gpus = tf.config.experimental.list_physical_devices('GPU')
if len(visible_gpus) > 0:
    # 如果有可见的 GPU 设备，设置 TensorFlow 在 GPU 上运行
    tf.config.set_visible_devices(visible_gpus, 'GPU')
    gpu_config = tf.config.experimental.set_memory_growth(visible_gpus[0], True)
    sess = tf.compat.v1.Session(config=gpu_config)
    tf.compat.v1.keras.backend.set_session(sess)
    print('GPU available')
else:
    # 如果没有可见的 GPU 设备，设置 TensorFlow 在 CPU 上运行
    tf.config.set_visible_devices([], 'GPU')
    sess = tf.compat.v1.Session()
    print('No GPU available')

# Load data
data, label = load_data(data_dir, ALL_MOTION)
print('\nLoaded dataset of ' + str(label.shape[0]) + ' samples, each sized ' + str(data[0,:,:].shape) + '\n')

# Split train and test
[data_train, data_test, label_train, label_test] = train_test_split(data, label, test_size=fraction_for_test)
print('\nTrain on ' + str(label_train.shape[0]) + ' samples\n' +\
    'Test on ' + str(label_test.shape[0]) + ' samples\n')

# One-hot encoding for train data
label_train = onehot_encoding(label_train, N_MOTION)

# Load or fabricate model
if use_existing_model:
    model = load_model('model_widar3_trained.h5')
    model.summary()
else:
    #model = assemble_model(input_shape=(T_MAX, 20, 20, 1), n_class=N_MOTION)
    model = assemble_model(input_shape=(T_MAX, 15, 15, 1), n_class=N_MOTION) #修改点4
    model.summary()

class AccuracyLossHistory(Callback):
    def on_train_begin(self, logs={}):
        self.acc = []
        self.loss = []
        self.val_acc = []
        self.val_loss = []

    def on_epoch_end(self, epoch, logs={}):
        self.acc.append(logs.get('accuracy'))
        self.loss.append(logs.get('loss'))
        self.val_acc.append(logs.get('val_accuracy'))
        self.val_loss.append(logs.get('val_loss'))

history = AccuracyLossHistory()

model.fit({'name_model_input': data_train},{'name_model_output': label_train},
          batch_size=n_batch_size,
          epochs=n_epochs,
          verbose=1,
          validation_split=0.1, shuffle=True, callbacks=[history])
print('Saving trained model...')
#model.save('model_widar3_trained.h5')
model.save(f'{result_folder}/model.h5')  # 改动

# Testing...
print('Testing...')
label_test_pred = model.predict(data_test)
# label_test_pred = np.argmax(label_test_pred, axis = -1) + 1
label_test_pred = np.argmax(label_test_pred, axis = -1) + 2 #修改点5

# Confusion Matrix
cm = confusion_matrix(label_test, label_test_pred)
print(cm)
cm = cm.astype('float')/cm.sum(axis=1)[:, np.newaxis]
cm = np.around(cm, decimals=2)
print(cm)
#cm_display = ConfusionMatrixDisplay(cm, display_labels=range(1, N_MOTION+1)).plot()
#cm_display = ConfusionMatrixDisplay(cm, display_labels=range(4, N_MOTION+3)).plot() #2345 lebel-2  4567 4=2+2  7=长度4+3
cm_display = ConfusionMatrixDisplay(cm, display_labels=range(2, N_MOTION+2)).plot() #2345 lebel-2  4567 4=2+2  7=长度4+3
plt.show()
plt.savefig(f'{result_folder}/cm.png') # 新增点1 保存混淆矩阵结果2023.09.11

# Accuracy 新增百分号
test_accuracy = np.sum(label_test == label_test_pred) / (label_test.shape[0])
#print(test_accuracy)
test_accuracy_percentage = test_accuracy * 100
test_accuracy_str = f"{test_accuracy_percentage:.2f}%"
print(test_accuracy_str)

df_accuracy = pd.DataFrame({'Test Accuracy': [test_accuracy]})
df_accuracy.to_excel(f'{result_folder}/{test_accuracy_str}.xlsx', index=False) ## 新增点2 保存测试集平均准确率结果2023.09.11


df = pd.DataFrame({
    'Epoch': range(1, n_epochs+1),
    'Train Accuracy': history.acc,
    'Train Loss': history.loss,
    'Validation Accuracy': history.val_acc,
    'Validation Loss': history.val_loss
})

# df.to_excel('accuracy_l'''  '''oss.xlsx', index=False)
# 保存准确率和损失数据到Excel表格中
df.to_excel(f'{result_folder}/accuracy_loss.xlsx', index=False) #改动

plt.plot(range(1, n_epochs+1), history.acc, label='Train Accuracy')
plt.plot(range(1, n_epochs+1), history.loss, label='Train Loss')
plt.plot(range(1, n_epochs+1), history.val_acc, label='Validation Accuracy')
plt.plot(range(1, n_epochs+1), history.val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.legend()
plt.savefig(f'{result_folder}/plot.png')
plt.show()

# 新增 修改文件名 并打印新的文件名
new_result_folder = result_folder + f'_{test_accuracy_str}'
os.rename(result_folder, new_result_folder)
result_folder = new_result_folder

print("新的结果文件夹名称为：", result_folder)

end_time = time.time()  # 记录程序结束时间
duration = end_time - start_time  # 计算程序运行时间
print("程序执行时间为：{:.2f}秒".format(duration))

with open(f'{result_folder}/runtime.txt', 'w') as f:
    f.write("程序执行时间为：{:.2f}秒".format(duration)) # 新增点3 保存程序执行时间结果2023.09.11
# Out:
# GPU available
#
# Loaded dataset of 1120 samples, each sized (20, 15, 15, 1)
#
#
# Train on 1008 samples
# Test on 112 samples
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.RMSprop.
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  name_model_input (InputLay  [(None, 20, 15, 15, 1)]      0         []
#  er)
#
#  time_distributed_12 (TimeD  (None, 20, 11, 11, 16)       416       ['name_model_input[0][0]']
#  istributed)
#
#  time_distributed_13 (TimeD  (None, 20, 5, 5, 16)         0         ['time_distributed_12[0][0]']
#  istributed)
#
#  time_distributed_14 (TimeD  (None, 20, 400)              0         ['time_distributed_13[0][0]']
#  istributed)
#
#  time_distributed_15 (TimeD  (None, 20, 64)               25664     ['time_distributed_14[0][0]']
#  istributed)
#
#  time_distributed_16 (TimeD  (None, 20, 64)               0         ['time_distributed_15[0][0]']
#  istributed)
#
#  time_distributed_17 (TimeD  (None, 20, 64)               4160      ['time_distributed_16[0][0]']
#  istributed)
#
#  multi_head_attention_2 (Mu  (None, 20, 64)               16640     ['time_distributed_17[0][0]',
#  ltiHeadAttention)                                                   'time_distributed_17[0][0]']
#
#  dropout_9 (Dropout)         (None, 20, 64)               0         ['multi_head_attention_2[0][0]
#                                                                     ']
#
#  tf.__operators__.add_2 (TF  (None, 20, 64)               0         ['dropout_9[0][0]',
#  OpLambda)                                                           'time_distributed_17[0][0]']
#
#  layer_normalization_4 (Lay  (None, 20, 64)               128       ['tf.__operators__.add_2[0][0]
#  erNormalization)                                                   ']
#
#  dense_10 (Dense)            (None, 20, 64)               4160      ['layer_normalization_4[0][0]'
#                                                                     ]
#
#  dense_11 (Dense)            (None, 20, 64)               4160      ['dense_10[0][0]']
#
#  dropout_10 (Dropout)        (None, 20, 64)               0         ['dense_11[0][0]']
#
#  layer_normalization_5 (Lay  (None, 20, 64)               128       ['dropout_10[0][0]']
#  erNormalization)
#
#  lstm_2 (LSTM)               (None, 128)                  98816     ['layer_normalization_5[0][0]'
#                                                                     ]
#
#  dropout_11 (Dropout)        (None, 128)                  0         ['lstm_2[0][0]']
#
#  name_model_output (Dense)   (None, 4)                    516       ['dropout_11[0][0]']
#
# ==================================================================================================
# Total params: 154788 (604.64 KB)
# Trainable params: 154788 (604.64 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/250
# 29/29 [==============================] - 7s 37ms/step - loss: 0.5834 - accuracy: 0.2657 - val_loss: 0.5774 - val_accuracy: 0.1584
# Epoch 2/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.5732 - accuracy: 0.2525 - val_loss: 0.5609 - val_accuracy: 0.2970
# Epoch 3/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.5712 - accuracy: 0.2569 - val_loss: 0.5462 - val_accuracy: 0.3663
# Epoch 4/250
# 29/29 [==============================] - 0s 14ms/step - loss: 0.5644 - accuracy: 0.2911 - val_loss: 0.5475 - val_accuracy: 0.2673
# Epoch 5/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.5535 - accuracy: 0.3407 - val_loss: 0.5325 - val_accuracy: 0.4059
# Epoch 6/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.5382 - accuracy: 0.3837 - val_loss: 0.5419 - val_accuracy: 0.3663
# Epoch 7/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.5329 - accuracy: 0.3914 - val_loss: 0.4843 - val_accuracy: 0.5149
# Epoch 8/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.5258 - accuracy: 0.4322 - val_loss: 0.5017 - val_accuracy: 0.4158
# Epoch 9/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.5013 - accuracy: 0.4675 - val_loss: 0.5286 - val_accuracy: 0.3663
# Epoch 10/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.4919 - accuracy: 0.4873 - val_loss: 0.4174 - val_accuracy: 0.6139
# Epoch 11/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.4646 - accuracy: 0.5314 - val_loss: 0.4460 - val_accuracy: 0.5347
# Epoch 12/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.4419 - accuracy: 0.5810 - val_loss: 0.3696 - val_accuracy: 0.6436
# Epoch 13/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.4304 - accuracy: 0.5921 - val_loss: 0.3423 - val_accuracy: 0.7129
# Epoch 14/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.4113 - accuracy: 0.6196 - val_loss: 0.3419 - val_accuracy: 0.6337
# Epoch 15/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.3977 - accuracy: 0.6406 - val_loss: 0.3515 - val_accuracy: 0.6832
# Epoch 16/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.3769 - accuracy: 0.6582 - val_loss: 0.3168 - val_accuracy: 0.7426
# Epoch 17/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.3687 - accuracy: 0.6792 - val_loss: 0.3987 - val_accuracy: 0.6535
# Epoch 18/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.3436 - accuracy: 0.7122 - val_loss: 0.4051 - val_accuracy: 0.6535
# Epoch 19/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.3420 - accuracy: 0.7045 - val_loss: 0.3897 - val_accuracy: 0.7129
# Epoch 20/250
# 29/29 [==============================] - 0s 17ms/step - loss: 0.3306 - accuracy: 0.7178 - val_loss: 0.4115 - val_accuracy: 0.6733
# Epoch 21/250
# 29/29 [==============================] - 0s 17ms/step - loss: 0.3208 - accuracy: 0.7321 - val_loss: 0.3488 - val_accuracy: 0.6832
# Epoch 22/250
# 29/29 [==============================] - 0s 17ms/step - loss: 0.3014 - accuracy: 0.7365 - val_loss: 0.3296 - val_accuracy: 0.7327
# Epoch 23/250
# 29/29 [==============================] - 0s 16ms/step - loss: 0.3020 - accuracy: 0.7475 - val_loss: 0.3766 - val_accuracy: 0.6733
# Epoch 24/250
# 29/29 [==============================] - 0s 16ms/step - loss: 0.2759 - accuracy: 0.7773 - val_loss: 0.4272 - val_accuracy: 0.6733
# Epoch 25/250
# 29/29 [==============================] - 0s 17ms/step - loss: 0.2763 - accuracy: 0.7883 - val_loss: 0.3439 - val_accuracy: 0.7228
# Epoch 26/250
# 29/29 [==============================] - 0s 15ms/step - loss: 0.2684 - accuracy: 0.7905 - val_loss: 0.3557 - val_accuracy: 0.6832
# Epoch 27/250
# 29/29 [==============================] - 0s 15ms/step - loss: 0.2550 - accuracy: 0.7971 - val_loss: 0.3084 - val_accuracy: 0.7624
# Epoch 28/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.2619 - accuracy: 0.7729 - val_loss: 0.3075 - val_accuracy: 0.7327
# Epoch 29/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.2440 - accuracy: 0.8060 - val_loss: 0.3971 - val_accuracy: 0.7129
# Epoch 30/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.2479 - accuracy: 0.8170 - val_loss: 0.3309 - val_accuracy: 0.7525
# Epoch 31/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.2444 - accuracy: 0.8148 - val_loss: 0.3572 - val_accuracy: 0.7030
# Epoch 32/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.2278 - accuracy: 0.8137 - val_loss: 0.3252 - val_accuracy: 0.7228
# Epoch 33/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.2394 - accuracy: 0.8004 - val_loss: 0.3987 - val_accuracy: 0.7030
# Epoch 34/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.2207 - accuracy: 0.8269 - val_loss: 0.3068 - val_accuracy: 0.7426
# Epoch 35/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.2158 - accuracy: 0.8269 - val_loss: 0.3248 - val_accuracy: 0.7327
# Epoch 36/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.1986 - accuracy: 0.8523 - val_loss: 0.3117 - val_accuracy: 0.7525
# Epoch 37/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.2072 - accuracy: 0.8445 - val_loss: 0.2737 - val_accuracy: 0.7822
# Epoch 38/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.1978 - accuracy: 0.8512 - val_loss: 0.3005 - val_accuracy: 0.7525
# Epoch 39/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.1744 - accuracy: 0.8721 - val_loss: 0.2512 - val_accuracy: 0.8317
# Epoch 40/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.1890 - accuracy: 0.8666 - val_loss: 0.3840 - val_accuracy: 0.7327
# Epoch 41/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.1685 - accuracy: 0.8809 - val_loss: 0.2849 - val_accuracy: 0.7921
# Epoch 42/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.1859 - accuracy: 0.8589 - val_loss: 0.3680 - val_accuracy: 0.7327
# Epoch 43/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.1729 - accuracy: 0.8666 - val_loss: 0.3223 - val_accuracy: 0.7624
# Epoch 44/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.1624 - accuracy: 0.8743 - val_loss: 0.3440 - val_accuracy: 0.7228
# Epoch 45/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.1571 - accuracy: 0.8809 - val_loss: 0.2706 - val_accuracy: 0.7624
# Epoch 46/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.1584 - accuracy: 0.8908 - val_loss: 0.2782 - val_accuracy: 0.7822
# Epoch 47/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.1437 - accuracy: 0.8875 - val_loss: 0.4754 - val_accuracy: 0.7129
# Epoch 48/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.1571 - accuracy: 0.8886 - val_loss: 0.3090 - val_accuracy: 0.7822
# Epoch 49/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.1572 - accuracy: 0.8842 - val_loss: 0.2900 - val_accuracy: 0.7624
# Epoch 50/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.1541 - accuracy: 0.8908 - val_loss: 0.2903 - val_accuracy: 0.8119
# Epoch 51/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.1363 - accuracy: 0.8997 - val_loss: 0.2987 - val_accuracy: 0.7525
# Epoch 52/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.1366 - accuracy: 0.9019 - val_loss: 0.2772 - val_accuracy: 0.7822
# Epoch 53/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.1401 - accuracy: 0.8964 - val_loss: 0.2932 - val_accuracy: 0.7624
# Epoch 54/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.1306 - accuracy: 0.9118 - val_loss: 0.2758 - val_accuracy: 0.7624
# Epoch 55/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.1182 - accuracy: 0.9184 - val_loss: 0.2829 - val_accuracy: 0.7822
# Epoch 56/250
# 29/29 [==============================] - 0s 14ms/step - loss: 0.1271 - accuracy: 0.9063 - val_loss: 0.2959 - val_accuracy: 0.8020
# Epoch 57/250
# 29/29 [==============================] - 0s 16ms/step - loss: 0.1074 - accuracy: 0.9228 - val_loss: 0.3205 - val_accuracy: 0.7723
# Epoch 58/250
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0966 - accuracy: 0.9383 - val_loss: 0.2385 - val_accuracy: 0.8119
# Epoch 59/250
# 29/29 [==============================] - 0s 17ms/step - loss: 0.1292 - accuracy: 0.9162 - val_loss: 0.2470 - val_accuracy: 0.8317
# Epoch 60/250
# 29/29 [==============================] - 0s 17ms/step - loss: 0.1216 - accuracy: 0.9107 - val_loss: 0.2514 - val_accuracy: 0.8020
# Epoch 61/250
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0968 - accuracy: 0.9305 - val_loss: 0.2488 - val_accuracy: 0.8218
# Epoch 62/250
# 29/29 [==============================] - 0s 16ms/step - loss: 0.1020 - accuracy: 0.9239 - val_loss: 0.2852 - val_accuracy: 0.8119
# Epoch 63/250
# 29/29 [==============================] - 1s 18ms/step - loss: 0.1069 - accuracy: 0.9228 - val_loss: 0.2855 - val_accuracy: 0.8119
# Epoch 64/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0913 - accuracy: 0.9438 - val_loss: 0.2672 - val_accuracy: 0.8119
# Epoch 65/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.1095 - accuracy: 0.9261 - val_loss: 0.2563 - val_accuracy: 0.8020
# Epoch 66/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0819 - accuracy: 0.9438 - val_loss: 0.3122 - val_accuracy: 0.7921
# Epoch 67/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.1161 - accuracy: 0.9162 - val_loss: 0.2435 - val_accuracy: 0.8218
# Epoch 68/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.0973 - accuracy: 0.9316 - val_loss: 0.3467 - val_accuracy: 0.8119
# Epoch 69/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.1054 - accuracy: 0.9294 - val_loss: 0.2621 - val_accuracy: 0.8020
# Epoch 70/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0950 - accuracy: 0.9294 - val_loss: 0.2622 - val_accuracy: 0.8317
# Epoch 71/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.0974 - accuracy: 0.9405 - val_loss: 0.3108 - val_accuracy: 0.7822
# Epoch 72/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0837 - accuracy: 0.9383 - val_loss: 0.2705 - val_accuracy: 0.8119
# Epoch 73/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0840 - accuracy: 0.9394 - val_loss: 0.2799 - val_accuracy: 0.7921
# Epoch 74/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.0728 - accuracy: 0.9548 - val_loss: 0.2757 - val_accuracy: 0.7921
# Epoch 75/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0883 - accuracy: 0.9427 - val_loss: 0.2595 - val_accuracy: 0.8119
# Epoch 76/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.0918 - accuracy: 0.9372 - val_loss: 0.2914 - val_accuracy: 0.8020
# Epoch 77/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0732 - accuracy: 0.9482 - val_loss: 0.3222 - val_accuracy: 0.8119
# Epoch 78/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0717 - accuracy: 0.9471 - val_loss: 0.2286 - val_accuracy: 0.8416
# Epoch 79/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.0686 - accuracy: 0.9592 - val_loss: 0.3173 - val_accuracy: 0.7921
# Epoch 80/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0640 - accuracy: 0.9548 - val_loss: 0.3102 - val_accuracy: 0.8119
# Epoch 81/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0789 - accuracy: 0.9427 - val_loss: 0.2809 - val_accuracy: 0.8317
# Epoch 82/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0645 - accuracy: 0.9570 - val_loss: 0.2563 - val_accuracy: 0.8515
# Epoch 83/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.0566 - accuracy: 0.9669 - val_loss: 0.3081 - val_accuracy: 0.8020
# Epoch 84/250
# 29/29 [==============================] - 0s 14ms/step - loss: 0.0629 - accuracy: 0.9548 - val_loss: 0.2949 - val_accuracy: 0.8119
# Epoch 85/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0788 - accuracy: 0.9394 - val_loss: 0.3202 - val_accuracy: 0.8119
# Epoch 86/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0599 - accuracy: 0.9559 - val_loss: 0.2676 - val_accuracy: 0.8020
# Epoch 87/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0556 - accuracy: 0.9680 - val_loss: 0.3230 - val_accuracy: 0.7921
# Epoch 88/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.0717 - accuracy: 0.9482 - val_loss: 0.3595 - val_accuracy: 0.7822
# Epoch 89/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0585 - accuracy: 0.9669 - val_loss: 0.3144 - val_accuracy: 0.8020
# Epoch 90/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0615 - accuracy: 0.9592 - val_loss: 0.3659 - val_accuracy: 0.7921
# Epoch 91/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.0722 - accuracy: 0.9504 - val_loss: 0.2882 - val_accuracy: 0.8317
# Epoch 92/250
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0634 - accuracy: 0.9647 - val_loss: 0.3317 - val_accuracy: 0.8020
# Epoch 93/250
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0570 - accuracy: 0.9625 - val_loss: 0.3372 - val_accuracy: 0.8020
# Epoch 94/250
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0694 - accuracy: 0.9559 - val_loss: 0.2656 - val_accuracy: 0.8317
# Epoch 95/250
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0358 - accuracy: 0.9824 - val_loss: 0.2975 - val_accuracy: 0.8119
# Epoch 96/250
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0613 - accuracy: 0.9603 - val_loss: 0.2664 - val_accuracy: 0.8218
# Epoch 97/250
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0568 - accuracy: 0.9581 - val_loss: 0.2559 - val_accuracy: 0.8218
# Epoch 98/250
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0542 - accuracy: 0.9592 - val_loss: 0.2980 - val_accuracy: 0.8119
# Epoch 99/250
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0545 - accuracy: 0.9658 - val_loss: 0.2899 - val_accuracy: 0.8020
# Epoch 100/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.0401 - accuracy: 0.9713 - val_loss: 0.2665 - val_accuracy: 0.8416
# Epoch 101/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0605 - accuracy: 0.9592 - val_loss: 0.3002 - val_accuracy: 0.8218
# Epoch 102/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0382 - accuracy: 0.9746 - val_loss: 0.2958 - val_accuracy: 0.8416
# Epoch 103/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0456 - accuracy: 0.9735 - val_loss: 0.2679 - val_accuracy: 0.8614
# Epoch 104/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0472 - accuracy: 0.9614 - val_loss: 0.3238 - val_accuracy: 0.8218
# Epoch 105/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0416 - accuracy: 0.9757 - val_loss: 0.3485 - val_accuracy: 0.8416
# Epoch 106/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.0380 - accuracy: 0.9746 - val_loss: 0.3479 - val_accuracy: 0.8119
# Epoch 107/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0574 - accuracy: 0.9691 - val_loss: 0.3256 - val_accuracy: 0.8317
# Epoch 108/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0535 - accuracy: 0.9647 - val_loss: 0.3852 - val_accuracy: 0.8020
# Epoch 109/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0518 - accuracy: 0.9658 - val_loss: 0.2774 - val_accuracy: 0.8416
# Epoch 110/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0516 - accuracy: 0.9713 - val_loss: 0.3135 - val_accuracy: 0.8317
# Epoch 111/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.0339 - accuracy: 0.9824 - val_loss: 0.3259 - val_accuracy: 0.8416
# Epoch 112/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.0445 - accuracy: 0.9713 - val_loss: 0.2547 - val_accuracy: 0.8515
# Epoch 113/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0420 - accuracy: 0.9757 - val_loss: 0.3252 - val_accuracy: 0.8218
# Epoch 114/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.0388 - accuracy: 0.9779 - val_loss: 0.2923 - val_accuracy: 0.8317
# Epoch 115/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0384 - accuracy: 0.9779 - val_loss: 0.3302 - val_accuracy: 0.8317
# Epoch 116/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.0280 - accuracy: 0.9846 - val_loss: 0.3323 - val_accuracy: 0.8218
# Epoch 117/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.0410 - accuracy: 0.9735 - val_loss: 0.2752 - val_accuracy: 0.8317
# Epoch 118/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0354 - accuracy: 0.9757 - val_loss: 0.3517 - val_accuracy: 0.8218
# Epoch 119/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.0434 - accuracy: 0.9724 - val_loss: 0.2700 - val_accuracy: 0.8416
# Epoch 120/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.0393 - accuracy: 0.9746 - val_loss: 0.2927 - val_accuracy: 0.8218
# Epoch 121/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0364 - accuracy: 0.9779 - val_loss: 0.3112 - val_accuracy: 0.8119
# Epoch 122/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0368 - accuracy: 0.9813 - val_loss: 0.2770 - val_accuracy: 0.8218
# Epoch 123/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0280 - accuracy: 0.9835 - val_loss: 0.2842 - val_accuracy: 0.8614
# Epoch 124/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0511 - accuracy: 0.9647 - val_loss: 0.3000 - val_accuracy: 0.8317
# Epoch 125/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.0451 - accuracy: 0.9779 - val_loss: 0.4523 - val_accuracy: 0.7624
# Epoch 126/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0580 - accuracy: 0.9713 - val_loss: 0.2761 - val_accuracy: 0.8317
# Epoch 127/250
# 29/29 [==============================] - 1s 19ms/step - loss: 0.0236 - accuracy: 0.9879 - val_loss: 0.2451 - val_accuracy: 0.8515
# Epoch 128/250
# 29/29 [==============================] - 1s 20ms/step - loss: 0.0367 - accuracy: 0.9768 - val_loss: 0.3923 - val_accuracy: 0.7921
# Epoch 129/250
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0269 - accuracy: 0.9879 - val_loss: 0.2888 - val_accuracy: 0.8317
# Epoch 130/250
# 29/29 [==============================] - 1s 17ms/step - loss: 0.0376 - accuracy: 0.9846 - val_loss: 0.2963 - val_accuracy: 0.8416
# Epoch 131/250
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0358 - accuracy: 0.9802 - val_loss: 0.4320 - val_accuracy: 0.7822
# Epoch 132/250
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0223 - accuracy: 0.9846 - val_loss: 0.2628 - val_accuracy: 0.8614
# Epoch 133/250
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0360 - accuracy: 0.9791 - val_loss: 0.3385 - val_accuracy: 0.8020
# Epoch 134/250
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0446 - accuracy: 0.9791 - val_loss: 0.3354 - val_accuracy: 0.8119
# Epoch 135/250
# 29/29 [==============================] - 0s 14ms/step - loss: 0.0355 - accuracy: 0.9757 - val_loss: 0.3299 - val_accuracy: 0.8515
# Epoch 136/250
# 29/29 [==============================] - 0s 14ms/step - loss: 0.0253 - accuracy: 0.9868 - val_loss: 0.2906 - val_accuracy: 0.8515
# Epoch 137/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0294 - accuracy: 0.9846 - val_loss: 0.3796 - val_accuracy: 0.8020
# Epoch 138/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0336 - accuracy: 0.9779 - val_loss: 0.3749 - val_accuracy: 0.7723
# Epoch 139/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0262 - accuracy: 0.9857 - val_loss: 0.3839 - val_accuracy: 0.8119
# Epoch 140/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0395 - accuracy: 0.9724 - val_loss: 0.3646 - val_accuracy: 0.8317
# Epoch 141/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0360 - accuracy: 0.9791 - val_loss: 0.3101 - val_accuracy: 0.8515
# Epoch 142/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0219 - accuracy: 0.9890 - val_loss: 0.3129 - val_accuracy: 0.8317
# Epoch 143/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0239 - accuracy: 0.9857 - val_loss: 0.3361 - val_accuracy: 0.8614
# Epoch 144/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0303 - accuracy: 0.9835 - val_loss: 0.3163 - val_accuracy: 0.8515
# Epoch 145/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0264 - accuracy: 0.9846 - val_loss: 0.2666 - val_accuracy: 0.8614
# Epoch 146/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0384 - accuracy: 0.9746 - val_loss: 0.3620 - val_accuracy: 0.8119
# Epoch 147/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0333 - accuracy: 0.9868 - val_loss: 0.3226 - val_accuracy: 0.8416
# Epoch 148/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0268 - accuracy: 0.9824 - val_loss: 0.2653 - val_accuracy: 0.8713
# Epoch 149/250
# 29/29 [==============================] - 1s 20ms/step - loss: 0.0424 - accuracy: 0.9779 - val_loss: 0.3042 - val_accuracy: 0.8515
# Epoch 150/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0247 - accuracy: 0.9879 - val_loss: 0.3250 - val_accuracy: 0.8614
# Epoch 151/250
# 29/29 [==============================] - 1s 20ms/step - loss: 0.0291 - accuracy: 0.9824 - val_loss: 0.2995 - val_accuracy: 0.8317
# Epoch 152/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0290 - accuracy: 0.9824 - val_loss: 0.2876 - val_accuracy: 0.8416
# Epoch 153/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0246 - accuracy: 0.9824 - val_loss: 0.3054 - val_accuracy: 0.8218
# Epoch 154/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0283 - accuracy: 0.9791 - val_loss: 0.3017 - val_accuracy: 0.8317
# Epoch 155/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0300 - accuracy: 0.9802 - val_loss: 0.3153 - val_accuracy: 0.8416
# Epoch 156/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0335 - accuracy: 0.9813 - val_loss: 0.2866 - val_accuracy: 0.8614
# Epoch 157/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0281 - accuracy: 0.9868 - val_loss: 0.2986 - val_accuracy: 0.8713
# Epoch 158/250
# 29/29 [==============================] - 0s 14ms/step - loss: 0.0237 - accuracy: 0.9879 - val_loss: 0.2904 - val_accuracy: 0.8515
# Epoch 159/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0287 - accuracy: 0.9802 - val_loss: 0.2524 - val_accuracy: 0.8317
# Epoch 160/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0242 - accuracy: 0.9879 - val_loss: 0.3045 - val_accuracy: 0.8416
# Epoch 161/250
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0263 - accuracy: 0.9857 - val_loss: 0.2788 - val_accuracy: 0.8515
# Epoch 162/250
# 29/29 [==============================] - 1s 19ms/step - loss: 0.0180 - accuracy: 0.9901 - val_loss: 0.3520 - val_accuracy: 0.7921
# Epoch 163/250
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0191 - accuracy: 0.9890 - val_loss: 0.3522 - val_accuracy: 0.7921
# Epoch 164/250
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0269 - accuracy: 0.9813 - val_loss: 0.3008 - val_accuracy: 0.8218
# Epoch 165/250
# 29/29 [==============================] - 1s 17ms/step - loss: 0.0277 - accuracy: 0.9835 - val_loss: 0.3291 - val_accuracy: 0.8020
# Epoch 166/250
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0172 - accuracy: 0.9923 - val_loss: 0.4229 - val_accuracy: 0.8119
# Epoch 167/250
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0246 - accuracy: 0.9868 - val_loss: 0.3727 - val_accuracy: 0.7921
# Epoch 168/250
# 29/29 [==============================] - 1s 17ms/step - loss: 0.0210 - accuracy: 0.9890 - val_loss: 0.3847 - val_accuracy: 0.8317
# Epoch 169/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0171 - accuracy: 0.9901 - val_loss: 0.3646 - val_accuracy: 0.8317
# Epoch 170/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0088 - accuracy: 0.9978 - val_loss: 0.4070 - val_accuracy: 0.8317
# Epoch 171/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0414 - accuracy: 0.9757 - val_loss: 0.3036 - val_accuracy: 0.8416
# Epoch 172/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0223 - accuracy: 0.9901 - val_loss: 0.3671 - val_accuracy: 0.8119
# Epoch 173/250
# 29/29 [==============================] - 0s 14ms/step - loss: 0.0257 - accuracy: 0.9868 - val_loss: 0.3431 - val_accuracy: 0.7921
# Epoch 174/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0164 - accuracy: 0.9923 - val_loss: 0.3993 - val_accuracy: 0.8317
# Epoch 175/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0262 - accuracy: 0.9879 - val_loss: 0.3144 - val_accuracy: 0.8416
# Epoch 176/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0136 - accuracy: 0.9912 - val_loss: 0.3251 - val_accuracy: 0.8515
# Epoch 177/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0211 - accuracy: 0.9879 - val_loss: 0.3596 - val_accuracy: 0.8317
# Epoch 178/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0282 - accuracy: 0.9824 - val_loss: 0.3525 - val_accuracy: 0.8416
# Epoch 179/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0309 - accuracy: 0.9813 - val_loss: 0.3032 - val_accuracy: 0.8218
# Epoch 180/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0152 - accuracy: 0.9923 - val_loss: 0.3206 - val_accuracy: 0.8416
# Epoch 181/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0241 - accuracy: 0.9890 - val_loss: 0.3345 - val_accuracy: 0.8119
# Epoch 182/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0178 - accuracy: 0.9945 - val_loss: 0.3681 - val_accuracy: 0.8416
# Epoch 183/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0226 - accuracy: 0.9912 - val_loss: 0.2440 - val_accuracy: 0.8317
# Epoch 184/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0174 - accuracy: 0.9890 - val_loss: 0.3932 - val_accuracy: 0.8218
# Epoch 185/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0253 - accuracy: 0.9868 - val_loss: 0.3797 - val_accuracy: 0.8119
# Epoch 186/250
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0125 - accuracy: 0.9934 - val_loss: 0.4020 - val_accuracy: 0.8416
# Epoch 187/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0179 - accuracy: 0.9879 - val_loss: 0.3580 - val_accuracy: 0.8218
# Epoch 188/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0155 - accuracy: 0.9923 - val_loss: 0.3258 - val_accuracy: 0.8416
# Epoch 189/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0276 - accuracy: 0.9835 - val_loss: 0.4424 - val_accuracy: 0.7921
# Epoch 190/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0199 - accuracy: 0.9868 - val_loss: 0.4329 - val_accuracy: 0.8317
# Epoch 191/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0275 - accuracy: 0.9813 - val_loss: 0.2977 - val_accuracy: 0.8020
# Epoch 192/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0280 - accuracy: 0.9835 - val_loss: 0.3433 - val_accuracy: 0.8218
# Epoch 193/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0272 - accuracy: 0.9824 - val_loss: 0.2817 - val_accuracy: 0.8218
# Epoch 194/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0199 - accuracy: 0.9879 - val_loss: 0.3794 - val_accuracy: 0.8416
# Epoch 195/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0262 - accuracy: 0.9890 - val_loss: 0.4405 - val_accuracy: 0.8020
# Epoch 196/250
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0265 - accuracy: 0.9802 - val_loss: 0.3780 - val_accuracy: 0.7921
# Epoch 197/250
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0143 - accuracy: 0.9956 - val_loss: 0.3447 - val_accuracy: 0.8317
# Epoch 198/250
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0264 - accuracy: 0.9879 - val_loss: 0.3961 - val_accuracy: 0.8218
# Epoch 199/250
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0172 - accuracy: 0.9901 - val_loss: 0.4578 - val_accuracy: 0.8218
# Epoch 200/250
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0326 - accuracy: 0.9835 - val_loss: 0.3718 - val_accuracy: 0.8416
# Epoch 201/250
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0089 - accuracy: 0.9956 - val_loss: 0.3982 - val_accuracy: 0.8515
# Epoch 202/250
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0162 - accuracy: 0.9945 - val_loss: 0.3471 - val_accuracy: 0.8317
# Epoch 203/250
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0229 - accuracy: 0.9857 - val_loss: 0.4021 - val_accuracy: 0.8416
# Epoch 204/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0216 - accuracy: 0.9879 - val_loss: 0.3433 - val_accuracy: 0.8317
# Epoch 205/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0114 - accuracy: 0.9945 - val_loss: 0.4672 - val_accuracy: 0.8020
# Epoch 206/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0211 - accuracy: 0.9857 - val_loss: 0.3226 - val_accuracy: 0.8515
# Epoch 207/250
# 29/29 [==============================] - 0s 14ms/step - loss: 0.0274 - accuracy: 0.9857 - val_loss: 0.3077 - val_accuracy: 0.8317
# Epoch 208/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0117 - accuracy: 0.9934 - val_loss: 0.3332 - val_accuracy: 0.8218
# Epoch 209/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0206 - accuracy: 0.9879 - val_loss: 0.3292 - val_accuracy: 0.8416
# Epoch 210/250
# 29/29 [==============================] - 0s 14ms/step - loss: 0.0064 - accuracy: 0.9978 - val_loss: 0.3757 - val_accuracy: 0.8317
# Epoch 211/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0094 - accuracy: 0.9923 - val_loss: 0.2882 - val_accuracy: 0.8614
# Epoch 212/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0199 - accuracy: 0.9912 - val_loss: 0.3492 - val_accuracy: 0.8020
# Epoch 213/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0160 - accuracy: 0.9890 - val_loss: 0.4018 - val_accuracy: 0.8218
# Epoch 214/250
# 29/29 [==============================] - 0s 14ms/step - loss: 0.0152 - accuracy: 0.9912 - val_loss: 0.3334 - val_accuracy: 0.8317
# Epoch 215/250
# 29/29 [==============================] - 0s 14ms/step - loss: 0.0197 - accuracy: 0.9923 - val_loss: 0.4393 - val_accuracy: 0.8119
# Epoch 216/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0203 - accuracy: 0.9890 - val_loss: 0.3849 - val_accuracy: 0.8317
# Epoch 217/250
# 29/29 [==============================] - 0s 14ms/step - loss: 0.0114 - accuracy: 0.9956 - val_loss: 0.3206 - val_accuracy: 0.8614
# Epoch 218/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0091 - accuracy: 0.9934 - val_loss: 0.3262 - val_accuracy: 0.8614
# Epoch 219/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0131 - accuracy: 0.9923 - val_loss: 0.3559 - val_accuracy: 0.8218
# Epoch 220/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0137 - accuracy: 0.9912 - val_loss: 0.4651 - val_accuracy: 0.7624
# Epoch 221/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0152 - accuracy: 0.9923 - val_loss: 0.4274 - val_accuracy: 0.8218
# Epoch 222/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0338 - accuracy: 0.9846 - val_loss: 0.3564 - val_accuracy: 0.8119
# Epoch 223/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0223 - accuracy: 0.9879 - val_loss: 0.2957 - val_accuracy: 0.8515
# Epoch 224/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0233 - accuracy: 0.9857 - val_loss: 0.3209 - val_accuracy: 0.8416
# Epoch 225/250
# 29/29 [==============================] - 0s 14ms/step - loss: 0.0132 - accuracy: 0.9956 - val_loss: 0.3125 - val_accuracy: 0.8515
# Epoch 226/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0131 - accuracy: 0.9912 - val_loss: 0.4506 - val_accuracy: 0.8317
# Epoch 227/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0172 - accuracy: 0.9912 - val_loss: 0.3514 - val_accuracy: 0.8317
# Epoch 228/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0196 - accuracy: 0.9890 - val_loss: 0.2743 - val_accuracy: 0.8416
# Epoch 229/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0227 - accuracy: 0.9879 - val_loss: 0.4273 - val_accuracy: 0.7921
# Epoch 230/250
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0170 - accuracy: 0.9923 - val_loss: 0.4083 - val_accuracy: 0.8119
# Epoch 231/250
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0168 - accuracy: 0.9923 - val_loss: 0.3774 - val_accuracy: 0.8218
# Epoch 232/250
# 29/29 [==============================] - 1s 17ms/step - loss: 0.0159 - accuracy: 0.9934 - val_loss: 0.3329 - val_accuracy: 0.8218
# Epoch 233/250
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0052 - accuracy: 0.9989 - val_loss: 0.3144 - val_accuracy: 0.8317
# Epoch 234/250
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0206 - accuracy: 0.9857 - val_loss: 0.3969 - val_accuracy: 0.8119
# Epoch 235/250
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0216 - accuracy: 0.9934 - val_loss: 0.4018 - val_accuracy: 0.8317
# Epoch 236/250
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0138 - accuracy: 0.9945 - val_loss: 0.3537 - val_accuracy: 0.8317
# Epoch 237/250
# 29/29 [==============================] - 1s 19ms/step - loss: 0.0155 - accuracy: 0.9923 - val_loss: 0.2661 - val_accuracy: 0.8416
# Epoch 238/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0213 - accuracy: 0.9901 - val_loss: 0.3500 - val_accuracy: 0.8515
# Epoch 239/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0175 - accuracy: 0.9923 - val_loss: 0.3213 - val_accuracy: 0.8317
# Epoch 240/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0110 - accuracy: 0.9945 - val_loss: 0.3544 - val_accuracy: 0.8614
# Epoch 241/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0194 - accuracy: 0.9868 - val_loss: 0.3709 - val_accuracy: 0.8119
# Epoch 242/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0162 - accuracy: 0.9890 - val_loss: 0.3958 - val_accuracy: 0.8317
# Epoch 243/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0270 - accuracy: 0.9857 - val_loss: 0.3495 - val_accuracy: 0.8416
# Epoch 244/250
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0057 - accuracy: 0.9978 - val_loss: 0.4018 - val_accuracy: 0.8119
# Epoch 245/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0097 - accuracy: 0.9923 - val_loss: 0.3353 - val_accuracy: 0.8416
# Epoch 246/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0124 - accuracy: 0.9901 - val_loss: 0.3138 - val_accuracy: 0.8614
# Epoch 247/250
# 29/29 [==============================] - 0s 14ms/step - loss: 0.0125 - accuracy: 0.9901 - val_loss: 0.2838 - val_accuracy: 0.8911
# Epoch 248/250
# 29/29 [==============================] - 0s 14ms/step - loss: 0.0279 - accuracy: 0.9879 - val_loss: 0.3112 - val_accuracy: 0.8515
# Epoch 249/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0083 - accuracy: 0.9934 - val_loss: 0.4406 - val_accuracy: 0.8218
# Epoch 250/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0098 - accuracy: 0.9945 - val_loss: 0.3776 - val_accuracy: 0.8416
# Saving trained model...
# Testing...
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 4/4 [==============================] - 1s 7ms/step
# [[29  4  1  1]
#  [ 3 17  0  1]
#  [ 1  1 28  1]
#  [ 2  0  3 20]]
# [[0.83 0.11 0.03 0.03]
#  [0.14 0.81 0.   0.05]
#  [0.03 0.03 0.9  0.03]
#  [0.08 0.   0.12 0.8 ]]
# 83.93%
# 新的结果文件夹名称为： result_MultiAttention_LSTM_1层Transformer_BCE_epoch250_batchsize32_lr0.005_83.93%
# 程序执行时间为：154.87秒

# %%
# 定位到指定路径下
import os
os.chdir('/content/drive/MyDrive/Colab_Notebooks/RNN-CAP')
print(os.getcwd())

# 打印版本
import sys
import tensorflow as tf

print("Python 版本:", sys.version)
print("TensorFlow 版本:", tf.__version__)

# !pip install xlwt
# !pip install matplotlib

# %%
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_categorical_crossentropy_epoch30.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_categorical_crossentropy_epoch250.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_categorical_crossentropy_epoch50.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_categorical_crossentropy_epoch100.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_categorical_crossentropy_epoch150.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_categorical_crossentropy_epoch200.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_squared_error_epoch30.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_squared_error_epoch50.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_squared_error_epoch100.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_squared_error_epoch150.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_squared_error_epoch200.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_squared_error_epoch250.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_absolute_error_epoch30.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_absolute_error_epoch50.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_absolute_error_epoch100.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_absolute_error_epoch150.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_absolute_error_epoch200.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_absolute_error_epoch250.py

# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_binary_crossentropy_epoch30.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_binary_crossentropy_epoch50.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_binary_crossentropy_epoch100.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_binary_crossentropy_epoch150.py

#!python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_binary_crossentropy_epoch200.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_binary_crossentropy_epoch250.py
