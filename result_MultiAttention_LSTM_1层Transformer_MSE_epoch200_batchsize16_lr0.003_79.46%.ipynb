# %% [markdown]
# <a href="https://colab.research.google.com/github/zuo-liangliang/fcn.berkeleyvision.org/blob/master/result_MultiAttention_LSTM_1%E5%B1%82Transformer_MSE_epoch200_batchsize16_lr0.003_79.46%25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import zipfile

# 定义源文件夹路径和目标 zip 文件夹路径
# source_folder = '/content/drive/MyDrive/Colab_Notebooks/528BVP-acnt2'
source_folder = '/content/drive/MyDrive/AugustResult'
# target_zip_folder = '/content/drive/MyDrive/Colab_Notebooks/zip_folder'
# target_zip_folder = '/content/drive/MyDrive/Colab_Notebooks/528BVP-acnt2/0827zip_folder'
target_zip_folder = '/content/drive/MyDrive/AugustResult/0907_月月账号zip_folder'

# 确保目标 zip 文件夹存在
os.makedirs(target_zip_folder, exist_ok=True)

# 获取源文件夹中以 "result" 开头的文件夹列表
folder_list = [folder for folder in os.listdir(source_folder) if os.path.isdir(os.path.join(source_folder, folder)) and folder.startswith("result")]

# 创建一个大的 zip 文件
with zipfile.ZipFile(os.path.join(target_zip_folder, '0907月月_all_folders.zip'), 'w', zipfile.ZIP_DEFLATED) as zipf:
    # 遍历文件夹列表，逐个压缩为 zip 文件
    for folder in folder_list:
        folder_path = os.path.join(source_folder, folder)

        # 遍历文件夹中的所有文件和子文件夹，并逐个添加到大的 zip 文件中
        for root, dirs, files in os.walk(folder_path):
            for file in files:
                file_path = os.path.join(root, file)
                zipf.write(file_path, os.path.relpath(file_path, source_folder))

print("所有文件夹已压缩为一个大的 zip 文件！")
# Out:
# 所有文件夹已压缩为一个大的 zip 文件！

# %%
import shutil
import os
# 指定要删除的文件夹路径
folder_path = '/content/drive/MyDrive/Colab_Notebooks/528BVP-acnt2/user14' #替换为你的文件夹路径

# 确保要删除的是一个目录而不是文件
assert os.path.isdir(folder_path), f"{folder_path} 不是一个目录"

# 递归删除文件夹下的所有文件和子文件夹
shutil.rmtree(folder_path)

# %%
# 解压指定文件夹到某一路径下
import zipfile

file_path = '/content/drive/MyDrive/Colab_Notebooks/528BVP-acnt2/528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4.zip'
extract_path = '/content/drive/MyDrive/Colab_Notebooks/528BVP-acnt2/528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4'

with zipfile.ZipFile(file_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# %%
# 定位到指定路径下
import os
# os.chdir('/content/drive/MyDrive/SeptemberResult/result_LSTM')
os.chdir('/content/drive/MyDrive/SeptemberResult/result_MultiAttention_LSTM_1层Transformer')
print(os.getcwd())
# Out:
# /content/drive/MyDrive/SeptemberResult/result_MultiAttention_LSTM_1层Transformer

# %%
# result_MultiAttention_LSTM_1层Transformer

from keras.callbacks import Callback
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay

from __future__ import print_function

import time
import os,sys
import numpy as np
import pandas as pd
import scipy.io as scio
import tensorflow as tf
tf.compat.v1.keras.backend.set_session
import keras
from keras.layers import Input, GRU, LSTM, Dense, Flatten, Dropout, Conv2D, Conv3D, MaxPooling2D, MaxPooling3D, TimeDistributed
from keras.models import Model, load_model
import keras.backend as K
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split

# Parameters
use_existing_model = False
fraction_for_test = 0.1
data_dir = '/content/drive/MyDrive/Colab_Notebooks/528BVP-acnt2/528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4/'
# data_dir = '/content/drive/MyDrive/new528BVP/528[-1,1]长度20-分辨率15_acnt2_sample_rate5000__剔14_改6为4/'

fraction_for_test = 0.1
#ALL_MOTION = [1,2,3,4,5,6]
ALL_MOTION = [2,3,4,5]
N_MOTION = len(ALL_MOTION)
T_MAX = 0
n_epochs = 200  #最优的是100；第2优的是200，原始是50 #修改点1
f_dropout_ratio = 0.5
n_gru_hidden_units = 128
n_batch_size = 16     #原始是32-->16
f_learning_rate = 0.003  #原始是0.001-->0.002

def normalize_data(data_1):
    # data(ndarray)=>data_norm(ndarray): [20,20,T]=>[20,20,T]
    data_1_max = np.concatenate((data_1.max(axis=0),data_1.max(axis=1)),axis=0).max(axis=0)
    data_1_min = np.concatenate((data_1.min(axis=0),data_1.min(axis=1)),axis=0).min(axis=0)
    if (len(np.where((data_1_max - data_1_min) == 0)[0]) > 0):
        return data_1
    data_1_max_rep = np.tile(data_1_max,(data_1.shape[0],data_1.shape[1],1))
    data_1_min_rep = np.tile(data_1_min,(data_1.shape[0],data_1.shape[1],1))
    data_1_norm = (data_1 - data_1_min_rep) / (data_1_max_rep - data_1_min_rep)
    return  data_1_norm

def zero_padding(data, T_MAX):
    # data(list)=>data_pad(ndarray): [20,20,T1/T2/...]=>[20,20,T_MAX]
    data_pad = []
    for i in range(len(data)):
        t = np.array(data[i]).shape[2]
        data_pad.append(np.pad(data[i], ((0,0),(0,0),(T_MAX - t,0)), 'constant', constant_values = 0).tolist())
    return np.array(data_pad)

def onehot_encoding(label, num_class):
    # label(list)=>_label(ndarray): [N,]=>[N,num_class]
    label = np.array(label).astype('int32')
    # assert (np.arange(0,np.unique(label).size)==np.unique(label)).prod()    # Check label from 0 to N
    label = np.squeeze(label)
    # _label = np.eye(num_class)[label-1]     # from label to onehot
    _label = np.eye(num_class)[label-2]   #修改点2
    return _label

def load_data(path_to_data, motion_sel):
    global T_MAX
    data = []
    label = []
    for data_root, data_dirs, data_files in os.walk(path_to_data):
        for data_file_name in data_files:

            file_path = os.path.join(data_root,data_file_name)
            try:
                data_1 = scio.loadmat(file_path)['velocity_spectrum_ro']
                label_1 = int(data_file_name.split('-')[1])
                #location = int(data_file_name.split('-')[2])
                #orientation = int(data_file_name.split('-')[3])
                #repetition = int(data_file_name.split('-')[4])
                repetition = int(data_file_name.split('-')[2])  #修改点3

                # Select Motion
                if (label_1 not in motion_sel):
                    continue

                # Select Location
                # if (location not in [1,2,3,5]):
                #     continue

                # Select Orientation
                # if (orientation not in [1,2,4,5]):
                #     continue

                # Normalization
                data_normed_1 = normalize_data(data_1)

                # Update T_MAX
                if T_MAX < np.array(data_1).shape[2]:
                    T_MAX = np.array(data_1).shape[2]
            except Exception:
                continue

            # Save List
            data.append(data_normed_1.tolist())
            label.append(label_1)
                # Zero-padding
    data = zero_padding(data, T_MAX)

    # Swap axes
    data = np.swapaxes(np.swapaxes(data, 1, 3), 2, 3)   # [N,20,20',T_MAX]=>[N,T_MAX,20,20']
    data = np.expand_dims(data, axis=-1)    # [N,T_MAX,20,20]=>[N,T_MAX,20,20,1]

    # Convert label to ndarray
    label = np.array(label)

    # data(ndarray): [N,T_MAX,20,20,1], label(ndarray): [N,N_MOTION]
    return data, label

# 构建符合输入形状为 (None, 20, 15, 15, 1) 和输出形状为 (None, 4) 的  模型：
from keras.layers import MultiHeadAttention, LayerNormalization  #加Transformer修改点1
num_transformer_layers = 1  # 设置Transformer层数 #加Transformer修改点2  2层-->1层

#加Transformer修改点3
def transformer_layer(inputs, hidden_units, dropout_rate):
    # Self-attention
    attention_output = MultiHeadAttention(
        num_heads=8, key_dim=hidden_units // 8
    )(inputs, inputs)
    attention_output = Dropout(dropout_rate)(attention_output)
    attention_output = LayerNormalization()(attention_output + inputs)

    # Feed-forward network
    ffn = Dense(hidden_units, activation="relu")(attention_output)
    ffn = Dense(hidden_units)(ffn)
    ffn = Dropout(dropout_rate)(ffn)
    ffn = LayerNormalization()(ffn)

    return ffn

#加Transformer修改点4
def assemble_model(input_shape, n_class):
    model_input = Input(shape=input_shape, dtype='float32', name='name_model_input')    # (@,T_MAX,20,20,1)

    # Feature extraction part
    x = TimeDistributed(Conv2D(16,kernel_size=(5,5),activation='relu',data_format='channels_last',\
        input_shape=input_shape))(model_input)   # (@,T_MAX,20,20,1)=>(@,T_MAX,16,16,16)
    x = TimeDistributed(MaxPooling2D(pool_size=(2,2)))(x)    # (@,T_MAX,16,16,16)=>(@,T_MAX,8,8,16)
    x = TimeDistributed(Flatten())(x)   # (@,T_MAX,8,8,16)=>(@,T_MAX,8*8*16)
    x = TimeDistributed(Dense(64,activation='relu'))(x) # (@,T_MAX,8*8*16)=>(@,T_MAX,64)
    x = TimeDistributed(Dropout(f_dropout_ratio))(x)
    x = TimeDistributed(Dense(64,activation='relu'))(x) # (@,T_MAX,64)=>(@,T_MAX,64)

    # Add transformer layers
    for _ in range(num_transformer_layers):
        #x = transformer_layer(x, hidden_units=n_gru_hidden_units, dropout_rate=f_dropout_ratio)
        x = transformer_layer(x, hidden_units=64, dropout_rate=f_dropout_ratio)  # 修改点1
    x = LSTM(n_gru_hidden_units,return_sequences=False)(x)  # (@,T_MAX,64)=>(@,128)
    x = Dropout(f_dropout_ratio)(x)
    model_output = Dense(n_class, activation='softmax', name='name_model_output')(x)  # (@,128)=>(@,n_class)

    # Create the model
    # Model compiling
    model = Model(inputs=model_input, outputs=model_output)
    model.compile(optimizer=keras.optimizers.RMSprop(lr=f_learning_rate),
                    # loss='categorical_crossentropy', # 将损失函数改为多类别交叉熵损失函数 最优的是CCE
                    loss='mean_squared_error',  # 将损失函数改为均方误差 第2优的是MSE
                    # loss='mean_absolute_error',  # 将损失函数改为平均绝对误差
                    # loss='binary_crossentropy',  # 将损失函数改为对数损失函数
                    metrics=['accuracy']
                )
    return model

# 改
#model_type = '双层LSTM'
#model_type = 'LSTM'
#model_type = 'BiLSTM'
model_type = 'MultiAttention_LSTM_1层Transformer'

# 创建结果文件夹
# result_folder = f'result_528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_GRU_改costfunction为mse_epoch200' # 每次都要改
# result_folder = f'result_528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_{model_type}_categorical_crossentropy_epoch{n_epochs}'
# result_folder = f'result_528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_{model_type}_mean_squared_error_epoch{n_epochs}'
# result_folder = f'result_528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_{model_type}_mean_absolute_error_epoch{n_epochs}'
# result_folder = f'result_528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_{model_type}_binary_crossentropy_epoch{n_epochs}'

# result_folder = f'result_{model_type}_CCE_epoch{n_epochs}_batchsize{n_batch_size}_lr{f_learning_rate}'
result_folder = f'result_{model_type}_MSE_epoch{n_epochs}_batchsize{n_batch_size}_lr{f_learning_rate}'

os.makedirs(result_folder, exist_ok=True)

# %%
# Let's BEGIN >>>>
start_time = time.time()  # 记录程序开始时间

# 获取可见的GPU设备列表
# visible_gpus = tf.config.experimental.list_physical_devices('GPU')
# 检查是否存在可见的GPU设备
# if len(visible_gpus) < 1:
    # print('No GPU available')
    # exit(0)
# 设置使用第一个可见的GPU设备
# os.environ["CUDA_VISIBLE_DEVICES"] = str(visible_gpus[0].index)
# 配置GPU选项
# gpu_config = tf.config.experimental.set_memory_growth(visible_gpus[0], True)
# 创建一个会话并应用GPU配置
# sess = tf.compat.v1.Session(config=gpu_config)
# tf.compat.v1.keras.backend.set_session(sess)
# tf.random.set_seed(1)

# 获取可见的 GPU 设备列表
visible_gpus = tf.config.experimental.list_physical_devices('GPU')
if len(visible_gpus) > 0:
    # 如果有可见的 GPU 设备，设置 TensorFlow 在 GPU 上运行
    tf.config.set_visible_devices(visible_gpus, 'GPU')
    gpu_config = tf.config.experimental.set_memory_growth(visible_gpus[0], True)
    sess = tf.compat.v1.Session(config=gpu_config)
    tf.compat.v1.keras.backend.set_session(sess)
    print('GPU available')
else:
    # 如果没有可见的 GPU 设备，设置 TensorFlow 在 CPU 上运行
    tf.config.set_visible_devices([], 'GPU')
    sess = tf.compat.v1.Session()
    print('No GPU available')

# Load data
data, label = load_data(data_dir, ALL_MOTION)
print('\nLoaded dataset of ' + str(label.shape[0]) + ' samples, each sized ' + str(data[0,:,:].shape) + '\n')

# Split train and test
[data_train, data_test, label_train, label_test] = train_test_split(data, label, test_size=fraction_for_test)
print('\nTrain on ' + str(label_train.shape[0]) + ' samples\n' +\
    'Test on ' + str(label_test.shape[0]) + ' samples\n')

# One-hot encoding for train data
label_train = onehot_encoding(label_train, N_MOTION)

# Load or fabricate model
if use_existing_model:
    model = load_model('model_widar3_trained.h5')
    model.summary()
else:
    #model = assemble_model(input_shape=(T_MAX, 20, 20, 1), n_class=N_MOTION)
    model = assemble_model(input_shape=(T_MAX, 15, 15, 1), n_class=N_MOTION) #修改点4
    model.summary()

class AccuracyLossHistory(Callback):
    def on_train_begin(self, logs={}):
        self.acc = []
        self.loss = []
        self.val_acc = []
        self.val_loss = []

    def on_epoch_end(self, epoch, logs={}):
        self.acc.append(logs.get('accuracy'))
        self.loss.append(logs.get('loss'))
        self.val_acc.append(logs.get('val_accuracy'))
        self.val_loss.append(logs.get('val_loss'))

history = AccuracyLossHistory()

model.fit({'name_model_input': data_train},{'name_model_output': label_train},
          batch_size=n_batch_size,
          epochs=n_epochs,
          verbose=1,
          validation_split=0.1, shuffle=True, callbacks=[history])
print('Saving trained model...')
#model.save('model_widar3_trained.h5')
model.save(f'{result_folder}/model.h5')  # 改动

# Testing...
print('Testing...')
label_test_pred = model.predict(data_test)
# label_test_pred = np.argmax(label_test_pred, axis = -1) + 1
label_test_pred = np.argmax(label_test_pred, axis = -1) + 2 #修改点5

# Confusion Matrix
cm = confusion_matrix(label_test, label_test_pred)
print(cm)
cm = cm.astype('float')/cm.sum(axis=1)[:, np.newaxis]
cm = np.around(cm, decimals=2)
print(cm)
#cm_display = ConfusionMatrixDisplay(cm, display_labels=range(1, N_MOTION+1)).plot()
#cm_display = ConfusionMatrixDisplay(cm, display_labels=range(4, N_MOTION+3)).plot() #2345 lebel-2  4567 4=2+2  7=长度4+3
cm_display = ConfusionMatrixDisplay(cm, display_labels=range(2, N_MOTION+2)).plot() #2345 lebel-2  4567 4=2+2  7=长度4+3
plt.show()
plt.savefig(f'{result_folder}/cm.png') # 新增点1 保存混淆矩阵结果2023.09.11

# Accuracy 新增百分号
test_accuracy = np.sum(label_test == label_test_pred) / (label_test.shape[0])
#print(test_accuracy)
test_accuracy_percentage = test_accuracy * 100
test_accuracy_str = f"{test_accuracy_percentage:.2f}%"
print(test_accuracy_str)

df_accuracy = pd.DataFrame({'Test Accuracy': [test_accuracy]})
df_accuracy.to_excel(f'{result_folder}/{test_accuracy_str}.xlsx', index=False) ## 新增点2 保存测试集平均准确率结果2023.09.11


df = pd.DataFrame({
    'Epoch': range(1, n_epochs+1),
    'Train Accuracy': history.acc,
    'Train Loss': history.loss,
    'Validation Accuracy': history.val_acc,
    'Validation Loss': history.val_loss
})

# df.to_excel('accuracy_l'''  '''oss.xlsx', index=False)
# 保存准确率和损失数据到Excel表格中
df.to_excel(f'{result_folder}/accuracy_loss.xlsx', index=False) #改动

plt.plot(range(1, n_epochs+1), history.acc, label='Train Accuracy')
plt.plot(range(1, n_epochs+1), history.loss, label='Train Loss')
plt.plot(range(1, n_epochs+1), history.val_acc, label='Validation Accuracy')
plt.plot(range(1, n_epochs+1), history.val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.legend()
plt.savefig(f'{result_folder}/plot.png')
plt.show()

# 新增 修改文件名 并打印新的文件名
new_result_folder = result_folder + f'_{test_accuracy_str}'
os.rename(result_folder, new_result_folder)
result_folder = new_result_folder

print("新的结果文件夹名称为：", result_folder)

end_time = time.time()  # 记录程序结束时间
duration = end_time - start_time  # 计算程序运行时间
print("程序执行时间为：{:.2f}秒".format(duration))

with open(f'{result_folder}/runtime.txt', 'w') as f:
    f.write("程序执行时间为：{:.2f}秒".format(duration)) # 新增点3 保存程序执行时间结果2023.09.11
# Out:
# GPU available
#
# Loaded dataset of 1120 samples, each sized (20, 15, 15, 1)
#
#
# Train on 1008 samples
# Test on 112 samples
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.RMSprop.
# Model: "model_10"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  name_model_input (InputLay  [(None, 20, 15, 15, 1)]      0         []
#  er)
#
#  time_distributed_60 (TimeD  (None, 20, 11, 11, 16)       416       ['name_model_input[0][0]']
#  istributed)
#
#  time_distributed_61 (TimeD  (None, 20, 5, 5, 16)         0         ['time_distributed_60[0][0]']
#  istributed)
#
#  time_distributed_62 (TimeD  (None, 20, 400)              0         ['time_distributed_61[0][0]']
#  istributed)
#
#  time_distributed_63 (TimeD  (None, 20, 64)               25664     ['time_distributed_62[0][0]']
#  istributed)
#
#  time_distributed_64 (TimeD  (None, 20, 64)               0         ['time_distributed_63[0][0]']
#  istributed)
#
#  time_distributed_65 (TimeD  (None, 20, 64)               4160      ['time_distributed_64[0][0]']
#  istributed)
#
#  multi_head_attention_10 (M  (None, 20, 64)               16640     ['time_distributed_65[0][0]',
#  ultiHeadAttention)                                                  'time_distributed_65[0][0]']
#
#  dropout_41 (Dropout)        (None, 20, 64)               0         ['multi_head_attention_10[0][0
#                                                                     ]']
#
#  tf.__operators__.add_10 (T  (None, 20, 64)               0         ['dropout_41[0][0]',
#  FOpLambda)                                                          'time_distributed_65[0][0]']
#
#  layer_normalization_20 (La  (None, 20, 64)               128       ['tf.__operators__.add_10[0][0
#  yerNormalization)                                                  ]']
#
#  dense_42 (Dense)            (None, 20, 64)               4160      ['layer_normalization_20[0][0]
#                                                                     ']
#
#  dense_43 (Dense)            (None, 20, 64)               4160      ['dense_42[0][0]']
#
#  dropout_42 (Dropout)        (None, 20, 64)               0         ['dense_43[0][0]']
#
#  layer_normalization_21 (La  (None, 20, 64)               128       ['dropout_42[0][0]']
#  yerNormalization)
#
#  lstm_10 (LSTM)              (None, 128)                  98816     ['layer_normalization_21[0][0]
#                                                                     ']
#
#  dropout_43 (Dropout)        (None, 128)                  0         ['lstm_10[0][0]']
#
#  name_model_output (Dense)   (None, 4)                    516       ['dropout_43[0][0]']
#
# ==================================================================================================
# Total params: 154788 (604.64 KB)
# Trainable params: 154788 (604.64 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/200
# 57/57 [==============================] - 6s 22ms/step - loss: 0.1962 - accuracy: 0.2503 - val_loss: 0.1961 - val_accuracy: 0.2673
# Epoch 2/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.1921 - accuracy: 0.2745 - val_loss: 0.1993 - val_accuracy: 0.2871
# Epoch 3/200
# 57/57 [==============================] - 1s 12ms/step - loss: 0.1884 - accuracy: 0.2988 - val_loss: 0.1798 - val_accuracy: 0.3762
# Epoch 4/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.1841 - accuracy: 0.3252 - val_loss: 0.1908 - val_accuracy: 0.3267
# Epoch 5/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.1835 - accuracy: 0.3418 - val_loss: 0.2013 - val_accuracy: 0.3267
# Epoch 6/200
# 57/57 [==============================] - 1s 13ms/step - loss: 0.1774 - accuracy: 0.4002 - val_loss: 0.1805 - val_accuracy: 0.3663
# Epoch 7/200
# 57/57 [==============================] - 1s 15ms/step - loss: 0.1721 - accuracy: 0.4057 - val_loss: 0.1709 - val_accuracy: 0.4653
# Epoch 8/200
# 57/57 [==============================] - 1s 15ms/step - loss: 0.1623 - accuracy: 0.4873 - val_loss: 0.1784 - val_accuracy: 0.4752
# Epoch 9/200
# 57/57 [==============================] - 1s 15ms/step - loss: 0.1506 - accuracy: 0.5325 - val_loss: 0.1554 - val_accuracy: 0.5248
# Epoch 10/200
# 57/57 [==============================] - 1s 15ms/step - loss: 0.1431 - accuracy: 0.5711 - val_loss: 0.1394 - val_accuracy: 0.5446
# Epoch 11/200
# 57/57 [==============================] - 1s 12ms/step - loss: 0.1362 - accuracy: 0.5888 - val_loss: 0.1340 - val_accuracy: 0.5941
# Epoch 12/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.1285 - accuracy: 0.6075 - val_loss: 0.1184 - val_accuracy: 0.6832
# Epoch 13/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.1155 - accuracy: 0.6637 - val_loss: 0.1420 - val_accuracy: 0.6139
# Epoch 14/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.1131 - accuracy: 0.6792 - val_loss: 0.1250 - val_accuracy: 0.6436
# Epoch 15/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.1068 - accuracy: 0.6957 - val_loss: 0.1010 - val_accuracy: 0.7228
# Epoch 16/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.1040 - accuracy: 0.6968 - val_loss: 0.0811 - val_accuracy: 0.7921
# Epoch 17/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.1004 - accuracy: 0.7178 - val_loss: 0.1041 - val_accuracy: 0.7030
# Epoch 18/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0958 - accuracy: 0.7200 - val_loss: 0.1089 - val_accuracy: 0.6931
# Epoch 19/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0924 - accuracy: 0.7475 - val_loss: 0.1053 - val_accuracy: 0.7129
# Epoch 20/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0855 - accuracy: 0.7530 - val_loss: 0.1088 - val_accuracy: 0.6832
# Epoch 21/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0873 - accuracy: 0.7607 - val_loss: 0.0801 - val_accuracy: 0.7525
# Epoch 22/200
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0740 - accuracy: 0.8060 - val_loss: 0.0830 - val_accuracy: 0.7723
# Epoch 23/200
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0795 - accuracy: 0.7839 - val_loss: 0.0792 - val_accuracy: 0.7525
# Epoch 24/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0744 - accuracy: 0.7982 - val_loss: 0.0863 - val_accuracy: 0.7723
# Epoch 25/200
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0757 - accuracy: 0.7993 - val_loss: 0.1002 - val_accuracy: 0.7426
# Epoch 26/200
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0712 - accuracy: 0.7982 - val_loss: 0.0856 - val_accuracy: 0.7426
# Epoch 27/200
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0709 - accuracy: 0.8104 - val_loss: 0.0830 - val_accuracy: 0.7822
# Epoch 28/200
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0642 - accuracy: 0.8236 - val_loss: 0.1365 - val_accuracy: 0.6535
# Epoch 29/200
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0697 - accuracy: 0.8115 - val_loss: 0.0816 - val_accuracy: 0.7624
# Epoch 30/200
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0627 - accuracy: 0.8346 - val_loss: 0.0647 - val_accuracy: 0.8218
# Epoch 31/200
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0579 - accuracy: 0.8401 - val_loss: 0.0697 - val_accuracy: 0.8020
# Epoch 32/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0590 - accuracy: 0.8280 - val_loss: 0.0748 - val_accuracy: 0.8020
# Epoch 33/200
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0565 - accuracy: 0.8534 - val_loss: 0.0997 - val_accuracy: 0.7327
# Epoch 34/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0541 - accuracy: 0.8534 - val_loss: 0.0730 - val_accuracy: 0.7723
# Epoch 35/200
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0567 - accuracy: 0.8467 - val_loss: 0.0808 - val_accuracy: 0.8020
# Epoch 36/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0520 - accuracy: 0.8633 - val_loss: 0.0758 - val_accuracy: 0.7921
# Epoch 37/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0492 - accuracy: 0.8666 - val_loss: 0.0678 - val_accuracy: 0.8218
# Epoch 38/200
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0547 - accuracy: 0.8589 - val_loss: 0.1469 - val_accuracy: 0.6535
# Epoch 39/200
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0487 - accuracy: 0.8721 - val_loss: 0.0647 - val_accuracy: 0.8218
# Epoch 40/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0475 - accuracy: 0.8754 - val_loss: 0.0625 - val_accuracy: 0.8416
# Epoch 41/200
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0489 - accuracy: 0.8732 - val_loss: 0.0768 - val_accuracy: 0.7921
# Epoch 42/200
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0458 - accuracy: 0.8831 - val_loss: 0.0694 - val_accuracy: 0.8020
# Epoch 43/200
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0397 - accuracy: 0.8997 - val_loss: 0.0850 - val_accuracy: 0.7723
# Epoch 44/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0438 - accuracy: 0.8908 - val_loss: 0.0835 - val_accuracy: 0.7723
# Epoch 45/200
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0395 - accuracy: 0.8953 - val_loss: 0.0614 - val_accuracy: 0.8218
# Epoch 46/200
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0388 - accuracy: 0.9030 - val_loss: 0.0813 - val_accuracy: 0.7921
# Epoch 47/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0413 - accuracy: 0.9008 - val_loss: 0.0813 - val_accuracy: 0.7723
# Epoch 48/200
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0393 - accuracy: 0.8908 - val_loss: 0.0771 - val_accuracy: 0.7723
# Epoch 49/200
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0383 - accuracy: 0.9030 - val_loss: 0.0705 - val_accuracy: 0.7921
# Epoch 50/200
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0362 - accuracy: 0.9063 - val_loss: 0.0676 - val_accuracy: 0.8119
# Epoch 51/200
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0319 - accuracy: 0.9140 - val_loss: 0.0901 - val_accuracy: 0.7426
# Epoch 52/200
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0330 - accuracy: 0.9184 - val_loss: 0.1194 - val_accuracy: 0.7030
# Epoch 53/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0358 - accuracy: 0.9052 - val_loss: 0.0787 - val_accuracy: 0.7921
# Epoch 54/200
# 57/57 [==============================] - 1s 12ms/step - loss: 0.0315 - accuracy: 0.9195 - val_loss: 0.0680 - val_accuracy: 0.8218
# Epoch 55/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0360 - accuracy: 0.9074 - val_loss: 0.0532 - val_accuracy: 0.8713
# Epoch 56/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0295 - accuracy: 0.9250 - val_loss: 0.0886 - val_accuracy: 0.7822
# Epoch 57/200
# 57/57 [==============================] - 1s 12ms/step - loss: 0.0310 - accuracy: 0.9195 - val_loss: 0.0730 - val_accuracy: 0.8119
# Epoch 58/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0364 - accuracy: 0.9063 - val_loss: 0.0638 - val_accuracy: 0.8218
# Epoch 59/200
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0300 - accuracy: 0.9228 - val_loss: 0.0628 - val_accuracy: 0.8614
# Epoch 60/200
# 57/57 [==============================] - 1s 12ms/step - loss: 0.0295 - accuracy: 0.9239 - val_loss: 0.0725 - val_accuracy: 0.7921
# Epoch 61/200
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0304 - accuracy: 0.9217 - val_loss: 0.0728 - val_accuracy: 0.8020
# Epoch 62/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0323 - accuracy: 0.9206 - val_loss: 0.0709 - val_accuracy: 0.8218
# Epoch 63/200
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0299 - accuracy: 0.9195 - val_loss: 0.0810 - val_accuracy: 0.7822
# Epoch 64/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0273 - accuracy: 0.9250 - val_loss: 0.0580 - val_accuracy: 0.8614
# Epoch 65/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0243 - accuracy: 0.9449 - val_loss: 0.0679 - val_accuracy: 0.8317
# Epoch 66/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0258 - accuracy: 0.9394 - val_loss: 0.0825 - val_accuracy: 0.8020
# Epoch 67/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0277 - accuracy: 0.9316 - val_loss: 0.0695 - val_accuracy: 0.8020
# Epoch 68/200
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0289 - accuracy: 0.9250 - val_loss: 0.0735 - val_accuracy: 0.8119
# Epoch 69/200
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0352 - accuracy: 0.9063 - val_loss: 0.0609 - val_accuracy: 0.8119
# Epoch 70/200
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0246 - accuracy: 0.9405 - val_loss: 0.1034 - val_accuracy: 0.7327
# Epoch 71/200
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0229 - accuracy: 0.9405 - val_loss: 0.0591 - val_accuracy: 0.8317
# Epoch 72/200
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0279 - accuracy: 0.9261 - val_loss: 0.0666 - val_accuracy: 0.7921
# Epoch 73/200
# 57/57 [==============================] - 1s 12ms/step - loss: 0.0248 - accuracy: 0.9383 - val_loss: 0.0691 - val_accuracy: 0.8218
# Epoch 74/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0293 - accuracy: 0.9272 - val_loss: 0.0805 - val_accuracy: 0.7822
# Epoch 75/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0259 - accuracy: 0.9350 - val_loss: 0.0753 - val_accuracy: 0.8119
# Epoch 76/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0226 - accuracy: 0.9438 - val_loss: 0.0811 - val_accuracy: 0.7723
# Epoch 77/200
# 57/57 [==============================] - 1s 12ms/step - loss: 0.0217 - accuracy: 0.9438 - val_loss: 0.0774 - val_accuracy: 0.8020
# Epoch 78/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0233 - accuracy: 0.9361 - val_loss: 0.0646 - val_accuracy: 0.8218
# Epoch 79/200
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0201 - accuracy: 0.9493 - val_loss: 0.0773 - val_accuracy: 0.7723
# Epoch 80/200
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0239 - accuracy: 0.9383 - val_loss: 0.0776 - val_accuracy: 0.7921
# Epoch 81/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0253 - accuracy: 0.9405 - val_loss: 0.0926 - val_accuracy: 0.7426
# Epoch 82/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0193 - accuracy: 0.9504 - val_loss: 0.0633 - val_accuracy: 0.8218
# Epoch 83/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0204 - accuracy: 0.9482 - val_loss: 0.0820 - val_accuracy: 0.7921
# Epoch 84/200
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0213 - accuracy: 0.9449 - val_loss: 0.0866 - val_accuracy: 0.7723
# Epoch 85/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0212 - accuracy: 0.9471 - val_loss: 0.0998 - val_accuracy: 0.7327
# Epoch 86/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0186 - accuracy: 0.9570 - val_loss: 0.0787 - val_accuracy: 0.7723
# Epoch 87/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0162 - accuracy: 0.9570 - val_loss: 0.0645 - val_accuracy: 0.8317
# Epoch 88/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0206 - accuracy: 0.9427 - val_loss: 0.0808 - val_accuracy: 0.8020
# Epoch 89/200
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0189 - accuracy: 0.9559 - val_loss: 0.1294 - val_accuracy: 0.6931
# Epoch 90/200
# 57/57 [==============================] - 1s 16ms/step - loss: 0.0198 - accuracy: 0.9460 - val_loss: 0.0928 - val_accuracy: 0.7624
# Epoch 91/200
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0215 - accuracy: 0.9471 - val_loss: 0.0770 - val_accuracy: 0.8119
# Epoch 92/200
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0204 - accuracy: 0.9427 - val_loss: 0.0688 - val_accuracy: 0.8218
# Epoch 93/200
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0177 - accuracy: 0.9559 - val_loss: 0.0796 - val_accuracy: 0.7921
# Epoch 94/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0162 - accuracy: 0.9570 - val_loss: 0.0718 - val_accuracy: 0.7921
# Epoch 95/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0181 - accuracy: 0.9515 - val_loss: 0.0764 - val_accuracy: 0.7822
# Epoch 96/200
# 57/57 [==============================] - 1s 12ms/step - loss: 0.0180 - accuracy: 0.9526 - val_loss: 0.0853 - val_accuracy: 0.7921
# Epoch 97/200
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0170 - accuracy: 0.9559 - val_loss: 0.1124 - val_accuracy: 0.7327
# Epoch 98/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0177 - accuracy: 0.9526 - val_loss: 0.0724 - val_accuracy: 0.7921
# Epoch 99/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0171 - accuracy: 0.9537 - val_loss: 0.0650 - val_accuracy: 0.8317
# Epoch 100/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0166 - accuracy: 0.9581 - val_loss: 0.0721 - val_accuracy: 0.8218
# Epoch 101/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0200 - accuracy: 0.9460 - val_loss: 0.0661 - val_accuracy: 0.8515
# Epoch 102/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0174 - accuracy: 0.9548 - val_loss: 0.0757 - val_accuracy: 0.8119
# Epoch 103/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0152 - accuracy: 0.9658 - val_loss: 0.0828 - val_accuracy: 0.7822
# Epoch 104/200
# 57/57 [==============================] - 1s 12ms/step - loss: 0.0148 - accuracy: 0.9625 - val_loss: 0.0751 - val_accuracy: 0.8119
# Epoch 105/200
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0128 - accuracy: 0.9647 - val_loss: 0.0775 - val_accuracy: 0.8020
# Epoch 106/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0155 - accuracy: 0.9570 - val_loss: 0.0869 - val_accuracy: 0.7723
# Epoch 107/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0163 - accuracy: 0.9559 - val_loss: 0.0653 - val_accuracy: 0.8416
# Epoch 108/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0158 - accuracy: 0.9581 - val_loss: 0.0742 - val_accuracy: 0.8020
# Epoch 109/200
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0155 - accuracy: 0.9592 - val_loss: 0.0729 - val_accuracy: 0.7822
# Epoch 110/200
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0169 - accuracy: 0.9581 - val_loss: 0.0812 - val_accuracy: 0.8020
# Epoch 111/200
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0202 - accuracy: 0.9482 - val_loss: 0.0839 - val_accuracy: 0.7723
# Epoch 112/200
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0128 - accuracy: 0.9658 - val_loss: 0.0685 - val_accuracy: 0.8317
# Epoch 113/200
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0158 - accuracy: 0.9603 - val_loss: 0.0794 - val_accuracy: 0.7822
# Epoch 114/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0134 - accuracy: 0.9658 - val_loss: 0.0747 - val_accuracy: 0.8119
# Epoch 115/200
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0134 - accuracy: 0.9669 - val_loss: 0.0827 - val_accuracy: 0.7921
# Epoch 116/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0148 - accuracy: 0.9603 - val_loss: 0.0658 - val_accuracy: 0.8416
# Epoch 117/200
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0142 - accuracy: 0.9636 - val_loss: 0.0661 - val_accuracy: 0.8515
# Epoch 118/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0145 - accuracy: 0.9603 - val_loss: 0.0826 - val_accuracy: 0.7822
# Epoch 119/200
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0150 - accuracy: 0.9614 - val_loss: 0.0821 - val_accuracy: 0.7624
# Epoch 120/200
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0150 - accuracy: 0.9581 - val_loss: 0.0794 - val_accuracy: 0.8020
# Epoch 121/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0131 - accuracy: 0.9592 - val_loss: 0.0663 - val_accuracy: 0.8020
# Epoch 122/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0112 - accuracy: 0.9735 - val_loss: 0.0739 - val_accuracy: 0.8119
# Epoch 123/200
# 57/57 [==============================] - 1s 12ms/step - loss: 0.0156 - accuracy: 0.9570 - val_loss: 0.0749 - val_accuracy: 0.8119
# Epoch 124/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0136 - accuracy: 0.9680 - val_loss: 0.0712 - val_accuracy: 0.8119
# Epoch 125/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0101 - accuracy: 0.9746 - val_loss: 0.0638 - val_accuracy: 0.8317
# Epoch 126/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0079 - accuracy: 0.9813 - val_loss: 0.0592 - val_accuracy: 0.8218
# Epoch 127/200
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0121 - accuracy: 0.9680 - val_loss: 0.0634 - val_accuracy: 0.8416
# Epoch 128/200
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0121 - accuracy: 0.9669 - val_loss: 0.0676 - val_accuracy: 0.8317
# Epoch 129/200
# 57/57 [==============================] - 1s 24ms/step - loss: 0.0121 - accuracy: 0.9702 - val_loss: 0.0677 - val_accuracy: 0.8119
# Epoch 130/200
# 57/57 [==============================] - 1s 16ms/step - loss: 0.0099 - accuracy: 0.9768 - val_loss: 0.0616 - val_accuracy: 0.8317
# Epoch 131/200
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0160 - accuracy: 0.9614 - val_loss: 0.0817 - val_accuracy: 0.7723
# Epoch 132/200
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0127 - accuracy: 0.9691 - val_loss: 0.0717 - val_accuracy: 0.8317
# Epoch 133/200
# 57/57 [==============================] - 1s 16ms/step - loss: 0.0101 - accuracy: 0.9735 - val_loss: 0.0797 - val_accuracy: 0.7921
# Epoch 134/200
# 57/57 [==============================] - 1s 12ms/step - loss: 0.0131 - accuracy: 0.9680 - val_loss: 0.0871 - val_accuracy: 0.7624
# Epoch 135/200
# 57/57 [==============================] - 1s 12ms/step - loss: 0.0129 - accuracy: 0.9680 - val_loss: 0.0751 - val_accuracy: 0.8119
# Epoch 136/200
# 57/57 [==============================] - 1s 12ms/step - loss: 0.0102 - accuracy: 0.9746 - val_loss: 0.0801 - val_accuracy: 0.7822
# Epoch 137/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0122 - accuracy: 0.9680 - val_loss: 0.0801 - val_accuracy: 0.8020
# Epoch 138/200
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0109 - accuracy: 0.9713 - val_loss: 0.0742 - val_accuracy: 0.8119
# Epoch 139/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0098 - accuracy: 0.9746 - val_loss: 0.0858 - val_accuracy: 0.7822
# Epoch 140/200
# 57/57 [==============================] - 1s 17ms/step - loss: 0.0090 - accuracy: 0.9802 - val_loss: 0.0956 - val_accuracy: 0.7525
# Epoch 141/200
# 57/57 [==============================] - 1s 13ms/step - loss: 0.0129 - accuracy: 0.9691 - val_loss: 0.1002 - val_accuracy: 0.7426
# Epoch 142/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0163 - accuracy: 0.9548 - val_loss: 0.0757 - val_accuracy: 0.8020
# Epoch 143/200
# 57/57 [==============================] - 1s 12ms/step - loss: 0.0081 - accuracy: 0.9813 - val_loss: 0.0861 - val_accuracy: 0.7822
# Epoch 144/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0112 - accuracy: 0.9724 - val_loss: 0.0726 - val_accuracy: 0.8218
# Epoch 145/200
# 57/57 [==============================] - 1s 12ms/step - loss: 0.0063 - accuracy: 0.9846 - val_loss: 0.0772 - val_accuracy: 0.7921
# Epoch 146/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0109 - accuracy: 0.9724 - val_loss: 0.0763 - val_accuracy: 0.8119
# Epoch 147/200
# 57/57 [==============================] - 1s 12ms/step - loss: 0.0113 - accuracy: 0.9724 - val_loss: 0.1050 - val_accuracy: 0.7525
# Epoch 148/200
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0097 - accuracy: 0.9757 - val_loss: 0.0787 - val_accuracy: 0.8020
# Epoch 149/200
# 57/57 [==============================] - 1s 16ms/step - loss: 0.0098 - accuracy: 0.9768 - val_loss: 0.0716 - val_accuracy: 0.8119
# Epoch 150/200
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0101 - accuracy: 0.9724 - val_loss: 0.0602 - val_accuracy: 0.8515
# Epoch 151/200
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0098 - accuracy: 0.9779 - val_loss: 0.0610 - val_accuracy: 0.8614
# Epoch 152/200
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0088 - accuracy: 0.9779 - val_loss: 0.0815 - val_accuracy: 0.7822
# Epoch 153/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0082 - accuracy: 0.9802 - val_loss: 0.0827 - val_accuracy: 0.7921
# Epoch 154/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0091 - accuracy: 0.9779 - val_loss: 0.0743 - val_accuracy: 0.8218
# Epoch 155/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0096 - accuracy: 0.9791 - val_loss: 0.0689 - val_accuracy: 0.8317
# Epoch 156/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0099 - accuracy: 0.9735 - val_loss: 0.0884 - val_accuracy: 0.7723
# Epoch 157/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0087 - accuracy: 0.9813 - val_loss: 0.0687 - val_accuracy: 0.8218
# Epoch 158/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0108 - accuracy: 0.9746 - val_loss: 0.0891 - val_accuracy: 0.7723
# Epoch 159/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0086 - accuracy: 0.9802 - val_loss: 0.0803 - val_accuracy: 0.8020
# Epoch 160/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0076 - accuracy: 0.9857 - val_loss: 0.0797 - val_accuracy: 0.7921
# Epoch 161/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0082 - accuracy: 0.9802 - val_loss: 0.1117 - val_accuracy: 0.7129
# Epoch 162/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0087 - accuracy: 0.9779 - val_loss: 0.0732 - val_accuracy: 0.8119
# Epoch 163/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0087 - accuracy: 0.9768 - val_loss: 0.0813 - val_accuracy: 0.8119
# Epoch 164/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0132 - accuracy: 0.9680 - val_loss: 0.0551 - val_accuracy: 0.8713
# Epoch 165/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0096 - accuracy: 0.9791 - val_loss: 0.0882 - val_accuracy: 0.7426
# Epoch 166/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0118 - accuracy: 0.9713 - val_loss: 0.0610 - val_accuracy: 0.8515
# Epoch 167/200
# 57/57 [==============================] - 1s 12ms/step - loss: 0.0081 - accuracy: 0.9791 - val_loss: 0.0733 - val_accuracy: 0.8218
# Epoch 168/200
# 57/57 [==============================] - 1s 12ms/step - loss: 0.0076 - accuracy: 0.9779 - val_loss: 0.0784 - val_accuracy: 0.8119
# Epoch 169/200
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0075 - accuracy: 0.9813 - val_loss: 0.0575 - val_accuracy: 0.8515
# Epoch 170/200
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0051 - accuracy: 0.9901 - val_loss: 0.0613 - val_accuracy: 0.8416
# Epoch 171/200
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0042 - accuracy: 0.9901 - val_loss: 0.0732 - val_accuracy: 0.8218
# Epoch 172/200
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0100 - accuracy: 0.9768 - val_loss: 0.0737 - val_accuracy: 0.8020
# Epoch 173/200
# 57/57 [==============================] - 1s 12ms/step - loss: 0.0069 - accuracy: 0.9802 - val_loss: 0.0777 - val_accuracy: 0.8218
# Epoch 174/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0070 - accuracy: 0.9824 - val_loss: 0.0691 - val_accuracy: 0.8317
# Epoch 175/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0085 - accuracy: 0.9779 - val_loss: 0.0724 - val_accuracy: 0.8317
# Epoch 176/200
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0101 - accuracy: 0.9735 - val_loss: 0.0822 - val_accuracy: 0.8020
# Epoch 177/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0072 - accuracy: 0.9857 - val_loss: 0.0826 - val_accuracy: 0.8020
# Epoch 178/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0060 - accuracy: 0.9879 - val_loss: 0.0645 - val_accuracy: 0.8317
# Epoch 179/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0092 - accuracy: 0.9768 - val_loss: 0.0613 - val_accuracy: 0.8416
# Epoch 180/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0087 - accuracy: 0.9779 - val_loss: 0.0926 - val_accuracy: 0.7723
# Epoch 181/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0086 - accuracy: 0.9791 - val_loss: 0.0958 - val_accuracy: 0.7822
# Epoch 182/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0077 - accuracy: 0.9835 - val_loss: 0.0844 - val_accuracy: 0.7921
# Epoch 183/200
# 57/57 [==============================] - 1s 12ms/step - loss: 0.0077 - accuracy: 0.9824 - val_loss: 0.0742 - val_accuracy: 0.8218
# Epoch 184/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0051 - accuracy: 0.9868 - val_loss: 0.0754 - val_accuracy: 0.8218
# Epoch 185/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0110 - accuracy: 0.9735 - val_loss: 0.0796 - val_accuracy: 0.7822
# Epoch 186/200
# 57/57 [==============================] - 1s 12ms/step - loss: 0.0072 - accuracy: 0.9813 - val_loss: 0.0744 - val_accuracy: 0.8119
# Epoch 187/200
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0101 - accuracy: 0.9724 - val_loss: 0.0738 - val_accuracy: 0.8119
# Epoch 188/200
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0087 - accuracy: 0.9791 - val_loss: 0.0702 - val_accuracy: 0.8218
# Epoch 189/200
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0066 - accuracy: 0.9846 - val_loss: 0.0627 - val_accuracy: 0.8515
# Epoch 190/200
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0057 - accuracy: 0.9879 - val_loss: 0.0635 - val_accuracy: 0.8218
# Epoch 191/200
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0099 - accuracy: 0.9757 - val_loss: 0.0689 - val_accuracy: 0.8119
# Epoch 192/200
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0073 - accuracy: 0.9813 - val_loss: 0.0628 - val_accuracy: 0.8317
# Epoch 193/200
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0068 - accuracy: 0.9835 - val_loss: 0.0633 - val_accuracy: 0.8317
# Epoch 194/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0067 - accuracy: 0.9846 - val_loss: 0.0668 - val_accuracy: 0.8317
# Epoch 195/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0101 - accuracy: 0.9735 - val_loss: 0.0902 - val_accuracy: 0.7822
# Epoch 196/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0053 - accuracy: 0.9868 - val_loss: 0.0696 - val_accuracy: 0.8218
# Epoch 197/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0068 - accuracy: 0.9824 - val_loss: 0.0762 - val_accuracy: 0.8020
# Epoch 198/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0052 - accuracy: 0.9868 - val_loss: 0.0553 - val_accuracy: 0.8515
# Epoch 199/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0043 - accuracy: 0.9901 - val_loss: 0.0614 - val_accuracy: 0.8218
# Epoch 200/200
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0042 - accuracy: 0.9901 - val_loss: 0.0782 - val_accuracy: 0.8020
# Saving trained model...
# Testing...
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 4/4 [==============================] - 1s 5ms/step
# [[20  5  2  3]
#  [ 1 20  0  0]
#  [ 0  0 30  0]
#  [ 0  3  9 19]]
# [[0.67 0.17 0.07 0.1 ]
#  [0.05 0.95 0.   0.  ]
#  [0.   0.   1.   0.  ]
#  [0.   0.1  0.29 0.61]]
# 79.46%
# 新的结果文件夹名称为： result_MultiAttention_LSTM_1层Transformer_MSE_epoch200_batchsize16_lr0.003_79.46%
# 程序执行时间为：152.87秒

# %%
# 定位到指定路径下
import os
os.chdir('/content/drive/MyDrive/Colab_Notebooks/RNN-CAP')
print(os.getcwd())

# 打印版本
import sys
import tensorflow as tf

print("Python 版本:", sys.version)
print("TensorFlow 版本:", tf.__version__)

# !pip install xlwt
# !pip install matplotlib
# Out:
# /content/drive/MyDrive/Colab_Notebooks/RNN-CAP
# Python 版本: 3.10.12 (main, Jun 11 2023, 05:26:28) [GCC 11.4.0]
# TensorFlow 版本: 2.12.0
# Collecting xlwt
#   Downloading xlwt-1.3.0-py2.py3-none-any.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.0/100.0 kB 3.1 MB/s eta 0:00:00
# Installing collected packages: xlwt
# Successfully installed xlwt-1.3.0
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_categorical_crossentropy_epoch30.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_categorical_crossentropy_epoch250.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_categorical_crossentropy_epoch50.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_categorical_crossentropy_epoch100.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_categorical_crossentropy_epoch150.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_categorical_crossentropy_epoch200.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_squared_error_epoch30.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_squared_error_epoch50.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_squared_error_epoch100.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_squared_error_epoch150.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_squared_error_epoch200.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_squared_error_epoch250.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_absolute_error_epoch30.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_absolute_error_epoch50.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_absolute_error_epoch100.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_absolute_error_epoch150.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_absolute_error_epoch200.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_absolute_error_epoch250.py

# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_binary_crossentropy_epoch30.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_binary_crossentropy_epoch50.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_binary_crossentropy_epoch100.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_binary_crossentropy_epoch150.py

#!python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_binary_crossentropy_epoch200.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_binary_crossentropy_epoch250.py
