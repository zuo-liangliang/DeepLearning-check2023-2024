# %% [markdown]
# <a href="https://colab.research.google.com/github/zuo-liangliang/fcn.berkeleyvision.org/blob/master/result_MultiAttention_LSTM_1%E5%B1%82Transformer_BCE_epoch250_batchsize16_lr0.008_75.89%25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import zipfile

# 定义源文件夹路径和目标 zip 文件夹路径
# source_folder = '/content/drive/MyDrive/Colab_Notebooks/528BVP-acnt2'
source_folder = '/content/drive/MyDrive/AugustResult'
# target_zip_folder = '/content/drive/MyDrive/Colab_Notebooks/zip_folder'
# target_zip_folder = '/content/drive/MyDrive/Colab_Notebooks/528BVP-acnt2/0827zip_folder'
target_zip_folder = '/content/drive/MyDrive/AugustResult/0907_月月账号zip_folder'

# 确保目标 zip 文件夹存在
os.makedirs(target_zip_folder, exist_ok=True)

# 获取源文件夹中以 "result" 开头的文件夹列表
folder_list = [folder for folder in os.listdir(source_folder) if os.path.isdir(os.path.join(source_folder, folder)) and folder.startswith("result")]

# 创建一个大的 zip 文件
with zipfile.ZipFile(os.path.join(target_zip_folder, '0907月月_all_folders.zip'), 'w', zipfile.ZIP_DEFLATED) as zipf:
    # 遍历文件夹列表，逐个压缩为 zip 文件
    for folder in folder_list:
        folder_path = os.path.join(source_folder, folder)

        # 遍历文件夹中的所有文件和子文件夹，并逐个添加到大的 zip 文件中
        for root, dirs, files in os.walk(folder_path):
            for file in files:
                file_path = os.path.join(root, file)
                zipf.write(file_path, os.path.relpath(file_path, source_folder))

print("所有文件夹已压缩为一个大的 zip 文件！")
# Out:
# 所有文件夹已压缩为一个大的 zip 文件！

# %%
import shutil
import os
# 指定要删除的文件夹路径
folder_path = '/content/drive/MyDrive/Colab_Notebooks/528BVP-acnt2/user14' #替换为你的文件夹路径

# 确保要删除的是一个目录而不是文件
assert os.path.isdir(folder_path), f"{folder_path} 不是一个目录"

# 递归删除文件夹下的所有文件和子文件夹
shutil.rmtree(folder_path)

# %%
# 解压指定文件夹到某一路径下
import zipfile

file_path = '/content/drive/MyDrive/Colab_Notebooks/528BVP-acnt2/528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4.zip'
extract_path = '/content/drive/MyDrive/Colab_Notebooks/528BVP-acnt2/528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4'

with zipfile.ZipFile(file_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# %%
# 定位到指定路径下
import os
# os.chdir('/content/drive/MyDrive/SeptemberResult/result_LSTM')
os.chdir('/content/drive/MyDrive/SeptemberResult/result_MultiAttention_LSTM_1层Transformer')
print(os.getcwd())
# Out:
# /content/drive/MyDrive/SeptemberResult/result_MultiAttention_LSTM_1层Transformer

# %%
# result_MultiAttention_LSTM_1层Transformer

from keras.callbacks import Callback
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay

from __future__ import print_function

import time
import os,sys
import numpy as np
import pandas as pd
import scipy.io as scio
import tensorflow as tf
tf.compat.v1.keras.backend.set_session
import keras
from keras.layers import Input, GRU, LSTM, Dense, Flatten, Dropout, Conv2D, Conv3D, MaxPooling2D, MaxPooling3D, TimeDistributed
from keras.models import Model, load_model
import keras.backend as K
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split

# Parameters
use_existing_model = False
fraction_for_test = 0.1
data_dir = '/content/drive/MyDrive/Colab_Notebooks/528BVP-acnt2/528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4/'
# data_dir = '/content/drive/MyDrive/new528BVP/528[-1,1]长度20-分辨率15_acnt2_sample_rate5000__剔14_改6为4/'

fraction_for_test = 0.1
#ALL_MOTION = [1,2,3,4,5,6]
ALL_MOTION = [2,3,4,5]
N_MOTION = len(ALL_MOTION)
T_MAX = 0
n_epochs = 250  #最优的是100；第2优的是200，第3优的是250，原始是50 #修改点1
f_dropout_ratio = 0.5
n_gru_hidden_units = 128
n_batch_size = 16     #原始是32-->16
f_learning_rate = 0.008  #原始是0.001-->0.002

def normalize_data(data_1):
    # data(ndarray)=>data_norm(ndarray): [20,20,T]=>[20,20,T]
    data_1_max = np.concatenate((data_1.max(axis=0),data_1.max(axis=1)),axis=0).max(axis=0)
    data_1_min = np.concatenate((data_1.min(axis=0),data_1.min(axis=1)),axis=0).min(axis=0)
    if (len(np.where((data_1_max - data_1_min) == 0)[0]) > 0):
        return data_1
    data_1_max_rep = np.tile(data_1_max,(data_1.shape[0],data_1.shape[1],1))
    data_1_min_rep = np.tile(data_1_min,(data_1.shape[0],data_1.shape[1],1))
    data_1_norm = (data_1 - data_1_min_rep) / (data_1_max_rep - data_1_min_rep)
    return  data_1_norm

def zero_padding(data, T_MAX):
    # data(list)=>data_pad(ndarray): [20,20,T1/T2/...]=>[20,20,T_MAX]
    data_pad = []
    for i in range(len(data)):
        t = np.array(data[i]).shape[2]
        data_pad.append(np.pad(data[i], ((0,0),(0,0),(T_MAX - t,0)), 'constant', constant_values = 0).tolist())
    return np.array(data_pad)

def onehot_encoding(label, num_class):
    # label(list)=>_label(ndarray): [N,]=>[N,num_class]
    label = np.array(label).astype('int32')
    # assert (np.arange(0,np.unique(label).size)==np.unique(label)).prod()    # Check label from 0 to N
    label = np.squeeze(label)
    # _label = np.eye(num_class)[label-1]     # from label to onehot
    _label = np.eye(num_class)[label-2]   #修改点2
    return _label

def load_data(path_to_data, motion_sel):
    global T_MAX
    data = []
    label = []
    for data_root, data_dirs, data_files in os.walk(path_to_data):
        for data_file_name in data_files:

            file_path = os.path.join(data_root,data_file_name)
            try:
                data_1 = scio.loadmat(file_path)['velocity_spectrum_ro']
                label_1 = int(data_file_name.split('-')[1])
                #location = int(data_file_name.split('-')[2])
                #orientation = int(data_file_name.split('-')[3])
                #repetition = int(data_file_name.split('-')[4])
                repetition = int(data_file_name.split('-')[2])  #修改点3

                # Select Motion
                if (label_1 not in motion_sel):
                    continue

                # Select Location
                # if (location not in [1,2,3,5]):
                #     continue

                # Select Orientation
                # if (orientation not in [1,2,4,5]):
                #     continue

                # Normalization
                data_normed_1 = normalize_data(data_1)

                # Update T_MAX
                if T_MAX < np.array(data_1).shape[2]:
                    T_MAX = np.array(data_1).shape[2]
            except Exception:
                continue

            # Save List
            data.append(data_normed_1.tolist())
            label.append(label_1)
                # Zero-padding
    data = zero_padding(data, T_MAX)

    # Swap axes
    data = np.swapaxes(np.swapaxes(data, 1, 3), 2, 3)   # [N,20,20',T_MAX]=>[N,T_MAX,20,20']
    data = np.expand_dims(data, axis=-1)    # [N,T_MAX,20,20]=>[N,T_MAX,20,20,1]

    # Convert label to ndarray
    label = np.array(label)

    # data(ndarray): [N,T_MAX,20,20,1], label(ndarray): [N,N_MOTION]
    return data, label

# 构建符合输入形状为 (None, 20, 15, 15, 1) 和输出形状为 (None, 4) 的  模型：
from keras.layers import MultiHeadAttention, LayerNormalization  #加Transformer修改点1
num_transformer_layers = 1  # 设置Transformer层数 #加Transformer修改点2  2层-->1层

#加Transformer修改点3
def transformer_layer(inputs, hidden_units, dropout_rate):
    # Self-attention
    attention_output = MultiHeadAttention(
        num_heads=8, key_dim=hidden_units // 8
    )(inputs, inputs)
    attention_output = Dropout(dropout_rate)(attention_output)
    attention_output = LayerNormalization()(attention_output + inputs)

    # Feed-forward network
    ffn = Dense(hidden_units, activation="relu")(attention_output)
    ffn = Dense(hidden_units)(ffn)
    ffn = Dropout(dropout_rate)(ffn)
    ffn = LayerNormalization()(ffn)

    return ffn

#加Transformer修改点4
def assemble_model(input_shape, n_class):
    model_input = Input(shape=input_shape, dtype='float32', name='name_model_input')    # (@,T_MAX,20,20,1)

    # Feature extraction part
    x = TimeDistributed(Conv2D(16,kernel_size=(5,5),activation='relu',data_format='channels_last',\
        input_shape=input_shape))(model_input)   # (@,T_MAX,20,20,1)=>(@,T_MAX,16,16,16)
    x = TimeDistributed(MaxPooling2D(pool_size=(2,2)))(x)    # (@,T_MAX,16,16,16)=>(@,T_MAX,8,8,16)
    x = TimeDistributed(Flatten())(x)   # (@,T_MAX,8,8,16)=>(@,T_MAX,8*8*16)
    x = TimeDistributed(Dense(64,activation='relu'))(x) # (@,T_MAX,8*8*16)=>(@,T_MAX,64)
    x = TimeDistributed(Dropout(f_dropout_ratio))(x)
    x = TimeDistributed(Dense(64,activation='relu'))(x) # (@,T_MAX,64)=>(@,T_MAX,64)

    # Add transformer layers
    for _ in range(num_transformer_layers):
        #x = transformer_layer(x, hidden_units=n_gru_hidden_units, dropout_rate=f_dropout_ratio)
        x = transformer_layer(x, hidden_units=64, dropout_rate=f_dropout_ratio)  # 修改点1
    x = LSTM(n_gru_hidden_units,return_sequences=False)(x)  # (@,T_MAX,64)=>(@,128)
    x = Dropout(f_dropout_ratio)(x)
    model_output = Dense(n_class, activation='softmax', name='name_model_output')(x)  # (@,128)=>(@,n_class)

    # Create the model
    # Model compiling
    model = Model(inputs=model_input, outputs=model_output)
    model.compile(optimizer=keras.optimizers.RMSprop(lr=f_learning_rate),
                    # loss='categorical_crossentropy', # 将损失函数改为多类别交叉熵损失函数 最优的是CCE
                    # loss='mean_squared_error',  # 将损失函数改为均方误差 第2优的是MSE
                    # loss='mean_absolute_error',  # 将损失函数改为平均绝对误差 第3优的是MAE
                    loss='binary_crossentropy',  # 将损失函数改为对数损失函数 第3优的是MAE
                    metrics=['accuracy']
                )
    return model

# 改
#model_type = '双层LSTM'
#model_type = 'LSTM'
#model_type = 'BiLSTM'
model_type = 'MultiAttention_LSTM_1层Transformer'

# 创建结果文件夹
# result_folder = f'result_528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_GRU_改costfunction为mse_epoch200' # 每次都要改
# result_folder = f'result_528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_{model_type}_categorical_crossentropy_epoch{n_epochs}'
# result_folder = f'result_528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_{model_type}_mean_squared_error_epoch{n_epochs}'
# result_folder = f'result_528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_{model_type}_mean_absolute_error_epoch{n_epochs}'
# result_folder = f'result_528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_{model_type}_binary_crossentropy_epoch{n_epochs}'

# result_folder = f'result_{model_type}_CCE_epoch{n_epochs}_batchsize{n_batch_size}_lr{f_learning_rate}'
# result_folder = f'result_{model_type}_MSE_epoch{n_epochs}_batchsize{n_batch_size}_lr{f_learning_rate}'
# result_folder = f'result_{model_type}_MAE_epoch{n_epochs}_batchsize{n_batch_size}_lr{f_learning_rate}'
result_folder = f'result_{model_type}_BCE_epoch{n_epochs}_batchsize{n_batch_size}_lr{f_learning_rate}'

os.makedirs(result_folder, exist_ok=True)

# %%
# Let's BEGIN >>>>

import time
start_time = time.time()  # 记录程序开始时间

# 获取可见的GPU设备列表
# visible_gpus = tf.config.experimental.list_physical_devices('GPU')
# 检查是否存在可见的GPU设备
# if len(visible_gpus) < 1:
    # print('No GPU available')
    # exit(0)
# 设置使用第一个可见的GPU设备
# os.environ["CUDA_VISIBLE_DEVICES"] = str(visible_gpus[0].index)
# 配置GPU选项
# gpu_config = tf.config.experimental.set_memory_growth(visible_gpus[0], True)
# 创建一个会话并应用GPU配置
# sess = tf.compat.v1.Session(config=gpu_config)
# tf.compat.v1.keras.backend.set_session(sess)
# tf.random.set_seed(1)

# 获取可见的 GPU 设备列表
visible_gpus = tf.config.experimental.list_physical_devices('GPU')
if len(visible_gpus) > 0:
    # 如果有可见的 GPU 设备，设置 TensorFlow 在 GPU 上运行
    tf.config.set_visible_devices(visible_gpus, 'GPU')
    gpu_config = tf.config.experimental.set_memory_growth(visible_gpus[0], True)
    sess = tf.compat.v1.Session(config=gpu_config)
    tf.compat.v1.keras.backend.set_session(sess)
    print('GPU available')
else:
    # 如果没有可见的 GPU 设备，设置 TensorFlow 在 CPU 上运行
    tf.config.set_visible_devices([], 'GPU')
    sess = tf.compat.v1.Session()
    print('No GPU available')

# Load data
data, label = load_data(data_dir, ALL_MOTION)
print('\nLoaded dataset of ' + str(label.shape[0]) + ' samples, each sized ' + str(data[0,:,:].shape) + '\n')

# Split train and test
[data_train, data_test, label_train, label_test] = train_test_split(data, label, test_size=fraction_for_test)
print('\nTrain on ' + str(label_train.shape[0]) + ' samples\n' +\
    'Test on ' + str(label_test.shape[0]) + ' samples\n')

# One-hot encoding for train data
label_train = onehot_encoding(label_train, N_MOTION)

# Load or fabricate model
if use_existing_model:
    model = load_model('model_widar3_trained.h5')
    model.summary()
else:
    #model = assemble_model(input_shape=(T_MAX, 20, 20, 1), n_class=N_MOTION)
    model = assemble_model(input_shape=(T_MAX, 15, 15, 1), n_class=N_MOTION) #修改点4
    model.summary()

class AccuracyLossHistory(Callback):
    def on_train_begin(self, logs={}):
        self.acc = []
        self.loss = []
        self.val_acc = []
        self.val_loss = []

    def on_epoch_end(self, epoch, logs={}):
        self.acc.append(logs.get('accuracy'))
        self.loss.append(logs.get('loss'))
        self.val_acc.append(logs.get('val_accuracy'))
        self.val_loss.append(logs.get('val_loss'))

history = AccuracyLossHistory()

model.fit({'name_model_input': data_train},{'name_model_output': label_train},
          batch_size=n_batch_size,
          epochs=n_epochs,
          verbose=1,
          validation_split=0.1, shuffle=True, callbacks=[history])
print('Saving trained model...')
#model.save('model_widar3_trained.h5')
model.save(f'{result_folder}/model.h5')  # 改动

# Testing...
print('Testing...')
label_test_pred = model.predict(data_test)
# label_test_pred = np.argmax(label_test_pred, axis = -1) + 1
label_test_pred = np.argmax(label_test_pred, axis = -1) + 2 #修改点5

# Confusion Matrix
cm = confusion_matrix(label_test, label_test_pred)
print(cm)
cm = cm.astype('float')/cm.sum(axis=1)[:, np.newaxis]
cm = np.around(cm, decimals=2)
print(cm)
#cm_display = ConfusionMatrixDisplay(cm, display_labels=range(1, N_MOTION+1)).plot()
#cm_display = ConfusionMatrixDisplay(cm, display_labels=range(4, N_MOTION+3)).plot() #2345 lebel-2  4567 4=2+2  7=长度4+3
cm_display = ConfusionMatrixDisplay(cm, display_labels=range(2, N_MOTION+2)).plot() #2345 lebel-2  4567 4=2+2  7=长度4+3
plt.show()
plt.savefig(f'{result_folder}/cm.png') # 新增点1 保存混淆矩阵结果2023.09.11

# Accuracy 新增百分号
test_accuracy = np.sum(label_test == label_test_pred) / (label_test.shape[0])
#print(test_accuracy)
test_accuracy_percentage = test_accuracy * 100
test_accuracy_str = f"{test_accuracy_percentage:.2f}%"
print(test_accuracy_str)

df_accuracy = pd.DataFrame({'Test Accuracy': [test_accuracy]})
df_accuracy.to_excel(f'{result_folder}/{test_accuracy_str}.xlsx', index=False) ## 新增点2 保存测试集平均准确率结果2023.09.11


df = pd.DataFrame({
    'Epoch': range(1, n_epochs+1),
    'Train Accuracy': history.acc,
    'Train Loss': history.loss,
    'Validation Accuracy': history.val_acc,
    'Validation Loss': history.val_loss
})

# df.to_excel('accuracy_l'''  '''oss.xlsx', index=False)
# 保存准确率和损失数据到Excel表格中
df.to_excel(f'{result_folder}/accuracy_loss.xlsx', index=False) #改动

plt.plot(range(1, n_epochs+1), history.acc, label='Train Accuracy')
plt.plot(range(1, n_epochs+1), history.loss, label='Train Loss')
plt.plot(range(1, n_epochs+1), history.val_acc, label='Validation Accuracy')
plt.plot(range(1, n_epochs+1), history.val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.legend()
plt.savefig(f'{result_folder}/plot.png')
plt.show()

# 新增 修改文件名 并打印新的文件名
new_result_folder = result_folder + f'_{test_accuracy_str}'
os.rename(result_folder, new_result_folder)
result_folder = new_result_folder

print("新的结果文件夹名称为：", result_folder)

end_time = time.time()  # 记录程序结束时间
duration = end_time - start_time  # 计算程序运行时间
print("程序执行时间为：{:.2f}秒".format(duration))

with open(f'{result_folder}/runtime.txt', 'w') as f:
    f.write("程序执行时间为：{:.2f}秒".format(duration)) # 新增点3 保存程序执行时间结果2023.09.11
# Out:
# GPU available
#
# Loaded dataset of 1120 samples, each sized (20, 15, 15, 1)
#
#
# Train on 1008 samples
# Test on 112 samples
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.RMSprop.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  name_model_input (InputLay  [(None, 20, 15, 15, 1)]      0         []
#  er)
#
#  time_distributed (TimeDist  (None, 20, 11, 11, 16)       416       ['name_model_input[0][0]']
#  ributed)
#
#  time_distributed_1 (TimeDi  (None, 20, 5, 5, 16)         0         ['time_distributed[0][0]']
#  stributed)
#
#  time_distributed_2 (TimeDi  (None, 20, 400)              0         ['time_distributed_1[0][0]']
#  stributed)
#
#  time_distributed_3 (TimeDi  (None, 20, 64)               25664     ['time_distributed_2[0][0]']
#  stributed)
#
#  time_distributed_4 (TimeDi  (None, 20, 64)               0         ['time_distributed_3[0][0]']
#  stributed)
#
#  time_distributed_5 (TimeDi  (None, 20, 64)               4160      ['time_distributed_4[0][0]']
#  stributed)
#
#  multi_head_attention (Mult  (None, 20, 64)               16640     ['time_distributed_5[0][0]',
#  iHeadAttention)                                                     'time_distributed_5[0][0]']
#
#  dropout_1 (Dropout)         (None, 20, 64)               0         ['multi_head_attention[0][0]']
#
#  tf.__operators__.add (TFOp  (None, 20, 64)               0         ['dropout_1[0][0]',
#  Lambda)                                                             'time_distributed_5[0][0]']
#
#  layer_normalization (Layer  (None, 20, 64)               128       ['tf.__operators__.add[0][0]']
#  Normalization)
#
#  dense_2 (Dense)             (None, 20, 64)               4160      ['layer_normalization[0][0]']
#
#  dense_3 (Dense)             (None, 20, 64)               4160      ['dense_2[0][0]']
#
#  dropout_2 (Dropout)         (None, 20, 64)               0         ['dense_3[0][0]']
#
#  layer_normalization_1 (Lay  (None, 20, 64)               128       ['dropout_2[0][0]']
#  erNormalization)
#
#  lstm (LSTM)                 (None, 128)                  98816     ['layer_normalization_1[0][0]'
#                                                                     ]
#
#  dropout_3 (Dropout)         (None, 128)                  0         ['lstm[0][0]']
#
#  name_model_output (Dense)   (None, 4)                    516       ['dropout_3[0][0]']
#
# ==================================================================================================
# Total params: 154788 (604.64 KB)
# Trainable params: 154788 (604.64 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/250
# 57/57 [==============================] - 17s 30ms/step - loss: 0.5807 - accuracy: 0.2822 - val_loss: 0.6050 - val_accuracy: 0.1584
# Epoch 2/250
# 57/57 [==============================] - 1s 14ms/step - loss: 0.5745 - accuracy: 0.2789 - val_loss: 0.5573 - val_accuracy: 0.2376
# Epoch 3/250
# 57/57 [==============================] - 1s 13ms/step - loss: 0.5690 - accuracy: 0.3032 - val_loss: 0.5515 - val_accuracy: 0.2673
# Epoch 4/250
# 57/57 [==============================] - 1s 13ms/step - loss: 0.5594 - accuracy: 0.2845 - val_loss: 0.5280 - val_accuracy: 0.3366
# Epoch 5/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.5578 - accuracy: 0.3120 - val_loss: 0.5273 - val_accuracy: 0.3960
# Epoch 6/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.5511 - accuracy: 0.3429 - val_loss: 0.5067 - val_accuracy: 0.4356
# Epoch 7/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.5435 - accuracy: 0.3561 - val_loss: 0.4961 - val_accuracy: 0.4950
# Epoch 8/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.5360 - accuracy: 0.3958 - val_loss: 0.4772 - val_accuracy: 0.5347
# Epoch 9/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.5125 - accuracy: 0.4465 - val_loss: 0.4515 - val_accuracy: 0.6040
# Epoch 10/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.4870 - accuracy: 0.4983 - val_loss: 0.4383 - val_accuracy: 0.5446
# Epoch 11/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.4652 - accuracy: 0.5347 - val_loss: 0.4412 - val_accuracy: 0.5842
# Epoch 12/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.4437 - accuracy: 0.5634 - val_loss: 0.4108 - val_accuracy: 0.6337
# Epoch 13/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.4287 - accuracy: 0.5987 - val_loss: 0.3737 - val_accuracy: 0.6337
# Epoch 14/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.4085 - accuracy: 0.6262 - val_loss: 0.3609 - val_accuracy: 0.6337
# Epoch 15/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.3915 - accuracy: 0.6637 - val_loss: 0.3661 - val_accuracy: 0.6535
# Epoch 16/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.3618 - accuracy: 0.6869 - val_loss: 0.3864 - val_accuracy: 0.6535
# Epoch 17/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.3442 - accuracy: 0.7067 - val_loss: 0.4040 - val_accuracy: 0.6040
# Epoch 18/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.3206 - accuracy: 0.7178 - val_loss: 0.3873 - val_accuracy: 0.6436
# Epoch 19/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.3139 - accuracy: 0.7508 - val_loss: 0.3018 - val_accuracy: 0.7327
# Epoch 20/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.2930 - accuracy: 0.7607 - val_loss: 0.2968 - val_accuracy: 0.7525
# Epoch 21/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.2850 - accuracy: 0.7574 - val_loss: 0.2670 - val_accuracy: 0.7525
# Epoch 22/250
# 57/57 [==============================] - 1s 14ms/step - loss: 0.2785 - accuracy: 0.7817 - val_loss: 0.2908 - val_accuracy: 0.7723
# Epoch 23/250
# 57/57 [==============================] - 1s 15ms/step - loss: 0.2743 - accuracy: 0.7784 - val_loss: 0.3282 - val_accuracy: 0.7030
# Epoch 24/250
# 57/57 [==============================] - 1s 14ms/step - loss: 0.2543 - accuracy: 0.7949 - val_loss: 0.3454 - val_accuracy: 0.7129
# Epoch 25/250
# 57/57 [==============================] - 1s 14ms/step - loss: 0.2586 - accuracy: 0.8071 - val_loss: 0.2820 - val_accuracy: 0.7723
# Epoch 26/250
# 57/57 [==============================] - 1s 13ms/step - loss: 0.2426 - accuracy: 0.8093 - val_loss: 0.2546 - val_accuracy: 0.8020
# Epoch 27/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.2216 - accuracy: 0.8258 - val_loss: 0.2209 - val_accuracy: 0.8020
# Epoch 28/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.2144 - accuracy: 0.8434 - val_loss: 0.3176 - val_accuracy: 0.7525
# Epoch 29/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.2107 - accuracy: 0.8423 - val_loss: 0.2768 - val_accuracy: 0.7525
# Epoch 30/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.2048 - accuracy: 0.8412 - val_loss: 0.2480 - val_accuracy: 0.7624
# Epoch 31/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.2077 - accuracy: 0.8456 - val_loss: 0.2491 - val_accuracy: 0.7822
# Epoch 32/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.1875 - accuracy: 0.8600 - val_loss: 0.2901 - val_accuracy: 0.7822
# Epoch 33/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.1854 - accuracy: 0.8490 - val_loss: 0.2208 - val_accuracy: 0.8614
# Epoch 34/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.1713 - accuracy: 0.8798 - val_loss: 0.2962 - val_accuracy: 0.7228
# Epoch 35/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.1677 - accuracy: 0.8798 - val_loss: 0.2426 - val_accuracy: 0.8119
# Epoch 36/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.1752 - accuracy: 0.8655 - val_loss: 0.2539 - val_accuracy: 0.7525
# Epoch 37/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.1789 - accuracy: 0.8556 - val_loss: 0.2196 - val_accuracy: 0.8119
# Epoch 38/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.1425 - accuracy: 0.8886 - val_loss: 0.2516 - val_accuracy: 0.7921
# Epoch 39/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.1607 - accuracy: 0.8842 - val_loss: 0.2470 - val_accuracy: 0.8119
# Epoch 40/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.1473 - accuracy: 0.9008 - val_loss: 0.2801 - val_accuracy: 0.7426
# Epoch 41/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.1482 - accuracy: 0.8864 - val_loss: 0.2772 - val_accuracy: 0.7723
# Epoch 42/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.1613 - accuracy: 0.8743 - val_loss: 0.2392 - val_accuracy: 0.7822
# Epoch 43/250
# 57/57 [==============================] - 1s 12ms/step - loss: 0.1417 - accuracy: 0.8964 - val_loss: 0.2212 - val_accuracy: 0.7921
# Epoch 44/250
# 57/57 [==============================] - 1s 14ms/step - loss: 0.1387 - accuracy: 0.9019 - val_loss: 0.2062 - val_accuracy: 0.8317
# Epoch 45/250
# 57/57 [==============================] - 1s 14ms/step - loss: 0.1305 - accuracy: 0.9030 - val_loss: 0.3347 - val_accuracy: 0.6931
# Epoch 46/250
# 57/57 [==============================] - 1s 14ms/step - loss: 0.1251 - accuracy: 0.9173 - val_loss: 0.2191 - val_accuracy: 0.8317
# Epoch 47/250
# 57/57 [==============================] - 1s 15ms/step - loss: 0.1203 - accuracy: 0.9272 - val_loss: 0.2308 - val_accuracy: 0.8119
# Epoch 48/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.1283 - accuracy: 0.9074 - val_loss: 0.2233 - val_accuracy: 0.8218
# Epoch 49/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.1153 - accuracy: 0.9173 - val_loss: 0.2517 - val_accuracy: 0.7822
# Epoch 50/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.1265 - accuracy: 0.9107 - val_loss: 0.2467 - val_accuracy: 0.7921
# Epoch 51/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.1023 - accuracy: 0.9316 - val_loss: 0.3064 - val_accuracy: 0.7723
# Epoch 52/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.1288 - accuracy: 0.9041 - val_loss: 0.2690 - val_accuracy: 0.7921
# Epoch 53/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0998 - accuracy: 0.9261 - val_loss: 0.2431 - val_accuracy: 0.8020
# Epoch 54/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0952 - accuracy: 0.9350 - val_loss: 0.2698 - val_accuracy: 0.7921
# Epoch 55/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0908 - accuracy: 0.9338 - val_loss: 0.2603 - val_accuracy: 0.7921
# Epoch 56/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0906 - accuracy: 0.9327 - val_loss: 0.2791 - val_accuracy: 0.7822
# Epoch 57/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0957 - accuracy: 0.9316 - val_loss: 0.2403 - val_accuracy: 0.7822
# Epoch 58/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0969 - accuracy: 0.9261 - val_loss: 0.2464 - val_accuracy: 0.8020
# Epoch 59/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0959 - accuracy: 0.9361 - val_loss: 0.2389 - val_accuracy: 0.8119
# Epoch 60/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0983 - accuracy: 0.9272 - val_loss: 0.2684 - val_accuracy: 0.7723
# Epoch 61/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0918 - accuracy: 0.9394 - val_loss: 0.2746 - val_accuracy: 0.7723
# Epoch 62/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0838 - accuracy: 0.9394 - val_loss: 0.2975 - val_accuracy: 0.7723
# Epoch 63/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0805 - accuracy: 0.9493 - val_loss: 0.3246 - val_accuracy: 0.7624
# Epoch 64/250
# 57/57 [==============================] - 1s 12ms/step - loss: 0.0802 - accuracy: 0.9471 - val_loss: 0.3104 - val_accuracy: 0.7921
# Epoch 65/250
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0703 - accuracy: 0.9515 - val_loss: 0.2269 - val_accuracy: 0.8317
# Epoch 66/250
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0663 - accuracy: 0.9526 - val_loss: 0.2388 - val_accuracy: 0.8218
# Epoch 67/250
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0639 - accuracy: 0.9614 - val_loss: 0.2701 - val_accuracy: 0.8218
# Epoch 68/250
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0724 - accuracy: 0.9493 - val_loss: 0.2763 - val_accuracy: 0.8218
# Epoch 69/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0911 - accuracy: 0.9338 - val_loss: 0.2353 - val_accuracy: 0.8119
# Epoch 70/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0671 - accuracy: 0.9537 - val_loss: 0.2522 - val_accuracy: 0.8020
# Epoch 71/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0801 - accuracy: 0.9482 - val_loss: 0.2430 - val_accuracy: 0.8416
# Epoch 72/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0689 - accuracy: 0.9493 - val_loss: 0.2215 - val_accuracy: 0.8416
# Epoch 73/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0659 - accuracy: 0.9482 - val_loss: 0.2557 - val_accuracy: 0.8218
# Epoch 74/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0630 - accuracy: 0.9614 - val_loss: 0.2478 - val_accuracy: 0.8218
# Epoch 75/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0820 - accuracy: 0.9482 - val_loss: 0.2793 - val_accuracy: 0.8218
# Epoch 76/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0612 - accuracy: 0.9603 - val_loss: 0.2457 - val_accuracy: 0.7822
# Epoch 77/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0653 - accuracy: 0.9592 - val_loss: 0.2798 - val_accuracy: 0.7624
# Epoch 78/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0590 - accuracy: 0.9636 - val_loss: 0.2523 - val_accuracy: 0.8416
# Epoch 79/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0617 - accuracy: 0.9570 - val_loss: 0.4290 - val_accuracy: 0.7327
# Epoch 80/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0626 - accuracy: 0.9526 - val_loss: 0.2603 - val_accuracy: 0.7921
# Epoch 81/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0584 - accuracy: 0.9570 - val_loss: 0.2976 - val_accuracy: 0.7525
# Epoch 82/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0624 - accuracy: 0.9559 - val_loss: 0.3152 - val_accuracy: 0.7723
# Epoch 83/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0674 - accuracy: 0.9570 - val_loss: 0.3274 - val_accuracy: 0.7822
# Epoch 84/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0488 - accuracy: 0.9713 - val_loss: 0.3064 - val_accuracy: 0.8119
# Epoch 85/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0542 - accuracy: 0.9724 - val_loss: 0.2810 - val_accuracy: 0.8020
# Epoch 86/250
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0587 - accuracy: 0.9559 - val_loss: 0.2248 - val_accuracy: 0.8317
# Epoch 87/250
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0452 - accuracy: 0.9735 - val_loss: 0.2421 - val_accuracy: 0.8119
# Epoch 88/250
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0519 - accuracy: 0.9636 - val_loss: 0.3300 - val_accuracy: 0.8218
# Epoch 89/250
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0632 - accuracy: 0.9581 - val_loss: 0.2658 - val_accuracy: 0.8119
# Epoch 90/250
# 57/57 [==============================] - 1s 12ms/step - loss: 0.0472 - accuracy: 0.9757 - val_loss: 0.2454 - val_accuracy: 0.8119
# Epoch 91/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0499 - accuracy: 0.9636 - val_loss: 0.2863 - val_accuracy: 0.8020
# Epoch 92/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0418 - accuracy: 0.9768 - val_loss: 0.2767 - val_accuracy: 0.8317
# Epoch 93/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0480 - accuracy: 0.9669 - val_loss: 0.3898 - val_accuracy: 0.8020
# Epoch 94/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0527 - accuracy: 0.9658 - val_loss: 0.3011 - val_accuracy: 0.7921
# Epoch 95/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0574 - accuracy: 0.9658 - val_loss: 0.2900 - val_accuracy: 0.7822
# Epoch 96/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0441 - accuracy: 0.9702 - val_loss: 0.2749 - val_accuracy: 0.8317
# Epoch 97/250
# 57/57 [==============================] - 1s 12ms/step - loss: 0.0337 - accuracy: 0.9824 - val_loss: 0.2102 - val_accuracy: 0.8713
# Epoch 98/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0409 - accuracy: 0.9757 - val_loss: 0.2790 - val_accuracy: 0.8515
# Epoch 99/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0567 - accuracy: 0.9691 - val_loss: 0.3013 - val_accuracy: 0.8020
# Epoch 100/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0656 - accuracy: 0.9603 - val_loss: 0.2953 - val_accuracy: 0.8020
# Epoch 101/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0551 - accuracy: 0.9625 - val_loss: 0.2954 - val_accuracy: 0.8218
# Epoch 102/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0392 - accuracy: 0.9735 - val_loss: 0.3043 - val_accuracy: 0.7525
# Epoch 103/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0450 - accuracy: 0.9724 - val_loss: 0.3355 - val_accuracy: 0.7921
# Epoch 104/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0583 - accuracy: 0.9691 - val_loss: 0.2513 - val_accuracy: 0.8416
# Epoch 105/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0453 - accuracy: 0.9724 - val_loss: 0.6441 - val_accuracy: 0.6634
# Epoch 106/250
# 57/57 [==============================] - 1s 12ms/step - loss: 0.0566 - accuracy: 0.9680 - val_loss: 0.2642 - val_accuracy: 0.7822
# Epoch 107/250
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0470 - accuracy: 0.9691 - val_loss: 0.3459 - val_accuracy: 0.8020
# Epoch 108/250
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0368 - accuracy: 0.9779 - val_loss: 0.2592 - val_accuracy: 0.8218
# Epoch 109/250
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0281 - accuracy: 0.9879 - val_loss: 0.2375 - val_accuracy: 0.8317
# Epoch 110/250
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0371 - accuracy: 0.9768 - val_loss: 0.2981 - val_accuracy: 0.8020
# Epoch 111/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0300 - accuracy: 0.9835 - val_loss: 0.2813 - val_accuracy: 0.8416
# Epoch 112/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0323 - accuracy: 0.9824 - val_loss: 0.2833 - val_accuracy: 0.8416
# Epoch 113/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0516 - accuracy: 0.9724 - val_loss: 0.3590 - val_accuracy: 0.7921
# Epoch 114/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0402 - accuracy: 0.9757 - val_loss: 0.2501 - val_accuracy: 0.8317
# Epoch 115/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0413 - accuracy: 0.9746 - val_loss: 0.2819 - val_accuracy: 0.8119
# Epoch 116/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0287 - accuracy: 0.9857 - val_loss: 0.3117 - val_accuracy: 0.7723
# Epoch 117/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0442 - accuracy: 0.9746 - val_loss: 0.3120 - val_accuracy: 0.8119
# Epoch 118/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0277 - accuracy: 0.9846 - val_loss: 0.2706 - val_accuracy: 0.8218
# Epoch 119/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0348 - accuracy: 0.9757 - val_loss: 0.2898 - val_accuracy: 0.7822
# Epoch 120/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0329 - accuracy: 0.9779 - val_loss: 0.3495 - val_accuracy: 0.8020
# Epoch 121/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0379 - accuracy: 0.9680 - val_loss: 0.3042 - val_accuracy: 0.8416
# Epoch 122/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0244 - accuracy: 0.9879 - val_loss: 0.2746 - val_accuracy: 0.8119
# Epoch 123/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0373 - accuracy: 0.9757 - val_loss: 0.3479 - val_accuracy: 0.7921
# Epoch 124/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0290 - accuracy: 0.9824 - val_loss: 0.3366 - val_accuracy: 0.8119
# Epoch 125/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0163 - accuracy: 0.9923 - val_loss: 0.2641 - val_accuracy: 0.8416
# Epoch 126/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0396 - accuracy: 0.9757 - val_loss: 0.2800 - val_accuracy: 0.8119
# Epoch 127/250
# 57/57 [==============================] - 1s 12ms/step - loss: 0.0379 - accuracy: 0.9835 - val_loss: 0.2987 - val_accuracy: 0.8218
# Epoch 128/250
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0347 - accuracy: 0.9791 - val_loss: 0.3613 - val_accuracy: 0.7921
# Epoch 129/250
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0332 - accuracy: 0.9835 - val_loss: 0.3015 - val_accuracy: 0.8020
# Epoch 130/250
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0294 - accuracy: 0.9824 - val_loss: 0.2701 - val_accuracy: 0.8317
# Epoch 131/250
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0319 - accuracy: 0.9802 - val_loss: 0.2922 - val_accuracy: 0.8020
# Epoch 132/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0323 - accuracy: 0.9746 - val_loss: 0.3419 - val_accuracy: 0.7921
# Epoch 133/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0251 - accuracy: 0.9846 - val_loss: 0.3183 - val_accuracy: 0.8119
# Epoch 134/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0320 - accuracy: 0.9824 - val_loss: 0.3473 - val_accuracy: 0.8020
# Epoch 135/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0383 - accuracy: 0.9791 - val_loss: 0.3764 - val_accuracy: 0.7723
# Epoch 136/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0398 - accuracy: 0.9802 - val_loss: 0.2909 - val_accuracy: 0.8218
# Epoch 137/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0322 - accuracy: 0.9824 - val_loss: 0.2867 - val_accuracy: 0.8416
# Epoch 138/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0243 - accuracy: 0.9890 - val_loss: 0.3075 - val_accuracy: 0.8317
# Epoch 139/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0165 - accuracy: 0.9912 - val_loss: 0.3501 - val_accuracy: 0.8020
# Epoch 140/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0193 - accuracy: 0.9890 - val_loss: 0.3728 - val_accuracy: 0.7723
# Epoch 141/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0323 - accuracy: 0.9824 - val_loss: 0.3105 - val_accuracy: 0.8218
# Epoch 142/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0292 - accuracy: 0.9824 - val_loss: 0.3265 - val_accuracy: 0.8020
# Epoch 143/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0300 - accuracy: 0.9824 - val_loss: 0.3326 - val_accuracy: 0.8614
# Epoch 144/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0351 - accuracy: 0.9802 - val_loss: 0.2982 - val_accuracy: 0.8119
# Epoch 145/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0320 - accuracy: 0.9779 - val_loss: 0.3611 - val_accuracy: 0.7624
# Epoch 146/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0236 - accuracy: 0.9835 - val_loss: 0.2647 - val_accuracy: 0.8020
# Epoch 147/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0243 - accuracy: 0.9890 - val_loss: 0.2757 - val_accuracy: 0.8119
# Epoch 148/250
# 57/57 [==============================] - 1s 12ms/step - loss: 0.0264 - accuracy: 0.9868 - val_loss: 0.3579 - val_accuracy: 0.7822
# Epoch 149/250
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0197 - accuracy: 0.9868 - val_loss: 0.3203 - val_accuracy: 0.8020
# Epoch 150/250
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0398 - accuracy: 0.9779 - val_loss: 0.3171 - val_accuracy: 0.7921
# Epoch 151/250
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0275 - accuracy: 0.9802 - val_loss: 0.3920 - val_accuracy: 0.7822
# Epoch 152/250
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0407 - accuracy: 0.9846 - val_loss: 0.3392 - val_accuracy: 0.7921
# Epoch 153/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0364 - accuracy: 0.9824 - val_loss: 0.3329 - val_accuracy: 0.7921
# Epoch 154/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0257 - accuracy: 0.9912 - val_loss: 0.2718 - val_accuracy: 0.8317
# Epoch 155/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0156 - accuracy: 0.9901 - val_loss: 0.2838 - val_accuracy: 0.8119
# Epoch 156/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0183 - accuracy: 0.9923 - val_loss: 0.2718 - val_accuracy: 0.8119
# Epoch 157/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0287 - accuracy: 0.9802 - val_loss: 0.2850 - val_accuracy: 0.8119
# Epoch 158/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0178 - accuracy: 0.9868 - val_loss: 0.3157 - val_accuracy: 0.8119
# Epoch 159/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0255 - accuracy: 0.9857 - val_loss: 0.3803 - val_accuracy: 0.7822
# Epoch 160/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0253 - accuracy: 0.9868 - val_loss: 0.3556 - val_accuracy: 0.7822
# Epoch 161/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0100 - accuracy: 0.9956 - val_loss: 0.3674 - val_accuracy: 0.8020
# Epoch 162/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0406 - accuracy: 0.9802 - val_loss: 0.2983 - val_accuracy: 0.7921
# Epoch 163/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0282 - accuracy: 0.9813 - val_loss: 0.2489 - val_accuracy: 0.8317
# Epoch 164/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0182 - accuracy: 0.9890 - val_loss: 0.2675 - val_accuracy: 0.8317
# Epoch 165/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0179 - accuracy: 0.9923 - val_loss: 0.2645 - val_accuracy: 0.8317
# Epoch 166/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0159 - accuracy: 0.9923 - val_loss: 0.3048 - val_accuracy: 0.8119
# Epoch 167/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0330 - accuracy: 0.9802 - val_loss: 0.4148 - val_accuracy: 0.7723
# Epoch 168/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0322 - accuracy: 0.9813 - val_loss: 0.3470 - val_accuracy: 0.7822
# Epoch 169/250
# 57/57 [==============================] - 1s 12ms/step - loss: 0.0265 - accuracy: 0.9879 - val_loss: 0.2965 - val_accuracy: 0.8515
# Epoch 170/250
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0119 - accuracy: 0.9945 - val_loss: 0.3356 - val_accuracy: 0.8416
# Epoch 171/250
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0256 - accuracy: 0.9879 - val_loss: 0.3468 - val_accuracy: 0.8119
# Epoch 172/250
# 57/57 [==============================] - 1s 13ms/step - loss: 0.0336 - accuracy: 0.9846 - val_loss: 0.3641 - val_accuracy: 0.8119
# Epoch 173/250
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0115 - accuracy: 0.9967 - val_loss: 0.3924 - val_accuracy: 0.7921
# Epoch 174/250
# 57/57 [==============================] - 1s 12ms/step - loss: 0.0223 - accuracy: 0.9912 - val_loss: 0.3232 - val_accuracy: 0.8119
# Epoch 175/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0202 - accuracy: 0.9890 - val_loss: 0.2952 - val_accuracy: 0.8317
# Epoch 176/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0254 - accuracy: 0.9846 - val_loss: 0.2814 - val_accuracy: 0.8317
# Epoch 177/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0174 - accuracy: 0.9901 - val_loss: 0.3670 - val_accuracy: 0.8218
# Epoch 178/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0336 - accuracy: 0.9868 - val_loss: 0.2812 - val_accuracy: 0.8119
# Epoch 179/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0210 - accuracy: 0.9835 - val_loss: 0.3511 - val_accuracy: 0.8317
# Epoch 180/250
# 57/57 [==============================] - 1s 12ms/step - loss: 0.0122 - accuracy: 0.9912 - val_loss: 0.3173 - val_accuracy: 0.8119
# Epoch 181/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0335 - accuracy: 0.9802 - val_loss: 0.3229 - val_accuracy: 0.8515
# Epoch 182/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0150 - accuracy: 0.9868 - val_loss: 0.3255 - val_accuracy: 0.8218
# Epoch 183/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0290 - accuracy: 0.9857 - val_loss: 0.3430 - val_accuracy: 0.8020
# Epoch 184/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0399 - accuracy: 0.9824 - val_loss: 0.2782 - val_accuracy: 0.8614
# Epoch 185/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0256 - accuracy: 0.9879 - val_loss: 0.3603 - val_accuracy: 0.8119
# Epoch 186/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0177 - accuracy: 0.9912 - val_loss: 0.3883 - val_accuracy: 0.8218
# Epoch 187/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0170 - accuracy: 0.9923 - val_loss: 0.3173 - val_accuracy: 0.8317
# Epoch 188/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0259 - accuracy: 0.9835 - val_loss: 0.3443 - val_accuracy: 0.8416
# Epoch 189/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0234 - accuracy: 0.9879 - val_loss: 0.3473 - val_accuracy: 0.8119
# Epoch 190/250
# 57/57 [==============================] - 1s 13ms/step - loss: 0.0322 - accuracy: 0.9879 - val_loss: 0.3165 - val_accuracy: 0.8317
# Epoch 191/250
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0175 - accuracy: 0.9901 - val_loss: 0.3453 - val_accuracy: 0.8317
# Epoch 192/250
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0283 - accuracy: 0.9824 - val_loss: 0.3099 - val_accuracy: 0.8218
# Epoch 193/250
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0224 - accuracy: 0.9879 - val_loss: 0.4470 - val_accuracy: 0.8020
# Epoch 194/250
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0352 - accuracy: 0.9857 - val_loss: 0.3382 - val_accuracy: 0.8416
# Epoch 195/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0223 - accuracy: 0.9846 - val_loss: 0.3045 - val_accuracy: 0.8119
# Epoch 196/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0327 - accuracy: 0.9824 - val_loss: 0.4150 - val_accuracy: 0.7723
# Epoch 197/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0134 - accuracy: 0.9901 - val_loss: 0.4007 - val_accuracy: 0.8119
# Epoch 198/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0237 - accuracy: 0.9868 - val_loss: 0.3277 - val_accuracy: 0.8218
# Epoch 199/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0201 - accuracy: 0.9868 - val_loss: 0.3971 - val_accuracy: 0.7921
# Epoch 200/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0201 - accuracy: 0.9868 - val_loss: 0.3505 - val_accuracy: 0.8218
# Epoch 201/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0162 - accuracy: 0.9923 - val_loss: 0.3287 - val_accuracy: 0.8317
# Epoch 202/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0166 - accuracy: 0.9923 - val_loss: 0.3171 - val_accuracy: 0.8515
# Epoch 203/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0156 - accuracy: 0.9956 - val_loss: 0.3415 - val_accuracy: 0.8416
# Epoch 204/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0268 - accuracy: 0.9879 - val_loss: 0.3120 - val_accuracy: 0.7822
# Epoch 205/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0200 - accuracy: 0.9868 - val_loss: 0.3505 - val_accuracy: 0.7822
# Epoch 206/250
# 57/57 [==============================] - 1s 12ms/step - loss: 0.0287 - accuracy: 0.9857 - val_loss: 0.3195 - val_accuracy: 0.8317
# Epoch 207/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0116 - accuracy: 0.9934 - val_loss: 0.2858 - val_accuracy: 0.8317
# Epoch 208/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0258 - accuracy: 0.9824 - val_loss: 0.3309 - val_accuracy: 0.8119
# Epoch 209/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0190 - accuracy: 0.9901 - val_loss: 0.3360 - val_accuracy: 0.7822
# Epoch 210/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0387 - accuracy: 0.9791 - val_loss: 0.3912 - val_accuracy: 0.8020
# Epoch 211/250
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0236 - accuracy: 0.9901 - val_loss: 0.3502 - val_accuracy: 0.7723
# Epoch 212/250
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0301 - accuracy: 0.9846 - val_loss: 0.2833 - val_accuracy: 0.8416
# Epoch 213/250
# 57/57 [==============================] - 1s 13ms/step - loss: 0.0202 - accuracy: 0.9879 - val_loss: 0.3167 - val_accuracy: 0.8119
# Epoch 214/250
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0114 - accuracy: 0.9934 - val_loss: 0.3576 - val_accuracy: 0.8020
# Epoch 215/250
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0227 - accuracy: 0.9857 - val_loss: 0.3825 - val_accuracy: 0.8218
# Epoch 216/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0211 - accuracy: 0.9879 - val_loss: 0.3144 - val_accuracy: 0.8119
# Epoch 217/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0153 - accuracy: 0.9923 - val_loss: 0.2747 - val_accuracy: 0.8416
# Epoch 218/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0317 - accuracy: 0.9857 - val_loss: 0.3479 - val_accuracy: 0.7921
# Epoch 219/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0148 - accuracy: 0.9956 - val_loss: 0.2823 - val_accuracy: 0.8119
# Epoch 220/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0128 - accuracy: 0.9901 - val_loss: 0.3948 - val_accuracy: 0.8119
# Epoch 221/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0130 - accuracy: 0.9934 - val_loss: 0.3709 - val_accuracy: 0.8317
# Epoch 222/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0242 - accuracy: 0.9901 - val_loss: 0.4153 - val_accuracy: 0.8218
# Epoch 223/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0108 - accuracy: 0.9956 - val_loss: 0.3886 - val_accuracy: 0.8119
# Epoch 224/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0099 - accuracy: 0.9967 - val_loss: 0.3405 - val_accuracy: 0.8119
# Epoch 225/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0128 - accuracy: 0.9923 - val_loss: 0.2741 - val_accuracy: 0.8119
# Epoch 226/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0255 - accuracy: 0.9879 - val_loss: 0.2969 - val_accuracy: 0.8119
# Epoch 227/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0155 - accuracy: 0.9923 - val_loss: 0.3911 - val_accuracy: 0.8020
# Epoch 228/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0171 - accuracy: 0.9934 - val_loss: 0.2932 - val_accuracy: 0.8416
# Epoch 229/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0147 - accuracy: 0.9923 - val_loss: 0.3226 - val_accuracy: 0.8218
# Epoch 230/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0134 - accuracy: 0.9912 - val_loss: 0.2986 - val_accuracy: 0.8416
# Epoch 231/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0144 - accuracy: 0.9923 - val_loss: 0.3390 - val_accuracy: 0.8317
# Epoch 232/250
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0057 - accuracy: 0.9978 - val_loss: 0.3688 - val_accuracy: 0.8119
# Epoch 233/250
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0240 - accuracy: 0.9890 - val_loss: 0.3858 - val_accuracy: 0.8218
# Epoch 234/250
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0228 - accuracy: 0.9857 - val_loss: 0.3399 - val_accuracy: 0.8317
# Epoch 235/250
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0077 - accuracy: 0.9978 - val_loss: 0.3726 - val_accuracy: 0.8416
# Epoch 236/250
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0212 - accuracy: 0.9890 - val_loss: 0.4239 - val_accuracy: 0.8218
# Epoch 237/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0150 - accuracy: 0.9923 - val_loss: 0.3666 - val_accuracy: 0.8020
# Epoch 238/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0117 - accuracy: 0.9945 - val_loss: 0.3722 - val_accuracy: 0.8416
# Epoch 239/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0219 - accuracy: 0.9901 - val_loss: 0.4380 - val_accuracy: 0.8020
# Epoch 240/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0156 - accuracy: 0.9912 - val_loss: 0.4293 - val_accuracy: 0.8119
# Epoch 241/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0139 - accuracy: 0.9945 - val_loss: 0.5944 - val_accuracy: 0.7822
# Epoch 242/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0073 - accuracy: 0.9945 - val_loss: 0.3487 - val_accuracy: 0.8020
# Epoch 243/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0189 - accuracy: 0.9890 - val_loss: 0.3886 - val_accuracy: 0.8020
# Epoch 244/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0099 - accuracy: 0.9945 - val_loss: 0.3821 - val_accuracy: 0.8020
# Epoch 245/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0068 - accuracy: 0.9978 - val_loss: 0.3952 - val_accuracy: 0.7921
# Epoch 246/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0271 - accuracy: 0.9890 - val_loss: 0.4106 - val_accuracy: 0.7723
# Epoch 247/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0107 - accuracy: 0.9945 - val_loss: 0.3561 - val_accuracy: 0.8119
# Epoch 248/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0383 - accuracy: 0.9813 - val_loss: 0.3979 - val_accuracy: 0.7921
# Epoch 249/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0170 - accuracy: 0.9890 - val_loss: 0.4423 - val_accuracy: 0.7426
# Epoch 250/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0084 - accuracy: 0.9967 - val_loss: 0.4320 - val_accuracy: 0.7921
# Saving trained model...
# Testing...
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 4/4 [==============================] - 1s 6ms/step
# [[22  1  1  4]
#  [ 2 24  2  2]
#  [ 2  3 21  1]
#  [ 2  4  3 18]]
# [[0.79 0.04 0.04 0.14]
#  [0.07 0.8  0.07 0.07]
#  [0.07 0.11 0.78 0.04]
#  [0.07 0.15 0.11 0.67]]
# 75.89%
# 新的结果文件夹名称为： result_MultiAttention_LSTM_1层Transformer_BCE_epoch250_batchsize16_lr0.008_75.89%
# 程序执行时间为：485.68秒

# %%
# 定位到指定路径下
import os
os.chdir('/content/drive/MyDrive/Colab_Notebooks/RNN-CAP')
print(os.getcwd())

# 打印版本
import sys
import tensorflow as tf

print("Python 版本:", sys.version)
print("TensorFlow 版本:", tf.__version__)

# !pip install xlwt
# !pip install matplotlib

# %%
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_categorical_crossentropy_epoch30.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_categorical_crossentropy_epoch250.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_categorical_crossentropy_epoch50.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_categorical_crossentropy_epoch100.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_categorical_crossentropy_epoch150.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_categorical_crossentropy_epoch200.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_squared_error_epoch30.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_squared_error_epoch50.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_squared_error_epoch100.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_squared_error_epoch150.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_squared_error_epoch200.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_squared_error_epoch250.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_absolute_error_epoch30.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_absolute_error_epoch50.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_absolute_error_epoch100.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_absolute_error_epoch150.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_absolute_error_epoch200.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_absolute_error_epoch250.py

# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_binary_crossentropy_epoch30.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_binary_crossentropy_epoch50.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_binary_crossentropy_epoch100.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_binary_crossentropy_epoch150.py

#!python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_binary_crossentropy_epoch200.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_binary_crossentropy_epoch250.py
