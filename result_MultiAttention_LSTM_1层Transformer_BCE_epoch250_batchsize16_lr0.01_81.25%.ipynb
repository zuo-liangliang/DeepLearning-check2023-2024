# %% [markdown]
# <a href="https://colab.research.google.com/github/zuo-liangliang/fcn.berkeleyvision.org/blob/master/result_MultiAttention_LSTM_1%E5%B1%82Transformer_BCE_epoch250_batchsize16_lr0.01_81.25%25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import zipfile

# 定义源文件夹路径和目标 zip 文件夹路径
# source_folder = '/content/drive/MyDrive/Colab_Notebooks/528BVP-acnt2'
source_folder = '/content/drive/MyDrive/AugustResult'
# target_zip_folder = '/content/drive/MyDrive/Colab_Notebooks/zip_folder'
# target_zip_folder = '/content/drive/MyDrive/Colab_Notebooks/528BVP-acnt2/0827zip_folder'
target_zip_folder = '/content/drive/MyDrive/AugustResult/0907_月月账号zip_folder'

# 确保目标 zip 文件夹存在
os.makedirs(target_zip_folder, exist_ok=True)

# 获取源文件夹中以 "result" 开头的文件夹列表
folder_list = [folder for folder in os.listdir(source_folder) if os.path.isdir(os.path.join(source_folder, folder)) and folder.startswith("result")]

# 创建一个大的 zip 文件
with zipfile.ZipFile(os.path.join(target_zip_folder, '0907月月_all_folders.zip'), 'w', zipfile.ZIP_DEFLATED) as zipf:
    # 遍历文件夹列表，逐个压缩为 zip 文件
    for folder in folder_list:
        folder_path = os.path.join(source_folder, folder)

        # 遍历文件夹中的所有文件和子文件夹，并逐个添加到大的 zip 文件中
        for root, dirs, files in os.walk(folder_path):
            for file in files:
                file_path = os.path.join(root, file)
                zipf.write(file_path, os.path.relpath(file_path, source_folder))

print("所有文件夹已压缩为一个大的 zip 文件！")
# Out:
# 所有文件夹已压缩为一个大的 zip 文件！

# %%
import shutil
import os
# 指定要删除的文件夹路径
folder_path = '/content/drive/MyDrive/Colab_Notebooks/528BVP-acnt2/user14' #替换为你的文件夹路径

# 确保要删除的是一个目录而不是文件
assert os.path.isdir(folder_path), f"{folder_path} 不是一个目录"

# 递归删除文件夹下的所有文件和子文件夹
shutil.rmtree(folder_path)

# %%
# 解压指定文件夹到某一路径下
import zipfile

file_path = '/content/drive/MyDrive/Colab_Notebooks/528BVP-acnt2/528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4.zip'
extract_path = '/content/drive/MyDrive/Colab_Notebooks/528BVP-acnt2/528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4'

with zipfile.ZipFile(file_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# %%
# 定位到指定路径下
import os
# os.chdir('/content/drive/MyDrive/SeptemberResult/result_LSTM')
os.chdir('/content/drive/MyDrive/SeptemberResult/result_MultiAttention_LSTM_1层Transformer')
print(os.getcwd())
# Out:
# /content/drive/MyDrive/SeptemberResult/result_MultiAttention_LSTM_1层Transformer

# %%
# result_MultiAttention_LSTM_1层Transformer

from keras.callbacks import Callback
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay

from __future__ import print_function

import time
import os,sys
import numpy as np
import pandas as pd
import scipy.io as scio
import tensorflow as tf
tf.compat.v1.keras.backend.set_session
import keras
from keras.layers import Input, GRU, LSTM, Dense, Flatten, Dropout, Conv2D, Conv3D, MaxPooling2D, MaxPooling3D, TimeDistributed
from keras.models import Model, load_model
import keras.backend as K
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split

# Parameters
use_existing_model = False
fraction_for_test = 0.1
data_dir = '/content/drive/MyDrive/Colab_Notebooks/528BVP-acnt2/528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4/'
# data_dir = '/content/drive/MyDrive/new528BVP/528[-1,1]长度20-分辨率15_acnt2_sample_rate5000__剔14_改6为4/'

fraction_for_test = 0.1
#ALL_MOTION = [1,2,3,4,5,6]
ALL_MOTION = [2,3,4,5]
N_MOTION = len(ALL_MOTION)
T_MAX = 0
n_epochs = 250  #最优的是100；第2优的是200，第3优的是250，原始是50 #修改点1
f_dropout_ratio = 0.5
n_gru_hidden_units = 128
n_batch_size = 16     #原始是32-->16
f_learning_rate = 0.01  #原始是0.001-->0.002

def normalize_data(data_1):
    # data(ndarray)=>data_norm(ndarray): [20,20,T]=>[20,20,T]
    data_1_max = np.concatenate((data_1.max(axis=0),data_1.max(axis=1)),axis=0).max(axis=0)
    data_1_min = np.concatenate((data_1.min(axis=0),data_1.min(axis=1)),axis=0).min(axis=0)
    if (len(np.where((data_1_max - data_1_min) == 0)[0]) > 0):
        return data_1
    data_1_max_rep = np.tile(data_1_max,(data_1.shape[0],data_1.shape[1],1))
    data_1_min_rep = np.tile(data_1_min,(data_1.shape[0],data_1.shape[1],1))
    data_1_norm = (data_1 - data_1_min_rep) / (data_1_max_rep - data_1_min_rep)
    return  data_1_norm

def zero_padding(data, T_MAX):
    # data(list)=>data_pad(ndarray): [20,20,T1/T2/...]=>[20,20,T_MAX]
    data_pad = []
    for i in range(len(data)):
        t = np.array(data[i]).shape[2]
        data_pad.append(np.pad(data[i], ((0,0),(0,0),(T_MAX - t,0)), 'constant', constant_values = 0).tolist())
    return np.array(data_pad)

def onehot_encoding(label, num_class):
    # label(list)=>_label(ndarray): [N,]=>[N,num_class]
    label = np.array(label).astype('int32')
    # assert (np.arange(0,np.unique(label).size)==np.unique(label)).prod()    # Check label from 0 to N
    label = np.squeeze(label)
    # _label = np.eye(num_class)[label-1]     # from label to onehot
    _label = np.eye(num_class)[label-2]   #修改点2
    return _label

def load_data(path_to_data, motion_sel):
    global T_MAX
    data = []
    label = []
    for data_root, data_dirs, data_files in os.walk(path_to_data):
        for data_file_name in data_files:

            file_path = os.path.join(data_root,data_file_name)
            try:
                data_1 = scio.loadmat(file_path)['velocity_spectrum_ro']
                label_1 = int(data_file_name.split('-')[1])
                #location = int(data_file_name.split('-')[2])
                #orientation = int(data_file_name.split('-')[3])
                #repetition = int(data_file_name.split('-')[4])
                repetition = int(data_file_name.split('-')[2])  #修改点3

                # Select Motion
                if (label_1 not in motion_sel):
                    continue

                # Select Location
                # if (location not in [1,2,3,5]):
                #     continue

                # Select Orientation
                # if (orientation not in [1,2,4,5]):
                #     continue

                # Normalization
                data_normed_1 = normalize_data(data_1)

                # Update T_MAX
                if T_MAX < np.array(data_1).shape[2]:
                    T_MAX = np.array(data_1).shape[2]
            except Exception:
                continue

            # Save List
            data.append(data_normed_1.tolist())
            label.append(label_1)
                # Zero-padding
    data = zero_padding(data, T_MAX)

    # Swap axes
    data = np.swapaxes(np.swapaxes(data, 1, 3), 2, 3)   # [N,20,20',T_MAX]=>[N,T_MAX,20,20']
    data = np.expand_dims(data, axis=-1)    # [N,T_MAX,20,20]=>[N,T_MAX,20,20,1]

    # Convert label to ndarray
    label = np.array(label)

    # data(ndarray): [N,T_MAX,20,20,1], label(ndarray): [N,N_MOTION]
    return data, label

# 构建符合输入形状为 (None, 20, 15, 15, 1) 和输出形状为 (None, 4) 的  模型：
from keras.layers import MultiHeadAttention, LayerNormalization  #加Transformer修改点1
num_transformer_layers = 1  # 设置Transformer层数 #加Transformer修改点2  2层-->1层

#加Transformer修改点3
def transformer_layer(inputs, hidden_units, dropout_rate):
    # Self-attention
    attention_output = MultiHeadAttention(
        num_heads=8, key_dim=hidden_units // 8
    )(inputs, inputs)
    attention_output = Dropout(dropout_rate)(attention_output)
    attention_output = LayerNormalization()(attention_output + inputs)

    # Feed-forward network
    ffn = Dense(hidden_units, activation="relu")(attention_output)
    ffn = Dense(hidden_units)(ffn)
    ffn = Dropout(dropout_rate)(ffn)
    ffn = LayerNormalization()(ffn)

    return ffn

#加Transformer修改点4
def assemble_model(input_shape, n_class):
    model_input = Input(shape=input_shape, dtype='float32', name='name_model_input')    # (@,T_MAX,20,20,1)

    # Feature extraction part
    x = TimeDistributed(Conv2D(16,kernel_size=(5,5),activation='relu',data_format='channels_last',\
        input_shape=input_shape))(model_input)   # (@,T_MAX,20,20,1)=>(@,T_MAX,16,16,16)
    x = TimeDistributed(MaxPooling2D(pool_size=(2,2)))(x)    # (@,T_MAX,16,16,16)=>(@,T_MAX,8,8,16)
    x = TimeDistributed(Flatten())(x)   # (@,T_MAX,8,8,16)=>(@,T_MAX,8*8*16)
    x = TimeDistributed(Dense(64,activation='relu'))(x) # (@,T_MAX,8*8*16)=>(@,T_MAX,64)
    x = TimeDistributed(Dropout(f_dropout_ratio))(x)
    x = TimeDistributed(Dense(64,activation='relu'))(x) # (@,T_MAX,64)=>(@,T_MAX,64)

    # Add transformer layers
    for _ in range(num_transformer_layers):
        #x = transformer_layer(x, hidden_units=n_gru_hidden_units, dropout_rate=f_dropout_ratio)
        x = transformer_layer(x, hidden_units=64, dropout_rate=f_dropout_ratio)  # 修改点1
    x = LSTM(n_gru_hidden_units,return_sequences=False)(x)  # (@,T_MAX,64)=>(@,128)
    x = Dropout(f_dropout_ratio)(x)
    model_output = Dense(n_class, activation='softmax', name='name_model_output')(x)  # (@,128)=>(@,n_class)

    # Create the model
    # Model compiling
    model = Model(inputs=model_input, outputs=model_output)
    model.compile(optimizer=keras.optimizers.RMSprop(lr=f_learning_rate),
                    # loss='categorical_crossentropy', # 将损失函数改为多类别交叉熵损失函数 最优的是CCE
                    # loss='mean_squared_error',  # 将损失函数改为均方误差 第2优的是MSE
                    # loss='mean_absolute_error',  # 将损失函数改为平均绝对误差 第3优的是MAE
                    loss='binary_crossentropy',  # 将损失函数改为对数损失函数 第3优的是MAE
                    metrics=['accuracy']
                )
    return model

# 改
#model_type = '双层LSTM'
#model_type = 'LSTM'
#model_type = 'BiLSTM'
model_type = 'MultiAttention_LSTM_1层Transformer'

# 创建结果文件夹
# result_folder = f'result_528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_GRU_改costfunction为mse_epoch200' # 每次都要改
# result_folder = f'result_528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_{model_type}_categorical_crossentropy_epoch{n_epochs}'
# result_folder = f'result_528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_{model_type}_mean_squared_error_epoch{n_epochs}'
# result_folder = f'result_528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_{model_type}_mean_absolute_error_epoch{n_epochs}'
# result_folder = f'result_528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_{model_type}_binary_crossentropy_epoch{n_epochs}'

# result_folder = f'result_{model_type}_CCE_epoch{n_epochs}_batchsize{n_batch_size}_lr{f_learning_rate}'
# result_folder = f'result_{model_type}_MSE_epoch{n_epochs}_batchsize{n_batch_size}_lr{f_learning_rate}'
# result_folder = f'result_{model_type}_MAE_epoch{n_epochs}_batchsize{n_batch_size}_lr{f_learning_rate}'
result_folder = f'result_{model_type}_BCE_epoch{n_epochs}_batchsize{n_batch_size}_lr{f_learning_rate}'

os.makedirs(result_folder, exist_ok=True)

# %%
# Let's BEGIN >>>>

import time
start_time = time.time()  # 记录程序开始时间

# 获取可见的GPU设备列表
# visible_gpus = tf.config.experimental.list_physical_devices('GPU')
# 检查是否存在可见的GPU设备
# if len(visible_gpus) < 1:
    # print('No GPU available')
    # exit(0)
# 设置使用第一个可见的GPU设备
# os.environ["CUDA_VISIBLE_DEVICES"] = str(visible_gpus[0].index)
# 配置GPU选项
# gpu_config = tf.config.experimental.set_memory_growth(visible_gpus[0], True)
# 创建一个会话并应用GPU配置
# sess = tf.compat.v1.Session(config=gpu_config)
# tf.compat.v1.keras.backend.set_session(sess)
# tf.random.set_seed(1)

# 获取可见的 GPU 设备列表
visible_gpus = tf.config.experimental.list_physical_devices('GPU')
if len(visible_gpus) > 0:
    # 如果有可见的 GPU 设备，设置 TensorFlow 在 GPU 上运行
    tf.config.set_visible_devices(visible_gpus, 'GPU')
    gpu_config = tf.config.experimental.set_memory_growth(visible_gpus[0], True)
    sess = tf.compat.v1.Session(config=gpu_config)
    tf.compat.v1.keras.backend.set_session(sess)
    print('GPU available')
else:
    # 如果没有可见的 GPU 设备，设置 TensorFlow 在 CPU 上运行
    tf.config.set_visible_devices([], 'GPU')
    sess = tf.compat.v1.Session()
    print('No GPU available')

# Load data
data, label = load_data(data_dir, ALL_MOTION)
print('\nLoaded dataset of ' + str(label.shape[0]) + ' samples, each sized ' + str(data[0,:,:].shape) + '\n')

# Split train and test
[data_train, data_test, label_train, label_test] = train_test_split(data, label, test_size=fraction_for_test)
print('\nTrain on ' + str(label_train.shape[0]) + ' samples\n' +\
    'Test on ' + str(label_test.shape[0]) + ' samples\n')

# One-hot encoding for train data
label_train = onehot_encoding(label_train, N_MOTION)

# Load or fabricate model
if use_existing_model:
    model = load_model('model_widar3_trained.h5')
    model.summary()
else:
    #model = assemble_model(input_shape=(T_MAX, 20, 20, 1), n_class=N_MOTION)
    model = assemble_model(input_shape=(T_MAX, 15, 15, 1), n_class=N_MOTION) #修改点4
    model.summary()

class AccuracyLossHistory(Callback):
    def on_train_begin(self, logs={}):
        self.acc = []
        self.loss = []
        self.val_acc = []
        self.val_loss = []

    def on_epoch_end(self, epoch, logs={}):
        self.acc.append(logs.get('accuracy'))
        self.loss.append(logs.get('loss'))
        self.val_acc.append(logs.get('val_accuracy'))
        self.val_loss.append(logs.get('val_loss'))

history = AccuracyLossHistory()

model.fit({'name_model_input': data_train},{'name_model_output': label_train},
          batch_size=n_batch_size,
          epochs=n_epochs,
          verbose=1,
          validation_split=0.1, shuffle=True, callbacks=[history])
print('Saving trained model...')
#model.save('model_widar3_trained.h5')
model.save(f'{result_folder}/model.h5')  # 改动

# Testing...
print('Testing...')
label_test_pred = model.predict(data_test)
# label_test_pred = np.argmax(label_test_pred, axis = -1) + 1
label_test_pred = np.argmax(label_test_pred, axis = -1) + 2 #修改点5

# Confusion Matrix
cm = confusion_matrix(label_test, label_test_pred)
print(cm)
cm = cm.astype('float')/cm.sum(axis=1)[:, np.newaxis]
cm = np.around(cm, decimals=2)
print(cm)
#cm_display = ConfusionMatrixDisplay(cm, display_labels=range(1, N_MOTION+1)).plot()
#cm_display = ConfusionMatrixDisplay(cm, display_labels=range(4, N_MOTION+3)).plot() #2345 lebel-2  4567 4=2+2  7=长度4+3
cm_display = ConfusionMatrixDisplay(cm, display_labels=range(2, N_MOTION+2)).plot() #2345 lebel-2  4567 4=2+2  7=长度4+3
plt.show()
plt.savefig(f'{result_folder}/cm.png') # 新增点1 保存混淆矩阵结果2023.09.11

# Accuracy 新增百分号
test_accuracy = np.sum(label_test == label_test_pred) / (label_test.shape[0])
#print(test_accuracy)
test_accuracy_percentage = test_accuracy * 100
test_accuracy_str = f"{test_accuracy_percentage:.2f}%"
print(test_accuracy_str)

df_accuracy = pd.DataFrame({'Test Accuracy': [test_accuracy]})
df_accuracy.to_excel(f'{result_folder}/{test_accuracy_str}.xlsx', index=False) ## 新增点2 保存测试集平均准确率结果2023.09.11


df = pd.DataFrame({
    'Epoch': range(1, n_epochs+1),
    'Train Accuracy': history.acc,
    'Train Loss': history.loss,
    'Validation Accuracy': history.val_acc,
    'Validation Loss': history.val_loss
})

# df.to_excel('accuracy_l'''  '''oss.xlsx', index=False)
# 保存准确率和损失数据到Excel表格中
df.to_excel(f'{result_folder}/accuracy_loss.xlsx', index=False) #改动

plt.plot(range(1, n_epochs+1), history.acc, label='Train Accuracy')
plt.plot(range(1, n_epochs+1), history.loss, label='Train Loss')
plt.plot(range(1, n_epochs+1), history.val_acc, label='Validation Accuracy')
plt.plot(range(1, n_epochs+1), history.val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.legend()
plt.savefig(f'{result_folder}/plot.png')
plt.show()

# 新增 修改文件名 并打印新的文件名
new_result_folder = result_folder + f'_{test_accuracy_str}'
os.rename(result_folder, new_result_folder)
result_folder = new_result_folder

print("新的结果文件夹名称为：", result_folder)

end_time = time.time()  # 记录程序结束时间
duration = end_time - start_time  # 计算程序运行时间
print("程序执行时间为：{:.2f}秒".format(duration))

with open(f'{result_folder}/runtime.txt', 'w') as f:
    f.write("程序执行时间为：{:.2f}秒".format(duration)) # 新增点3 保存程序执行时间结果2023.09.11
# Out:
# GPU available
#
# Loaded dataset of 1120 samples, each sized (20, 15, 15, 1)
#
#
# Train on 1008 samples
# Test on 112 samples
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.RMSprop.
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  name_model_input (InputLay  [(None, 20, 15, 15, 1)]      0         []
#  er)
#
#  time_distributed_12 (TimeD  (None, 20, 11, 11, 16)       416       ['name_model_input[0][0]']
#  istributed)
#
#  time_distributed_13 (TimeD  (None, 20, 5, 5, 16)         0         ['time_distributed_12[0][0]']
#  istributed)
#
#  time_distributed_14 (TimeD  (None, 20, 400)              0         ['time_distributed_13[0][0]']
#  istributed)
#
#  time_distributed_15 (TimeD  (None, 20, 64)               25664     ['time_distributed_14[0][0]']
#  istributed)
#
#  time_distributed_16 (TimeD  (None, 20, 64)               0         ['time_distributed_15[0][0]']
#  istributed)
#
#  time_distributed_17 (TimeD  (None, 20, 64)               4160      ['time_distributed_16[0][0]']
#  istributed)
#
#  multi_head_attention_2 (Mu  (None, 20, 64)               16640     ['time_distributed_17[0][0]',
#  ltiHeadAttention)                                                   'time_distributed_17[0][0]']
#
#  dropout_9 (Dropout)         (None, 20, 64)               0         ['multi_head_attention_2[0][0]
#                                                                     ']
#
#  tf.__operators__.add_2 (TF  (None, 20, 64)               0         ['dropout_9[0][0]',
#  OpLambda)                                                           'time_distributed_17[0][0]']
#
#  layer_normalization_4 (Lay  (None, 20, 64)               128       ['tf.__operators__.add_2[0][0]
#  erNormalization)                                                   ']
#
#  dense_10 (Dense)            (None, 20, 64)               4160      ['layer_normalization_4[0][0]'
#                                                                     ]
#
#  dense_11 (Dense)            (None, 20, 64)               4160      ['dense_10[0][0]']
#
#  dropout_10 (Dropout)        (None, 20, 64)               0         ['dense_11[0][0]']
#
#  layer_normalization_5 (Lay  (None, 20, 64)               128       ['dropout_10[0][0]']
#  erNormalization)
#
#  lstm_2 (LSTM)               (None, 128)                  98816     ['layer_normalization_5[0][0]'
#                                                                     ]
#
#  dropout_11 (Dropout)        (None, 128)                  0         ['lstm_2[0][0]']
#
#  name_model_output (Dense)   (None, 4)                    516       ['dropout_11[0][0]']
#
# ==================================================================================================
# Total params: 154788 (604.64 KB)
# Trainable params: 154788 (604.64 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/250
# 57/57 [==============================] - 7s 31ms/step - loss: 0.5871 - accuracy: 0.2348 - val_loss: 0.5633 - val_accuracy: 0.2277
# Epoch 2/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.5701 - accuracy: 0.2734 - val_loss: 0.5553 - val_accuracy: 0.3366
# Epoch 3/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.5599 - accuracy: 0.3087 - val_loss: 0.5606 - val_accuracy: 0.3069
# Epoch 4/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.5510 - accuracy: 0.3462 - val_loss: 0.5969 - val_accuracy: 0.3663
# Epoch 5/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.5398 - accuracy: 0.3969 - val_loss: 0.5281 - val_accuracy: 0.4554
# Epoch 6/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.5158 - accuracy: 0.4487 - val_loss: 0.4808 - val_accuracy: 0.5149
# Epoch 7/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.4891 - accuracy: 0.4906 - val_loss: 0.4505 - val_accuracy: 0.5644
# Epoch 8/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.
250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.1281 - accuracy: 0.9096 - val_loss: 0.3416 - val_accuracy: 0.7624
# Epoch 40/250
# 57/57 [==============================] - 1s 13ms/step - loss: 0.1452 - accuracy: 0.8908 - val_loss: 0.2932 - val_accuracy: 0.7624
# Epoch 41/250
# 57/57 [==============================] - 1s 14ms/step - loss: 0.1222 - accuracy: 0.9107 - val_loss: 0.3038 - val_accuracy: 0.7624
# Epoch 42/250
# 57/57 [==============================] - 1s 14ms/step - loss: 0.1302 - accuracy: 0.9063 - val_loss: 0.3789 - val_accuracy: 0.7426
# Epoch 43/250
# 57/57 [==============================] - 1s 14ms/step - loss: 0.1192 - accuracy: 0.9140 - val_loss: 0.3045 - val_accuracy: 0.7525
# Epoch 44/250
# 57/57 [==============================] - 1s 12ms/step - loss: 0.1237 - accuracy: 0.9074 - val_loss: 0.2942 - val_accuracy: 0.7624
# Epoch 45/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.1059 - accuracy: 0.9283 - val_loss: 0.3092 - val_accuracy: 0.7624
# Epoch 46/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.1317 - accuracy: 0.9107 - val_loss: 0.2959 - val_accuracy: 0.7624
# Epoch 47/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.1136 - accuracy: 0.9217 - val_loss: 0.3019 - val_accuracy: 0.7921
# Epoch 48/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.1170 - accuracy: 0.9107 - val_loss: 0.2920 - val_accuracy: 0.7723
# Epoch 49/250
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0976 - accuracy: 0.9338 - val_loss: 0.3025 - val_accuracy: 0.7921
# Epoch 50/250
# 57/57 [==============================] - 1s 12ms/step - loss: 0.1099 - accuracy: 0.9140 - val_loss: 0.2673 - val_accuracy: 0.8119
# Epoch 51/250
# 57/57 [==============================] - 1s 17ms/step - loss: 0.1077 - accuracy: 0.9217 - val_loss: 0.3062 - val_accuracy: 0.7921
# Epoch 52/250
# 57/57 [==============================] - 1s 17ms/step - loss: 0.1035 - accuracy: 0.9283 - val_loss: 0.2938 - val_accuracy: 0.7624
# Epoch 53/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0841 - accuracy: 0.9449 - val_loss: 0.2703 - val_accuracy: 0.8317
# Epoch 54/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0844 - accuracy: 0.9394 - val_loss: 0.3880 - val_accuracy: 0.7624
# Epoch 55/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.1077 - accuracy: 0.9217 - val_loss: 0.3357 - val_accuracy: 0.7723
# Epoch 56/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0927 - accuracy: 0.9416 - val_loss: 0.2819 - val_accuracy: 0.7624
# Epoch 57/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0852 - accuracy: 0.9438 - val_loss: 0.3366 - val_accuracy: 0.7723
# Epoch 58/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0955 - accuracy: 0.9372 - val_loss: 0.3116 - val_accuracy: 0.7822
# Epoch 59/250
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0819 - accuracy: 0.9460 - val_loss: 0.3088 - val_accuracy: 0.8020
# Epoch 60/250
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0895 - accuracy: 0.9361 - val_loss: 0.3079 - val_accuracy: 0.7624
# Epoch 61/250
# 57/57 [==============================] - 1s 13ms/step - loss: 0.0695 - accuracy: 0.9526 - val_loss: 0.3658 - val_accuracy: 0.7624
# Epoch 62/250
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0903 - accuracy: 0.9405 - val_loss: 0.3071 - val_accuracy: 0.7624
# Epoch 63/250
# 57/57 [==============================] - 1s 12ms/step - loss: 0.0730 - accuracy: 0.9537 - val_loss: 0.2767 - val_accuracy: 0.7822
# Epoch 64/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0662 - accuracy: 0.9526 - val_loss: 0.3004 - val_accuracy: 0.7822
# Epoch 65/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0813 - accuracy: 0.9548 - val_loss: 0.3134 - val_accuracy: 0.7921
# Epoch 66/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0706 - accuracy: 0.9581 - val_loss: 0.2892 - val_accuracy: 0.7921
# Epoch 67/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0650 - accuracy: 0.9592 - val_loss: 0.3476 - val_accuracy: 0.7624
# Epoch 68/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0738 - accuracy: 0.9493 - val_loss: 0.3467 - val_accuracy: 0.7723
# Epoch 69/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0726 - accuracy: 0.9537 - val_loss: 0.3525 - val_accuracy: 0.7624
# Epoch 70/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0601 - accuracy: 0.9548 - val_loss: 0.3418 - val_accuracy: 0.7822
# Epoch 71/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0566 - accuracy: 0.9603 - val_loss: 0.3832 - val_accuracy: 0.7426
# Epoch 72/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0653 - accuracy: 0.9537 - val_loss: 0.3600 - val_accuracy: 0.7624
# Epoch 73/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0676 - accuracy: 0.9559 - val_loss: 0.3218 - val_accuracy: 0.8119
# Epoch 74/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0519 - accuracy: 0.9724 - val_loss: 0.5313 - val_accuracy: 0.7228
# Epoch 75/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0542 - accuracy: 0.9669 - val_loss: 0.3502 - val_accuracy: 0.7624
# Epoch 76/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0681 - accuracy: 0.9537 - val_loss: 0.3099 - val_accuracy: 0.7921
# Epoch 77/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0609 - accuracy: 0.9669 - val_loss: 0.3641 - val_accuracy: 0.7624
# Epoch 78/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0594 - accuracy: 0.9614 - val_loss: 0.3625 - val_accuracy: 0.7525
# Epoch 79/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0412 - accuracy: 0.9779 - val_loss: 0.3394 - val_accuracy: 0.8119
# Epoch 80/250
# 57/57 [==============================] - 1s 13ms/step - loss: 0.0565 - accuracy: 0.9680 - val_loss: 0.3925 - val_accuracy: 0.7723
# Epoch 81/250
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0617 - accuracy: 0.9614 - val_loss: 0.3256 - val_accuracy: 0.7822
# Epoch 82/250
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0415 - accuracy: 0.9735 - val_loss: 0.3492 - val_accuracy: 0.8020
# Epoch 83/250
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0474 - accuracy: 0.9680 - val_loss: 0.4211 - val_accuracy: 0.7426
# Epoch 84/250
# 57/57 [==============================] - 1s 13ms/step - loss: 0.0420 - accuracy: 0.9768 - val_loss: 0.4045 - val_accuracy: 0.7921
# Epoch 85/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0599 - accuracy: 0.9647 - val_loss: 0.3570 - val_accuracy: 0.7723
# Epoch 86/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0564 - accuracy: 0.9658 - val_loss: 0.3260 - val_accuracy: 0.8020
# Epoch 87/250
# 57/57 [==============================] - 1s 12ms/step - loss: 0.0603 - accuracy: 0.9669 - val_loss: 0.3296 - val_accuracy: 0.8020
# Epoch 88/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0456 - accuracy: 0.9746 - val_loss: 0.5072 - val_accuracy: 0.7525
# Epoch 89/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0458 - accuracy: 0.9735 - val_loss: 0.3181 - val_accuracy: 0.8119
# Epoch 90/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0480 - accuracy: 0.9680 - val_loss: 0.3232 - val_accuracy: 0.7723
# Epoch 91/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0421 - accuracy: 0.9702 - val_loss: 0.4190 - val_accuracy: 0.7426
# Epoch 92/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0423 - accuracy: 0.9702 - val_loss: 0.3336 - val_accuracy: 0.7921
# Epoch 93/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0306 - accuracy: 0.9779 - val_loss: 0.5075 - val_accuracy: 0.7327
# Epoch 94/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0420 - accuracy: 0.9702 - val_loss: 0.3616 - val_accuracy: 0.8119
# Epoch 95/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0348 - accuracy: 0.9768 - val_loss: 0.4136 - val_accuracy: 0.8020
# Epoch 96/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0577 - accuracy: 0.9680 - val_loss: 0.3322 - val_accuracy: 0.7624
# Epoch 97/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0353 - accuracy: 0.9768 - val_loss: 0.3919 - val_accuracy: 0.8020
# Epoch 98/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0399 - accuracy: 0.9735 - val_loss: 0.4263 - val_accuracy: 0.7921
# Epoch 99/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0349 - accuracy: 0.9791 - val_loss: 0.4308 - val_accuracy: 0.7822
# Epoch 100/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0286 - accuracy: 0.9824 - val_loss: 0.4702 - val_accuracy: 0.7723
# Epoch 101/250
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0497 - accuracy: 0.9713 - val_loss: 0.4168 - val_accuracy: 0.7822
# Epoch 102/250
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0515 - accuracy: 0.9757 - val_loss: 0.4204 - val_accuracy: 0.7624
# Epoch 103/250
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0428 - accuracy: 0.9757 - val_loss: 0.3656 - val_accuracy: 0.7624
# Epoch 104/250
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0486 - accuracy: 0.9757 - val_loss: 0.4032 - val_accuracy: 0.7723
# Epoch 105/250
# 57/57 [==============================] - 1s 12ms/step - loss: 0.0245 - accuracy: 0.9868 - val_loss: 0.5071 - val_accuracy: 0.7426
# Epoch 106/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0387 - accuracy: 0.9791 - val_loss: 0.4851 - val_accuracy: 0.7426
# Epoch 107/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0313 - accuracy: 0.9802 - val_loss: 0.3983 - val_accuracy: 0.8119
# Epoch 108/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0376 - accuracy: 0.9746 - val_loss: 0.4424 - val_accuracy: 0.7822
# Epoch 109/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0449 - accuracy: 0.9713 - val_loss: 0.5779 - val_accuracy: 0.7129
# Epoch 110/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0349 - accuracy: 0.9824 - val_loss: 0.4666 - val_accuracy: 0.7723
# Epoch 111/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0332 - accuracy: 0.9835 - val_loss: 0.4175 - val_accuracy: 0.7822
# Epoch 112/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0537 - accuracy: 0.9713 - val_loss: 0.4142 - val_accuracy: 0.7822
# Epoch 113/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0225 - accuracy: 0.9846 - val_loss: 0.4830 - val_accuracy: 0.7921
# Epoch 114/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0169 - accuracy: 0.9923 - val_loss: 0.4341 - val_accuracy: 0.7921
# Epoch 115/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0231 - accuracy: 0.9835 - val_loss: 0.4558 - val_accuracy: 0.7624
# Epoch 116/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0381 - accuracy: 0.9791 - val_loss: 0.4366 - val_accuracy: 0.8119
# Epoch 117/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0254 - accuracy: 0.9868 - val_loss: 0.4331 - val_accuracy: 0.8020
# Epoch 118/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0415 - accuracy: 0.9724 - val_loss: 0.5088 - val_accuracy: 0.7426
# Epoch 119/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0272 - accuracy: 0.9879 - val_loss: 0.4706 - val_accuracy: 0.7822
# Epoch 120/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0370 - accuracy: 0.9813 - val_loss: 0.3810 - val_accuracy: 0.8020
# Epoch 121/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0237 - accuracy: 0.9879 - val_loss: 0.4673 - val_accuracy: 0.7822
# Epoch 122/250
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0370 - accuracy: 0.9791 - val_loss: 0.4738 - val_accuracy: 0.7921
# Epoch 123/250
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0449 - accuracy: 0.9757 - val_loss: 0.3736 - val_accuracy: 0.8218
# Epoch 124/250
# 57/57 [==============================] - 1s 13ms/step - loss: 0.0181 - accuracy: 0.9879 - val_loss: 0.4212 - val_accuracy: 0.8020
# Epoch 125/250
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0408 - accuracy: 0.9802 - val_loss: 0.3524 - val_accuracy: 0.7921
# Epoch 126/250
# 57/57 [==============================] - 1s 13ms/step - loss: 0.0272 - accuracy: 0.9846 - val_loss: 0.4279 - val_accuracy: 0.7327
# Epoch 127/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0423 - accuracy: 0.9746 - val_loss: 0.4525 - val_accuracy: 0.7228
# Epoch 128/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0271 - accuracy: 0.9857 - val_loss: 0.3811 - val_accuracy: 0.8317
# Epoch 129/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0364 - accuracy: 0.9802 - val_loss: 0.4908 - val_accuracy: 0.7129
# Epoch 130/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0375 - accuracy: 0.9802 - val_loss: 0.5029 - val_accuracy: 0.7327
# Epoch 131/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0324 - accuracy: 0.9768 - val_loss: 0.4071 - val_accuracy: 0.8020
# Epoch 132/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.
250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0227 - accuracy: 0.9901 - val_loss: 0.5038 - val_accuracy: 0.7723
# Epoch 196/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0124 - accuracy: 0.9956 - val_loss: 0.5174 - val_accuracy: 0.8020
# Epoch 197/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0279 - accuracy: 0.9868 - val_loss: 0.4488 - val_accuracy: 0.8416
# Epoch 198/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0144 - accuracy: 0.9934 - val_loss: 0.5235 - val_accuracy: 0.8317
# Epoch 199/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0181 - accuracy: 0.9901 - val_loss: 0.5763 - val_accuracy: 0.7921
# Epoch 200/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0162 - accuracy: 0.9945 - val_loss: 0.4886 - val_accuracy: 0.8218
# Epoch 201/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0272 - accuracy: 0.9868 - val_loss: 0.4850 - val_accuracy: 0.8020
# Epoch 202/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0212 - accuracy: 0.9890 - val_loss: 0.5145 - val_accuracy: 0.7723
# Epoch 203/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0181 - accuracy: 0.9901 - val_loss: 0.4360 - val_accuracy: 0.8119
# Epoch 204/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0173 - accuracy: 0.9912 - val_loss: 0.5004 - val_accuracy: 0.7921
# Epoch 205/250
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0258 - accuracy: 0.9879 - val_loss: 0.5979 - val_accuracy: 0.7822
# Epoch 206/250
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0185 - accuracy: 0.9912 - val_loss: 0.6902 - val_accuracy: 0.7525
# Epoch 207/250
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0225 - accuracy: 0.9879 - val_loss: 0.5731 - val_accuracy: 0.7822
# Epoch 208/250
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0142 - accuracy: 0.9923 - val_loss: 0.6229 - val_accuracy: 0.7624
# Epoch 209/250
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0145 - accuracy: 0.9923 - val_loss: 0.5878 - val_accuracy: 0.7723
# Epoch 210/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0195 - accuracy: 0.9923 - val_loss: 0.5551 - val_accuracy: 0.7723
# Epoch 211/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0231 - accuracy: 0.9934 - val_loss: 0.4594 - val_accuracy: 0.7723
# Epoch 212/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0186 - accuracy: 0.9912 - val_loss: 0.7095 - val_accuracy: 0.7624
# Epoch 213/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0132 - accuracy: 0.9934 - val_loss: 0.5804 - val_accuracy: 0.7723
# Epoch 214/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0174 - accuracy: 0.9879 - val_loss: 0.4576 - val_accuracy: 0.7723
# Epoch 215/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0067 - accuracy: 0.9945 - val_loss: 0.4899 - val_accuracy: 0.7723
# Epoch 216/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0243 - accuracy: 0.9846 - val_loss: 0.4187 - val_accuracy: 0.8317
# Epoch 217/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0235 - accuracy: 0.9879 - val_loss: 0.5113 - val_accuracy: 0.8020
# Epoch 218/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0112 - accuracy: 0.9945 - val_loss: 0.5343 - val_accuracy: 0.8020
# Epoch 219/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0134 - accuracy: 0.9934 - val_loss: 0.4781 - val_accuracy: 0.8020
# Epoch 220/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0103 - accuracy: 0.9945 - val_loss: 0.4716 - val_accuracy: 0.8218
# Epoch 221/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0098 - accuracy: 0.9967 - val_loss: 0.4924 - val_accuracy: 0.8119
# Epoch 222/250
# 57/57 [==============================] - 1s 12ms/step - loss: 0.0121 - accuracy: 0.9945 - val_loss: 0.5427 - val_accuracy: 0.8020
# Epoch 223/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0097 - accuracy: 0.9945 - val_loss: 0.6540 - val_accuracy: 0.7426
# Epoch 224/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0093 - accuracy: 0.9967 - val_loss: 0.5348 - val_accuracy: 0.7921
# Epoch 225/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0143 - accuracy: 0.9912 - val_loss: 0.5125 - val_accuracy: 0.8317
# Epoch 226/250
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0101 - accuracy: 0.9956 - val_loss: 0.6704 - val_accuracy: 0.7822
# Epoch 227/250
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0134 - accuracy: 0.9934 - val_loss: 0.6069 - val_accuracy: 0.8218
# Epoch 228/250
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0094 - accuracy: 0.9956 - val_loss: 0.5921 - val_accuracy: 0.8119
# Epoch 229/250
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0245 - accuracy: 0.9912 - val_loss: 0.7262 - val_accuracy: 0.7525
# Epoch 230/250
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0070 - accuracy: 0.9956 - val_loss: 0.4693 - val_accuracy: 0.8317
# Epoch 231/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0140 - accuracy: 0.9923 - val_loss: 0.4869 - val_accuracy: 0.8317
# Epoch 232/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0200 - accuracy: 0.9945 - val_loss: 0.5132 - val_accuracy: 0.8317
# Epoch 233/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0095 - accuracy: 0.9923 - val_loss: 0.7025 - val_accuracy: 0.7426
# Epoch 234/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0154 - accuracy: 0.9945 - val_loss: 0.5260 - val_accuracy: 0.8020
# Epoch 235/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0180 - accuracy: 0.9923 - val_loss: 0.4092 - val_accuracy: 0.8614
# Epoch 236/250
# 57/57 [==============================] - 1s 10ms/step - loss: 0.0186 - accuracy: 0.9901 - val_loss: 0.4789 - val_accuracy: 0.8119
# Epoch 237/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0038 - accuracy: 0.9978 - val_loss: 0.4889 - val_accuracy: 0.8218
# Epoch 238/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0090 - accuracy: 0.9967 - val_loss: 0.4571 - val_accuracy: 0.8416
# Epoch 239/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0170 - accuracy: 0.9912 - val_loss: 0.6109 - val_accuracy: 0.7723
# Epoch 240/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0151 - accuracy: 0.9923 - val_loss: 0.4638 - val_accuracy: 0.8317
# Epoch 241/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0148 - accuracy: 0.9945 - val_loss: 0.4591 - val_accuracy: 0.8020
# Epoch 242/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0216 - accuracy: 0.9879 - val_loss: 0.4610 - val_accuracy: 0.8020
# Epoch 243/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0277 - accuracy: 0.9868 - val_loss: 0.4859 - val_accuracy: 0.8317
# Epoch 244/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0203 - accuracy: 0.9923 - val_loss: 0.5894 - val_accuracy: 0.7921
# Epoch 245/250
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0057 - accuracy: 0.9978 - val_loss: 0.5660 - val_accuracy: 0.8119
# Epoch 246/250
# 57/57 [==============================] - 1s 12ms/step - loss: 0.0182 - accuracy: 0.9923 - val_loss: 0.5720 - val_accuracy: 0.7723
# Epoch 247/250
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0348 - accuracy: 0.9857 - val_loss: 0.3949 - val_accuracy: 0.8218
# Epoch 248/250
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0122 - accuracy: 0.9934 - val_loss: 0.3986 - val_accuracy: 0.8317
# Epoch 249/250
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0166 - accuracy: 0.9912 - val_loss: 0.5255 - val_accuracy: 0.7723
# Epoch 250/250
# 57/57 [==============================] - 1s 13ms/step - loss: 0.0228 - accuracy: 0.9868 - val_loss: 0.5359 - val_accuracy: 0.8218
# Saving trained model...
# Testing...
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 4/4 [==============================] - 1s 5ms/step
# [[18  0  1  5]
#  [ 1 21  3  4]
#  [ 0  2 29  5]
#  [ 0  0  0 23]]
# [[0.75 0.   0.04 0.21]
#  [0.03 0.72 0.1  0.14]
#  [0.   0.06 0.81 0.14]
#  [0.   0.   0.   1.  ]]
# 81.25%
# 新的结果文件夹名称为： result_MultiAttention_LSTM_1层Transformer_BCE_epoch250_batchsize16_lr0.01_81.25%
# 程序执行时间为：216.37秒

# %%
# 定位到指定路径下
import os
os.chdir('/content/drive/MyDrive/Colab_Notebooks/RNN-CAP')
print(os.getcwd())

# 打印版本
import sys
import tensorflow as tf

print("Python 版本:", sys.version)
print("TensorFlow 版本:", tf.__version__)

# !pip install xlwt
# !pip install matplotlib

# %%
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_categorical_crossentropy_epoch30.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_categorical_crossentropy_epoch250.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_categorical_crossentropy_epoch50.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_categorical_crossentropy_epoch100.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_categorical_crossentropy_epoch150.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_categorical_crossentropy_epoch200.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_squared_error_epoch30.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_squared_error_epoch50.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_squared_error_epoch100.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_squared_error_epoch150.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_squared_error_epoch200.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_squared_error_epoch250.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_absolute_error_epoch30.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_absolute_error_epoch50.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_absolute_error_epoch100.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_absolute_error_epoch150.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_absolute_error_epoch200.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_absolute_error_epoch250.py

# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_binary_crossentropy_epoch30.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_binary_crossentropy_epoch50.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_binary_crossentropy_epoch100.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_binary_crossentropy_epoch150.py

#!python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_binary_crossentropy_epoch200.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_binary_crossentropy_epoch250.py
