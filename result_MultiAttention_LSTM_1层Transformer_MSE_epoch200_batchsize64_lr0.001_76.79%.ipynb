# %% [markdown]
# <a href="https://colab.research.google.com/github/zuo-liangliang/fcn.berkeleyvision.org/blob/master/result_MultiAttention_LSTM_1%E5%B1%82Transformer_MSE_epoch200_batchsize64_lr0.001_76.79%25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import zipfile

# 定义源文件夹路径和目标 zip 文件夹路径
# source_folder = '/content/drive/MyDrive/Colab_Notebooks/528BVP-acnt2'
source_folder = '/content/drive/MyDrive/AugustResult'
# target_zip_folder = '/content/drive/MyDrive/Colab_Notebooks/zip_folder'
# target_zip_folder = '/content/drive/MyDrive/Colab_Notebooks/528BVP-acnt2/0827zip_folder'
target_zip_folder = '/content/drive/MyDrive/AugustResult/0907_月月账号zip_folder'

# 确保目标 zip 文件夹存在
os.makedirs(target_zip_folder, exist_ok=True)

# 获取源文件夹中以 "result" 开头的文件夹列表
folder_list = [folder for folder in os.listdir(source_folder) if os.path.isdir(os.path.join(source_folder, folder)) and folder.startswith("result")]

# 创建一个大的 zip 文件
with zipfile.ZipFile(os.path.join(target_zip_folder, '0907月月_all_folders.zip'), 'w', zipfile.ZIP_DEFLATED) as zipf:
    # 遍历文件夹列表，逐个压缩为 zip 文件
    for folder in folder_list:
        folder_path = os.path.join(source_folder, folder)

        # 遍历文件夹中的所有文件和子文件夹，并逐个添加到大的 zip 文件中
        for root, dirs, files in os.walk(folder_path):
            for file in files:
                file_path = os.path.join(root, file)
                zipf.write(file_path, os.path.relpath(file_path, source_folder))

print("所有文件夹已压缩为一个大的 zip 文件！")
# Out:
# 所有文件夹已压缩为一个大的 zip 文件！

# %%
import shutil
import os
# 指定要删除的文件夹路径
folder_path = '/content/drive/MyDrive/Colab_Notebooks/528BVP-acnt2/user14' #替换为你的文件夹路径

# 确保要删除的是一个目录而不是文件
assert os.path.isdir(folder_path), f"{folder_path} 不是一个目录"

# 递归删除文件夹下的所有文件和子文件夹
shutil.rmtree(folder_path)

# %%
# 解压指定文件夹到某一路径下
import zipfile

file_path = '/content/drive/MyDrive/Colab_Notebooks/528BVP-acnt2/528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4.zip'
extract_path = '/content/drive/MyDrive/Colab_Notebooks/528BVP-acnt2/528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4'

with zipfile.ZipFile(file_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# %%
# 定位到指定路径下
import os
# os.chdir('/content/drive/MyDrive/SeptemberResult/result_LSTM')
os.chdir('/content/drive/MyDrive/SeptemberResult/result_MultiAttention_LSTM_1层Transformer')
print(os.getcwd())
# Out:
# /content/drive/MyDrive/SeptemberResult/result_MultiAttention_LSTM_1层Transformer

# %%
# result_MultiAttention_LSTM_1层Transformer

from keras.callbacks import Callback
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay

from __future__ import print_function

import time
import os,sys
import numpy as np
import pandas as pd
import scipy.io as scio
import tensorflow as tf
tf.compat.v1.keras.backend.set_session
import keras
from keras.layers import Input, GRU, LSTM, Dense, Flatten, Dropout, Conv2D, Conv3D, MaxPooling2D, MaxPooling3D, TimeDistributed
from keras.models import Model, load_model
import keras.backend as K
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split

# Parameters
use_existing_model = False
fraction_for_test = 0.1
data_dir = '/content/drive/MyDrive/Colab_Notebooks/528BVP-acnt2/528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4/'
# data_dir = '/content/drive/MyDrive/new528BVP/528[-1,1]长度20-分辨率15_acnt2_sample_rate5000__剔14_改6为4/'

fraction_for_test = 0.1
#ALL_MOTION = [1,2,3,4,5,6]
ALL_MOTION = [2,3,4,5]
N_MOTION = len(ALL_MOTION)
T_MAX = 0
n_epochs = 200  #最优的是100；第2优的是200，原始是50 #修改点1
f_dropout_ratio = 0.5
n_gru_hidden_units = 128
n_batch_size = 64     #原始是32-->16
f_learning_rate = 0.001  #原始是0.001-->0.002

def normalize_data(data_1):
    # data(ndarray)=>data_norm(ndarray): [20,20,T]=>[20,20,T]
    data_1_max = np.concatenate((data_1.max(axis=0),data_1.max(axis=1)),axis=0).max(axis=0)
    data_1_min = np.concatenate((data_1.min(axis=0),data_1.min(axis=1)),axis=0).min(axis=0)
    if (len(np.where((data_1_max - data_1_min) == 0)[0]) > 0):
        return data_1
    data_1_max_rep = np.tile(data_1_max,(data_1.shape[0],data_1.shape[1],1))
    data_1_min_rep = np.tile(data_1_min,(data_1.shape[0],data_1.shape[1],1))
    data_1_norm = (data_1 - data_1_min_rep) / (data_1_max_rep - data_1_min_rep)
    return  data_1_norm

def zero_padding(data, T_MAX):
    # data(list)=>data_pad(ndarray): [20,20,T1/T2/...]=>[20,20,T_MAX]
    data_pad = []
    for i in range(len(data)):
        t = np.array(data[i]).shape[2]
        data_pad.append(np.pad(data[i], ((0,0),(0,0),(T_MAX - t,0)), 'constant', constant_values = 0).tolist())
    return np.array(data_pad)

def onehot_encoding(label, num_class):
    # label(list)=>_label(ndarray): [N,]=>[N,num_class]
    label = np.array(label).astype('int32')
    # assert (np.arange(0,np.unique(label).size)==np.unique(label)).prod()    # Check label from 0 to N
    label = np.squeeze(label)
    # _label = np.eye(num_class)[label-1]     # from label to onehot
    _label = np.eye(num_class)[label-2]   #修改点2
    return _label

def load_data(path_to_data, motion_sel):
    global T_MAX
    data = []
    label = []
    for data_root, data_dirs, data_files in os.walk(path_to_data):
        for data_file_name in data_files:

            file_path = os.path.join(data_root,data_file_name)
            try:
                data_1 = scio.loadmat(file_path)['velocity_spectrum_ro']
                label_1 = int(data_file_name.split('-')[1])
                #location = int(data_file_name.split('-')[2])
                #orientation = int(data_file_name.split('-')[3])
                #repetition = int(data_file_name.split('-')[4])
                repetition = int(data_file_name.split('-')[2])  #修改点3

                # Select Motion
                if (label_1 not in motion_sel):
                    continue

                # Select Location
                # if (location not in [1,2,3,5]):
                #     continue

                # Select Orientation
                # if (orientation not in [1,2,4,5]):
                #     continue

                # Normalization
                data_normed_1 = normalize_data(data_1)

                # Update T_MAX
                if T_MAX < np.array(data_1).shape[2]:
                    T_MAX = np.array(data_1).shape[2]
            except Exception:
                continue

            # Save List
            data.append(data_normed_1.tolist())
            label.append(label_1)
                # Zero-padding
    data = zero_padding(data, T_MAX)

    # Swap axes
    data = np.swapaxes(np.swapaxes(data, 1, 3), 2, 3)   # [N,20,20',T_MAX]=>[N,T_MAX,20,20']
    data = np.expand_dims(data, axis=-1)    # [N,T_MAX,20,20]=>[N,T_MAX,20,20,1]

    # Convert label to ndarray
    label = np.array(label)

    # data(ndarray): [N,T_MAX,20,20,1], label(ndarray): [N,N_MOTION]
    return data, label

# 构建符合输入形状为 (None, 20, 15, 15, 1) 和输出形状为 (None, 4) 的  模型：
from keras.layers import MultiHeadAttention, LayerNormalization  #加Transformer修改点1
num_transformer_layers = 1  # 设置Transformer层数 #加Transformer修改点2  2层-->1层

#加Transformer修改点3
def transformer_layer(inputs, hidden_units, dropout_rate):
    # Self-attention
    attention_output = MultiHeadAttention(
        num_heads=8, key_dim=hidden_units // 8
    )(inputs, inputs)
    attention_output = Dropout(dropout_rate)(attention_output)
    attention_output = LayerNormalization()(attention_output + inputs)

    # Feed-forward network
    ffn = Dense(hidden_units, activation="relu")(attention_output)
    ffn = Dense(hidden_units)(ffn)
    ffn = Dropout(dropout_rate)(ffn)
    ffn = LayerNormalization()(ffn)

    return ffn

#加Transformer修改点4
def assemble_model(input_shape, n_class):
    model_input = Input(shape=input_shape, dtype='float32', name='name_model_input')    # (@,T_MAX,20,20,1)

    # Feature extraction part
    x = TimeDistributed(Conv2D(16,kernel_size=(5,5),activation='relu',data_format='channels_last',\
        input_shape=input_shape))(model_input)   # (@,T_MAX,20,20,1)=>(@,T_MAX,16,16,16)
    x = TimeDistributed(MaxPooling2D(pool_size=(2,2)))(x)    # (@,T_MAX,16,16,16)=>(@,T_MAX,8,8,16)
    x = TimeDistributed(Flatten())(x)   # (@,T_MAX,8,8,16)=>(@,T_MAX,8*8*16)
    x = TimeDistributed(Dense(64,activation='relu'))(x) # (@,T_MAX,8*8*16)=>(@,T_MAX,64)
    x = TimeDistributed(Dropout(f_dropout_ratio))(x)
    x = TimeDistributed(Dense(64,activation='relu'))(x) # (@,T_MAX,64)=>(@,T_MAX,64)

    # Add transformer layers
    for _ in range(num_transformer_layers):
        #x = transformer_layer(x, hidden_units=n_gru_hidden_units, dropout_rate=f_dropout_ratio)
        x = transformer_layer(x, hidden_units=64, dropout_rate=f_dropout_ratio)  # 修改点1
    x = LSTM(n_gru_hidden_units,return_sequences=False)(x)  # (@,T_MAX,64)=>(@,128)
    x = Dropout(f_dropout_ratio)(x)
    model_output = Dense(n_class, activation='softmax', name='name_model_output')(x)  # (@,128)=>(@,n_class)

    # Create the model
    # Model compiling
    model = Model(inputs=model_input, outputs=model_output)
    model.compile(optimizer=keras.optimizers.RMSprop(lr=f_learning_rate),
                    # loss='categorical_crossentropy', # 将损失函数改为多类别交叉熵损失函数 最优的是CCE
                    loss='mean_squared_error',  # 将损失函数改为均方误差 第2优的是MSE
                    # loss='mean_absolute_error',  # 将损失函数改为平均绝对误差
                    # loss='binary_crossentropy',  # 将损失函数改为对数损失函数
                    metrics=['accuracy']
                )
    return model

# 改
#model_type = '双层LSTM'
#model_type = 'LSTM'
#model_type = 'BiLSTM'
model_type = 'MultiAttention_LSTM_1层Transformer'

# 创建结果文件夹
# result_folder = f'result_528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_GRU_改costfunction为mse_epoch200' # 每次都要改
# result_folder = f'result_528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_{model_type}_categorical_crossentropy_epoch{n_epochs}'
# result_folder = f'result_528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_{model_type}_mean_squared_error_epoch{n_epochs}'
# result_folder = f'result_528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_{model_type}_mean_absolute_error_epoch{n_epochs}'
# result_folder = f'result_528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_{model_type}_binary_crossentropy_epoch{n_epochs}'

# result_folder = f'result_{model_type}_CCE_epoch{n_epochs}_batchsize{n_batch_size}_lr{f_learning_rate}'
result_folder = f'result_{model_type}_MSE_epoch{n_epochs}_batchsize{n_batch_size}_lr{f_learning_rate}'

os.makedirs(result_folder, exist_ok=True)

# %%
# Let's BEGIN >>>>
start_time = time.time()  # 记录程序开始时间

# 获取可见的GPU设备列表
# visible_gpus = tf.config.experimental.list_physical_devices('GPU')
# 检查是否存在可见的GPU设备
# if len(visible_gpus) < 1:
    # print('No GPU available')
    # exit(0)
# 设置使用第一个可见的GPU设备
# os.environ["CUDA_VISIBLE_DEVICES"] = str(visible_gpus[0].index)
# 配置GPU选项
# gpu_config = tf.config.experimental.set_memory_growth(visible_gpus[0], True)
# 创建一个会话并应用GPU配置
# sess = tf.compat.v1.Session(config=gpu_config)
# tf.compat.v1.keras.backend.set_session(sess)
# tf.random.set_seed(1)

# 获取可见的 GPU 设备列表
visible_gpus = tf.config.experimental.list_physical_devices('GPU')
if len(visible_gpus) > 0:
    # 如果有可见的 GPU 设备，设置 TensorFlow 在 GPU 上运行
    tf.config.set_visible_devices(visible_gpus, 'GPU')
    gpu_config = tf.config.experimental.set_memory_growth(visible_gpus[0], True)
    sess = tf.compat.v1.Session(config=gpu_config)
    tf.compat.v1.keras.backend.set_session(sess)
    print('GPU available')
else:
    # 如果没有可见的 GPU 设备，设置 TensorFlow 在 CPU 上运行
    tf.config.set_visible_devices([], 'GPU')
    sess = tf.compat.v1.Session()
    print('No GPU available')

# Load data
data, label = load_data(data_dir, ALL_MOTION)
print('\nLoaded dataset of ' + str(label.shape[0]) + ' samples, each sized ' + str(data[0,:,:].shape) + '\n')

# Split train and test
[data_train, data_test, label_train, label_test] = train_test_split(data, label, test_size=fraction_for_test)
print('\nTrain on ' + str(label_train.shape[0]) + ' samples\n' +\
    'Test on ' + str(label_test.shape[0]) + ' samples\n')

# One-hot encoding for train data
label_train = onehot_encoding(label_train, N_MOTION)

# Load or fabricate model
if use_existing_model:
    model = load_model('model_widar3_trained.h5')
    model.summary()
else:
    #model = assemble_model(input_shape=(T_MAX, 20, 20, 1), n_class=N_MOTION)
    model = assemble_model(input_shape=(T_MAX, 15, 15, 1), n_class=N_MOTION) #修改点4
    model.summary()

class AccuracyLossHistory(Callback):
    def on_train_begin(self, logs={}):
        self.acc = []
        self.loss = []
        self.val_acc = []
        self.val_loss = []

    def on_epoch_end(self, epoch, logs={}):
        self.acc.append(logs.get('accuracy'))
        self.loss.append(logs.get('loss'))
        self.val_acc.append(logs.get('val_accuracy'))
        self.val_loss.append(logs.get('val_loss'))

history = AccuracyLossHistory()

model.fit({'name_model_input': data_train},{'name_model_output': label_train},
          batch_size=n_batch_size,
          epochs=n_epochs,
          verbose=1,
          validation_split=0.1, shuffle=True, callbacks=[history])
print('Saving trained model...')
#model.save('model_widar3_trained.h5')
model.save(f'{result_folder}/model.h5')  # 改动

# Testing...
print('Testing...')
label_test_pred = model.predict(data_test)
# label_test_pred = np.argmax(label_test_pred, axis = -1) + 1
label_test_pred = np.argmax(label_test_pred, axis = -1) + 2 #修改点5

# Confusion Matrix
cm = confusion_matrix(label_test, label_test_pred)
print(cm)
cm = cm.astype('float')/cm.sum(axis=1)[:, np.newaxis]
cm = np.around(cm, decimals=2)
print(cm)
#cm_display = ConfusionMatrixDisplay(cm, display_labels=range(1, N_MOTION+1)).plot()
#cm_display = ConfusionMatrixDisplay(cm, display_labels=range(4, N_MOTION+3)).plot() #2345 lebel-2  4567 4=2+2  7=长度4+3
cm_display = ConfusionMatrixDisplay(cm, display_labels=range(2, N_MOTION+2)).plot() #2345 lebel-2  4567 4=2+2  7=长度4+3
plt.show()
plt.savefig(f'{result_folder}/cm.png') # 新增点1 保存混淆矩阵结果2023.09.11

# Accuracy 新增百分号
test_accuracy = np.sum(label_test == label_test_pred) / (label_test.shape[0])
#print(test_accuracy)
test_accuracy_percentage = test_accuracy * 100
test_accuracy_str = f"{test_accuracy_percentage:.2f}%"
print(test_accuracy_str)

df_accuracy = pd.DataFrame({'Test Accuracy': [test_accuracy]})
df_accuracy.to_excel(f'{result_folder}/{test_accuracy_str}.xlsx', index=False) ## 新增点2 保存测试集平均准确率结果2023.09.11


df = pd.DataFrame({
    'Epoch': range(1, n_epochs+1),
    'Train Accuracy': history.acc,
    'Train Loss': history.loss,
    'Validation Accuracy': history.val_acc,
    'Validation Loss': history.val_loss
})

# df.to_excel('accuracy_l'''  '''oss.xlsx', index=False)
# 保存准确率和损失数据到Excel表格中
df.to_excel(f'{result_folder}/accuracy_loss.xlsx', index=False) #改动

plt.plot(range(1, n_epochs+1), history.acc, label='Train Accuracy')
plt.plot(range(1, n_epochs+1), history.loss, label='Train Loss')
plt.plot(range(1, n_epochs+1), history.val_acc, label='Validation Accuracy')
plt.plot(range(1, n_epochs+1), history.val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.legend()
plt.savefig(f'{result_folder}/plot.png')
plt.show()

# 新增 修改文件名 并打印新的文件名
new_result_folder = result_folder + f'_{test_accuracy_str}'
os.rename(result_folder, new_result_folder)
result_folder = new_result_folder

print("新的结果文件夹名称为：", result_folder)

end_time = time.time()  # 记录程序结束时间
duration = end_time - start_time  # 计算程序运行时间
print("程序执行时间为：{:.2f}秒".format(duration))

with open(f'{result_folder}/runtime.txt', 'w') as f:
    f.write("程序执行时间为：{:.2f}秒".format(duration)) # 新增点3 保存程序执行时间结果2023.09.11
# Out:
# GPU available
#
# Loaded dataset of 1120 samples, each sized (20, 15, 15, 1)
#
#
# Train on 1008 samples
# Test on 112 samples
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.RMSprop.
# Model: "model_18"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  name_model_input (InputLay  [(None, 20, 15, 15, 1)]      0         []
#  er)
#
#  time_distributed_108 (Time  (None, 20, 11, 11, 16)       416       ['name_model_input[0][0]']
#  Distributed)
#
#  time_distributed_109 (Time  (None, 20, 5, 5, 16)         0         ['time_distributed_108[0][0]']
#  Distributed)
#
#  time_distributed_110 (Time  (None, 20, 400)              0         ['time_distributed_109[0][0]']
#  Distributed)
#
#  time_distributed_111 (Time  (None, 20, 64)               25664     ['time_distributed_110[0][0]']
#  Distributed)
#
#  time_distributed_112 (Time  (None, 20, 64)               0         ['time_distributed_111[0][0]']
#  Distributed)
#
#  time_distributed_113 (Time  (None, 20, 64)               4160      ['time_distributed_112[0][0]']
#  Distributed)
#
#  multi_head_attention_18 (M  (None, 20, 64)               16640     ['time_distributed_113[0][0]',
#  ultiHeadAttention)                                                  'time_distributed_113[0][0]']
#
#  dropout_73 (Dropout)        (None, 20, 64)               0         ['multi_head_attention_18[0][0
#                                                                     ]']
#
#  tf.__operators__.add_18 (T  (None, 20, 64)               0         ['dropout_73[0][0]',
#  FOpLambda)                                                          'time_distributed_113[0][0]']
#
#  layer_normalization_36 (La  (None, 20, 64)               128       ['tf.__operators__.add_18[0][0
#  yerNormalization)                                                  ]']
#
#  dense_74 (Dense)            (None, 20, 64)               4160      ['layer_normalization_36[0][0]
#                                                                     ']
#
#  dense_75 (Dense)            (None, 20, 64)               4160      ['dense_74[0][0]']
#
#  dropout_74 (Dropout)        (None, 20, 64)               0         ['dense_75[0][0]']
#
#  layer_normalization_37 (La  (None, 20, 64)               128       ['dropout_74[0][0]']
#  yerNormalization)
#
#  lstm_18 (LSTM)              (None, 128)                  98816     ['layer_normalization_37[0][0]
#                                                                     ']
#
#  dropout_75 (Dropout)        (None, 128)                  0         ['lstm_18[0][0]']
#
#  name_model_output (Dense)   (None, 4)                    516       ['dropout_75[0][0]']
#
# ==================================================================================================
# Total params: 154788 (604.64 KB)
# Trainable params: 154788 (604.64 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/200
# 15/15 [==============================] - 6s 66ms/step - loss: 0.1923 - accuracy: 0.2536 - val_loss: 0.1879 - val_accuracy: 0.2970
# Epoch 2/200
# 15/15 [==============================] - 0s 13ms/step - loss: 0.
200
# 15/15 [==============================] - 0s 14ms/step - loss: 0.0601 - accuracy: 0.8357 - val_loss: 0.1040 - val_accuracy: 0.7327
# Epoch 59/200
# 15/15 [==============================] - 0s 14ms/step - loss: 0.0630 - accuracy: 0.8258 - val_loss: 0.0877 - val_accuracy: 0.7525
# Epoch 60/200
# 15/15 [==============================] - 0s 15ms/step - loss: 0.0677 - accuracy: 0.8192 - val_loss: 0.0692 - val_accuracy: 0.8218
# Epoch 61/200
# 15/15 [==============================] - 0s 14ms/step - loss: 0.0567 - accuracy: 0.8445 - val_loss: 0.1886 - val_accuracy: 0.5347
# Epoch 62/200
# 15/15 [==============================] - 0s 14ms/step - loss: 0.0735 - accuracy: 0.8159 - val_loss: 0.0566 - val_accuracy: 0.8515
# Epoch 63/200
# 15/15 [==============================] - 0s 13ms/step - loss: 0.0602 - accuracy: 0.8379 - val_loss: 0.0717 - val_accuracy: 0.8317
# Epoch 64/200
# 15/15 [==============================] - 0s 14ms/step - loss: 0.0591 - accuracy: 0.8379 - val_loss: 0.0905 - val_accuracy: 0.7525
# Epoch 65/200
# 15/15 [==============================] - 0s 14ms/step - loss: 0.0589 - accuracy: 0.8390 - val_loss: 0.0971 - val_accuracy: 0.7525
# Epoch 66/200
# 15/15 [==============================] - 0s 13ms/step - loss: 0.0547 - accuracy: 0.8523 - val_loss: 0.0567 - val_accuracy: 0.8515
# Epoch 67/200
# 15/15 [==============================] - 0s 15ms/step - loss: 0.0528 - accuracy: 0.8567 - val_loss: 0.0861 - val_accuracy: 0.7723
# Epoch 68/200
# 15/15 [==============================] - 0s 13ms/step - loss: 0.0553 - accuracy: 0.8456 - val_loss: 0.0896 - val_accuracy: 0.7525
# Epoch 69/200
# 15/15 [==============================] - 0s 15ms/step - loss: 0.0548 - accuracy: 0.8512 - val_loss: 0.0733 - val_accuracy: 0.8020
# Epoch 70/200
# 15/15 [==============================] - 0s 13ms/step - loss: 0.0604 - accuracy: 0.8390 - val_loss: 0.0580 - val_accuracy: 0.8515
# Epoch 71/200
# 15/15 [==============================] - 0s 14ms/step - loss: 0.0541 - accuracy: 0.8501 - val_loss: 0.1017 - val_accuracy: 0.7525
# Epoch 72/200
# 15/15 [==============================] - 0s 16ms/step - loss: 0.0550 - accuracy: 0.8556 - val_loss: 0.0663 - val_accuracy: 0.8317
# Epoch 73/200
# 15/15 [==============================] - 0s 16ms/step - loss: 0.0484 - accuracy: 0.8765 - val_loss: 0.1028 - val_accuracy: 0.7228
# Epoch 74/200
# 15/15 [==============================] - 0s 14ms/step - loss: 0.0537 - accuracy: 0.8523 - val_loss: 0.0720 - val_accuracy: 0.8317
# Epoch 75/200
# 15/15 [==============================] - 0s 13ms/step - loss: 0.0528 - accuracy: 0.8556 - val_loss: 0.0739 - val_accuracy: 0.8020
# Epoch 76/200
# 15/15 [==============================] - 0s 14ms/step - loss: 0.0485 - accuracy: 0.8655 - val_loss: 0.0787 - val_accuracy: 0.7822
# Epoch 77/200
# 15/15 [==============================] - 0s 13ms/step - loss: 0.0443 - accuracy: 0.8809 - val_loss: 0.1074 - val_accuracy: 0.7525
# Epoch 78/200
# 15/15 [==============================] - 0s 14ms/step - loss: 0.0501 - accuracy: 0.8666 - val_loss: 0.0591 - val_accuracy: 0.8218
# Epoch 79/200
# 15/15 [==============================] - 0s 13ms/step - loss: 0.0452 - accuracy: 0.8798 - val_loss: 0.0397 - val_accuracy: 0.8812
# Epoch 80/200
# 15/15 [==============================] - 0s 15ms/step - loss: 0.0401 - accuracy: 0.8931 - val_loss: 0.0421 - val_accuracy: 0.8713
# Epoch 81/200
# 15/15 [==============================] - 0s 14ms/step - loss: 0.0470 - accuracy: 0.8754 - val_loss: 0.0777 - val_accuracy: 0.8020
# Epoch 82/200
# 15/15 [==============================] - 0s 14ms/step - loss: 0.0423 - accuracy: 0.8964 - val_loss: 0.0628 - val_accuracy: 0.8218
# Epoch 83/200
# 15/15 [==============================] - 0s 15ms/step - loss: 0.0434 - accuracy: 0.8897 - val_loss: 0.0592 - val_accuracy: 0.8218
# Epoch 84/200
# 15/15 [==============================] - 0s 14ms/step - loss: 0.0446 - accuracy: 0.8908 - val_loss: 0.0560 - val_accuracy: 0.8416
# Epoch 85/200
# 15/15 [==============================] - 0s 13ms/step - loss: 0.0492 - accuracy: 0.8666 - val_loss: 0.0873 - val_accuracy: 0.7723
# Epoch 86/200
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0471 - accuracy: 0.8732 - val_loss: 0.0461 - val_accuracy: 0.8911
# Epoch 87/200
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0368 - accuracy: 0.9030 - val_loss: 0.0900 - val_accuracy: 0.8020
# Epoch 88/200
# 15/15 [==============================] - 0s 20ms/step - loss: 0.0387 - accuracy: 0.8908 - val_loss: 0.0515 - val_accuracy: 0.8416
# Epoch 89/200
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0375 - accuracy: 0.9074 - val_loss: 0.0641 - val_accuracy: 0.8416
# Epoch 90/200
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0401 - accuracy: 0.8986 - val_loss: 0.0480 - val_accuracy: 0.8515
# Epoch 91/200
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0378 - accuracy: 0.9008 - val_loss: 0.0965 - val_accuracy: 0.7723
# Epoch 92/200
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0353 - accuracy: 0.9118 - val_loss: 0.0491 - val_accuracy: 0.8416
# Epoch 93/200
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0390 - accuracy: 0.9052 - val_loss: 0.0459 - val_accuracy: 0.8911
# Epoch 94/200
# 15/15 [==============================] - 0s 20ms/step - loss: 0.0342 - accuracy: 0.9063 - val_loss: 0.0540 - val_accuracy: 0.8614
# Epoch 95/200
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0353 - accuracy: 0.9041 - val_loss: 0.0606 - val_accuracy: 0.8119
# Epoch 96/200
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0378 - accuracy: 0.8997 - val_loss: 0.0466 - val_accuracy: 0.8515
# Epoch 97/200
# 15/15 [==============================] - 0s 20ms/step - loss: 0.0370 - accuracy: 0.9063 - val_loss: 0.0539 - val_accuracy: 0.8614
# Epoch 98/200
# 15/15 [==============================] - 0s 20ms/step - loss: 0.0321 - accuracy: 0.9129 - val_loss: 0.0549 - val_accuracy: 0.8218
# Epoch 99/200
# 15/15 [==============================] - 0s 20ms/step - loss: 0.0423 - accuracy: 0.8864 - val_loss: 0.0490 - val_accuracy: 0.8515
# Epoch 100/200
# 15/15 [==============================] - 0s 14ms/step - loss: 0.0376 - accuracy: 0.9008 - val_loss: 0.0413 - val_accuracy: 0.8713
# Epoch 101/200
# 15/15 [==============================] - 0s 14ms/step - loss: 0.0405 - accuracy: 0.8997 - val_loss: 0.0384 - val_accuracy: 0.9010
# Epoch 102/200
# 15/15 [==============================] - 0s 15ms/step - loss: 0.0312 - accuracy: 0.9217 - val_loss: 0.0617 - val_accuracy: 0.8515
# Epoch 103/200
# 15/15 [==============================] - 0s 14ms/step - loss: 0.0331 - accuracy: 0.9151 - val_loss: 0.0521 - val_accuracy: 0.8515
# Epoch 104/200
# 15/15 [==============================] - 0s 14ms/step - loss: 0.0348 - accuracy: 0.9118 - val_loss: 0.0445 - val_accuracy: 0.8614
# Epoch 105/200
# 15/15 [==============================] - 0s 14ms/step - loss: 0.0322 - accuracy: 0.9206 - val_loss: 0.0773 - val_accuracy: 0.8020
# Epoch 106/200
# 15/15 [==============================] - 0s 16ms/step - loss: 0.0367 - accuracy: 0.9030 - val_loss: 0.0465 - val_accuracy: 0.8713
# Epoch 107/200
# 15/15 [==============================] - 0s 16ms/step - loss: 0.0343 - accuracy: 0.9096 - val_loss: 0.1421 - val_accuracy: 0.6634
# Epoch 108/200
# 15/15 [==============================] - 0s 16ms/step - loss: 0.0360 - accuracy: 0.9151 - val_loss: 0.0461 - val_accuracy: 0.8713
# Epoch 109/200
# 15/15 [==============================] - 0s 14ms/step - loss: 0.0243 - accuracy: 0.9350 - val_loss: 0.0431 - val_accuracy: 0.8713
# Epoch 110/200
# 15/15 [==============================] - 0s 14ms/step - loss: 0.0285 - accuracy: 0.9272 - val_loss: 0.0715 - val_accuracy: 0.8119
# Epoch 111/200
# 15/15 [==============================] - 0s 15ms/step - loss: 0.0332 - accuracy: 0.9184 - val_loss: 0.1106 - val_accuracy: 0.7426
# Epoch 112/200
# 15/15 [==============================] - 0s 14ms/step - loss: 0.0320 - accuracy: 0.9250 - val_loss: 0.0526 - val_accuracy: 0.8515
# Epoch 113/200
# 15/15 [==============================] - 0s 14ms/step - loss: 0.0308 - accuracy: 0.9206 - val_loss: 0.0596 - val_accuracy: 0.8515
# Epoch 114/200
# 15/15 [==============================] - 0s 14ms/step - loss: 0.0278 - accuracy: 0.9272 - val_loss: 0.0774 - val_accuracy: 0.8218
# Epoch 115/200
# 15/15 [==============================] - 0s 14ms/step - loss: 0.0333 - accuracy: 0.9162 - val_loss: 0.0376 - val_accuracy: 0.9010
# Epoch 116/200
# 15/15 [==============================] - 0s 13ms/step - loss: 0.0252 - accuracy: 0.9361 - val_loss: 0.0926 - val_accuracy: 0.7525
# Epoch 117/200
# 15/15 [==============================] - 0s 15ms/step - loss: 0.0286 - accuracy: 0.9305 - val_loss: 0.0324 - val_accuracy: 0.9208
# Epoch 118/200
# 15/15 [==============================] - 0s 14ms/step - loss: 0.
200
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0209 - accuracy: 0.9471 - val_loss: 0.0416 - val_accuracy: 0.9109
# Epoch 150/200
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0167 - accuracy: 0.9570 - val_loss: 0.0753 - val_accuracy: 0.8119
# Epoch 151/200
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0219 - accuracy: 0.9460 - val_loss: 0.0437 - val_accuracy: 0.9010
# Epoch 152/200
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0168 - accuracy: 0.9548 - val_loss: 0.0523 - val_accuracy: 0.8614
# Epoch 153/200
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0189 - accuracy: 0.9493 - val_loss: 0.0713 - val_accuracy: 0.8119
# Epoch 154/200
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0180 - accuracy: 0.9548 - val_loss: 0.0488 - val_accuracy: 0.8812
# Epoch 155/200
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0190 - accuracy: 0.9493 - val_loss: 0.0705 - val_accuracy: 0.8218
# Epoch 156/200
# 15/15 [==============================] - 0s 21ms/step - loss: 0.0173 - accuracy: 0.9548 - val_loss: 0.0561 - val_accuracy: 0.8515
# Epoch 157/200
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0138 - accuracy: 0.9658 - val_loss: 0.0467 - val_accuracy: 0.8515
# Epoch 158/200
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0158 - accuracy: 0.9592 - val_loss: 0.0480 - val_accuracy: 0.8713
# Epoch 159/200
# 15/15 [==============================] - 0s 15ms/step - loss: 0.0201 - accuracy: 0.9493 - val_loss: 0.0599 - val_accuracy: 0.8614
# Epoch 160/200
# 15/15 [==============================] - 0s 16ms/step - loss: 0.0223 - accuracy: 0.9372 - val_loss: 0.0436 - val_accuracy: 0.9010
# Epoch 161/200
# 15/15 [==============================] - 0s 15ms/step - loss: 0.0139 - accuracy: 0.9625 - val_loss: 0.0467 - val_accuracy: 0.8812
# Epoch 162/200
# 15/15 [==============================] - 0s 15ms/step - loss: 0.0186 - accuracy: 0.9515 - val_loss: 0.0424 - val_accuracy: 0.9010
# Epoch 163/200
# 15/15 [==============================] - 0s 15ms/step - loss: 0.0166 - accuracy: 0.9537 - val_loss: 0.0446 - val_accuracy: 0.8812
# Epoch 164/200
# 15/15 [==============================] - 0s 14ms/step - loss: 0.0238 - accuracy: 0.9372 - val_loss: 0.0566 - val_accuracy: 0.8515
# Epoch 165/200
# 15/15 [==============================] - 0s 15ms/step - loss: 0.0185 - accuracy: 0.9526 - val_loss: 0.0526 - val_accuracy: 0.8614
# Epoch 166/200
# 15/15 [==============================] - 0s 15ms/step - loss: 0.0186 - accuracy: 0.9493 - val_loss: 0.0468 - val_accuracy: 0.8713
# Epoch 167/200
# 15/15 [==============================] - 0s 15ms/step - loss: 0.0125 - accuracy: 0.9702 - val_loss: 0.0476 - val_accuracy: 0.8911
# Epoch 168/200
# 15/15 [==============================] - 0s 14ms/step - loss: 0.0151 - accuracy: 0.9625 - val_loss: 0.0510 - val_accuracy: 0.8515
# Epoch 169/200
# 15/15 [==============================] - 0s 14ms/step - loss: 0.0206 - accuracy: 0.9460 - val_loss: 0.0491 - val_accuracy: 0.8614
# Epoch 170/200
# 15/15 [==============================] - 0s 15ms/step - loss: 0.0116 - accuracy: 0.9691 - val_loss: 0.0589 - val_accuracy: 0.8515
# Epoch 171/200
# 15/15 [==============================] - 0s 15ms/step - loss: 0.0153 - accuracy: 0.9625 - val_loss: 0.0677 - val_accuracy: 0.8317
# Epoch 172/200
# 15/15 [==============================] - 0s 16ms/step - loss: 0.0149 - accuracy: 0.9658 - val_loss: 0.0434 - val_accuracy: 0.8911
# Epoch 173/200
# 15/15 [==============================] - 0s 14ms/step - loss: 0.0096 - accuracy: 0.9779 - val_loss: 0.0606 - val_accuracy: 0.8614
# Epoch 174/200
# 15/15 [==============================] - 0s 15ms/step - loss: 0.0146 - accuracy: 0.9647 - val_loss: 0.0425 - val_accuracy: 0.9010
# Epoch 175/200
# 15/15 [==============================] - 0s 15ms/step - loss: 0.0165 - accuracy: 0.9548 - val_loss: 0.0415 - val_accuracy: 0.9010
# Epoch 176/200
# 15/15 [==============================] - 0s 15ms/step - loss: 0.0146 - accuracy: 0.9625 - val_loss: 0.0443 - val_accuracy: 0.8713
# Epoch 177/200
# 15/15 [==============================] - 0s 14ms/step - loss: 0.0137 - accuracy: 0.9658 - val_loss: 0.0551 - val_accuracy: 0.8515
# Epoch 178/200
# 15/15 [==============================] - 0s 14ms/step - loss: 0.0123 - accuracy: 0.9702 - val_loss: 0.0570 - val_accuracy: 0.8317
# Epoch 179/200
# 15/15 [==============================] - 0s 14ms/step - loss: 0.0145 - accuracy: 0.9658 - val_loss: 0.0701 - val_accuracy: 0.8218
# Epoch 180/200
# 15/15 [==============================] - 0s 15ms/step - loss: 0.0156 - accuracy: 0.9592 - val_loss: 0.0562 - val_accuracy: 0.8713
# Epoch 181/200
# 15/15 [==============================] - 0s 15ms/step - loss: 0.0141 - accuracy: 0.9669 - val_loss: 0.0370 - val_accuracy: 0.9109
# Epoch 182/200
# 15/15 [==============================] - 0s 14ms/step - loss: 0.0125 - accuracy: 0.9702 - val_loss: 0.0858 - val_accuracy: 0.7723
# Epoch 183/200
# 15/15 [==============================] - 0s 14ms/step - loss: 0.0152 - accuracy: 0.9603 - val_loss: 0.0499 - val_accuracy: 0.8614
# Epoch 184/200
# 15/15 [==============================] - 0s 14ms/step - loss: 0.0146 - accuracy: 0.9658 - val_loss: 0.0670 - val_accuracy: 0.8317
# Epoch 185/200
# 15/15 [==============================] - 0s 15ms/step - loss: 0.0149 - accuracy: 0.9636 - val_loss: 0.0665 - val_accuracy: 0.8317
# Epoch 186/200
# 15/15 [==============================] - 0s 13ms/step - loss: 0.0122 - accuracy: 0.9713 - val_loss: 0.0660 - val_accuracy: 0.8218
# Epoch 187/200
# 15/15 [==============================] - 0s 15ms/step - loss: 0.0126 - accuracy: 0.9724 - val_loss: 0.0481 - val_accuracy: 0.8713
# Epoch 188/200
# 15/15 [==============================] - 0s 14ms/step - loss: 0.0137 - accuracy: 0.9680 - val_loss: 0.0425 - val_accuracy: 0.8812
# Epoch 189/200
# 15/15 [==============================] - 0s 14ms/step - loss: 0.0130 - accuracy: 0.9691 - val_loss: 0.0504 - val_accuracy: 0.8614
# Epoch 190/200
# 15/15 [==============================] - 0s 15ms/step - loss: 0.0095 - accuracy: 0.9746 - val_loss: 0.0937 - val_accuracy: 0.7624
# Epoch 191/200
# 15/15 [==============================] - 0s 14ms/step - loss: 0.0146 - accuracy: 0.9614 - val_loss: 0.0524 - val_accuracy: 0.8713
# Epoch 192/200
# 15/15 [==============================] - 0s 14ms/step - loss: 0.0142 - accuracy: 0.9680 - val_loss: 0.0614 - val_accuracy: 0.8515
# Epoch 193/200
# 15/15 [==============================] - 0s 13ms/step - loss: 0.0161 - accuracy: 0.9614 - val_loss: 0.0498 - val_accuracy: 0.8614
# Epoch 194/200
# 15/15 [==============================] - 0s 15ms/step - loss: 0.0108 - accuracy: 0.9768 - val_loss: 0.0591 - val_accuracy: 0.8317
# Epoch 195/200
# 15/15 [==============================] - 0s 15ms/step - loss: 0.0120 - accuracy: 0.9713 - val_loss: 0.0597 - val_accuracy: 0.8515
# Epoch 196/200
# 15/15 [==============================] - 0s 13ms/step - loss: 0.0101 - accuracy: 0.9746 - val_loss: 0.0643 - val_accuracy: 0.8317
# Epoch 197/200
# 15/15 [==============================] - 0s 15ms/step - loss: 0.0153 - accuracy: 0.9658 - val_loss: 0.0866 - val_accuracy: 0.8020
# Epoch 198/200
# 15/15 [==============================] - 0s 13ms/step - loss: 0.0170 - accuracy: 0.9537 - val_loss: 0.0493 - val_accuracy: 0.8713
# Epoch 199/200
# 15/15 [==============================] - 0s 15ms/step - loss: 0.0129 - accuracy: 0.9647 - val_loss: 0.0509 - val_accuracy: 0.8614
# Epoch 200/200
# 15/15 [==============================] - 0s 15ms/step - loss: 0.0137 - accuracy: 0.9636 - val_loss: 0.0474 - val_accuracy: 0.8713
# Saving trained model...
# Testing...
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 4/4 [==============================] - 1s 5ms/step
# [[25  1  1  1]
#  [ 3 15  4  4]
#  [ 0  3 25  5]
#  [ 2  0  2 21]]
# [[0.89 0.04 0.04 0.04]
#  [0.12 0.58 0.15 0.15]
#  [0.   0.09 0.76 0.15]
#  [0.08 0.   0.08 0.84]]
# 76.79%
# 新的结果文件夹名称为： result_MultiAttention_LSTM_1层Transformer_MSE_epoch200_batchsize64_lr0.001_76.79%
# 程序执行时间为：93.21秒

# %%
# 定位到指定路径下
import os
os.chdir('/content/drive/MyDrive/Colab_Notebooks/RNN-CAP')
print(os.getcwd())

# 打印版本
import sys
import tensorflow as tf

print("Python 版本:", sys.version)
print("TensorFlow 版本:", tf.__version__)

# !pip install xlwt
# !pip install matplotlib

# %%
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_categorical_crossentropy_epoch30.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_categorical_crossentropy_epoch250.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_categorical_crossentropy_epoch50.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_categorical_crossentropy_epoch100.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_categorical_crossentropy_epoch150.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_categorical_crossentropy_epoch200.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_squared_error_epoch30.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_squared_error_epoch50.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_squared_error_epoch100.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_squared_error_epoch150.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_squared_error_epoch200.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_squared_error_epoch250.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_absolute_error_epoch30.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_absolute_error_epoch50.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_absolute_error_epoch100.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_absolute_error_epoch150.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_absolute_error_epoch200.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_absolute_error_epoch250.py

# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_binary_crossentropy_epoch30.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_binary_crossentropy_epoch50.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_binary_crossentropy_epoch100.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_binary_crossentropy_epoch150.py

#!python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_binary_crossentropy_epoch200.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_binary_crossentropy_epoch250.py
