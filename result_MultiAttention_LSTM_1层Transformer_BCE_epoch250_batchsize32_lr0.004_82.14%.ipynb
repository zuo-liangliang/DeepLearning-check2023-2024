# %% [markdown]
# <a href="https://colab.research.google.com/github/zuo-liangliang/fcn.berkeleyvision.org/blob/master/result_MultiAttention_LSTM_1%E5%B1%82Transformer_BCE_epoch250_batchsize32_lr0.004_82.14%25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import zipfile

# 定义源文件夹路径和目标 zip 文件夹路径
# source_folder = '/content/drive/MyDrive/Colab_Notebooks/528BVP-acnt2'
source_folder = '/content/drive/MyDrive/AugustResult'
# target_zip_folder = '/content/drive/MyDrive/Colab_Notebooks/zip_folder'
# target_zip_folder = '/content/drive/MyDrive/Colab_Notebooks/528BVP-acnt2/0827zip_folder'
target_zip_folder = '/content/drive/MyDrive/AugustResult/0907_月月账号zip_folder'

# 确保目标 zip 文件夹存在
os.makedirs(target_zip_folder, exist_ok=True)

# 获取源文件夹中以 "result" 开头的文件夹列表
folder_list = [folder for folder in os.listdir(source_folder) if os.path.isdir(os.path.join(source_folder, folder)) and folder.startswith("result")]

# 创建一个大的 zip 文件
with zipfile.ZipFile(os.path.join(target_zip_folder, '0907月月_all_folders.zip'), 'w', zipfile.ZIP_DEFLATED) as zipf:
    # 遍历文件夹列表，逐个压缩为 zip 文件
    for folder in folder_list:
        folder_path = os.path.join(source_folder, folder)

        # 遍历文件夹中的所有文件和子文件夹，并逐个添加到大的 zip 文件中
        for root, dirs, files in os.walk(folder_path):
            for file in files:
                file_path = os.path.join(root, file)
                zipf.write(file_path, os.path.relpath(file_path, source_folder))

print("所有文件夹已压缩为一个大的 zip 文件！")
# Out:
# 所有文件夹已压缩为一个大的 zip 文件！

# %%
import shutil
import os
# 指定要删除的文件夹路径
folder_path = 'xxx' #替换为你的文件夹路径

# 确保要删除的是一个目录而不是文件
assert os.path.isdir(folder_path), f"{folder_path} 不是一个目录"

# 递归删除文件夹下的所有文件和子文件夹
shutil.rmtree(folder_path)

# %%
# 解压指定文件夹到某一路径下
import zipfile

file_path = '/content/drive/MyDrive/Colab_Notebooks/528BVP-acnt2/528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4.zip'
extract_path = '/content/drive/MyDrive/Colab_Notebooks/528BVP-acnt2/528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4'

with zipfile.ZipFile(file_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# %%
# 定位到指定路径下
import os
# os.chdir('/content/drive/MyDrive/SeptemberResult/result_LSTM')
os.chdir('/content/drive/MyDrive/SeptemberResult/result_MultiAttention_LSTM_1层Transformer')
print(os.getcwd())
# Out:
# /content/drive/MyDrive/SeptemberResult/result_MultiAttention_LSTM_1层Transformer

# %%
# result_MultiAttention_LSTM_1层Transformer

from keras.callbacks import Callback
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay

from __future__ import print_function

import time
import os,sys
import numpy as np
import pandas as pd
import scipy.io as scio
import tensorflow as tf
tf.compat.v1.keras.backend.set_session
import keras
from keras.layers import Input, GRU, LSTM, Dense, Flatten, Dropout, Conv2D, Conv3D, MaxPooling2D, MaxPooling3D, TimeDistributed
from keras.models import Model, load_model
import keras.backend as K
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split

# Parameters
use_existing_model = False
fraction_for_test = 0.1
data_dir = '/content/drive/MyDrive/Colab_Notebooks/528BVP-acnt2/528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4/'
# data_dir = '/content/drive/MyDrive/new528BVP/528[-1,1]长度20-分辨率15_acnt2_sample_rate5000__剔14_改6为4/'

fraction_for_test = 0.1
#ALL_MOTION = [1,2,3,4,5,6]
ALL_MOTION = [2,3,4,5]
N_MOTION = len(ALL_MOTION)
T_MAX = 0
n_epochs = 250  #最优的是100；第2优的是200，第3优的是250，原始是50 #修改点1
f_dropout_ratio = 0.5
n_gru_hidden_units = 128
n_batch_size = 32     #原始是32-->16
f_learning_rate = 0.004  #原始是0.001-->0.002

def normalize_data(data_1):
    # data(ndarray)=>data_norm(ndarray): [20,20,T]=>[20,20,T]
    data_1_max = np.concatenate((data_1.max(axis=0),data_1.max(axis=1)),axis=0).max(axis=0)
    data_1_min = np.concatenate((data_1.min(axis=0),data_1.min(axis=1)),axis=0).min(axis=0)
    if (len(np.where((data_1_max - data_1_min) == 0)[0]) > 0):
        return data_1
    data_1_max_rep = np.tile(data_1_max,(data_1.shape[0],data_1.shape[1],1))
    data_1_min_rep = np.tile(data_1_min,(data_1.shape[0],data_1.shape[1],1))
    data_1_norm = (data_1 - data_1_min_rep) / (data_1_max_rep - data_1_min_rep)
    return  data_1_norm

def zero_padding(data, T_MAX):
    # data(list)=>data_pad(ndarray): [20,20,T1/T2/...]=>[20,20,T_MAX]
    data_pad = []
    for i in range(len(data)):
        t = np.array(data[i]).shape[2]
        data_pad.append(np.pad(data[i], ((0,0),(0,0),(T_MAX - t,0)), 'constant', constant_values = 0).tolist())
    return np.array(data_pad)

def onehot_encoding(label, num_class):
    # label(list)=>_label(ndarray): [N,]=>[N,num_class]
    label = np.array(label).astype('int32')
    # assert (np.arange(0,np.unique(label).size)==np.unique(label)).prod()    # Check label from 0 to N
    label = np.squeeze(label)
    # _label = np.eye(num_class)[label-1]     # from label to onehot
    _label = np.eye(num_class)[label-2]   #修改点2
    return _label

def load_data(path_to_data, motion_sel):
    global T_MAX
    data = []
    label = []
    for data_root, data_dirs, data_files in os.walk(path_to_data):
        for data_file_name in data_files:

            file_path = os.path.join(data_root,data_file_name)
            try:
                data_1 = scio.loadmat(file_path)['velocity_spectrum_ro']
                label_1 = int(data_file_name.split('-')[1])
                #location = int(data_file_name.split('-')[2])
                #orientation = int(data_file_name.split('-')[3])
                #repetition = int(data_file_name.split('-')[4])
                repetition = int(data_file_name.split('-')[2])  #修改点3

                # Select Motion
                if (label_1 not in motion_sel):
                    continue

                # Select Location
                # if (location not in [1,2,3,5]):
                #     continue

                # Select Orientation
                # if (orientation not in [1,2,4,5]):
                #     continue

                # Normalization
                data_normed_1 = normalize_data(data_1)

                # Update T_MAX
                if T_MAX < np.array(data_1).shape[2]:
                    T_MAX = np.array(data_1).shape[2]
            except Exception:
                continue

            # Save List
            data.append(data_normed_1.tolist())
            label.append(label_1)
                # Zero-padding
    data = zero_padding(data, T_MAX)

    # Swap axes
    data = np.swapaxes(np.swapaxes(data, 1, 3), 2, 3)   # [N,20,20',T_MAX]=>[N,T_MAX,20,20']
    data = np.expand_dims(data, axis=-1)    # [N,T_MAX,20,20]=>[N,T_MAX,20,20,1]

    # Convert label to ndarray
    label = np.array(label)

    # data(ndarray): [N,T_MAX,20,20,1], label(ndarray): [N,N_MOTION]
    return data, label

# 构建符合输入形状为 (None, 20, 15, 15, 1) 和输出形状为 (None, 4) 的  模型：
from keras.layers import MultiHeadAttention, LayerNormalization  #加Transformer修改点1
num_transformer_layers = 1  # 设置Transformer层数 #加Transformer修改点2  2层-->1层

#加Transformer修改点3
def transformer_layer(inputs, hidden_units, dropout_rate):
    # Self-attention
    attention_output = MultiHeadAttention(
        num_heads=8, key_dim=hidden_units // 8
    )(inputs, inputs)
    attention_output = Dropout(dropout_rate)(attention_output)
    attention_output = LayerNormalization()(attention_output + inputs)

    # Feed-forward network
    ffn = Dense(hidden_units, activation="relu")(attention_output)
    ffn = Dense(hidden_units)(ffn)
    ffn = Dropout(dropout_rate)(ffn)
    ffn = LayerNormalization()(ffn)

    return ffn

#加Transformer修改点4
def assemble_model(input_shape, n_class):
    model_input = Input(shape=input_shape, dtype='float32', name='name_model_input')    # (@,T_MAX,20,20,1)

    # Feature extraction part
    x = TimeDistributed(Conv2D(16,kernel_size=(5,5),activation='relu',data_format='channels_last',\
        input_shape=input_shape))(model_input)   # (@,T_MAX,20,20,1)=>(@,T_MAX,16,16,16)
    x = TimeDistributed(MaxPooling2D(pool_size=(2,2)))(x)    # (@,T_MAX,16,16,16)=>(@,T_MAX,8,8,16)
    x = TimeDistributed(Flatten())(x)   # (@,T_MAX,8,8,16)=>(@,T_MAX,8*8*16)
    x = TimeDistributed(Dense(64,activation='relu'))(x) # (@,T_MAX,8*8*16)=>(@,T_MAX,64)
    x = TimeDistributed(Dropout(f_dropout_ratio))(x)
    x = TimeDistributed(Dense(64,activation='relu'))(x) # (@,T_MAX,64)=>(@,T_MAX,64)

    # Add transformer layers
    for _ in range(num_transformer_layers):
        #x = transformer_layer(x, hidden_units=n_gru_hidden_units, dropout_rate=f_dropout_ratio)
        x = transformer_layer(x, hidden_units=64, dropout_rate=f_dropout_ratio)  # 修改点1
    x = LSTM(n_gru_hidden_units,return_sequences=False)(x)  # (@,T_MAX,64)=>(@,128)
    x = Dropout(f_dropout_ratio)(x)
    model_output = Dense(n_class, activation='softmax', name='name_model_output')(x)  # (@,128)=>(@,n_class)

    # Create the model
    # Model compiling
    model = Model(inputs=model_input, outputs=model_output)
    model.compile(optimizer=keras.optimizers.RMSprop(lr=f_learning_rate),
                    # loss='categorical_crossentropy', # 将损失函数改为多类别交叉熵损失函数 最优的是CCE
                    # loss='mean_squared_error',  # 将损失函数改为均方误差 第2优的是MSE
                    # loss='mean_absolute_error',  # 将损失函数改为平均绝对误差 第3优的是MAE
                    loss='binary_crossentropy',  # 将损失函数改为对数损失函数 第3优的是MAE
                    metrics=['accuracy']
                )
    return model

# 改
#model_type = '双层LSTM'
#model_type = 'LSTM'
#model_type = 'BiLSTM'
model_type = 'MultiAttention_LSTM_1层Transformer'

# 创建结果文件夹
# result_folder = f'result_528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_GRU_改costfunction为mse_epoch200' # 每次都要改
# result_folder = f'result_528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_{model_type}_categorical_crossentropy_epoch{n_epochs}'
# result_folder = f'result_528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_{model_type}_mean_squared_error_epoch{n_epochs}'
# result_folder = f'result_528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_{model_type}_mean_absolute_error_epoch{n_epochs}'
# result_folder = f'result_528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_{model_type}_binary_crossentropy_epoch{n_epochs}'

# result_folder = f'result_{model_type}_CCE_epoch{n_epochs}_batchsize{n_batch_size}_lr{f_learning_rate}'
# result_folder = f'result_{model_type}_MSE_epoch{n_epochs}_batchsize{n_batch_size}_lr{f_learning_rate}'
# result_folder = f'result_{model_type}_MAE_epoch{n_epochs}_batchsize{n_batch_size}_lr{f_learning_rate}'
result_folder = f'result_{model_type}_BCE_epoch{n_epochs}_batchsize{n_batch_size}_lr{f_learning_rate}'

os.makedirs(result_folder, exist_ok=True)

# %%
# Let's BEGIN >>>>

import time
start_time = time.time()  # 记录程序开始时间

# 获取可见的GPU设备列表
# visible_gpus = tf.config.experimental.list_physical_devices('GPU')
# 检查是否存在可见的GPU设备
# if len(visible_gpus) < 1:
    # print('No GPU available')
    # exit(0)
# 设置使用第一个可见的GPU设备
# os.environ["CUDA_VISIBLE_DEVICES"] = str(visible_gpus[0].index)
# 配置GPU选项
# gpu_config = tf.config.experimental.set_memory_growth(visible_gpus[0], True)
# 创建一个会话并应用GPU配置
# sess = tf.compat.v1.Session(config=gpu_config)
# tf.compat.v1.keras.backend.set_session(sess)
# tf.random.set_seed(1)

# 获取可见的 GPU 设备列表
visible_gpus = tf.config.experimental.list_physical_devices('GPU')
if len(visible_gpus) > 0:
    # 如果有可见的 GPU 设备，设置 TensorFlow 在 GPU 上运行
    tf.config.set_visible_devices(visible_gpus, 'GPU')
    gpu_config = tf.config.experimental.set_memory_growth(visible_gpus[0], True)
    sess = tf.compat.v1.Session(config=gpu_config)
    tf.compat.v1.keras.backend.set_session(sess)
    print('GPU available')
else:
    # 如果没有可见的 GPU 设备，设置 TensorFlow 在 CPU 上运行
    tf.config.set_visible_devices([], 'GPU')
    sess = tf.compat.v1.Session()
    print('No GPU available')

# Load data
data, label = load_data(data_dir, ALL_MOTION)
print('\nLoaded dataset of ' + str(label.shape[0]) + ' samples, each sized ' + str(data[0,:,:].shape) + '\n')

# Split train and test
[data_train, data_test, label_train, label_test] = train_test_split(data, label, test_size=fraction_for_test)
print('\nTrain on ' + str(label_train.shape[0]) + ' samples\n' +\
    'Test on ' + str(label_test.shape[0]) + ' samples\n')

# One-hot encoding for train data
label_train = onehot_encoding(label_train, N_MOTION)

# Load or fabricate model
if use_existing_model:
    model = load_model('model_widar3_trained.h5')
    model.summary()
else:
    #model = assemble_model(input_shape=(T_MAX, 20, 20, 1), n_class=N_MOTION)
    model = assemble_model(input_shape=(T_MAX, 15, 15, 1), n_class=N_MOTION) #修改点4
    model.summary()

class AccuracyLossHistory(Callback):
    def on_train_begin(self, logs={}):
        self.acc = []
        self.loss = []
        self.val_acc = []
        self.val_loss = []

    def on_epoch_end(self, epoch, logs={}):
        self.acc.append(logs.get('accuracy'))
        self.loss.append(logs.get('loss'))
        self.val_acc.append(logs.get('val_accuracy'))
        self.val_loss.append(logs.get('val_loss'))

history = AccuracyLossHistory()

model.fit({'name_model_input': data_train},{'name_model_output': label_train},
          batch_size=n_batch_size,
          epochs=n_epochs,
          verbose=1,
          validation_split=0.1, shuffle=True, callbacks=[history])
print('Saving trained model...')
#model.save('model_widar3_trained.h5')
model.save(f'{result_folder}/model.h5')  # 改动

# Testing...
print('Testing...')
label_test_pred = model.predict(data_test)
# label_test_pred = np.argmax(label_test_pred, axis = -1) + 1
label_test_pred = np.argmax(label_test_pred, axis = -1) + 2 #修改点5

# Confusion Matrix
cm = confusion_matrix(label_test, label_test_pred)
print(cm)
cm = cm.astype('float')/cm.sum(axis=1)[:, np.newaxis]
cm = np.around(cm, decimals=2)
print(cm)
#cm_display = ConfusionMatrixDisplay(cm, display_labels=range(1, N_MOTION+1)).plot()
#cm_display = ConfusionMatrixDisplay(cm, display_labels=range(4, N_MOTION+3)).plot() #2345 lebel-2  4567 4=2+2  7=长度4+3
cm_display = ConfusionMatrixDisplay(cm, display_labels=range(2, N_MOTION+2)).plot() #2345 lebel-2  4567 4=2+2  7=长度4+3
plt.show()
plt.savefig(f'{result_folder}/cm.png') # 新增点1 保存混淆矩阵结果2023.09.11

# Accuracy 新增百分号
test_accuracy = np.sum(label_test == label_test_pred) / (label_test.shape[0])
#print(test_accuracy)
test_accuracy_percentage = test_accuracy * 100
test_accuracy_str = f"{test_accuracy_percentage:.2f}%"
print(test_accuracy_str)

df_accuracy = pd.DataFrame({'Test Accuracy': [test_accuracy]})
df_accuracy.to_excel(f'{result_folder}/{test_accuracy_str}.xlsx', index=False) ## 新增点2 保存测试集平均准确率结果2023.09.11


df = pd.DataFrame({
    'Epoch': range(1, n_epochs+1),
    'Train Accuracy': history.acc,
    'Train Loss': history.loss,
    'Validation Accuracy': history.val_acc,
    'Validation Loss': history.val_loss
})

# df.to_excel('accuracy_l'''  '''oss.xlsx', index=False)
# 保存准确率和损失数据到Excel表格中
df.to_excel(f'{result_folder}/accuracy_loss.xlsx', index=False) #改动

plt.plot(range(1, n_epochs+1), history.acc, label='Train Accuracy')
plt.plot(range(1, n_epochs+1), history.loss, label='Train Loss')
plt.plot(range(1, n_epochs+1), history.val_acc, label='Validation Accuracy')
plt.plot(range(1, n_epochs+1), history.val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.legend()
plt.savefig(f'{result_folder}/plot.png')
plt.show()

# 新增 修改文件名 并打印新的文件名
new_result_folder = result_folder + f'_{test_accuracy_str}'
os.rename(result_folder, new_result_folder)
result_folder = new_result_folder

print("新的结果文件夹名称为：", result_folder)

end_time = time.time()  # 记录程序结束时间
duration = end_time - start_time  # 计算程序运行时间
print("程序执行时间为：{:.2f}秒".format(duration))

with open(f'{result_folder}/runtime.txt', 'w') as f:
    f.write("程序执行时间为：{:.2f}秒".format(duration)) # 新增点3 保存程序执行时间结果2023.09.11
# Out:
# GPU available
#
# Loaded dataset of 1120 samples, each sized (20, 15, 15, 1)
#
#
# Train on 1008 samples
# Test on 112 samples
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.RMSprop.
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  name_model_input (InputLay  [(None, 20, 15, 15, 1)]      0         []
#  er)
#
#  time_distributed_6 (TimeDi  (None, 20, 11, 11, 16)       416       ['name_model_input[0][0]']
#  stributed)
#
#  time_distributed_7 (TimeDi  (None, 20, 5, 5, 16)         0         ['time_distributed_6[0][0]']
#  stributed)
#
#  time_distributed_8 (TimeDi  (None, 20, 400)              0         ['time_distributed_7[0][0]']
#  stributed)
#
#  time_distributed_9 (TimeDi  (None, 20, 64)               25664     ['time_distributed_8[0][0]']
#  stributed)
#
#  time_distributed_10 (TimeD  (None, 20, 64)               0         ['time_distributed_9[0][0]']
#  istributed)
#
#  time_distributed_11 (TimeD  (None, 20, 64)               4160      ['time_distributed_10[0][0]']
#  istributed)
#
#  multi_head_attention_1 (Mu  (None, 20, 64)               16640     ['time_distributed_11[0][0]',
#  ltiHeadAttention)                                                   'time_distributed_11[0][0]']
#
#  dropout_5 (Dropout)         (None, 20, 64)               0         ['multi_head_attention_1[0][0]
#                                                                     ']
#
#  tf.__operators__.add_1 (TF  (None, 20, 64)               0         ['dropout_5[0][0]',
#  OpLambda)                                                           'time_distributed_11[0][0]']
#
#  layer_normalization_2 (Lay  (None, 20, 64)               128       ['tf.__operators__.add_1[0][0]
#  erNormalization)                                                   ']
#
#  dense_6 (Dense)             (None, 20, 64)               4160      ['layer_normalization_2[0][0]'
#                                                                     ]
#
#  dense_7 (Dense)             (None, 20, 64)               4160      ['dense_6[0][0]']
#
#  dropout_6 (Dropout)         (None, 20, 64)               0         ['dense_7[0][0]']
#
#  layer_normalization_3 (Lay  (None, 20, 64)               128       ['dropout_6[0][0]']
#  erNormalization)
#
#  lstm_1 (LSTM)               (None, 128)                  98816     ['layer_normalization_3[0][0]'
#                                                                     ]
#
#  dropout_7 (Dropout)         (None, 128)                  0         ['lstm_1[0][0]']
#
#  name_model_output (Dense)   (None, 4)                    516       ['dropout_7[0][0]']
#
# ==================================================================================================
# Total params: 154788 (604.64 KB)
# Trainable params: 154788 (604.64 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/250
# 29/29 [==============================] - 7s 35ms/step - loss: 0.5883 - accuracy: 0.2492 - val_loss: 0.5638 - val_accuracy: 0.2871
# Epoch 2/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.5699 - accuracy: 0.2745 - val_loss: 0.5633 - val_accuracy: 0.2871
# Epoch 3/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.5690 - accuracy: 0.2745 - val_loss: 0.5616 - val_accuracy: 0.2376
# Epoch 4/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.5612 - accuracy: 0.3043 - val_loss: 0.5456 - val_accuracy: 0.3960
# Epoch 5/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.5557 - accuracy: 0.3286 - val_loss: 0.5211 - val_accuracy: 0.4257
# Epoch 6/250
# 29/29 [==============================] - 0s 14ms/step - loss: 0.5391 - accuracy: 0.3826 - val_loss: 0.5380 - val_accuracy: 0.3960
# Epoch 7/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.5272 - accuracy: 0.4333 - val_loss: 0.5329 - val_accuracy: 0.3762
# Epoch 8/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.5150 - accuracy: 0.4476 - val_loss: 0.5095 - val_accuracy: 0.4257
# Epoch 9/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.4931 - accuracy: 0.4873 - val_loss: 0.4757 - val_accuracy: 0.5347
# Epoch 10/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.4707 - accuracy: 0.5259 - val_loss: 0.4730 - val_accuracy: 0.4950
# Epoch 11/250
# 29/29 [==============================] - 0s 14ms/step - loss: 0.4524 - accuracy: 0.5502 - val_loss: 0.5739 - val_accuracy: 0.3960
# Epoch 12/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.4513 - accuracy: 0.5413 - val_loss: 0.4331 - val_accuracy: 0.5446
# Epoch 13/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.4308 - accuracy: 0.5865 - val_loss: 0.4442 - val_accuracy: 0.5149
# Epoch 14/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.4050 - accuracy: 0.6196 - val_loss: 0.4443 - val_accuracy: 0.4752
# Epoch 15/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.3935 - accuracy: 0.6351 - val_loss: 0.3647 - val_accuracy: 0.7228
# Epoch 16/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.3874 - accuracy: 0.6472 - val_loss: 0.4896 - val_accuracy: 0.4752
# Epoch 17/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.3791 - accuracy: 0.6637 - val_loss: 0.4007 - val_accuracy: 0.6535
# Epoch 18/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.3583 - accuracy: 0.6847 - val_loss: 0.2920 - val_accuracy: 0.7525
# Epoch 19/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.3599 - accuracy: 0.6858 - val_loss: 0.3574 - val_accuracy: 0.6832
# Epoch 20/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.3385 - accuracy: 0.6858 - val_loss: 0.2971 - val_accuracy: 0.7030
# Epoch 21/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.3273 - accuracy: 0.7255 - val_loss: 0.3303 - val_accuracy: 0.6931
# Epoch 22/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.3255 - accuracy: 0.7211 - val_loss: 0.2875 - val_accuracy: 0.7426
# Epoch 23/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.3058 - accuracy: 0.7508 - val_loss: 0.2744 - val_accuracy: 0.7426
# Epoch 24/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.2818 - accuracy: 0.7718 - val_loss: 0.4849 - val_accuracy: 0.5941
# Epoch 25/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.2896 - accuracy: 0.7729 - val_loss: 0.3184 - val_accuracy: 0.7030
# Epoch 26/250
# 29/29 [==============================] - 0s 14ms/step - loss: 0.2819 - accuracy: 0.7817 - val_loss: 0.2827 - val_accuracy: 0.7624
# Epoch 27/250
# 29/29 [==============================] - 0s 17ms/step - loss: 0.2785 - accuracy: 0.7828 - val_loss: 0.2638 - val_accuracy: 0.7723
# Epoch 28/250
# 29/29 [==============================] - 0s 17ms/step - loss: 0.2540 - accuracy: 0.8004 - val_loss: 0.4480 - val_accuracy: 0.6337
# Epoch 29/250
# 29/29 [==============================] - 1s 18ms/step - loss: 0.2662 - accuracy: 0.7960 - val_loss: 0.2277 - val_accuracy: 0.8020
# Epoch 30/250
# 29/29 [==============================] - 1s 17ms/step - loss: 0.2554 - accuracy: 0.7949 - val_loss: 0.2775 - val_accuracy: 0.7723
# Epoch 31/250
# 29/29 [==============================] - 0s 16ms/step - loss: 0.2642 - accuracy: 0.7861 - val_loss: 0.2770 - val_accuracy: 0.7525
# Epoch 32/250
# 29/29 [==============================] - 0s 17ms/step - loss: 0.2481 - accuracy: 0.7960 - val_loss: 0.2593 - val_accuracy: 0.7921
# Epoch 33/250
# 29/29 [==============================] - 0s 16ms/step - loss: 0.2205 - accuracy: 0.8269 - val_loss: 0.2677 - val_accuracy: 0.7624
# Epoch 34/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.2137 - accuracy: 0.8313 - val_loss: 0.2477 - val_accuracy: 0.7921
# Epoch 35/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.2186 - accuracy: 0.8357 - val_loss: 0.2701 - val_accuracy: 0.7921
# Epoch 36/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.2088 - accuracy: 0.8490 - val_loss: 0.2135 - val_accuracy: 0.8317
# Epoch 37/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.1971 - accuracy: 0.8556 - val_loss: 0.2328 - val_accuracy: 0.7921
# Epoch 38/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.1922 - accuracy: 0.8512 - val_loss: 0.2172 - val_accuracy: 0.8218
# Epoch 39/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.1935 - accuracy: 0.8600 - val_loss: 0.2142 - val_accuracy: 0.8119
# Epoch 40/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.1939 - accuracy: 0.8523 - val_loss: 0.2196 - val_accuracy: 0.7723
# Epoch 41/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.1774 - accuracy: 0.8677 - val_loss: 0.2402 - val_accuracy: 0.8317
# Epoch 42/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.1891 - accuracy: 0.8578 - val_loss: 0.2076 - val_accuracy: 0.8317
# Epoch 43/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.1711 - accuracy: 0.8809 - val_loss: 0.2455 - val_accuracy: 0.7921
# Epoch 44/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.1695 - accuracy: 0.8721 - val_loss: 0.2231 - val_accuracy: 0.8218
# Epoch 45/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.1861 - accuracy: 0.8633 - val_loss: 0.2374 - val_accuracy: 0.8119
# Epoch 46/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.1687 - accuracy: 0.8732 - val_loss: 0.2977 - val_accuracy: 0.7426
# Epoch 47/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.1604 - accuracy: 0.8787 - val_loss: 0.2379 - val_accuracy: 0.8317
# Epoch 48/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.1613 - accuracy: 0.8798 - val_loss: 0.2141 - val_accuracy: 0.8119
# Epoch 49/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.1424 - accuracy: 0.8897 - val_loss: 0.2122 - val_accuracy: 0.8218
# Epoch 50/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.1409 - accuracy: 0.8964 - val_loss: 0.2211 - val_accuracy: 0.8317
# Epoch 51/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.1381 - accuracy: 0.8975 - val_loss: 0.2355 - val_accuracy: 0.8218
# Epoch 52/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.1542 - accuracy: 0.8875 - val_loss: 0.2192 - val_accuracy: 0.8020
# Epoch 53/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.1317 - accuracy: 0.9052 - val_loss: 0.2170 - val_accuracy: 0.8515
# Epoch 54/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.1417 - accuracy: 0.9041 - val_loss: 0.2139 - val_accuracy: 0.8416
# Epoch 55/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.1210 - accuracy: 0.9140 - val_loss: 0.2041 - val_accuracy: 0.8218
# Epoch 56/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.1285 - accuracy: 0.9074 - val_loss: 0.2709 - val_accuracy: 0.7822
# Epoch 57/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.1215 - accuracy: 0.9162 - val_loss: 0.2043 - val_accuracy: 0.8416
# Epoch 58/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.1289 - accuracy: 0.9008 - val_loss: 0.2527 - val_accuracy: 0.7921
# Epoch 59/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.1211 - accuracy: 0.9239 - val_loss: 0.2334 - val_accuracy: 0.8515
# Epoch 60/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.1048 - accuracy: 0.9272 - val_loss: 0.2272 - val_accuracy: 0.8317
# Epoch 61/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.1207 - accuracy: 0.9118 - val_loss: 0.2195 - val_accuracy: 0.8515
# Epoch 62/250
# 29/29 [==============================] - 0s 14ms/step - loss: 0.0993 - accuracy: 0.9294 - val_loss: 0.2623 - val_accuracy: 0.7822
# Epoch 63/250
# 29/29 [==============================] - 0s 15ms/step - loss: 0.1125 - accuracy: 0.9107 - val_loss: 0.2267 - val_accuracy: 0.8515
# Epoch 64/250
# 29/29 [==============================] - 0s 15ms/step - loss: 0.1060 - accuracy: 0.9283 - val_loss: 0.2062 - val_accuracy: 0.8317
# Epoch 65/250
# 29/29 [==============================] - 0s 17ms/step - loss: 0.1177 - accuracy: 0.9129 - val_loss: 0.2525 - val_accuracy: 0.7822
# Epoch 66/250
# 29/29 [==============================] - 1s 18ms/step - loss: 0.1061 - accuracy: 0.9250 - val_loss: 0.2774 - val_accuracy: 0.7723
# Epoch 67/250
# 29/29 [==============================] - 0s 17ms/step - loss: 0.1056 - accuracy: 0.9272 - val_loss: 0.2213 - val_accuracy: 0.8317
# Epoch 68/250
# 29/29 [==============================] - 1s 17ms/step - loss: 0.1059 - accuracy: 0.9294 - val_loss: 0.2323 - val_accuracy: 0.8317
# Epoch 69/250
# 29/29 [==============================] - 1s 17ms/step - loss: 0.1055 - accuracy: 0.9261 - val_loss: 0.2212 - val_accuracy: 0.8416
# Epoch 70/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0964 - accuracy: 0.9350 - val_loss: 0.2654 - val_accuracy: 0.8218
# Epoch 71/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0980 - accuracy: 0.9272 - val_loss: 0.1944 - val_accuracy: 0.8515
# Epoch 72/250
# 29/29 [==============================] - 0s 14ms/step - loss: 0.0892 - accuracy: 0.9361 - val_loss: 0.1841 - val_accuracy: 0.8317
# Epoch 73/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0727 - accuracy: 0.9559 - val_loss: 0.2315 - val_accuracy: 0.8416
# Epoch 74/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0890 - accuracy: 0.9427 - val_loss: 0.2225 - val_accuracy: 0.8119
# Epoch 75/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.1074 - accuracy: 0.9239 - val_loss: 0.2478 - val_accuracy: 0.8317
# Epoch 76/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0813 - accuracy: 0.9427 - val_loss: 0.2480 - val_accuracy: 0.8020
# Epoch 77/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.0908 - accuracy: 0.9283 - val_loss: 0.2319 - val_accuracy: 0.8614
# Epoch 78/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0861 - accuracy: 0.9460 - val_loss: 0.2450 - val_accuracy: 0.8317
# Epoch 79/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0811 - accuracy: 0.9482 - val_loss: 0.3960 - val_accuracy: 0.7426
# Epoch 80/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0850 - accuracy: 0.9361 - val_loss: 0.2817 - val_accuracy: 0.8119
# Epoch 81/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0776 - accuracy: 0.9537 - val_loss: 0.2419 - val_accuracy: 0.8416
# Epoch 82/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0736 - accuracy: 0.9559 - val_loss: 0.2537 - val_accuracy: 0.8119
# Epoch 83/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0719 - accuracy: 0.9537 - val_loss: 0.2382 - val_accuracy: 0.8317
# Epoch 84/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0792 - accuracy: 0.9526 - val_loss: 0.2544 - val_accuracy: 0.8416
# Epoch 85/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0713 - accuracy: 0.9493 - val_loss: 0.2231 - val_accuracy: 0.8416
# Epoch 86/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0673 - accuracy: 0.9581 - val_loss: 0.2243 - val_accuracy: 0.8416
# Epoch 87/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0683 - accuracy: 0.9603 - val_loss: 0.2273 - val_accuracy: 0.8515
# Epoch 88/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0590 - accuracy: 0.9636 - val_loss: 0.2304 - val_accuracy: 0.8515
# Epoch 89/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0881 - accuracy: 0.9383 - val_loss: 0.2116 - val_accuracy: 0.8614
# Epoch 90/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0605 - accuracy: 0.9592 - val_loss: 0.2372 - val_accuracy: 0.8515
# Epoch 91/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0770 - accuracy: 0.9471 - val_loss: 0.2607 - val_accuracy: 0.8317
# Epoch 92/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.0529 - accuracy: 0.9636 - val_loss: 0.2353 - val_accuracy: 0.8218
# Epoch 93/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0642 - accuracy: 0.9592 - val_loss: 0.2413 - val_accuracy: 0.8416
# Epoch 94/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0755 - accuracy: 0.9581 - val_loss: 0.2756 - val_accuracy: 0.8218
# Epoch 95/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0641 - accuracy: 0.9559 - val_loss: 0.2307 - val_accuracy: 0.8614
# Epoch 96/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0467 - accuracy: 0.9735 - val_loss: 0.3306 - val_accuracy: 0.8020
# Epoch 97/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0602 - accuracy: 0.9592 - val_loss: 0.2566 - val_accuracy: 0.8218
# Epoch 98/250
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0598 - accuracy: 0.9570 - val_loss: 0.2249 - val_accuracy: 0.8416
# Epoch 99/250
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0561 - accuracy: 0.9680 - val_loss: 0.2670 - val_accuracy: 0.8119
# Epoch 100/250
# 29/29 [==============================] - 1s 19ms/step - loss: 0.0592 - accuracy: 0.9636 - val_loss: 0.2428 - val_accuracy: 0.8218
# Epoch 101/250
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0426 - accuracy: 0.9691 - val_loss: 0.2492 - val_accuracy: 0.8218
# Epoch 102/250
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0482 - accuracy: 0.9680 - val_loss: 0.2628 - val_accuracy: 0.8218
# Epoch 103/250
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0552 - accuracy: 0.9603 - val_loss: 0.2521 - val_accuracy: 0.8713
# Epoch 104/250
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0528 - accuracy: 0.9669 - val_loss: 0.2226 - val_accuracy: 0.8416
# Epoch 105/250
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0511 - accuracy: 0.9548 - val_loss: 0.2426 - val_accuracy: 0.8812
# Epoch 106/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0525 - accuracy: 0.9614 - val_loss: 0.2759 - val_accuracy: 0.7921
# Epoch 107/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0591 - accuracy: 0.9680 - val_loss: 0.2593 - val_accuracy: 0.8218
# Epoch 108/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0543 - accuracy: 0.9691 - val_loss: 0.2390 - val_accuracy: 0.8515
# Epoch 109/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0613 - accuracy: 0.9647 - val_loss: 0.2605 - val_accuracy: 0.8614
# Epoch 110/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0549 - accuracy: 0.9625 - val_loss: 0.2577 - val_accuracy: 0.8317
# Epoch 111/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0448 - accuracy: 0.9724 - val_loss: 0.2373 - val_accuracy: 0.8614
# Epoch 112/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0676 - accuracy: 0.9559 - val_loss: 0.2841 - val_accuracy: 0.7921
# Epoch 113/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0587 - accuracy: 0.9647 - val_loss: 0.2144 - val_accuracy: 0.8218
# Epoch 114/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0385 - accuracy: 0.9768 - val_loss: 0.2357 - val_accuracy: 0.8218
# Epoch 115/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0538 - accuracy: 0.9680 - val_loss: 0.2639 - val_accuracy: 0.8416
# Epoch 116/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0401 - accuracy: 0.9735 - val_loss: 0.3343 - val_accuracy: 0.7822
# Epoch 117/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0472 - accuracy: 0.9702 - val_loss: 0.2475 - val_accuracy: 0.8614
# Epoch 118/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0350 - accuracy: 0.9735 - val_loss: 0.2551 - val_accuracy: 0.8614
# Epoch 119/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0458 - accuracy: 0.9713 - val_loss: 0.2714 - val_accuracy: 0.8317
# Epoch 120/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0415 - accuracy: 0.9746 - val_loss: 0.2403 - val_accuracy: 0.8416
# Epoch 121/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0441 - accuracy: 0.9757 - val_loss: 0.2569 - val_accuracy: 0.8218
# Epoch 122/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0357 - accuracy: 0.9779 - val_loss: 0.2232 - val_accuracy: 0.8515
# Epoch 123/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0472 - accuracy: 0.9702 - val_loss: 0.2199 - val_accuracy: 0.8713
# Epoch 124/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0283 - accuracy: 0.9857 - val_loss: 0.2464 - val_accuracy: 0.8218
# Epoch 125/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0464 - accuracy: 0.9702 - val_loss: 0.2437 - val_accuracy: 0.8515
# Epoch 126/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0287 - accuracy: 0.9813 - val_loss: 0.2373 - val_accuracy: 0.8713
# Epoch 127/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0505 - accuracy: 0.9669 - val_loss: 0.2526 - val_accuracy: 0.8416
# Epoch 128/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0410 - accuracy: 0.9724 - val_loss: 0.2770 - val_accuracy: 0.8515
# Epoch 129/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0273 - accuracy: 0.9846 - val_loss: 0.2723 - val_accuracy: 0.8416
# Epoch 130/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0291 - accuracy: 0.9802 - val_loss: 0.2624 - val_accuracy: 0.8416
# Epoch 131/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0462 - accuracy: 0.9779 - val_loss: 0.2716 - val_accuracy: 0.8515
# Epoch 132/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0478 - accuracy: 0.9724 - val_loss: 0.2226 - val_accuracy: 0.8515
# Epoch 133/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0257 - accuracy: 0.9890 - val_loss: 0.2793 - val_accuracy: 0.8515
# Epoch 134/250
# 29/29 [==============================] - 1s 17ms/step - loss: 0.0423 - accuracy: 0.9746 - val_loss: 0.3526 - val_accuracy: 0.7723
# Epoch 135/250
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0408 - accuracy: 0.9791 - val_loss: 0.2293 - val_accuracy: 0.8812
# Epoch 136/250
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0331 - accuracy: 0.9779 - val_loss: 0.2772 - val_accuracy: 0.8416
# Epoch 137/250
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0304 - accuracy: 0.9846 - val_loss: 0.2913 - val_accuracy: 0.8515
# Epoch 138/250
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0323 - accuracy: 0.9846 - val_loss: 0.2968 - val_accuracy: 0.8317
# Epoch 139/250
# 29/29 [==============================] - 1s 17ms/step - loss: 0.0343 - accuracy: 0.9735 - val_loss: 0.2586 - val_accuracy: 0.8416
# Epoch 140/250
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0323 - accuracy: 0.9802 - val_loss: 0.2646 - val_accuracy: 0.8515
# Epoch 141/250
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0451 - accuracy: 0.9647 - val_loss: 0.2818 - val_accuracy: 0.8416
# Epoch 142/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0464 - accuracy: 0.9768 - val_loss: 0.2499 - val_accuracy: 0.8317
# Epoch 143/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0281 - accuracy: 0.9835 - val_loss: 0.2631 - val_accuracy: 0.8713
# Epoch 144/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0459 - accuracy: 0.9735 - val_loss: 0.2694 - val_accuracy: 0.8218
# Epoch 145/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0239 - accuracy: 0.9835 - val_loss: 0.2617 - val_accuracy: 0.8515
# Epoch 146/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0354 - accuracy: 0.9824 - val_loss: 0.2297 - val_accuracy: 0.8614
# Epoch 147/250
# 29/29 [==============================] - 0s 14ms/step - loss: 0.0315 - accuracy: 0.9813 - val_loss: 0.3271 - val_accuracy: 0.8317
# Epoch 148/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0404 - accuracy: 0.9779 - val_loss: 0.2490 - val_accuracy: 0.8713
# Epoch 149/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0342 - accuracy: 0.9757 - val_loss: 0.2691 - val_accuracy: 0.8119
# Epoch 150/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0257 - accuracy: 0.9901 - val_loss: 0.2663 - val_accuracy: 0.8317
# Epoch 151/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0398 - accuracy: 0.9735 - val_loss: 0.2987 - val_accuracy: 0.8416
# Epoch 152/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0207 - accuracy: 0.9901 - val_loss: 0.3026 - val_accuracy: 0.8515
# Epoch 153/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0325 - accuracy: 0.9802 - val_loss: 0.2787 - val_accuracy: 0.8416
# Epoch 154/250
# 29/29 [==============================] - 0s 11ms/step - loss: 0.0309 - accuracy: 0.9779 - val_loss: 0.2936 - val_accuracy: 0.8416
# Epoch 155/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0221 - accuracy: 0.9868 - val_loss: 0.2771 - val_accuracy: 0.8515
# Epoch 156/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0280 - accuracy: 0.9857 - val_loss: 0.3668 - val_accuracy: 0.8020
# Epoch 157/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0374 - accuracy: 0.9791 - val_loss: 0.3275 - val_accuracy: 0.8020
# Epoch 158/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0219 - accuracy: 0.9890 - val_loss: 0.2588 - val_accuracy: 0.8416
# Epoch 159/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0327 - accuracy: 0.9868 - val_loss: 0.2555 - val_accuracy: 0.8614
# Epoch 160/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0231 - accuracy: 0.9879 - val_loss: 0.2829 - val_accuracy: 0.8317
# Epoch 161/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0376 - accuracy: 0.9791 - val_loss: 0.2907 - val_accuracy: 0.8416
# Epoch 162/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0254 - accuracy: 0.9846 - val_loss: 0.2724 - val_accuracy: 0.8218
# Epoch 163/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0354 - accuracy: 0.9835 - val_loss: 0.2530 - val_accuracy: 0.8614
# Epoch 164/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0191 - accuracy: 0.9890 - val_loss: 0.2545 - val_accuracy: 0.8515
# Epoch 165/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0318 - accuracy: 0.9890 - val_loss: 0.2673 - val_accuracy: 0.8416
# Epoch 166/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0264 - accuracy: 0.9879 - val_loss: 0.3118 - val_accuracy: 0.8218
# Epoch 167/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0410 - accuracy: 0.9768 - val_loss: 0.2764 - val_accuracy: 0.8317
# Epoch 168/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0172 - accuracy: 0.9901 - val_loss: 0.2929 - val_accuracy: 0.8614
# Epoch 169/250
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0338 - accuracy: 0.9791 - val_loss: 0.3045 - val_accuracy: 0.8119
# Epoch 170/250
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0293 - accuracy: 0.9835 - val_loss: 0.2776 - val_accuracy: 0.8416
# Epoch 171/250
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0222 - accuracy: 0.9879 - val_loss: 0.2976 - val_accuracy: 0.8416
# Epoch 172/250
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0255 - accuracy: 0.9846 - val_loss: 0.2761 - val_accuracy: 0.8416
# Epoch 173/250
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0161 - accuracy: 0.9901 - val_loss: 0.3238 - val_accuracy: 0.8020
# Epoch 174/250
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0224 - accuracy: 0.9857 - val_loss: 0.3585 - val_accuracy: 0.8218
# Epoch 175/250
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0245 - accuracy: 0.9813 - val_loss: 0.2806 - val_accuracy: 0.8614
# Epoch 176/250
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0275 - accuracy: 0.9835 - val_loss: 0.2845 - val_accuracy: 0.8317
# Epoch 177/250
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0208 - accuracy: 0.9890 - val_loss: 0.2922 - val_accuracy: 0.8317
# Epoch 178/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0245 - accuracy: 0.9824 - val_loss: 0.3181 - val_accuracy: 0.8119
# Epoch 179/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0267 - accuracy: 0.9813 - val_loss: 0.2567 - val_accuracy: 0.8218
# Epoch 180/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0246 - accuracy: 0.9846 - val_loss: 0.2469 - val_accuracy: 0.8812
# Epoch 181/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0181 - accuracy: 0.9912 - val_loss: 0.3009 - val_accuracy: 0.8119
# Epoch 182/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0315 - accuracy: 0.9846 - val_loss: 0.2992 - val_accuracy: 0.8218
# Epoch 183/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0358 - accuracy: 0.9791 - val_loss: 0.2920 - val_accuracy: 0.8416
# Epoch 184/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0153 - accuracy: 0.9912 - val_loss: 0.2518 - val_accuracy: 0.8614
# Epoch 185/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0223 - accuracy: 0.9868 - val_loss: 0.2363 - val_accuracy: 0.8812
# Epoch 186/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0097 - accuracy: 0.9945 - val_loss: 0.2715 - val_accuracy: 0.8317
# Epoch 187/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0183 - accuracy: 0.9868 - val_loss: 0.2533 - val_accuracy: 0.8614
# Epoch 188/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0142 - accuracy: 0.9923 - val_loss: 0.2671 - val_accuracy: 0.8614
# Epoch 189/250
# 29/29 [==============================] - 0s 14ms/step - loss: 0.0117 - accuracy: 0.9923 - val_loss: 0.3063 - val_accuracy: 0.8713
# Epoch 190/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0232 - accuracy: 0.9835 - val_loss: 0.3680 - val_accuracy: 0.8020
# Epoch 191/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0210 - accuracy: 0.9890 - val_loss: 0.2482 - val_accuracy: 0.8812
# Epoch 192/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0243 - accuracy: 0.9879 - val_loss: 0.2614 - val_accuracy: 0.8911
# Epoch 193/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0239 - accuracy: 0.9879 - val_loss: 0.2830 - val_accuracy: 0.8317
# Epoch 194/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0348 - accuracy: 0.9813 - val_loss: 0.3046 - val_accuracy: 0.8515
# Epoch 195/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0147 - accuracy: 0.9923 - val_loss: 0.2890 - val_accuracy: 0.8218
# Epoch 196/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0316 - accuracy: 0.9824 - val_loss: 0.3609 - val_accuracy: 0.8119
# Epoch 197/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0266 - accuracy: 0.9857 - val_loss: 0.2900 - val_accuracy: 0.8416
# Epoch 198/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0186 - accuracy: 0.9912 - val_loss: 0.2996 - val_accuracy: 0.8416
# Epoch 199/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0278 - accuracy: 0.9857 - val_loss: 0.2782 - val_accuracy: 0.8713
# Epoch 200/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0194 - accuracy: 0.9890 - val_loss: 0.2709 - val_accuracy: 0.8713
# Epoch 201/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0245 - accuracy: 0.9879 - val_loss: 0.2848 - val_accuracy: 0.8713
# Epoch 202/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0315 - accuracy: 0.9846 - val_loss: 0.2778 - val_accuracy: 0.8614
# Epoch 203/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0152 - accuracy: 0.9879 - val_loss: 0.2703 - val_accuracy: 0.8416
# Epoch 204/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0188 - accuracy: 0.9901 - val_loss: 0.2879 - val_accuracy: 0.8416
# Epoch 205/250
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0141 - accuracy: 0.9945 - val_loss: 0.3087 - val_accuracy: 0.8416
# Epoch 206/250
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0316 - accuracy: 0.9802 - val_loss: 0.4164 - val_accuracy: 0.8020
# Epoch 207/250
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0130 - accuracy: 0.9923 - val_loss: 0.2878 - val_accuracy: 0.8614
# Epoch 208/250
# 29/29 [==============================] - 1s 19ms/step - loss: 0.0189 - accuracy: 0.9879 - val_loss: 0.3200 - val_accuracy: 0.8515
# Epoch 209/250
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0188 - accuracy: 0.9879 - val_loss: 0.4323 - val_accuracy: 0.8020
# Epoch 210/250
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0323 - accuracy: 0.9824 - val_loss: 0.2413 - val_accuracy: 0.8614
# Epoch 211/250
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0130 - accuracy: 0.9923 - val_loss: 0.2636 - val_accuracy: 0.8812
# Epoch 212/250
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0136 - accuracy: 0.9945 - val_loss: 0.3729 - val_accuracy: 0.8515
# Epoch 213/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0209 - accuracy: 0.9890 - val_loss: 0.2802 - val_accuracy: 0.8515
# Epoch 214/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0085 - accuracy: 0.9934 - val_loss: 0.2594 - val_accuracy: 0.8614
# Epoch 215/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0150 - accuracy: 0.9923 - val_loss: 0.2694 - val_accuracy: 0.8416
# Epoch 216/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0265 - accuracy: 0.9835 - val_loss: 0.2890 - val_accuracy: 0.8515
# Epoch 217/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0209 - accuracy: 0.9857 - val_loss: 0.2723 - val_accuracy: 0.8812
# Epoch 218/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0254 - accuracy: 0.9846 - val_loss: 0.2710 - val_accuracy: 0.8713
# Epoch 219/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0171 - accuracy: 0.9901 - val_loss: 0.2615 - val_accuracy: 0.8713
# Epoch 220/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0160 - accuracy: 0.9912 - val_loss: 0.2751 - val_accuracy: 0.8515
# Epoch 221/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0188 - accuracy: 0.9912 - val_loss: 0.2875 - val_accuracy: 0.8614
# Epoch 222/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0165 - accuracy: 0.9890 - val_loss: 0.2686 - val_accuracy: 0.8515
# Epoch 223/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0248 - accuracy: 0.9901 - val_loss: 0.2792 - val_accuracy: 0.8812
# Epoch 224/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0187 - accuracy: 0.9890 - val_loss: 0.2539 - val_accuracy: 0.8812
# Epoch 225/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0134 - accuracy: 0.9945 - val_loss: 0.2684 - val_accuracy: 0.8515
# Epoch 226/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0193 - accuracy: 0.9835 - val_loss: 0.2942 - val_accuracy: 0.8020
# Epoch 227/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0185 - accuracy: 0.9923 - val_loss: 0.2533 - val_accuracy: 0.8515
# Epoch 228/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0238 - accuracy: 0.9846 - val_loss: 0.2859 - val_accuracy: 0.8515
# Epoch 229/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0186 - accuracy: 0.9934 - val_loss: 0.3311 - val_accuracy: 0.8317
# Epoch 230/250
# 29/29 [==============================] - 0s 14ms/step - loss: 0.0400 - accuracy: 0.9791 - val_loss: 0.2715 - val_accuracy: 0.8515
# Epoch 231/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0112 - accuracy: 0.9978 - val_loss: 0.2685 - val_accuracy: 0.8515
# Epoch 232/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0248 - accuracy: 0.9835 - val_loss: 0.2746 - val_accuracy: 0.9010
# Epoch 233/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0148 - accuracy: 0.9912 - val_loss: 0.2971 - val_accuracy: 0.8713
# Epoch 234/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0169 - accuracy: 0.9868 - val_loss: 0.2727 - val_accuracy: 0.8416
# Epoch 235/250
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0230 - accuracy: 0.9868 - val_loss: 0.2826 - val_accuracy: 0.8614
# Epoch 236/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0232 - accuracy: 0.9890 - val_loss: 0.2709 - val_accuracy: 0.8614
# Epoch 237/250
# 29/29 [==============================] - 0s 14ms/step - loss: 0.0053 - accuracy: 0.9978 - val_loss: 0.2882 - val_accuracy: 0.8614
# Epoch 238/250
# 29/29 [==============================] - 0s 14ms/step - loss: 0.0251 - accuracy: 0.9879 - val_loss: 0.3105 - val_accuracy: 0.8515
# Epoch 239/250
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0232 - accuracy: 0.9857 - val_loss: 0.2733 - val_accuracy: 0.8515
# Epoch 240/250
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0115 - accuracy: 0.9923 - val_loss: 0.2956 - val_accuracy: 0.8713
# Epoch 241/250
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0252 - accuracy: 0.9857 - val_loss: 0.2586 - val_accuracy: 0.8416
# Epoch 242/250
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0219 - accuracy: 0.9912 - val_loss: 0.2727 - val_accuracy: 0.8515
# Epoch 243/250
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0174 - accuracy: 0.9901 - val_loss: 0.3081 - val_accuracy: 0.8317
# Epoch 244/250
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0185 - accuracy: 0.9901 - val_loss: 0.3001 - val_accuracy: 0.8515
# Epoch 245/250
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0136 - accuracy: 0.9945 - val_loss: 0.3295 - val_accuracy: 0.8218
# Epoch 246/250
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0133 - accuracy: 0.9934 - val_loss: 0.2962 - val_accuracy: 0.8713
# Epoch 247/250
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0097 - accuracy: 0.9923 - val_loss: 0.2889 - val_accuracy: 0.8515
# Epoch 248/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0285 - accuracy: 0.9868 - val_loss: 0.2947 - val_accuracy: 0.8515
# Epoch 249/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0164 - accuracy: 0.9923 - val_loss: 0.2865 - val_accuracy: 0.8614
# Epoch 250/250
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0195 - accuracy: 0.9923 - val_loss: 0.2605 - val_accuracy: 0.8515
# Saving trained model...
# Testing...
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 4/4 [==============================] - 1s 6ms/step
# [[24  0  3  2]
#  [ 2 26  1  0]
#  [ 1  2 23  1]
#  [ 2  1  5 19]]
# [[0.83 0.   0.1  0.07]
#  [0.07 0.9  0.03 0.  ]
#  [0.04 0.07 0.85 0.04]
#  [0.07 0.04 0.19 0.7 ]]
# 82.14%
# 新的结果文件夹名称为： result_MultiAttention_LSTM_1层Transformer_BCE_epoch250_batchsize32_lr0.004_82.14%
# 程序执行时间为：114.95秒

# %%
# 定位到指定路径下
import os
os.chdir('/content/drive/MyDrive/Colab_Notebooks/RNN-CAP')
print(os.getcwd())

# 打印版本
import sys
import tensorflow as tf

print("Python 版本:", sys.version)
print("TensorFlow 版本:", tf.__version__)

# !pip install xlwt
# !pip install matplotlib

# %%
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_categorical_crossentropy_epoch30.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_categorical_crossentropy_epoch250.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_categorical_crossentropy_epoch50.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_categorical_crossentropy_epoch100.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_categorical_crossentropy_epoch150.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_categorical_crossentropy_epoch200.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_squared_error_epoch30.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_squared_error_epoch50.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_squared_error_epoch100.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_squared_error_epoch150.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_squared_error_epoch200.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_squared_error_epoch250.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_absolute_error_epoch30.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_absolute_error_epoch50.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_absolute_error_epoch100.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_absolute_error_epoch150.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_absolute_error_epoch200.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_mean_absolute_error_epoch250.py

# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_binary_crossentropy_epoch30.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_binary_crossentropy_epoch50.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_binary_crossentropy_epoch100.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_binary_crossentropy_epoch150.py

#!python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_binary_crossentropy_epoch200.py
# !python 528[-1,1]长度20-分辨率15_acnt2_剔14_改6为4_RNNCAP_binary_crossentropy_epoch250.py
